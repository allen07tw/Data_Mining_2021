# %% [markdown]
# ## Note:
#
# 1. we dont handle out of vocabulary problem
# 2. we split each single chinese word and punctuation, and keep english words and number stick together

# %%
import os
import sys
import numpy as np
import pandas as pd
import re
import pickle
import math
import matplotlib.pyplot as plt

# %%
with open('./data/train_1_update.txt','r', encoding='utf8') as f:
    file_text = f.read().encode('utf-8').decode('utf-8-sig')
datas = file_text.split('\n\n--------------------\n\n')[:-1]
with open('./data/train_1_pos_ner.pkl', 'rb') as f:
    pos_ner = pickle.load(f)

# %%
with open('./data/SampleData_deid.txt','r', encoding='utf8') as f:
    file_text = f.read().encode('utf-8').decode('utf-8-sig')
datas = file_text.split('\n\n--------------------\n\n')[:-1]
with open('./data/SampleData_pos_ner.pkl', 'rb') as f:
    pos_ner = pickle.load(f)

# %%
with open('./data/development_1.txt','r', encoding='utf8') as f:
    file_text = f.read().encode('utf-8').decode('utf-8-sig')
datas = [i.split('\n')[1] for i in file_text.split('\n\n--------------------\n\n')[:-1]]
with open('./data/development_1_pos_ner.pkl', 'rb') as f:
    pos_ner = pickle.load(f)

# %% [markdown]
# ## origin data

# %%
def parse_data_by_word_split(data, with_label=True):
    all_lines = []
    label_count = {}

    label_transform = {
        '醫師：': 'DOC',
        '個管師：': 'CAS',
        '民眾：': 'PAT'
    }

    for data in datas:
        article, *entity = data.split('\n')

        entity_parse = [[int(col) if i != 4 and i != 3 else col for i, col in enumerate(e.split('\t'))] for e in entity[1:]]
        split_article = re.sub(r"((醫師：)|(民眾：)|(個管師：)|[^A-Za-z\d ']|[A-Za-z\d\-#%&\./+×]+)", r'\1 ', article).split()
        
        if with_label:
            split_label = []
            char_idx = 0
            entity_idx = 0

            for word in split_article:
                full_label = label_transform[word] if word in label_transform else 'O'
                if entity_idx < len(entity_parse):
                    _, stidx, edidx, _, label = entity_parse[entity_idx]
                    if stidx <= char_idx < edidx:
                        prefix = 'B' if char_idx == stidx else 'I'
                        full_label = f'{prefix}-{label}'
                        if char_idx == edidx - len(word):
                            entity_idx += 1

                split_label.append(full_label)    
                char_idx += len(word)
                
            ###
            for k in split_label:
                if k not in label_count:
                    label_count[k] = 0
                label_count[k] += 1
            ###
                
        else:
            split_label = ['O' for _ in range(len(split_article))]

        all_lines.append(f'{" ".join(split_article)}\t{" ".join(split_label)}')
        
    #with open('./train_data_mod.txt', 'w', encoding='utf8') as f:
    #    f.write('\n'.join(all_lines))
    
    return all_lines


def parse_data_by_char(data, with_label=True):
    all_lines = []
    
    for data in datas:
        article, *entity = data.split('\n')

        entity_parse = [[int(col) if i != 4 and i != 3 else col for i, col in enumerate(e.split('\t'))] for e in entity[1:]]
        split_article = list(article)
        split_label = ['O' for _ in range(len(split_article))]
        
        if with_label:
            for _, stidx, edidx, _, label in entity_parse:
                for idx in range(stidx, edidx):
                    prefix = 'B' if idx == stidx else 'I'
                    split_label[idx] = f'{prefix}-{label}'
        all_lines.append(f'{" ".join(split_article)}\t{" ".join(split_label)}')
        
    return all_lines


def parse_data_by_sentence_with_neighbor(data, with_label=True, sep_limit=1, sep_chars={'，', '。'}, neighbor_len=100):
    all_lines = []
    
    for aid, data in enumerate(datas):
        article, *entity = data.split('\n')
        
        # save all entity with idx
        entity_idxs = {}
        if with_label:
            for e in entity[1:]:
                _, stidx, edidx, _, tp = e.split('\t')
                for i in range(int(stidx), int(edidx)):
                    prefix = 'B' if i == int(stidx) else 'I'
                    full_label = f'{prefix}-{tp}'
                    entity_idxs[i] = full_label
                    
        # iterate the article character 
        sid = 0
        sep_count = 0
        curr_text = []
        curr_label = []
        curr_neighbor = []

        for idx, char in enumerate(article):
            curr_text.append(char)
            curr_label.append(entity_idxs[idx] if idx in entity_idxs else 'O')
            
            if char in sep_chars:
                sep_count += 1
            
            ### one sentence ends ###
            if (char in sep_chars and sep_count >= sep_limit) or idx == len(article)-1:
                ### get post neighbor for this sentence ###
                if idx != len(article)-1:
                    curr_neighbor.append(article[idx+1:idx+1+(neighbor_len*2)])
                
                ### find substring of pre and post neighbor ###
                if len(curr_neighbor) == 2:
                    # for middle sentences
                    pre_neighbor = curr_neighbor[0][-neighbor_len//2:]
                    post_neighbor = curr_neighbor[1][:neighbor_len//2]
                elif idx == len(article)-1:
                    # for last sentence
                    #pre_neighbor = curr_neighbor[0][-neighbor_len//2:]
                    #post_neighbor = curr_neighbor[0][-neighbor_len:-neighbor_len//2]
                    pre_neighbor = curr_neighbor[0][-neighbor_len:]
                    post_neighbor = ''
                else:
                    # for first sentence
                    #pre_neighbor = curr_neighbor[0][neighbor_len//2:neighbor_len]
                    #post_neighbor = curr_neighbor[0][:neighbor_len//2]
                    pre_neighbor = ''
                    post_neighbor = curr_neighbor[0][:neighbor_len]
                
                ### record line result ###
                all_lines.append(f'{" ".join(curr_text)}\t{" ".join(curr_label)}\t{" ".join(pre_neighbor)}\t{" ".join(post_neighbor)}\t{aid}\t{sid}')
                
                ### re-init ###
                curr_text = []
                curr_label = []
                curr_neighbor = []
                sep_count = 0
                sid += 1
                
                ### get pre neighbor for next sentence ###
                if idx != len(article)-1:
                    stidx = idx-(neighbor_len*2)+1
                    stidx = 0 if stidx < 0 else stidx
                    curr_neighbor.append(article[stidx:idx+1])
    return all_lines


def parse_data_by_sentence(data, with_label=True, sep_limit=3, sep_chars={'，', '。'}):
    all_lines = []

    for aid, data in enumerate(datas):
        # get curr article and entity
        article, *entity = data.split('\n')
        cpos = pos_ner['pos'][aid]
        cner = pos_ner['ner'][aid]

        # save all entity with idx
        entity_idxs = {}
        if with_label:
            for e in entity[1:]:
                _, stidx, edidx, _, tp = e.split('\t')
                for i in range(int(stidx), int(edidx)):
                    prefix = 'B' if i == int(stidx) else 'I'
                    full_label = f'{prefix}-{tp}'
                    entity_idxs[i] = full_label

        # iterate the article character 
        sid = 0
        sep_count = 0
        curr_text = []
        curr_label = []
        curr_pos = []
        curr_ner = []

        for idx, char in enumerate(article):
            curr_text.append(char)
            curr_label.append(entity_idxs[idx] if idx in entity_idxs else 'O')
            curr_pos.append(cpos[idx] if idx in cpos else 'O')
            curr_ner.append(cner[idx] if idx in cner else 'O')
            
            if char in sep_chars:
                sep_count += 1
            
            if (char in sep_chars and sep_count >= sep_limit) or idx == len(article)-1:
                all_lines.append(f'{" ".join(curr_text)}\t{" ".join(curr_label)}\t{" ".join(curr_pos)}\t{" ".join(curr_ner)}\t{aid}\t{sid}')
                curr_text = []
                curr_label = []
                curr_pos = []
                curr_ner = []
                sep_count = 0
                sid += 1
    
    return all_lines   


def parse_data_by_sentence_into_bio(data, with_label=True, sep_limit=3, sep_chars={'，', '。'}):
    all_lines = []
    
    for aid, data in enumerate(datas):
        # get curr article and entity
        article, *entity = data.split('\n')

        # save all entity with idx
        entity_idxs = {}
        if with_label:
            for e in entity[1:]:
                _, stidx, edidx, _, tp = e.split('\t')
                for i in range(int(stidx), int(edidx)):
                    prefix = 'B' if i == int(stidx) else 'I'
                    full_label = f'{prefix}-{tp}'
                    entity_idxs[i] = full_label

        # iterate the article character 
        sid = 0
        sep_count = 0
        curr_line = []

        for idx, char in enumerate(article):
            curr_line.append(f'{char} {entity_idxs[idx] if idx in entity_idxs else "O"} {aid}')
            
            if char in sep_chars:
                sep_count += 1
            
            if (char in sep_chars and sep_count > sep_limit) or idx == len(article)-1:
                all_lines.append('\n'.join(curr_line))
                curr_line = []
                sep_count = 0
                sid += 1
    
    return all_lines


def parse_data_by_sentence_into_bio_with_max_len(data, with_label=True, max_len=400):
    all_lines = []

    for aid, data in enumerate(datas):
        # get curr article and entity
        article, *entity = data.split('\n')

        # save all entity with idx
        entity_idxs = {}
        if with_label:
            for e in entity[1:]:
                _, stidx, edidx, _, tp = e.split('\t')
                for i in range(int(stidx), int(edidx)):
                    prefix = 'B' if i == int(stidx) else 'I'
                    full_label = f'{prefix}-{tp}'
                    entity_idxs[i] = full_label

        # find all breakpoints
        np_article = np.array(list(article))
        is_split, = np.where(((np_article == '，') + (np_article == '。') + (np_article == '？') + (np_article == '！') + (np_article == ',')) == True)        
        #is_split += 1
        
        # iterate the article character 
        word_count = 0
        total_count = 0
        curr_line = []

        for idx, char in enumerate(article):
            curr_line.append(f'{char} {entity_idxs[idx] if idx in entity_idxs else "O"} {aid}')
            word_count += 1
            
            # if article ends
            if idx == len(article)-1:
                all_lines.append('\n'.join(curr_line))
                curr_line = []
                word_count = 0
            
            # if is breakpoint
            elif len(is_split) and idx == is_split[0]:
                nxt_sentence_len = (is_split[1] if len(is_split) > 1 else len(article)) - is_split[0]
                if word_count + nxt_sentence_len > max_len:
                    all_lines.append('\n'.join(curr_line))
                    curr_line = []
                    word_count = 0
                is_split = is_split[1:]
        #break
        
    return all_lines


def parse_data_by_sentence_with_max_len(data, with_label=True, max_len=400):
    all_lines = []

    for aid, data in enumerate(datas):
        # get curr article and entity
        article, *entity = data.split('\n')
        cpos = pos_ner['pos'][aid]
        cner = pos_ner['ner'][aid]

        # save all entity with idx
        entity_idxs = {}
        if with_label:
            for e in entity[1:]:
                _, stidx, edidx, _, tp = e.split('\t')
                for i in range(int(stidx), int(edidx)):
                    prefix = 'B' if i == int(stidx) else 'I'
                    full_label = f'{prefix}-{tp}'
                    entity_idxs[i] = full_label

        # find all breakpoints
        np_article = np.array(list(article))
        is_split, = np.where(((np_article == '，') + (np_article == '。') + (np_article == '？') + (np_article == '！') + (np_article == ',')) == True)
        
        # iterate the article character 
        word_count = 0
        sid = 0
        curr_text = []
        curr_label = []
        curr_pos = []
        curr_ner = []

        for idx, char in enumerate(article):
            curr_text.append(char)
            curr_label.append(entity_idxs[idx] if idx in entity_idxs else 'O')
            curr_pos.append(cpos[idx] if idx in cpos else 'O')
            curr_ner.append(cner[idx] if idx in cner else 'O')
            word_count += 1
            
            # if article ends
            if idx == len(article)-1:
                all_lines.append(f'{" ".join(curr_text)}\t{" ".join(curr_label)}\t{" ".join(curr_pos)}\t{" ".join(curr_ner)}\t{aid}\t{sid}')
                curr_text = []
                curr_label = []
                curr_pos = []
                curr_ner = []
                word_count = 0
                sid += 1
            
            # if is breakpoint
            elif len(is_split) and idx == is_split[0]:
                nxt_sentence_len = (is_split[1] if len(is_split) > 1 else len(article)) - is_split[0]
                if word_count + nxt_sentence_len > max_len:
                    all_lines.append(f'{" ".join(curr_text)}\t{" ".join(curr_label)}\t{" ".join(curr_pos)}\t{" ".join(curr_ner)}\t{aid}\t{sid}')
                    curr_text = []
                    curr_label = []
                    curr_pos = []
                    curr_ner = []
                    word_count = 0
                    sid += 1
                is_split = is_split[1:]
        #break
        
    return all_lines

# %% [markdown]
# ## split data with sentence + neighbor data

# %%
neighbor_len = 20
all_lines = parse_data_by_sentence_with_neighbor(data, with_label=True, sep_limit=1, 
                                                 sep_chars={'，', '。', '？', '?', '!', '！'}, neighbor_len=neighbor_len)

# %%
with open(f'../bert-sequence-tagging/TEA/test_data_sen_sep1_neigh{neighbor_len}.txt', 'w', encoding='utf8') as f:
    f.write('\n'.join(all_lines))

# %% [markdown]
# ## split data with max len sentence split

# %%
all_lines = parse_data_by_sentence_with_max_len(data, with_label=True, max_len=125)

# %%
with open(f'../bert-sequence-tagging/TEA/test_deid_sep_maxlen_125.txt', 'w', encoding='utf8') as f:
    f.write('\n'.join(all_lines))

# %% [markdown]
# ## split data into bio with max len sentence split

# %%
all_lines = parse_data_by_sentence_into_bio_with_max_len(data, with_label=True, max_len=140)

# %%
with open(f'../mrc-for-flat-nested-ner/data_preprocess/example/dev_deid_sep_maxlen_140.bio', 'w', encoding='utf8') as f:
    f.write('\n\n'.join(all_lines) + '\n\n')

# %% [markdown]
# ## split data into bio

# %%
all_lines = parse_data_by_sentence_into_bio(data, with_label=True, sep_limit=3)

# %%
with open(f'../mrc-for-flat-nested-ner/data_preprocess/example/train_deid_sep_3.bio', 'w', encoding='utf8') as f:
    f.write('\n\n'.join(all_lines) + '\n\n')

# %% [markdown]
# ## split data with sentence

# %%
all_lines = parse_data_by_sentence(datas, with_label=True, sep_limit=1, sep_chars={'。', '？', '?', '!', '！', '，'})

# %%
#with open(f'../bert-sequence-tagging/TEA/train_data_sen_sep_5_ext.txt', 'w', encoding='utf8') as f:
#    f.write('\n'.join(all_lines))
    
with open(f'../bert-sequence-tagging/TEA/dev_data_sen_sep_1_ext.txt', 'w', encoding='utf8') as f:
    f.write('\n'.join(all_lines))

# %%
len_count = [len(i.split('\t')[0].split()) for i in all_lines]
mean = np.mean(len_count)
std = np.std(len_count)
max_ = np.max(len_count)
min_ = np.min(len_count)

x = [i+1 for i in range(min_, max_+1)]
y = [0 for i in range(min_, max_+1)]
for c in len_count:
    y[c-min_] += 1
    
plt.plot(x, y)
plt.xlabel('length')
plt.title(f'{mean:.4f} / {std:.4f} / {max_} / {min_}')
plt.show()

# %%
for idx, ele in enumerate(len_count):
    if ele > 128:
        print(ele, all_lines[idx].split('\t')[0])
# Out:
# 140 醫 師 ： 我 開 影 像 給 你 看 你 就 知 道 ， 你 那 時 候 細 菌 感 染 影 響 到 很 多 地 方 ， 看 一 下 右 邊 大 腿 後 側 ， 這 些 都 被 細 菌 吃 掉 了 ， 這 些 細 菌 感 染 的 髖 骨 這 邊 都 黑 掉 了 ， 核 子 醫 學 的 檢 查 右 邊 大 腿 後 側 還 有 左 肩 這 個 地 方 也 比 較 黑 ， 左 肩 看 起 來 都 黑 黑 的 地 方 ， 所 以 他 那 個 時 候 電 腦 斷 層 你 的 肉 那 邊 發 炎 的 地 方 ， 你 有 看 到 左 肩 這 邊 不 對 稱 嗎 ？
# 174 應 該 是 可 以 齁 ， 阿 我 有 一 顆 藥 齁 就 是 ， 誒 ， 過 敏 的 藥 我 稍 微 減 ⋯ ⋯ 減 弱 一 點 ， 是 ， 還 是 有 吃 但 我 稍 微 減 弱 一 點 這 樣 子 ， o k ， 這 樣 好 不 好 ， 然 後 我 們 下 下 禮 拜 是 回 診 的 話 ， 剛 好 我 們 病 毒 的 藥 已 經 吃 ⋯ ⋯ 吃 了 ， 我 們 1 0 月 7 號 開 始 吃 藥 的 ， 所 以 到 下 下 禮 拜 剛 好 滿 四 周 ， 所 以 我 們 要 測 ， 要 抽 血 了 ， 就 是 要 測 病 毒 量 ， 這 個 ⋯ ⋯ 這 個 是 標 準 需 要 ， 我 們 吃 ， 治 療 四 個 禮 拜 之 後 我 們 要 看 你 病 毒 下 降 的 趨 勢 。
# 150 醫 師 ： 對 對 對 ， 再 報 到 這 樣 子 ， 因 為 這 樣 比 較 省 時 間 啦 ～ 那 抽 完 血 之 後 ， 因 為 ⋯ ⋯ 因 為 這 個 病 毒 量 跟 免 疫 力 的 報 告 運 作 比 較 久 ， 當 天 也 不 會 看 到 這 樣 子 ， 是 ， 但 是 你 ⋯ ⋯ 你 先 抽 完 ， 然 後 我 看 完 診 沒 什 麼 問 題 ， 你 就 可 以 早 點 回 去 這 樣 ， 是 ， 好 不 好 ， 就 抽 血 ， 照 X 光 ， 阿 X 光 單 我 已 經 開 好 了 ， 就 是 先 抽 血 ， 然 後 去 照 X 光 ， 然 後 回 來 我 這 邊 報 到 。
 是 並 不 是 不 行 ， 但 是 就 是 一 定 要 ， 就 是 要 好 好 的 再 把 保 險 套 百 分 之 百 的 戴 好 ， 因 為 我 們 確 實 ， 包 括 國 際 上 很 多 個 案 都 是 一 開 始 有 吃 藥 ， 那 因 為 吃 藥 的 時 候 ， 你 假 設 沒 有 那 麼 要 求 保 險 套 可 能 還 比 較 沒 有 關 係 ， 但 是 如 果 藥 停 了 你 沒 有 把 這 個 習 慣 找 回 來 ， 那 很 容 易 在 這 種 時 候 就 出 事 。
# 178 醫 師 ： 我 所 謂 會 出 事 就 是 ， 沒 想 到 我 們 吃 了 一 年 的 預 防 結 果 那 個 停 了 藥 沒 多 久 就 感 染 ， 這 個 不 會 很 少 見 喔 ， 對 ， 就 是 因 為 要 ， 我 們 要 建 立 一 個 習 慣 ， 可 是 現 在 要 把 這 個 習 慣 拿 掉 ， 要 再 建 立 一 個 新 的 習 慣 有 時 候 需 要 一 點 時 間 阿 ， 但 是 就 是 要 特 別 注 意 ， 就 是 說 這 不 是 一 個 ， 唯 一 一 個 預 防 的 方 法 ， 但 是 當 你 沒 有 這 個 預 防 的 方 法 的 時 候 你 就 其 它 的 預 防 方 法 就 是 還 要 更 加 小 心 ， 可 以 嗎 ， 對 ， 阿 你 可 以 回 家 想 想 看 。
# 179 醫 師 ： 恩 ， 因 為 那 個 學 名 藥 基 本 上 是 ， 它 雖 然 是 因 為 在 台 灣 不 能 賣 ， 因 為 沒 有 藥 證 ， 但 是 其 實 ， 恩 ， 至 少 我 們 這 幾 個 網 站 他 們 拿 的 學 名 藥 是 ， 就 是 是 真 的 學 名 藥 啦 ～ 學 名 藥 如 果 是 拿 到 假 的 就 很 慘 ～ 那 這 些 學 名 藥 其 實 包 括 在 美 國 在 英 國 在 澳 洲 他 們 其 實 是 有 在 用 的 ， 那 只 是 因 為 台 灣 的 專 利 期 還 沒 有 過 所 以 還 不 能 用 ， 對 ， 所 以 真 的 學 名 藥 在 這 些 主 要 的 國 家 事 實 上 是 可 以 用 的 ， 就 是 如 果 他 們 專 利 期 已 經 過 了 的 話 。
# 155 醫 師 ： 是 ， 那 這 樣 子 的 這 個 所 謂 的 依 需 求 吃 法 就 是 ， 這 個 ， 比 方 說 就 是 我 預 計 性 行 為 前 吃 兩 顆 ， 後 吃 兩 顆 的 這 個 ， 它 原 則 上 只 有 在 ， 就 是 男 同 志 族 群 裡 面 有 做 這 樣 的 研 究 ， 那 當 然 也 認 為 是 也 也 ， 也 證 明 是 有 效 的 是 沒 有 錯 ， 那 效 果 沒 有 ， 沒 有 比 ， 如 果 吃 得 好 效 果 沒 有 比 每 天 吃 還 要 來 的 差 ， 是 ， 不 過 因 為 他 目 標 的 族 群 是 ， 就 是 . . . . . . 民 眾 ： 男 同 志 。
# 132 如 果 有 發 現 藥 停 之 後 ， 他 都 會 改 善 ， 甚 至 會 恢 復 吼 ， 那 所 以 我 們 在 吃 藥 過 程 中 ， 我 們 至 少 會 先 測 腎 臟 指 數 ， 因 爲 這 兩 個 ， 大 家 都 還 年 輕 啦 ， 我 們 一 般 比 較 容 易 受 影 響 的 年 紀 ， 大 概 是 4 0 嵗 以 上 ， 4 0 嵗 以 上 就 要 非 常 非 常 的 小 心 ， 4 0 嵗 以 下 的 大 部 分 可 能 都 還 好 ， 不 過 原 則 上 我 們 還 是 會 追 蹤 這 個 指 數 。
# 190 醫 師 ： 嗯 ， 我 猜 如 果 以 你 現 在 啦 ， 以 你 現 在 假 設 是 沒 有 伴 侶 的 狀 態 ， 那 你 可 能 可 以 吃 計 劃 ， 但 是 我 覺 得 你 可 能 可 以 考 慮 看 ， 假 設 你 之 後 你 有 固 定 的 伴 侶 ， 或 固 定 的 對 象 ， 也 就 是 説 性 行 爲 的 次 數 上 比 較 頻 繁 的 話 ， 那 或 許 可 以 天 天 吃 ， 這 本 來 就 可 以 隨 時 改 變 的 ， 就 是 看 你 的 生 活 形 態 啦 ， 或 是 怎 麼 樣 啦 ， 因 爲 ， 因 為 通 常 有 對 象 ， 頻 率 或 次 數 比 較 多 ， 那 你 整 天 要 這 邊 算 這 個 ， 我 其 實 是 覺 得 就 有 點 煩 啦 ， 可 能 有 點 解 h i g h 啦 ， 就 是 說 诶 ？
# 140 那 一 年 總 共 ， 就 是 你 最 多 可 以 領 一 年 份 ， 就 是 1 2 瓶 藥 ， 那 除 了 就 是 藥 錢 會 幫 你 出 ， 但 檢 驗 費 你 就 要 自 己 負 責 啦 吼 ， 那 所 以 原 則 上 ， 每 一 次 標 準 上 每 三 個 月 都 會 抽 血 ， 那 每 三 個 月 這 個 固 定 的 抽 血 就 是 愛 滋 跟 梅 毒 ， 那 他 其 實 有 規 定 ， 反 正 你 一 定 要 有 固 定 的 時 間 內 回 來 抽 血 ， 才 能 夠 繼 續 領 下 去 ， 不 然 就 會 被 踢 出 這 個 計 劃 。
# 168 醫 師 ： 總 之 今 天 頭 尾 的 抽 血 會 抽 比 較 多 ， 所 以 大 概 會 花 到 2 1 0 0 塊 ， 那 半 年 這 個 抽 血 除 了 愛 滋 、 梅 毒 之 外 ， 我 們 還 會 多 抽 一 個 腎 臟 指 數 所 以 會 5 0 0 多 ， 那 三 個 月 這 愛 滋 、 梅 毒 可 能 也 是 5 0 0 ， 4 0 0 到 5 0 0 上 下 ， 那 剩 下 的 這 種 只 有 拿 藥 的 月 份 ， 那 大 概 就 是 醫 院 的 掛 號 費 4 0 0 多 ， 所 以 當 然 平 均 每 個 月 ， 比 較 麻 煩 的 是 每 個 月 都 要 回 來 ， 但 是 平 均 每 個 月 裡 面 花 不 到 1 2 0 0 塊 。

# %% [markdown]
# ## split data with max length

# %%
# for training data
#all_lines = parse_data_by_word_split(datas, with_label=True)
#all_lines = parse_data_by_char(datas, with_label=True)

# for testing data
#all_lines = parse_data_by_word_split(datas, with_label=False)
all_lines = parse_data_by_char(datas, with_label=False)

all_sublines = []
max_seq_len = 510 #127 #511 #255

for article_id, line in enumerate(all_lines):
    curr_segment = []
    article_list, label_list = [_.split() for _ in line.split('\t')]
    #max_segment = int(len(label_list)/max_seq_len) + 1
    max_segment = math.ceil(len(label_list)/max_seq_len)
    for s in range(max_segment):
        curr_a = article_list[s*max_seq_len:(s+1)*max_seq_len]
        curr_l = label_list[s*max_seq_len:(s+1)*max_seq_len]
        curr_segment.append(f'{" ".join(curr_a)}\t{" ".join(curr_l)}\t{article_id}\t{s}')
    all_sublines.append('\n'.join(curr_segment))
    
#with open(f'../bert-sequence-tagging/TEA/train_data_char_sub_{max_seq_len}.txt', 'w', encoding='utf8') as f:
#    f.write('\n'.join(all_sublines))
    
with open(f'../bert-sequence-tagging/TEA/dev_data_char_sub_{max_seq_len}.txt', 'w', encoding='utf8') as f:
    f.write('\n'.join(all_sublines))

# %%
all_lines[0].split('\t')[0].split('。')
# Out:
# ['醫 師 ： 這 個 要 電 腦 看 才 有 辦 法 ， 這 是 嚴 重 或 一 般 的 ',
#  ' 民 眾 ： 這 是 沒 關 係 啦 ',
#  ' 醫 師 ： 沒 關 係 齁 ',
#  ' 民 眾 ： 他 一 定 要 有 說 ， 這 樣 才 有 辦 法 ',
#  ' 醫 師 ： 是 是 多 謝 你 ',
#  ' 民 眾 ： 沒 關 係 ',
#  ' 醫 師 ： 這 樣 ， 你 過 去 是 有 得 糖 尿 病 嘛 ？ 民 眾 ： 有 ',
#  ' 醫 師 ： 啊 出 院 後 還 有 再 發 燒 或 是 ？ 民 眾 ： 欸 出 院 是 沒 有 啦 ',
#  ' 醫 師 ： 沒 有 啦 齁 ',
#  ' 民 眾 ： 啊 ， 有 感 覺 人 齁 ',
#  ' 醫 師 ： 嘿 ',
#  ' 民 眾 ： 比 較 沒 沒 有 像 以 前 那 樣 ',
#  ' 醫 師 ： 嘿 ',
#  ' 民 眾 ： 全 部 都 沒 有 力 啦 ',
#  ' 醫 師 ： 齁 ',
#  ' 民 眾 ： 啊 現 在 比 較 有 力 了 啦 ， 不 知 道 是 那 一 天 ， 說 我 貧 血 齁 ',
#  ' 醫 師 ： 稍 微 貧 血 ',
#  ' 民 眾 ： 啊 幫 我 輸 血 進 來 ',
#  ' 醫 師 ： 他 有 幫 你 輸 血 喔 ？ 民 眾 ： 感 覺 這 樣 比 較 ',
#  ' 家 屬 ： 他 有 給 他 輸 2 5 的 ',
#  ' 民 眾 ： 是 感 覺 精 神 啦 ',
#  ' 醫 師 ： 李 醫 生 ',
#  ' 家 屬 ： 他 就 說 他 貧 血 ',
#  ' 醫 師 ： 有 幫 你 輸 一 袋 了 齁 ',
#  ' 家 屬 ： 嘿 ， 輸 一 袋 ',
#  ' 醫 師 ： 輸 一 袋 ',
#  ' 民 眾 ： 那 個 2 5 ',
#  ' 醫 師 ： 2 5 ',
#  ' 家 屬 ： 一 包 小 包 的 ',
#  ' 醫 師 ： 啊 你 排 尿 有 比 較 好 嗎 ？ 排 尿 的 那 個 ？ 家 屬 ： 哦 他 ',
#  ' 民 眾 ： 變 成 說 我 晚 上 齁 ， 我 都 要 吃 睡 眠 的 ',
#  ' 醫 師 ： 要 吃 睡 眠 的 ',
#  ' 民 眾 ： 啊 我 都 差 不 多 1 1 點 吃 睡 到 差 不 多 4 點 ',
#  ' 醫 師 ： 是 ',
#  ' 民 眾 ： 開 始 起 來 一 小 時 起 來 一 次 到 天 亮 ， 都 沒 有 停 喔 ',
#  ' 醫 師 ： 頻 尿 欸 喔 ',
#  ' 家 屬 ： 沒 有 ',
#  ' 民 眾 ： 沒 有 ， 廁 所 ',
#  ' 醫 師 ： 廁 所 ',
#  ' 民 眾 ： 啊 如 果 ',
#  ' 家 屬 ： 他 的 腳 齁 ， 他 的 腳 ',
#  ' 醫 師 ： 水 腫 齁 ',
#  ' 家 屬 ： 在 水 腫 欸 ， 他 那 個 藥 吃 太 多 ， 你 幫 他 看 一 下 ',
#  ' 民 眾 ： 以 前 是 沒 有 啦 ',
#  ' 醫 師 ： 以 前 是 沒 有 啦 ',
#  ' 家 屬 ： 都 沒 有 ',
#  ' 醫 師 ： 好 ',
#  ' 民 眾 ： 啊 現 在 有 水 腫 ',
#  ' 醫 師 ： 現 在 有 水 腫 齁 ， 好 ',
#  ' 民 眾 ： 啊 我 嚇 一 跳 ， 我 就 沒 吃 睡 眠 的 ',
#  ' 醫 師 ： 沒 吃 睡 眠 的 ， 好 那 我 幫 你 聽 一 下 ， 來 ',
#  ' 民 眾 ： 睡 到 1 1 點 多 就 都 沒 有 睡 了 啊 ',
#  ' 醫 師 ： 最 近 沒 感 冒 的 現 象 啦 齁 ',
#  ' 民 眾 ： 這 兩 天 都 沒 有 ',
#  ' 醫 師 ： 啊 有 發 燒 嗎 ？ 民 眾 ： 欸 ， 有 時 候 會 稍 微 冷 冷 的 ， 但 是 摸 起 來 是 沒 有 算 發 燒 啦 ',
#  ' 醫 師 ： 沒 有 算 發 燒 ',
#  ' 家 屬 ： 主 要 是 肚 子 脹 氣 ， 現 在 比 較 沒 有 肚 子 脹 氣 了 齁 ？ 民 眾 ： 我 都 吃 得 飽 ',
#  ' 家 屬 ： 不 是 吃 得 飽 ',
#  ' 民 眾 ： 有 啦 ， 比 較 沒 有 肚 子 脹 氣 ， 比 較 消 了 ',
#  ' 醫 師 ： 比 較 消 了 喔 ， 我 們 來 按 一 下 肚 子 一 下 ， 有 在 吃 糖 尿 病 的 藥 嗎 ？ 家 屬 ： 有 ',
#  ' 民 眾 ： 有 ',
#  ' 家 屬 ： 他 就 多 他 很 會 脹 氣 ， 非 常 會 脹 氣 ， 晚 上 都 會 吐 ',
#  ' 醫 師 ： 肚 子 會 痛 嗎 ？ 家 屬 ： 他 那 天 說 ',
#  ' 民 眾 ： 壓 下 去 會 痛 痛 的 ',
#  ' 醫 師 ： 是 左 邊 還 是 右 邊 ',
#  ' 民 眾 ： 右 邊 這 裡 ',
#  ' 醫 師 ： 右 邊 這 裡 ',
#  ' 民 眾 ： 這 種 痛 的 感 覺 是 ， 像 硬 壓 下 去 在 痛 ',
#  ' 醫 師 ： 硬 壓 下 去 在 痛 ',
#  ' 民 眾 ： 對 對 對 ',
#  ' 醫 師 ： 啊 走 路 啦 ， 平 常 時 候 不 會 痛 啦 齁 ',
#  ' 民 眾 ： 嗯 嗯 嗯 嗯 ',
#  ' 醫 師 ： 啊 我 聽 後 背 看 看 齁 ',
#  ' 民 眾 ： 走 路 是 不 會 啦 ',
#  ' 醫 師 ： 走 路 是 不 會 啊 ， 脊 椎 這 邊 ， 脊 椎 這 邊 ， 這 邊 會 痛 嗎 ？ 民 眾 ： 不 會 ',
#  ' 醫 師 ： 不 會 齁 ， 這 樣 按 也 不 會 痛 ？ 民 眾 ： 不 會 ',
#  ' 醫 師 ： 這 樣 也 還 好 ， 啊 喉 嚨 呢 ？ 民 眾 ： 喔 喉 嚨 如 果 要 天 亮 的 時 候 ， 有 夠 乾 的 ',
#  ' 醫 師 ： 會 比 較 乾 齁 ',
#  ' 民 眾 ： 很 乾 ， 我 就 快 去 一 直 喝 水 一 直 喝 水 ， 喝 很 久 ',
#  ' 醫 師 ： 好 那 我 們 來 看 那 天 ， 有 幫 你 照 Ｘ 光 檢 查 齁 ',
#  ' 民 眾 ： 嘿 ',
#  ' 家 屬 ： 嘿 ， 啊 好 像 我 們 有 抽 血 ',
#  ' 醫 師 ： 抽 血 嘿 ',
#  ' 家 屬 ： 還 有 尿 液 檢 查 欸 ',
#  ' 醫 師 ： 超 音 波 ',
#  ' 家 屬 ： 哦 哦 有 照 超 音 波 ',
#  ' 醫 師 ： 這 這 這 照 超 音 波 7 月 2 1 ， 哇 肝 、 腎 臟 ， 你 腎 臟 功 能 有 比 較 退 化 了 ',
#  ' 家 屬 ： 比 較 退 化 齁 ',
#  ' 民 眾 ： 那 邊 ',
#  ' 醫 師 ： 齁 ',
#  ' 民 眾 ： 有 醫 生 齁 ',
#  ' 家 屬 ： 那 想 說 他 那 個 退 化 有 藥 可 以 吃 ， 可 以 好 一 點 ',
#  ' 醫 師 ： 要 保 養 ， 不 要 隨 便 亂 吃 藥 ',
#  ' 家 屬 ： 哦 這 樣 喔 ',
#  ' 醫 師 ： 一 些 止 痛 的 齁 ， 都 要 看 照 醫 生 的 指 示 ',
#  ' 民 眾 ： 哦 啊 ， 不 要 隨 便 亂 吃 齁 ',
#  ' 醫 師 ： 嘿 ， 不 要 隨 便 亂 吃 ',
#  ' 家 屬 ： 就 是 因 為 這 樣 ， 腳 都 會 水 腫 起 來 齁 ',
#  ' 醫 師 ： 這 個 跟 糖 尿 病 有 關 係 ',
#  ' 家 屬 ： 跟 糖 尿 病 有 關 係 ',
#  ' 醫 師 ： 長 期 的 糖 尿 病 齁 ',
#  ' 民 眾 ： 以 前 ， 以 前 ， 我 很 痛 苦 的 時 候 那 時 候 沒 有 在 水 腫 的 ',
#  ' 醫 師 ： 沒 有 在 水 腫 的 啦 齁 ',
#  ' 民 眾 ： 啊 我 這 次 很 痛 苦 的 時 候 水 腫 的 有 夠 大 ',
#  ' 醫 師 ： 哦 他 有 幫 你 照 Ｘ 光 ， 肺 部 是 沒 有 發 炎 啦 ',
#  ' 家 屬 ： 嘿 嘿 嘿 ',
#  ' 醫 師 ： 看 起 來 是 還 好 ',
#  ' 民 眾 ： 看 起 來 是 還 好 ， 這 就 是 肺 部 喔 ？ 醫 師 ： 嘿 ， 這 就 是 肺 部 ， 這 是 你 的 影 像 ， 這 心 臟 嘛 ， 啊 這 看 起 來 是 沒 有 ',
#  ' 家 屬 ： 他 肺 部 沒 有 怎 樣 吧 ？ 醫 師 ： 對 啊 ',
#  ' 家 屬 ： 主 要 是 他 這 個 ， 肚 子 比 較 會 脹 氣 ， 他 以 前 一 直 吐 一 直 吐 一 直 吐 ',
#  ' 醫 師 ： 一 直 吐 喔 ？ 家 屬 ： 吐 1 0 多 次 了 ， 然 後 發 燒 ',
#  ' 醫 師 ： 發 燒 起 來 喔 ？ 民 眾 ： 第 一 次 是 一 直 吐 ',
#  ' 家 屬 ： 那 時 候 來 掛 急 診 ',
#  ' 民 眾 ： 吐 到 天 亮 ',
#  ' 家 屬 ： 然 後 看 完 就 回 去 ',
#  ' 民 眾 ： 啊 第 二 次 是 一 直 拉 肚 子 拉 到 天 亮 ',
#  ' 醫 師 ： 一 直 拉 肚 子 ',
#  ' 民 眾 ： 這 樣 ',
#  ' 醫 師 ： 來 兩 次 欸 齁 ',
#  ' 家 屬 ： 嘿 來 兩 次 ',
#  ' 民 眾 ： 我 來 兩 次 ， 第 一 次 照 尿 道 ， 第 二 次 照 肚 子 ',
#  ' 醫 師 ： 第 二 次 照 肚 子 啦 齁 ',
#  ' 民 眾 ： 用 超 音 波 的 樣 子 ',
#  ' 醫 師 ： 超 音 波 ， 第 一 次 是 那 個 ， 人 不 舒 服 是 因 為 尿 道 感 染 沒 有 錯 啦 ',
#  ' 家 屬 ： 這 樣 喔 ',
#  ' 醫 師 ： 啊 再 來 第 二 次 是 吐 嘛 齁 ',
#  ' 民 眾 ： 第 二 次 是 拉 肚 子 ',
#  ' 醫 師 ： 拉 肚 子 ',
#  ' 家 屬 ： 第 一 次 ， 是 吐 ， 他 吐 了 1 0 多 次 ',
#  ' 醫 師 ： 再 來 就 拉 肚 子 這 樣 ',
#  ' 家 屬 ： 再 來 就 發 燒 嘛 ， 我 就 來 掛 急 診 ， 啊 急 診 又 變 成 拉 肚 子 ， 發 燒 ',
#  ' 醫 師 ： 啊 現 在 胃 腸 也 沒 有 很 好 這 樣 ',
#  ' 家 屬 ： 這 樣 齁 ',
#  ' 醫 師 ： 嗯 ',
#  ' 家 屬 ： 沒 有 很 好 ， 啊 都 會 脹 氣 欸 ',
#  ' 醫 師 ： 脹 氣 喔 ',
#  ' 家 屬 ： 對 ， 啊 這 個 脹 氣 也 是 甚 麼 原 因 啦 齁 ？ 民 眾 ： 啊 吃 齁 ',
#  ' 醫 師 ： 是 不 是 吃 抗 生 素 啊 ？ 家 屬 ： 哦 ～ 民 眾 ： 喔 抗 生 素 喔 ',
#  ' 醫 師 ： 因 為 你 那 個 尿 道 發 炎 會 開 抗 生 素 齁 ， 有 可 能 欸 ， 因 為 開 那 個 橘 色 的 那 顆 是 抗 生 素 ',
#  ' 民 眾 ： 嗯 嗯 ',
#  ' 家 屬 ： 啊 還 有 一 顆 ， 白 的 欸 ， 他 第 二 次 就 用 白 的 那 顆 ',
#  ' 醫 師 ： 白 的 ',
#  ' 家 屬 ： 他 那 天 有 幫 他 打 的 抗 生 素 ',
#  ' 醫 師 ： 打 抗 生 素 嘛 ， 消 炎 的 ， 啊 出 院 後 就 用 吃 的 這 樣 ',
#  ' 家 屬 ： 嘿 ， 對 對 對 ',
#  ' 醫 師 ： 啊 這 次 出 院 ， 第 二 次 開 得 比 較 適 合 齁 ， 比 較 不 會 吐 齁 ',
#  ' 民 眾 ： 這 次 比 較 沒 有 ',
#  ' 醫 師 ： 比 較 沒 有 齁 ， 好 ',
#  ' 民 眾 ： 啊 ， 人 感 覺 胃 口 … … 醫 師 ： 比 較 不 好 ？ 民 眾 ： 比 較 好 一 些 啦 ',
#  ' 醫 師 ： 比 較 好 一 些 ， 他 有 幫 你 加 那 個 胃 藥 啦 ',
#  ' 民 眾 ： 有 啦 齁 ',
#  ' 醫 師 ： 好 ， 因 為 我 們 現 在 ， 我 們 1 3 號 來 掛 第 一 次 的 急 診 ， 已 經 1 5 天 了 ， 我 們 抗 生 素 再 吃 3 天 好 不 好 ？ 家 屬 ： 好 ',
#  ' 醫 師 ： 一 個 療 程 再 三 天 結 束 ， 但 是 胃 腸 藥 還 要 再 吃 一 個 禮 拜 喔 ',
#  ' 民 眾 ： 還 要 再 保 養 齁 ',
#  ' 家 屬 ： 好 好 好 ',
#  ' 醫 師 ： 啊 還 有 消 脹 氣 的 ',
#  ' 民 眾 ： 好 好 好 ',
#  ' 醫 師 ： 啊 沒 有 拉 肚 子 啦 齁 ？ 民 眾 ： 我 已 經 ， 禮 拜 一 嗎 ？ 醫 師 ： 嘿 ～ 民 眾 ： 禮 拜 一 ， 回 去 到 現 在 都 沒 去 上 廁 所 ',
#  ' 醫 師 ： 沒 去 上 廁 所 ， 都 沒 去 上 廁 所 ， 這 樣 ',
#  ' 民 眾 ： 啊 我 前 幾 天 就 都 吃 不 下 ',
#  ' 醫 師 ： 這 樣 喔 ',
#  ' 民 眾 ： 因 為 怎 麼 吃 都 吃 不 下 啊 ',
#  ' 醫 師 ： 這 樣 你 自 己 吃 比 較 多 ， 水 還 是 要 稍 微 喝 一 下 喔 ， 補 充 ',
#  ' 民 眾 ： 有 啦 ',
#  ' 家 屬 ： 他 平 常 是 有 ',
#  ' 民 眾 ： 我 這 兩 天 就 有 勉 強 吃 吃 吃 ， 啊 人 就 比 較 有 元 氣 ',
#  ' 醫 師 ： 這 樣 我 要 幫 你 加 軟 便 的 ？ 家 屬 ： 軟 便 的 ？ 不 用 ， 我 們 好 像 還 有 ',
#  ' 醫 師 ： 好 像 還 有 齁 ， 阿 姨 我 請 教 你 一 下 ， 你 腎 臟 都 有 固 定 在 追 蹤 啦 齁 ？ 民 眾 ： 嗯 ',
#  ' 醫 師 ： 固 定 在 看 齁 ',
#  ' 民 眾 ： 我 有 在 一 間 ， 我 們 皇 后 區 那 邊 ',
#  ' 家 屬 ： 不 過 那 間 他 沒 在 幫 他 記 錄 沒 幫 他 看 腎 臟 ',
#  ' 醫 師 ： 腎 臟 沒 有 … … 家 屬 ： 沒 有 ',
#  ' 民 眾 ： 我 不 知 道 ',
#  ' 醫 師 ： 好 ， 這 樣 我 們 ， 阿 姨 我 們 下 一 趟 齁 ， 下 下 禮 拜 要 再 來 一 趟 ',
#  ' 家 屬 ： 好 ',
#  ' 醫 師 ： 再 來 回 診 ， 啊 因 為 我 要 幫 你 檢 查 腎 臟 功 能 ',
#  ' 家 屬 ： 嘿 ',
#  ' 民 眾 ： 看 你 治 療 之 後 腎 臟 功 能 有 沒 有 改 善 ',
#  ' 家 屬 ： 有 沒 有 改 善 ',
#  ' 醫 師 ： 有 沒 有 改 善 ',
#  ' 民 眾 ： 看 一 下 這 樣 ',
#  ' 家 屬 ： 這 樣 看 一 下 這 樣 好 ',
#  ' 醫 師 ： 好 齁 ， 啊 你 們 住 在 布 魯 克 林 區 那 邊 齁 ？ 家 屬 ： 嘿 ',
#  ' 民 眾 ： 皇 后 區 喔 ',
#  ' 家 屬 ： 皇 后 區 ',
#  ' 醫 師 ： 皇 后 區 ',
#  ' 家 屬 ： 皇 后 區 那 邊 算 北 區 ',
#  ' 醫 師 ： 這 樣 因 為 你 們 住 比 較 遠 ',
#  ' 家 屬 ： 嘿 ～ 醫 師 ： 你 們 下 禮 拜 來 你 直 接 來 的 時 候 齁 ， 我 單 子 先 開 好 ， 你 先 到 櫃 台 那 邊 抽 血 ',
#  ' 家 屬 ： 哦 ～ 醫 師 ： 啊 我 幫 你 用 緊 急 的 ， 所 以 差 不 多 1 小 時 附 近 報 告 就 … … 家 屬 ： 很 快 就 出 來 了 ？ 醫 師 ： 很 快 就 出 來 了 ',
#  ' 家 屬 ： 哦 這 樣 好 啊 ， 這 樣 好 啊 ',
#  ' 醫 師 ： 我 們 先 去 抽 ， 等 換 到 你 的 時 候 報 告 就 出 來 了 ',
#  ' 民 眾 ： 我 我 我 是 想 說 ， 抽 血 我 們 可 以 再 等 一 段 時 間 嗎 ？ 醫 師 ： 再 等 一 段 時 間 嗎 ？ 民 眾 ： 我 最 近 我 抽 血 抽 到 我 人 都 會 暈 ',
#  ' 家 屬 ： 他 這 兩 次 抽 都 抽 很 多 ',
#  ' 醫 師 ： 這 樣 喔 ',
#  ' 民 眾 ： 連 坐 著 頭 都 會 暈 欸 ',
#  ' 醫 師 ： 暈 暈 的 齁 ， 啊 這 樣 不 然 就 … … 民 眾 ： 昨 天 也 暈 暈 的 ',
#  ' 醫 師 ： 不 然 就 不 然 就 再 延 長 一 陣 子 好 不 好 ？ 民 眾 ： 延 長 一 點 ',
#  ' 醫 師 ： 那 下 禮 拜 再 來 一 趟 可 以 嗎 ？ 民 眾 ： 好 啊 ',
#  ' 醫 師 ： 好 齁 ， 看 狀 況 怎 樣 齁 ',
#  ' 民 眾 ： 好 好 好 ',
#  ' 醫 師 ： 好 齁 ',
#  ' 民 眾 ： 我 很 怕 要 再 抽 血 的 ',
#  ' 醫 師 ： 很 怕 要 再 抽 血 ',
#  ' 民 眾 ： 因 為 我 現 在 頭 都 會 暈 啦 ',
#  ' 醫 師 ： 因 為 你 現 在 人 是 還 好 我 就 不 急 啦 ， 好 不 好 ， 那 我 們 就 先 約 診 這 樣 子 ',
#  ' 民 眾 ： 好 ',
#  ' 家 屬 ： 那 如 果 沒 有 那 樣 就 要 趕 快 抽 看 看 ',
#  ' 醫 師 ： 要 不 然 就 是 另 外 腎 臟 的 部 分 我 幫 你 另 外 安 排 以 後 齁 這 裡 ',
#  ' 民 眾 ： 可 以 可 以 ',
#  ' 醫 師 ： 追 蹤 ',
#  ' 家 屬 ： 這 樣 也 比 較 好 ',
#  ' 醫 師 ： 這 樣 也 比 較 好 齁 ， 好 好 ',
#  ' 民 眾 ： 好 好 好 ',
#  ' 醫 師 ： 好 齁 ， 好 這 樣 我 開 三 種 藥 ',
#  ' 家 屬 ： 好 ',
#  ' 醫 師 ： 因 為 是 那 個 抗 生 素 3 天 份 的 ， 啊 兩 種 是 胃 腸 藥 ',
#  ' 家 屬 ： 喔 ～ 民 眾 ： 哦 ～ 啊 這 樣 就 可 以 了 ， 啊 我 再 下 禮 拜 要 再 來 這 樣 ',
#  ' 醫 師 ： 要 再 一 趟 ',
#  ' 家 屬 ： 這 樣 你 幫 我 掛 號 ',
#  ' 醫 師 ： 好 ',
#  '']

# %% [markdown]
# ## split data with conversation

# %%
all_conversation = []

for line in all_lines:
    curr_conversation = []
    char_idx = 0
    
    article_list, label_list = [_.split() for _ in line.split('\t')]
    np_label_list = np.array(label_list)
    is_speaker, = np.where(((np_label_list == 'DOC') + (np_label_list == 'PAT') + (np_label_list == 'CAS')) == True)
    
    for idx in range(len(is_speaker)-1):
        stidx, edidx = is_speaker[idx], is_speaker[idx+1]
        curr_conversation.append((article_list[stidx:edidx], label_list[stidx:edidx]))
    
    all_conversation.append(curr_conversation)
    
with open('./train_data_conversation.pkl', 'wb') as f:
    pickle.dump(all_conversation, f)

# %% [markdown]
# ## find max conversation in one training data

# %%
all_lines_short = []
max_seq_len = 128

word_count = 0
curr_a = []
curr_l = []

for aid, curr_conversation in enumerate(all_conversation):
    for cid, (a, l) in enumerate(curr_conversation):
        curr_a.extend(a)
        
        curr_l.extend(l)
        word_count += len(l)
        
        if cid == len(curr_conversation)-1 or word_count + len(curr_conversation[cid+1][0]) > max_seq_len:
            all_lines_short.append(f'{" ".join(curr_a)}\t{" ".join(curr_l)}')
            word_count = 0
            curr_a = []
            curr_l = []
        
with open('./train_data_short.txt', 'w', encoding='utf8') as f:
    f.write('\n'.join(all_lines_short))

# %%
train_test_split = int(len(all_lines_short)*0.7)

with open('../bert-sequence-tagging/TEA/train_row__.txt', 'w', encoding='utf8') as f:
    f.write('\n'.join(all_lines_short[:train_test_split]))
    
with open('../bert-sequence-tagging/TEA/dev_row__.txt', 'w', encoding='utf8') as f:
    f.write('\n'.join(all_lines_short[train_test_split:]))
