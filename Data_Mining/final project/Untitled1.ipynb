# %% [markdown]
# # dev_predict

# %%
import pandas as pd

train=pd.read_csv('baseline_v6_wmd_lwlr_e10.tsv', sep='\t', header=0)

# %%
train
# Out:
#       article_id  start_position  end_position entity_text entity_type
# 0              0             198           200          新樓    location
# 1              0             227           229          麻豆    location
# 2              0             237           239          麻豆    location
# 3              0             295           297          今年        time
# 4              1              31            33          今天        time
# ...          ...             ...           ...         ...         ...
# 3425         158            1082          1086        第三個月        time
# 3426         158            1143          1145          今天        time
# 3427         158            1199          1201          小安        name
# 3428         158            1353          1355          今天        time
# 3429         158            1380          1390  A124699678     contact
#
# [3430 rows x 5 columns]

# %%
import pandas as pd

train=pd.read_csv('baseline_v6_wmd_lwlr_e10.tsv', sep='\t', header=0)
private_types = list(train['entity_type'])

# %%
import pandas as pd

train=pd.read_csv('baseline_v6_wmd_lwlr_e10.tsv', sep='\t', header=0)
private_types = list(train['entity_type'])
private_types_dict = {}
for private_type in  private_types:
    if private_type not in private_types_dict:
        private_types_dict[private_type] = 1
    else:
        private_types_dict[private_type] +=1

# %%
private_types_dict
# Out:
# {'name': 134,
#  'med_exam': 197,
#  'time': 862,
#  'location': 137,
#  'family': 33,
#  'money': 42,
#  'contact': 8,
#  'profession': 7,
#  'ID': 3}

# %% [markdown]
# # train_1

# %%
with open("test.txt","r",encoding="utf-8") as f:
    lines = f.readlines()
    #print(lines)
with open("train_1_read.txt","w",encoding="utf-8") as f_w:
    for line in lines:
        if "醫師：" in line:#or''or''or or'' '\n'or""
            continue
        if "家屬:" in line:
            continue
        if "個管師：" in line:
            continue
        if "民眾:" in line:
            continue
        if "----" in line:
            continue
        if " " in line:
            continue

        f_w.write(line)
        
with open("train_1_read_wo_article_id.txt","w",encoding="utf-8") as f_w:
    for line in lines:
        if "article_id：" in line:#or''or''or or'' '\n'or""
            continue
        if "----" in line:
            continue
        if " " in line:
            continue

        f_w.write(line)

# %%
train_1 = pd.read_csv("train_1_read.txt",  sep='\t', header=0)

# %%
train_1
# Out:
#      article_id start_position end_position entity_text entity_type
# 0             0             69           71          前天        time
# 1             0             75           77          前天        time
# 2             0            738          740          85    med_exam
# 3             0            741          744         102    med_exam
# 4             0            809          811          前年        time
# ...         ...            ...          ...         ...         ...
# 2250        119           1136         1138          彰化    location
# 2251        119           1143         1145          彰化    location
# 2252        119           1173         1177        彰化醫院    location
# 2253        119           1216         1221       陳明明醫師        name
# 2254        119           1250         1255       陳明明醫師        name
#
# [2255 rows x 5 columns]

# %%
private_types_train_1 = list(train_1['entity_type'])

# %%
private_types_train_1_dict = {}
for private_type in  private_types_train_1:
    if private_type not in private_types_train_1_dict:
        private_types_train_1_dict[private_type] = 1
    else:
        private_types_train_1_dict[private_type] +=1

# %%
private_types_train_1_dict
# Out:
# {'time': 1434,
#  'med_exam': 220,
#  'profession': 13,
#  'name': 169,
#  'location': 161,
#  'entity_type': 119,
#  'family': 25,
#  'ID': 8,
#  'clinical_event': 5,
#  'education': 3,
#  'money': 78,
#  'contact': 19,
#  'organization': 1}

# %% [markdown]
# # train_2

# %%
with open("train_2.txt","r",encoding="utf-8") as f:
    lines = f.readlines()
    #print(lines)
with open("train_2_read.txt","w",encoding="utf-8") as f_w:
    for line in lines:
        if "醫師：" in line:#or''or''or or'' '\n'or""
            continue
        if "家屬:" in line:
            continue
        if "個管師：" in line:
            continue
        if "民眾:" in line:
            continue
        if "----" in line:
            continue
        if " " in line:
            continue

        f_w.write(line)

# %%
train_2 = pd.read_csv("train_2_read.txt",  sep='\t', header=0)

# %%
train_2
# Out:
#      article_id start_position end_position entity_text entity_type
# 0             0             69           71          前天        time
# 1             0             75           77          前天        time
# 2             0            738          740          85    med_exam
# 3             0            741          744         102    med_exam
# 4             0            809          811          前年        time
# ...         ...            ...          ...         ...         ...
# 4025        199             36           39         1.7    med_exam
# 4026        199             40           43         1.7    med_exam
# 4027        199             48           51         9.0    med_exam
# 4028        199             53           56         1.7    med_exam
# 4029        199           1065         1067          小美        name
#
# [4030 rows x 5 columns]

# %%
private_types_train_2 = list(train_2['entity_type'])

# %%
train_2 = pd.read_csv("train_2_read.txt",  sep='\t', header=0)
private_types_train_2 = list(train_2['entity_type'])
private_types_train_2_dict = {}
for private_type in  private_types_train_2:
    if private_type not in private_types_train_2_dict:
        private_types_train_2_dict[private_type] = 1
    else:
        private_types_train_2_dict[private_type] +=1

# %%
private_types_train_2_dict
# Out:
# {'time': 2525,
#  'med_exam': 443,
#  'profession': 42,
#  'name': 279,
#  'location': 278,
#  'entity_type': 199,
#  'family': 50,
#  'ID': 21,
#  'clinical_event': 5,
#  'education': 6,
#  'money': 126,
#  'contact': 52,
#  'organization': 1,
#  'others': 3}

# %%
job_list = job.split(':')

# %%
from 台灣各行政區列表 import area_data

# %%
area_data
# Out:
# {'臺北市': ['中正區',
#   '大同區',
#   '中山區',
#   '萬華區',
#   '信義區',
#   '松山區',
#   '大安區',
#   '南港區',
#   '北投區',
#   '內湖區',
#   '士林區',
#   '文山區'],
#  '新北市': ['板橋區',
#   '新莊區',
#   '泰山區',
#   '林口區',
#   '淡水區',
#   '金山區',
#   '八里區',
#   '萬里區',
#   '石門區',
#   '三芝區',
#   '瑞芳區',
#   '汐止區',
#   '平溪區',
#   '貢寮區',
#   '雙溪區',
#   '深坑區',
#   '石碇區',
#   '新店區',
#   '坪林區',
#   '烏來區',
#   '中和區',
#   '永和區',
#   '土城區',
#   '三峽區',
#   '樹林區',
#   '鶯歌區',
#   '三重區',
#   '蘆洲區',
#   '五股區'],
#  '基隆市': ['仁愛區', '中正區', '信義區', '中山區', '安樂區', '暖暖區', '七堵區'],
#  '桃園市': ['桃園區',
#   '中壢區',
#   '平鎮區',
#   '八德區',
#   '楊梅區',
#   '蘆竹區',
#   '龜山區',
#   '龍潭區',
#   '大溪區',
#   '大園區',
#   '觀音區',
#   '新屋區',
#   '復興區'],
#  '新竹縣': ['竹北市',
#   '竹東鎮',
#   '新埔鎮',
#   '關西鎮',
#   '峨眉鄉',
#   '寶山鄉',
#   '北埔鄉',
#   '橫山鄉',
#   '芎林鄉',
#   '湖口鄉',
#   '新豐鄉',
#   '尖石鄉',
#   '五峰鄉'],
#  '新竹市': ['東區', '北區', '香山區'],
#  '苗栗縣': ['苗栗市',
#   '通霄鎮',
#   '苑裡鎮',
#   '竹南鎮',
#   '頭份鎮',
#   '後龍鎮',
#   '卓蘭鎮',
#   '西湖鄉',
#   '頭屋鄉',
#   '公館鄉',
#   '銅鑼鄉',
#   '三義鄉',
# ...

# %%
countys = list(area_data)

# %%
countys
# Out:
# ['臺北市',
#  '新北市',
#  '基隆市',
#  '桃園市',
#  '新竹縣',
#  '新竹市',
#  '苗栗縣',
#  '臺中市',
#  '南投縣',
#  '彰化縣',
#  '雲林縣',
#  '嘉義縣',
#  '嘉義市',
#  '臺南市',
#  '高雄市',
#  '屏東縣',
#  '宜蘭縣',
#  '花蓮縣',
#  '臺東縣',
#  '澎湖縣',
#  '金門縣',
#  '連江縣']

# %%
countys_list = ''
for county in countys:
    countys_list += county
    countys_list += '|'
    countys_list += county[:2]
    countys_list += '|'

# %%
countys_list
# Out:
# '臺北市|臺北|新北市|新北|基隆市|基隆|桃園市|桃園|新竹縣|新竹|新竹市|新竹|苗栗縣|苗栗|臺中市|臺中|南投縣|南投|彰化縣|彰化|雲林縣|雲林|嘉義縣|嘉義|嘉義市|嘉義|臺南市|臺南|高雄市|高雄|屏東縣|屏東|宜蘭縣|宜蘭|花蓮縣|花蓮|臺東縣|臺東|澎湖縣|澎湖|金門縣|金門|連江縣|連江|'

# %%
countys_list
# Out:
# '臺北市|新北市|基隆市|桃園市|新竹縣|新竹市|苗栗縣|臺中市|南投縣|彰化縣|雲林縣|嘉義縣|嘉義市|臺南市|高雄市|屏東縣|宜蘭縣|花蓮縣|臺東縣|澎湖縣|金門縣|連江縣|'

# %%
b = ''+'a'

# %%
f"''+{b}"
# Out:
# "''+a"

# %%
Districts_list = []
for county in countys:
    Districts_list.extend(area_data[county])

# %%
Districts_list
# Out:
# ['中正區',
#  '大同區',
#  '中山區',
#  '萬華區',
#  '信義區',
#  '松山區',
#  '大安區',
#  '南港區',
#  '北投區',
#  '內湖區',
#  '士林區',
#  '文山區',
#  '板橋區',
#  '新莊區',
#  '泰山區',
#  '林口區',
#  '淡水區',
#  '金山區',
#  '八里區',
#  '萬里區',
#  '石門區',
#  '三芝區',
#  '瑞芳區',
#  '汐止區',
#  '平溪區',
#  '貢寮區',
#  '雙溪區',
#  '深坑區',
#  '石碇區',
#  '新店區',
#  '坪林區',
#  '烏來區',
#  '中和區',
#  '永和區',
#  '土城區',
#  '三峽區',
#  '樹林區',
#  '鶯歌區',
#  '三重區',
#  '蘆洲區',
#  '五股區',
#  '仁愛區',
#  '中正區',
#  '信義區',
#  '中山區',
#  '安樂區',
#  '暖暖區',
#  '七堵區',
#  '桃園區',
#  '中壢區',
#  '平鎮區',
#  '八德區',
#  '楊梅區',
#  '蘆竹區',
#  '龜山區',
#  '龍潭區',
#  '大溪區',
#  '大園區',
#  '觀音區',
#  '新屋區',
#  '復興區',
#  '竹北市',
#  '竹東鎮',
#  '新埔鎮',
#  '關西鎮',
#  '峨眉鄉',
#  '寶山鄉',
#  '北埔鄉',
#  '橫山鄉',
#  '芎林鄉',
#  '湖口鄉',
#  '新豐鄉',
#  '尖石鄉',
#  '五峰鄉',
#  '東區',
#  '北區',
#  '香山區',
#  '苗栗市',
#  '通霄鎮',
#  '苑裡鎮',
#  '竹南鎮',
#  '頭份鎮',
#  '後龍鎮',
#  '卓蘭鎮',
#  '西湖鄉',
#  '頭屋鄉',
#  '公館鄉',
#  '銅鑼鄉',
#  '三義鄉',
#  '造橋鄉',
#  '三灣鄉',
#  '南庄鄉',
#  '大湖鄉',
#  '獅潭鄉',
#  '泰安鄉',
#  '中區',
#  '東區',
#  '南區',
#  '西區',
#  '北區',
# ...

# %%
len(Districts_list)
# Out:
# 368

# %%
Districts_list_reduce = set(Districts_list)

# %%
len(Districts_list_reduce)
# Out:
# 357

# %%
Districts_list = list(Districts_list_reduce)

# %%
districts_list = ''
for districts in Districts_list:
    districts_list += districts
    districts_list += '|'
    districts_list += districts[:2]
    districts_list += '|'

# %%
districts_list
# Out:
# '仁愛鄉|仁愛|里港鄉|里港|水上鄉|水上|美濃區|美濃|永靖鄉|永靖|安定區|安定|鹽水區|鹽水|文山區|文山|鹿草鄉|鹿草|蘇澳鎮|蘇澳|口湖鄉|口湖|梅山鄉|梅山|永和區|永和|南澳鄉|南澳|大園區|大園|竹塘鄉|竹塘|頭城鎮|頭城|官田區|官田|斗六市|斗六|霧台鄉|霧台|溪州鄉|溪州|麟洛鄉|麟洛|民雄鄉|民雄|橋頭區|橋頭|海端鄉|海端|三灣鄉|三灣|新埔鎮|新埔|福興鄉|福興|南屯區|南屯|那瑪夏區|那瑪|高樹鄉|高樹|後壁區|後壁|北投區|北投|仁武區|仁武|將軍區|將軍|造橋鄉|造橋|峨眉鄉|峨眉|尖石鄉|尖石|北竿鄉|北竿|南投市|南投|褒忠鄉|褒忠|金山區|金山|麥寮鄉|麥寮|淡水區|淡水|埔鹽鄉|埔鹽|長治鄉|長治|左鎮區|左鎮|五結鄉|五結|南竿鄉|南竿|芳苑鄉|芳苑|平鎮區|平鎮|六甲區|六甲|東石鄉|東石|萬丹鄉|萬丹|苑裡鎮|苑裡|臺西鄉|臺西|六龜區|六龜|望安鄉|望安|坪林區|坪林|新港鄉|新港|富里鄉|富里|湖西鄉|湖西|新化區|新化|雙溪區|雙溪|苓雅區|苓雅|玉里鎮|玉里|草屯鎮|草屯|大里區|大里|春日鄉|春日|北港鎮|北港|竹崎鄉|竹崎|九如鄉|九如|前金區|前金|桃園區|桃園|阿里山鄉|阿里|茂林區|茂林|達仁鄉|達仁|布袋鎮|布袋|甲仙區|甲仙|大武鄉|大武|楊梅區|楊梅|仁愛區|仁愛|前鎮區|前鎮|二崙鄉|二崙|燕巢區|燕巢|后里區|后里|枋山鄉|枋山|土城區
	"澎湖縣":[["160302","國立馬公高中"],["160401","國立澎湖海事水產"]],
	"基隆市":[["170301","國立基隆女中"],["170302","國立基隆高中"],["170403","國立基隆海事"],["170404","國立基隆商工"],["171306","私立二信高中"],["171308","輔大聖心高中"],["171405","私立光隆家商"],["171407","私立培德工家"],["173304","市立中山高中"],["173306","市立安樂高中"],["173307","市立暖暖高中"],["173314","市立八斗高中"]],
	"新竹市":[["180301","國立科學工業園區實驗高中"],["180302","國立新竹女中"],["180309","國立新竹高中"],["180403","國立新竹高商"],["180404","國立新竹高工"],["181305","私立光復高中"],["181306","私立曙光女中"],["181307","私立磐石高中"],["181308","私立世界高中"],["183306","市立成德高中"],["183307","市立香山高中"],["183313","市立建功高中"]],
	"嘉義市":[["200302","國立嘉義女中"],["200303","國立嘉義高中"],["200401","國立華南高商"],["200405","國立嘉義高工"],["200406","國立嘉義高商"],["200407","國立嘉義家職"],["201304","私立興華高中"],["201309","私立仁義高中"],["201310","私立嘉華高中"],["201312","私立輔仁高中"],["201313","私立宏仁女中"],["201314","私立立仁高中"],["201408","私立東吳工家"]],
	"金門縣":[["710301","國立金門高中"],["710401","國立金門農工"]],
	"連江縣":[["720301","國立馬祖高中"]]
};

# %%
college_countys = list(tw_coll_json)

# %%
College_list = []
for county in college_countys:
    for college_number in range(len(tw_coll_json[county])):
        College_list.append(tw_coll_json[county][college_number][1])

# %%
college_list = ''
for college in College_list:
    college_list += college
    college_list += '|'

# %%
college_list
# Out:
# '國立政治大學|國立臺灣大學|國立臺灣師範大學|國立陽明大學|國立臺灣科技大學|國立臺北科技大學|國立臺北藝術大學|國立臺北教育大學|國立臺北護理健康大學|國立臺北商業大學|東吳大學|中國文化大學|世新大學|銘傳大學|實踐大學|大同大學|臺北醫學大學|中國科技大學|德明財經科技大學|中華科技大學|臺北城市科技大學|康寧大學|臺北市立大學|國立臺灣戲曲學院|馬偕醫護管理專科學校|國立清華大學|國立交通大學|國立新竹教育大學|中華大學|玄奘大學|元培醫事科技大學|國立成功大學|國立臺南藝術大學|國立臺南大學|南臺科技大學|崑山科技大學|嘉南藥理大學|長榮大學|台南應用科技大學|遠東科技大學|中華醫事科技大學|台灣首府大學|南榮科技大學|中信金融管理學院|國立臺南護理專科學校|敏惠醫護管理專科學校|國立中興大學|國立臺中教育大學|國立勤益科技大學|國立臺灣體育運動大學|國立臺中科技大學|東海大學|逢甲大學|靜宜大學|朝陽科技大學|中山醫學大學|弘光科技大學|中國醫藥大學|嶺東科技大學|中臺科技大學|亞洲大學|僑光科技大學|修平科技大學|國立中央大學|國立體育大學|中原大學|長庚大學|元智大學|龍華科技大學|健行科技大學|萬能科技大學|開南大學|長庚科技大學|桃園創新技術學院|新生醫護管理專科學校|國立中山大學|國立高雄師範大學|國立高雄大學|國立高雄第一科技大學|國立高雄應用科技大學|國立高雄海洋科技大學|國立高雄餐旅大學|義守大學|高雄醫學大學|樹德科技大學|輔英科技大學|正修科技大學|高苑科技大學|文藻外語大學|和春技術學院|東方設計學院|樹人醫護管理專科學校|高美醫護管理專科學校|育英醫護管理專科學校|國立臺灣海洋大學|經國管理暨健康學院|崇右技術學院|國立中正大學|南華大學|吳鳳科技大學|稻江科技暨管理學院|國立彰化師範大學|大葉大學|建國科技大學|明道大學|中州科技大學|國立臺北大學|國立臺灣藝術大學|輔仁大學|淡江大學|華梵大學|真理大學|明志科技大學|聖約翰科技大學|景文科技大學|東南科技大學|醒吾科技大學|華夏科技大學|致理科技大學|亞東技術學院|德霖技術學院|黎明技術學院|馬偕醫學院|法鼓文理學院|台北海洋技術學院|耕莘健康管理專科學校|國立嘉義大學|大同技術學院|崇仁醫護管理專科學校|國立東華大學|慈濟大學|慈濟科技大學|大漢技術學院|臺灣觀光學院
# ...

# %%
台大|清大|清華|交大|成大|政大|台科大|中央|中山|中興|台師|中正|輔仁|中原|東吳|逢甲|東海|靜宜|長庚|元智|高師大|北醫
|台師大|師大|高雄醫學大學|高醫|中國醫|中山醫學大學|淡江|北大|海大

# %%
from country_list import available_languages

for language in available_languages():
    print(language)
# Out:
# af
# af_NA
# af_ZA
# ak
# ak_GH
# am
# am_ET
# ar
# ar_001
# ar_AE
# ar_BH
# ar_DJ
# ar_DZ
# ar_EG
# ar_EH
# ar_ER
# ar_IL
# ar_IQ
# ar_JO
# ar_KM
# ar_KW
# ar_LB
# ar_LY
# ar_MA
# ar_MR
# ar_OM
# ar_PS
# ar_QA
# ar_SA
# ar_SD
# ar_SO
# ar_SS
# ar_SY
# ar_TD
# ar_TN
# ar_YE
# as
# as_IN
# az
# az_AZ
# az_Cyrl
# az_Cyrl_AZ
# az_Latn
# az_Latn_AZ
# be
# be_BY
# bg
# bg_BG
# bm
# bm_Latn
# bm_Latn_ML
# bm_ML
# bn
# bn_BD
# bn_IN
# bo
# bo_CN
# bo_IN
# br
# br_FR
# bs
# bs_BA
# bs_Cyrl
# bs_Cyrl_BA
# bs_Latn
# bs_Latn_BA
# ca
# ca_AD
# ca_ES
# ca_FR
# ca_IT
# ce
# ce_RU
# cs
# cs_CZ
# cy
# cy_GB
# da
# da_DK
# da_GL
# de
# de_AT
# de_BE
# de_CH
# de_DE
# de_IT
# de_LI
# de_LU
# dz
# dz_BT
# ee
# ee_GH
# ee_TG
# el
# el_CY
# el_GR
# en
# en_001
# en_150
# en_AE
# en_AG
# en_AI
# en_AS
# en_AT
# en_AU
# en_BB
# en_BE
# en_BI
# en_BM
# en_BS
# en_BW
# en_BZ
# en_CA
# en_CC
# en_CH
# en_CK
# en_CM
# en_CX
# en_CY
# en_DE
# en_DG
# en_DK
# en_DM
# en_ER
# en_FI
# en_FJ
# en_FK
# en_FM
# ...

# %%
from country_list import countries_for_language
# countries_for_language returns a list of tuples now, might be changed to an OrderedDict
countries = dict(countries_for_language('en'))
countries_abbreviation = list(countries.keys())

# %%
countries
# Out:
# {'AF': 'Afghanistan',
#  'AX': 'Åland Islands',
#  'AL': 'Albania',
#  'DZ': 'Algeria',
#  'AS': 'American Samoa',
#  'AD': 'Andorra',
#  'AO': 'Angola',
#  'AI': 'Anguilla',
#  'AQ': 'Antarctica',
#  'AG': 'Antigua & Barbuda',
#  'AR': 'Argentina',
#  'AM': 'Armenia',
#  'AW': 'Aruba',
#  'AU': 'Australia',
#  'AT': 'Austria',
#  'AZ': 'Azerbaijan',
#  'BS': 'Bahamas',
#  'BH': 'Bahrain',
#  'BD': 'Bangladesh',
#  'BB': 'Barbados',
#  'BY': 'Belarus',
#  'BE': 'Belgium',
#  'BZ': 'Belize',
#  'BJ': 'Benin',
#  'BM': 'Bermuda',
#  'BT': 'Bhutan',
#  'BO': 'Bolivia',
#  'BA': 'Bosnia & Herzegovina',
#  'BW': 'Botswana',
#  'BV': 'Bouvet Island',
#  'BR': 'Brazil',
#  'IO': 'British Indian Ocean Territory',
#  'VG': 'British Virgin Islands',
#  'BN': 'Brunei',
#  'BG': 'Bulgaria',
#  'BF': 'Burkina Faso',
#  'BI': 'Burundi',
#  'KH': 'Cambodia',
#  'CM': 'Cameroon',
#  'CA': 'Canada',
#  'CV': 'Cape Verde',
#  'BQ': 'Caribbean Netherlands',
#  'KY': 'Cayman Islands',
# ...

# %%
countries_list = '' 
for country in countries_abbreviation:
    countries_list += countries[country]
    countries_list += '|'

# %%
countries_list
# Out:
# 'Afghanistan|Åland Islands|Albania|Algeria|American Samoa|Andorra|Angola|Anguilla|Antarctica|Antigua & Barbuda|Argentina|Armenia|Aruba|Australia|Austria|Azerbaijan|Bahamas|Bahrain|Bangladesh|Barbados|Belarus|Belgium|Belize|Benin|Bermuda|Bhutan|Bolivia|Bosnia & Herzegovina|Botswana|Bouvet Island|Brazil|British Indian Ocean Territory|British Virgin Islands|Brunei|Bulgaria|Burkina Faso|Burundi|Cambodia|Cameroon|Canada|Cape Verde|Caribbean Netherlands|Cayman Islands|Central African Republic|Chad|Chile|China|Christmas Island|Cocos (Keeling) Islands|Colombia|Comoros|Congo - Brazzaville|Congo - Kinshasa|Cook Islands|Costa Rica|Côte d’Ivoire|Croatia|Cuba|Curaçao|Cyprus|Czechia|Denmark|Djibouti|Dominica|Dominican Republic|Ecuador|Egypt|El Salvador|Equatorial Guinea|Eritrea|Estonia|Eswatini|Ethiopia|Falkland Islands|Faroe Islands|Fiji|Finland|France|French Guiana|French Polynesia|French Southern Territories|Gabon|Gambia|Georgia|Germany|Ghana|Gibraltar|Greece|Greenland|Grenada|Guadeloupe|Guam|G
# ...

# %%
private_types_dict
# Out:
# {'name': 134,
#  'med_exam': 197,
#  'time': 862,
#  'location': 137,
#  'family': 33,
#  'money': 42,
#  'contact': 8,
#  'profession': 7,
#  'ID': 3}

# %%
private_types_train_2_dict
# Out:
# {'time': 2525,
#  'med_exam': 443,
#  'profession': 42,
#  'name': 279,
#  'location': 278,
#  'entity_type': 199,
#  'family': 50,
#  'ID': 21,
#  'clinical_event': 5,
#  'education': 6,
#  'money': 126,
#  'contact': 52,
#  'organization': 1,
#  'others': 3}

# %% [markdown]
# # predict_test_fianl

# %%
import pandas as pd

test_predict_final = pd.read_csv('(test)blc_rgr_lwld_sw_wc=T_rn=F_sv=T_ls=T_il=F_bies=F_tm=T_b16_fold0-5_es=e9_sw=vote_fix.tsv', sep='\t', header=0)
private_types = list(test_predict_final['entity_type'])
private_types_final_dict = {}
for private_type in  private_types:
    if private_type not in private_types_final_dict:
        private_types_final_dict[private_type] = 1
    else:
        private_types_final_dict[private_type] +=1

# %%
test_predict_final['start_position']
# Out:
# 0        198
# 1        227
# 2        237
# 3        295
# 4         31
#         ...
# 3425    1082
# 3426    1143
# 3427    1199
# 3428    1353
# 3429    1380
# Name: start_position, Length: 3430, dtype: int64

# %%
private_types_final_dict
# Out:
# {'location': 176,
#  'time': 2231,
#  'med_exam': 451,
#  'name': 261,
#  'money': 146,
#  'family': 41,
#  'ID': 32,
#  'contact': 51,
#  'profession': 37,
#  'education': 4}

# %%
# Out:
# 0       location
# 1       location
# 2       location
# 3           time
# 4           time
#           ...
# 3425        time
# 3426        time
# 3427        name
# 3428        time
# 3429     contact
# Name: entity_type, Length: 3430, dtype: object

# %% [markdown]
# # name

# %%
name_index_test_final = []
name_context_test_final = []
for idx, private_type in enumerate(private_types):
    private_name_art_id = []
    if private_type == 'name':
        private_name_art_id.append(test_predict_final['entity_text'][idx])
        private_name_art_id.append(test_predict_final['article_id'][idx])
        private_name_art_id.append(test_predict_final['start_position'][idx])
        
        name_context_test_final.append(private_name_art_id)

# %%
name_context_test_final
# Out:
# [['黃醫師', 1, 360],
#  ['劉老師', 1, 497],
#  ['黃醫師', 1, 626],
#  ['格里曼', 1, 754],
#  ['吳醫師', 3, 678],
#  ['劉醫師', 5, 1235],
#  ['鞏醫師', 6, 1191],
#  ['小夜', 7, 124],
#  ['偉哲', 8, 3],
#  ['林醫師', 9, 74],
#  ['李醫師', 10, 8],
#  ['美珠', 10, 1537],
#  ['許醫師', 11, 1161],
#  ['許王玉醫師', 11, 4562],
#  ['許醫師', 11, 5124],
#  ['徐醫師', 11, 6171],
#  ['舒雅', 13, 13],
#  ['曉萍', 13, 342],
#  ['曉萍', 13, 499],
#  ['李醫師', 15, 58],
#  ['李醫師', 15, 67],
#  ['李醫師', 15, 81],
#  ['志明', 16, 1090],
#  ['顏醫師', 17, 619],
#  ['顏醫師', 17, 656],
#  ['秀女', 18, 979],
#  ['秀女', 18, 1443],
#  ['秀女', 18, 1827],
#  ['鄭醫師', 20, 121],
#  ['鄭醫師', 20, 663],
#  ['鄭醫師', 20, 893],
#  ['張光良', 22, 756],
#  ['胡蘭竹', 23, 897],
#  ['DRCHEN', 24, 438],
#  ['慧英', 26, 925],
#  ['慧英', 26, 976],
#  ['慧英姐', 26, 1019],
#  ['李醫師', 26, 1030],
#  ['慧英', 26, 1049],
#  ['佳明', 26, 1053],
#  ['佳建', 27, 3],
#  ['新寶', 27, 164],
#  ['阿小明', 30, 3],
#  ['劉醫師', 31, 269],
#  ['劉醫師', 31, 317],
#  ['劉醫師', 31, 1093],
#  ['劉醫師', 31, 1628],
#  ['林醫師', 32, 78],
# ...

# %% [markdown]
# # ID

# %%
ID_context_test_final = []
for idx, private_type in enumerate(private_types):
    private_ID_art_id = []
    if private_type == 'ID':
        private_ID_art_id.append(test_predict_final['entity_text'][idx])
        private_ID_art_id.append(test_predict_final['article_id'][idx])
        private_ID_art_id.append(test_predict_final['start_position'][idx])
        
        ID_context_test_final.append(private_ID_art_id)

# %%
ID_context_test_final
# Out:
# [['56387', 8, 1153],
#  ['E127388873', 9, 7],
#  ['六零九', 13, 366],
#  ['78362', 14, 1258],
#  ['1107', 21, 132],
#  ['7382', 22, 752],
#  ['8353', 39, 1486],
#  ['63554', 42, 5],
#  ['R113566480', 44, 6],
#  ['23343', 45, 3281],
#  ['吳小美66674', 48, 1863],
#  ['R113993846', 49, 8],
#  ['蔡貴麗女士R334666726', 51, 15],
#  ['v237', 53, 1394],
#  ['234526780', 63, 7],
#  ['F178290737', 65, 2301],
#  ['723', 84, 2024],
#  ['78392', 89, 9],
#  ['E1287394675', 93, 802],
#  ['S137465537', 103, 633],
#  ['83946', 106, 690],
#  ['630', 112, 658],
#  ['5362', 114, 2643],
#  ['A289370198', 121, 996],
#  ['7846', 128, 928],
#  ['73846', 131, 1213],
#  ['R100382694', 142, 15],
#  ['29', 145, 377],
#  ['8932', 145, 1669],
#  ['9370256', 146, 9],
#  ['837654', 150, 7565],
#  ['5632', 156, 3273]]

# %%
a = '醫師：顏先生他這樣……最近還好嗎？家屬：他是現在好像……血壓不知道不是很好。醫師：恩，有沒有變越……變比較差還是？家屬：都……都差不多。醫師：都差不多齁。家屬：阿就是吃完飯就血壓掉得很快。醫師：血壓降低，恩。集中到腸胃裡面。家屬：每次吃飽飯他……現在好像比以前速度還快。醫師：喔，那表示那彈性越來越沒有那麼好欸。家屬：嗯，所以他……因為我幫他換……換那個床齁。醫師：嘿。家屬：現在買這個是比較小……比較小張，阿所以他……可是他這個……因為我們買床他沒辦法讓我們看這，看那個DM。醫師：恩。家屬：阿所以也不知道他坐的……他翹起來只是大腿，結果小腿是向下垂的，我都還要跟他墊枕頭。醫師：墊枕頭。家屬：嘿阿，他就嫌……有時候嫌麻煩，我說有時候洗……你不……你說剛買嘛，阿不好，你也不能是說……醫師：電動的。家屬：對，阿因為之前買，我是沒有想到是說，因為買那台比較大台，我想說好啊，阿不然買這個這樣，阿不知道他比較大隻，齁，阿所以他每次就會往下垂，腳就攤開，阿又我們看到他就是說……那個他以後他的髖關節會受傷，叫我要把他用直。醫師：用正這樣。家屬：阿所以現在他起來我都要往下拉，然後再把那個腳用扶的，把它扶著不要讓他開開。醫師：恩恩。家屬：阿所以他有時候也嫌麻煩。醫師：是因為血壓低的時候要頭低腳高啦齁，所以你們會調。家屬：嘿阿，嘿阿。阿我跟他說剛買而已啊，阿不能看實……實體的我也不知道買回來是這這樣子。醫師：阿一條是多少？家屬：嗯……看看狀況，因為我們之前早期三十幾年前買那個是席夢思的。醫師：恩。家屬：它的床比較大，然後睡起來可能比較舒服，阿因為我想說用了三十年，哈哈，我都沒……阿現在社……社會局那個專員說你們的床那麼久了吱吱叫，不然換一個好了啦。醫師：有補助這樣子。家屬：對，可是，痾……嘿，嘿。阿……嘿阿，嘿。阿所以他就覺得說沒辦法看到實體的東西，也是啦，嘿阿。醫師：恩，阿傷口呢？家屬：傷口喔，現在說這個那個……大腿這個齁，算現在換這個在出血，好像有一點惡化。醫師：出血這樣子，是出血，不是流膿還是？家屬：它那個本來算是就蠻多的。醫師：蠻多的。家屬：阿所以都去那個診所給他拿藥膏，我今天去診所抽血，早上阿，游醫師就問我說阿他……因為剛剛都還……剛剛他說叫我用完瓶子要回收。醫師：回收。家屬：阿所以就給他換那個沒有了，瓶子拿去換再換回來。醫師：是。家屬：啊他有……就問說他出血的狀況，我說現在換成那個大腿這邊那個出血比較嚴重，以前那個屁股，那個……阿因為你有開止血劑給他吃。醫師：嗯，對。家屬：所以有，那……這陣子好很多，阿不知道是大腿這邊是在惡化或者是怎麼……醫師：阿肉色看起來是？家屬：肉色還……醫師：還美美的，紅紅的？家屬：嘿，嘿阿，啊我就是跟你說他都長那個小塊、小塊、小塊、小塊，阿回家也像……不完全這樣。阿所以那個他現在流血變紅血。醫師：紅色。家屬：所以變成他那個……他不……變成那個傷口沒進展。醫師：沒進展齁。家屬：阿可是我覺得現在開那個類固醇，好像……腳好像沒有……好像稍微有改善了。醫師：喔，真的齁。家屬：因為吃了一個月了。醫師：嗯嗯嗯。家屬：啊我看到那個破皮然後是瘀青的程度好像……好像沒有那麼嚴重了。醫師：因為他這個又是等於是又降一級齁。家屬：嘿。醫師：他就是可以顧血壓，但是比較不會影響到皮膚啦，比較不會影響到感染的阿。家屬：喔喔，嘿。醫師：嘿阿，我想……那麼我們就繼續這個新的這個，新換的就繼續。家屬：好。醫師：阿那個止血的藥丸我每天都備一個，我給你量開多一點好不好？家屬：因……因為他如果是，因為我是要過去那邊……因為他是不一定，你如果真正在出血的時候還是要用波斯命……醫師：用波斯命，喔。家屬：就去止血，阿不然你這裡，你貼著就止血有時候也不知道他到底是，你也要看到他有止血的狀況。醫師：是。家屬：嘿阿，嘿阿所以應該是這樣開就好，阿……醫師：我上次才開一……才開兩個禮拜。家屬：嘿阿，阿，他他他……他有時候就想說如果沒有出血就不吃這樣。醫師：喔，那我就開兩次這樣就好了。家屬：嘿阿。醫師：阿其他的藥都……都照舊嘛齁？家屬：诶？對，阿那個……這個齁，那個神經內科這個……醫師：一起開齁？家屬：嗯，這個，這個阿。醫師：喔，游醫師……723喔，723剛好差一個禮拜欸。家屬：這樣可以開嗎？醫師：差一個禮拜剛好……怎麼那麼剛好。你今天還有沒有……我們下……開得藥還有沒有夠一個禮拜？還夠不夠？家屬：應該夠。醫師：夠齁？家屬：恩。醫師：還是我們下禮拜再一起？今天我就先補，下次我們再一起好不好？家屬：喔，好。醫師：可以，我就退掛這樣子。家屬：喔，好啊，好啊。醫師：好齁，好。醫師：這樣我就先幫你約，這樣我下次就幫你跟游醫師的這樣一起開起來。家屬：阿這個，這個就……因為我怕……我也是擔心出狀況，所以我復康巴士今天就要訂了，所以我早上有跟他跟我說來等你確認我就給他取消。醫師：好，好，好那我們就還是照樣併好不好？家屬：蛤？醫師：就723嘛，我的意思是說今天我們是就……我都先沒開藥，阿723那天我再幫你多掛一個我這邊。家屬：阿，好好好。醫師：因為我這樣這邊齁，剛好卡一個禮拜。家屬：嗯嗯嗯。醫師：一個禮拜內你如果說差6天、5天我開得出來。家屬：嗯嗯嗯。醫師：阿剛好7天它會擋這樣子。家屬：好好好。醫師：這樣可以齁。家屬：好好，因為顏先生來他都血壓太低，阿所以……醫師：喔，他會來喔？家屬：他他……那個醫師就是要他來阿。醫師：喔，要鑑定啦齁。家屬：不是，不是鑑定。醫師：喔，就是他，要他都要來。家屬：他現在……他他……就是很穩定了阿，所以他就是有減量了阿。醫師：減量。家屬：半顆阿，嘿阿。醫師：那我們就這樣子好不好。家屬：好，謝謝。'

# %%
a[2000:2050]
# Out:
# '，好那我們就還是照樣併好不好？家屬：蛤？醫師：就723嘛，我的意思是說今天我們是就……我都先沒開藥，'

# %% [markdown]
# # contact

# %%
contact_context_test_final = []
for idx, private_type in enumerate(private_types):
    private_contact_art_id = []
    if private_type == 'contact':
        private_contact_art_id.append(test_predict_final['entity_text'][idx])
        private_contact_art_id.append(test_predict_final['article_id'][idx])
        private_contact_art_id.append(test_predict_final['start_position'][idx])
        
        contact_context_test_final.append(private_contact_art_id)

# %%
contact_context_test_final
# Out:
# [['林大華，', 9, 3],
#  ['E137354975', 13, 1273],
#  ['line', 24, 425],
#  ['ine', 24, 466],
#  ['E183745524', 36, 1115],
#  ['0935642234', 38, 766],
#  ['E184666204', 40, 499],
#  ['0933625337', 46, 384],
#  ['LINE', 50, 2410],
#  ['RLINOP', 50, 2416],
#  ['臉書', 62, 1400],
#  ['R2', 63, 6],
#  ['line', 64, 925],
#  ['R223640298', 90, 1525],
#  ['A148390275', 92, 1423],
#  ['Finska', 111, 2352],
#  ['bbs', 115, 1131],
#  ['bbs', 115, 1140],
#  ['LINE', 115, 1252],
#  ['PREPEAT', 115, 2746],
#  ['LINE', 116, 1301],
#  ['www.prep.com', 120, 1768],
#  ['line', 122, 1844],
#  ['Line', 124, 466],
#  ['GAMEONE', 124, 487],
#  ['R147380478', 126, 743],
#  ['line', 127, 709],
#  ['line', 131, 219],
#  ['line', 131, 349],
#  ['line', 131, 1154],
#  ['ＬＩＮＥ', 132, 1420],
#  ['ＰＲＥＰＣＵ', 132, 1436],
#  ['LINE', 133, 322],
#  ['LINE', 133, 1012],
#  ['mail', 135, 699],
#  ['mail', 135, 710],
#  ['LINE', 136, 465],
#  ['LINE', 136, 528],
#  ['LINE', 136, 776],
#  ['Line', 137, 1399],
# ...

# %% [markdown]
# # profession

# %%
profession_context_test_final = []
for idx, private_type in enumerate(private_types):
    private_profession_art_id = []
    if private_type == 'profession':
        private_profession_art_id.append(test_predict_final['entity_text'][idx])
        private_profession_art_id.append(test_predict_final['article_id'][idx])
        private_profession_art_id.append(test_predict_final['start_position'][idx])
        
        profession_context_test_final.append(private_profession_art_id)

# %%
profession_context_test_final
# Out:
# [['台南國小當老師', 11, 4919],
#  ['爭鮮迴轉壽司', 19, 1379],
#  ['餐飲', 26, 607],
#  ['餐飲業', 26, 613],
#  ['生物科技', 45, 999],
#  ['台中生物科技', 45, 1020],
#  ['扶輪社', 45, 1080],
#  ['台積電', 47, 906],
#  ['肝膽腸胃科', 56, 215],
#  ['FOODPANDA', 62, 1376],
#  ['急診', 67, 1256],
#  ['急診', 67, 1263],
#  ['急診', 67, 1274],
#  ['急診', 67, 1303],
#  ['急診', 83, 2796],
#  ['急診', 83, 2800],
#  ['今天急診', 83, 3286],
#  ['工地', 85, 1572],
#  ['工地', 85, 1588],
#  ['一日早餐店', 94, 564],
#  ['汎生藥廠', 95, 1174],
#  ['大夜班保全', 102, 379],
#  ['海商', 110, 1546],
#  ['國泰', 113, 1613],
#  ['國泰', 113, 1622],
#  ['富邦', 113, 1629],
#  ['遠雄', 113, 1632],
#  ['富邦', 113, 1642],
#  ['遠雄', 113, 1645],
#  ['三商美邦', 127, 181],
#  ['替代役', 130, 378],
#  ['資訊科', 136, 143],
#  ['麵包店', 138, 572],
#  ['健身工廠', 138, 792],
#  ['健身工廠', 138, 801],
#  ['電機所', 144, 107],
#  ['台積電', 151, 28]]

# %% [markdown]
# # location

# %%
location_context_test_final = []
for idx, private_type in enumerate(private_types):
    private_location_art_id = []
    if private_type == 'location':
        private_location_art_id.append(test_predict_final['entity_text'][idx])
        private_location_art_id.append(test_predict_final['article_id'][idx])
        private_location_art_id.append(test_predict_final['start_position'][idx])
        
        location_context_test_final.append(private_location_art_id)

# %%
location_context_test_final
# Out:
# [['新樓', 0, 198],
#  ['麻豆', 0, 227],
#  ['麻豆', 0, 237],
#  ['嘉明', 4, 6],
#  ['榮總', 5, 184],
#  ['台大', 8, 216],
#  ['學校', 11, 1299],
#  ['學校', 11, 1613],
#  ['學校', 11, 4904],
#  ['台大醫院', 14, 1011],
#  ['台中', 20, 143],
#  ['中山路', 20, 1286],
#  ['威信診所', 20, 1290],
#  ['中山路', 20, 1298],
#  ['今年長庚', 21, 294],
#  ['成功國小', 25, 682],
#  ['北部', 28, 1057],
#  ['蘆洲', 29, 859],
#  ['長庚醫院', 30, 540],
#  ['苓雅區', 30, 809],
#  ['苓雅區', 30, 862],
#  ['高雄', 30, 868],
#  ['高雄', 30, 878],
#  ['苓雅區', 30, 885],
#  ['新光三越', 37, 502],
#  ['台東', 41, 2593],
#  ['台東', 41, 2680],
#  ['大學路', 42, 1301],
#  ['大華', 43, 142],
#  ['星星幼兒園', 43, 967],
#  ['普林', 44, 692],
#  ['普林', 44, 705],
#  ['普林', 44, 712],
#  ['普林', 44, 716],
#  ['長庚', 45, 26],
#  ['台中', 45, 997],
#  ['台中', 45, 1032],
#  ['長庚', 45, 2273],
#  ['長庚醫院', 45, 2292],
#  ['長庚', 45, 2456],
#  ['高醫', 45, 2631],
#  ['台大', 45, 2795],
#  ['長庚醫院', 45, 2844],
#  ['長庚', 45, 2869],
#  ['香港', 50, 385],
#  ['貴麗', 51, 202],
#  ['大東醫院', 60, 294],
#  ['大東醫院', 60, 2159],
# ...

# %% [markdown]
# # ......times

# %%
all_point_times = 0
every_point_times = []
with open('train_2.txt','r') as f:
    for line in f.readlines():
#         print(line)
        times = line.count('……')
        all_point_times += times
        every_point_times.append(times)

# %%
all_point_times
# Out:
# 1796

# %%
all_point_times
# Out:
# 2099

# %%
point_frequency_test = 0
for frequency in every_point_times:
    if frequency != 0 :
        point_frequency_test += 1

# %%
point_frequency_test
# Out:
# 125

# %%
1796/158
# Out:
# 11.367088607594937

# %%
2100/200
# Out:
# 10.5

# %%
f.read()
f.close
# Out:
# <function TextIOWrapper.close()>

# %% [markdown]
# # family

# %%
family_context_test_final = []
for idx, private_type in enumerate(private_types):
    private_family_art_id = []
    if private_type == 'family':
        private_family_art_id.append(test_predict_final['entity_text'][idx])
        private_family_art_id.append(test_predict_final['article_id'][idx])
        private_family_art_id.append(test_predict_final['start_position'][idx])
        
        family_context_test_final.append(private_family_art_id)

# %%
family_context_test_final
# Out:
# [['媽媽', 7, 1087],
#  ['媽媽', 9, 861],
#  ['爺爺', 11, 1425],
#  ['爸爸', 11, 1632],
#  ['哥哥', 18, 1767],
#  ['兒子', 25, 602],
#  ['兒子', 25, 722],
#  ['兒子', 39, 1202],
#  ['小妹', 39, 1379],
#  ['老媽', 39, 1410],
#  ['爸爸', 39, 1421],
#  ['女兒', 42, 1519],
#  ['女兒', 45, 508],
#  ['阿嬤', 54, 650],
#  ['叔叔、阿姨', 54, 658],
#  ['兒子', 58, 366],
#  ['兒子', 58, 1006],
#  ['兒子', 58, 1761],
#  ['兒子', 58, 1765],
#  ['哥哥他女兒', 62, 1768],
#  ['女兒', 62, 1804],
#  ['爸爸', 66, 404],
#  ['奶奶', 66, 1017],
#  ['爸爸', 69, 553],
#  ['女兒', 69, 608],
#  ['女兒', 76, 2237],
#  ['女兒', 76, 3379],
#  ['兒子', 77, 705],
#  ['弟弟', 77, 711],
#  ['兒子', 77, 1575],
#  ['哥哥', 77, 2001],
#  ['爸爸', 77, 2018],
#  ['媽媽', 79, 1626],
#  ['兒子', 79, 1901],
#  ['女兒', 81, 207],
#  ['親戚', 81, 1511],
#  ['兒子', 85, 2908],
#  ['爸爸、媽媽', 110, 434],
#  ['公公', 119, 705],
#  ['弟弟', 137, 53],
#  ['爺爺', 140, 319]]

# %% [markdown]
# # education

# %%
education_context_test_final = []
for idx, private_type in enumerate(private_types):
    private_education_art_id = []
    if private_type == 'education':
        private_education_art_id.append(test_predict_final['entity_text'][idx])
        private_education_art_id.append(test_predict_final['article_id'][idx])
        private_education_art_id.append(test_predict_final['start_position'][idx])
        
        education_context_test_final.append(private_education_art_id)

# %%
education_context_test_final
# Out:
# [['讀大學', 25, 636], ['高雄大學的法律系', 25, 647], ['成大', 149, 26], ['化學系', 149, 39]]

# %% [markdown]
# # money

# %%
money_context_test_final = []
for idx, private_type in enumerate(private_types):
    private_money_art_id = []
    if private_type == 'money':
        private_money_art_id.append(test_predict_final['entity_text'][idx])
        private_money_art_id.append(test_predict_final['article_id'][idx])
        private_money_art_id.append(test_predict_final['start_position'][idx])
        
        money_context_test_final.append(private_money_art_id)

# %%
money_context_test_final
# Out:
# [['500', 2, 275],
#  ['500', 2, 285],
#  ['450塊', 2, 1151],
#  ['450塊', 2, 1394],
#  ['800塊', 7, 1128],
#  ['800塊', 7, 1136],
#  ['五千五', 8, 504],
#  ['五千五', 8, 525],
#  ['一萬五千', 8, 543],
#  ['一萬五千', 8, 553],
#  ['三百塊', 8, 882],
#  ['幾千塊', 10, 463],
#  ['幾千塊', 10, 472],
#  ['100塊', 10, 683],
#  ['100塊', 10, 694],
#  ['七十五', 13, 1153],
#  ['一二五', 13, 1165],
#  ['七十五', 13, 1169],
#  ['三百塊', 14, 900],
#  ['1500元', 16, 794],
#  ['三十二塊', 18, 1540],
#  ['三十二塊', 19, 1589],
#  ['215塊', 23, 1166],
#  ['一千六', 41, 806],
#  ['一千六', 41, 824],
#  ['一千六', 41, 834],
#  ['一一三五', 41, 1505],
#  ['一一三五', 41, 1513],
#  ['一千', 41, 1524],
#  ['一千七', 41, 1527],
#  ['五萬', 45, 257],
#  ['1.2000', 51, 1627],
#  ['1.2000', 51, 1640],
#  ['十一萬', 55, 558],
#  ['150', 62, 1222],
#  ['150', 62, 1229],
#  ['270', 62, 1252],
#  ['270', 62, 1259],
#  ['500', 62, 1313],
#  ['500', 62, 1365],
#  ['三百', 65, 1319],
#  ['十塊錢', 67, 2335],
#  ['兩百二十八塊', 67, 3221],
#  ['十塊', 67, 3242],
#  ['600', 75, 833],
# ...

# %% [markdown]
# # med_exam

# %%
med_exam_context_test_final = []
for idx, private_type in enumerate(private_types):
    private_med_exam_art_id = []
    if private_type == 'med_exam':
        private_med_exam_art_id.append(test_predict_final['entity_text'][idx])
        private_med_exam_art_id.append(test_predict_final['article_id'][idx])
        private_med_exam_art_id.append(test_predict_final['start_position'][idx])
        
        med_exam_context_test_final.append(private_med_exam_art_id)

# %%
med_exam_context_test_final
# Out:
# [['0.79', 1, 76],
#  ['88', 1, 94],
#  ['60', 1, 122],
#  ['2.6', 1, 258],
#  ['6.6', 1, 366],
#  ['6.6', 1, 385],
#  ['8.3', 1, 394],
#  ['8.3', 1, 407],
#  ['8.3', 1, 418],
#  ['6.2', 1, 463],
#  ['21', 1, 867],
#  ['1100', 2, 170],
#  ['1145', 2, 245],
#  ['55', 2, 678],
#  ['57', 2, 681],
#  ['52', 2, 699],
#  ['3', 2, 872],
#  ['3', 2, 880],
#  ['7.56', 2, 1090],
#  ['35', 2, 1239],
#  ['36．9度', 4, 148],
#  ['36．9度', 4, 157],
#  ['36．9度', 4, 163],
#  ['114/66', 4, 173],
#  ['622', 4, 215],
#  ['15', 4, 288],
#  ['6', 4, 292],
#  ['30', 4, 299],
#  ['12', 4, 303],
#  ['15', 4, 319],
#  ['31', 4, 326],
#  ['20', 5, 106],
#  ['20', 5, 114],
#  ['9700', 5, 151],
#  ['9700', 5, 162],
#  ['9700', 5, 171],
#  ['10600', 5, 188],
#  ['10600', 5, 197],
#  ['10600', 5, 206],
#  ['10600', 5, 217],
#  ['9700', 5, 232],
#  ['9000幾', 5, 699],
#  ['9700', 5, 2223],
#  ['9700', 5, 2241],
#  ['20', 5, 2268],
#  ['20', 5, 2271],
#  ['20', 5, 2275],
#  ['90', 5, 2309],
#  ['100', 5, 2312],
# ...

# %%
a = '民眾：最近真的沒有怎麽在吃。個管師：業績好嗎？民眾：業績很好，真的很忙。個管師：所以業績太好，所以太累。民眾：對啊，真的很忙，等下還有繼續。個管師：這樣不錯，這樣可以做業務類別。民眾：嗯，業務。個管師：哦，業務。最近遇到好多業務。民眾：真的哦？個管師：對啊，我的學生都去做業務了，要不然都去做推銷。好哦，這個要給你簽名，因爲要本人同意。那你在哪間業務公司？民眾：三商美邦。個管師：那交友軟體都是固定在用一個還是好幾個交友軟體在用？民眾：一個。個管師：一個，然後上面的約，然後會無套嗎？民眾：不會。個管師：都會戴套？民眾：嗯。個管師：然後在約之前都會吃藥嗎？民眾：對，可是很久沒有了。個管師：很久沒有約，還是很久沒有吃藥？民眾：很久沒有約，也很久沒有吃。個管師：有時候工作忙真的是這樣子，回家累了就想睡覺了。你，你家裏大概有剩4罐哦？民眾：3，4罐應該有。個管師：有沒有3罐多，因爲你還是有在吃嘛，就是吃得比較少。好，那我跟你説今天會抽血，然後你下個禮拜問報告。對，然後接下來就是，如果你不要回診沒有關係。然後就是三個月要到匿篩。然後今天因爲會有抽血，領抽血單，所以我幫你部分補助300。那等一下那個收據要拿來給我。民眾：你説繳完費的時候？個管師：對，你就拿回來100診間就好了。因爲他要看這一張，所以不能機器繳費哦。民眾：好。個管師：然後今天就是幫你驗HIV，然後梅毒，肝腎功能這樣子，這樣ok，這個是今天抽因爲你今天可以抽。好，因爲今天是12號，還有一天。那你等下就是先去抽血，因爲就在那邊，抽完血後就去繳費再回來給我那個紅色收據。民眾：好。個管師：好，那一樣，保險套還是要戴著哦。民眾：ok。個管師：有任何問題就在line上詢問。民眾：好啊好啊。'

# %%
a[360:380]
# Out:
# '有剩4罐哦？民眾：3，4罐應該有。個管師'

# %%
b='醫師：有LONGTIME嗎，還好啦誒兩個多月一點點？民眾：對。醫師：喔OK好，阿最近還好嗎？民眾：還不錯。醫師：所以你現在藥是天天吃還是吃任務型？民眾：任務型。醫師：現在吃任務型，什麼時候開始改任務型的阿？民眾：很久了誒。醫師：已經很久了？民眾：對阿。醫師：所以已經好幾個月？民眾：一兩個月了。醫師：恩亨，所以你現在手上剩多少藥？民眾：一瓶多。醫師：剩一瓶多？民眾：對，省省地用。醫師：喔ok。民眾：呵呵呵～醫師：好啦不過你省省地用所以都通常都是用在什麼時候？民眾：跟男朋友的時候啊，哈哈哈～醫師：沒有其他的那個對象？民眾：沒有，沒有。醫師：喔。民眾：而且男朋友現在兩個禮拜才回來一次而已。醫師：喔。民眾：他搬回新竹。醫師：喔齁。民眾：陪爺爺。醫師：喔新竹也不遠啊，鹿港比較遠一點�
樣子。民眾：好。醫師：是，好，你會很擔心你伴侶有其他的伴侶嗎？民眾：不會。醫師：不會？民眾：因為他每天上班都在……醫師：都累死了？民眾：都很累。醫師：喔OK。民眾：對阿，他每天都加班。醫師：好，好喔那聽起來還不錯，誒你交往多久了啊？民眾：我跟他多久了？醫師：恩。民眾：四年多了。醫師：喔OK，聽說超過兩年就……就已經很厲害了。民眾：真的嗎？醫師：哈哈哈～民眾：我第一任五年誒。醫師：哇，哇所以你很早就已經開始？民眾：17歲，呵呵呵～。醫師：呵呵呵～民眾：17歲。醫師：OK，好啦那就……就這樣囉？民眾：好。醫師：好，好啊還有沒有什麼事情要問我的？民眾：沒有，誒那下次還需要回診嗎？醫師：下次就暫時先不用了。民眾：下次就暫時先不用？醫師：對對對，啊你的病歷表在這裡，王小陸2735，要拿出去。民眾：好。'

# %%
b[690:720]
# Out:
# '下是沒有關係。民眾：好。醫師：阿反正你就記得自己30這個數字'

# %% [markdown]
# # time

# %%
time_context_test_final = []
for idx, private_type in enumerate(private_types):
    private_time_art_id = []
    if private_type == 'time':
        private_time_art_id.append(test_predict_final['entity_text'][idx])
        private_time_art_id.append(test_predict_final['article_id'][idx])
        private_time_art_id.append(test_predict_final['start_position'][idx])
        
        time_context_test_final.append(private_time_art_id)

# %%
time_context_test_final[:1500]
# Out:
# [['今年', 0, 295],
#  ['今天', 1, 31],
#  ['昨天', 1, 40],
#  ['四個月前', 1, 414],
#  ['三個月', 1, 469],
#  ['中午', 1, 742],
#  ['21', 1, 873],
#  ['12天', 1, 881],
#  ['12天', 1, 890],
#  ['三個星期', 1, 902],
#  ['三個月', 2, 390],
#  ['三個月', 2, 402],
#  ['兩個月', 2, 792],
#  ['國中', 2, 1202],
#  ['35', 2, 1246],
#  ['國中', 2, 1310],
#  ['今天', 2, 1406],
#  ['昨天', 3, 6],
#  ['一天', 3, 11],
#  ['今天早上', 3, 43],
#  ['昨天', 3, 221],
#  ['早上', 3, 225],
#  ['一天', 3, 232],
#  ['今天早上', 3, 263],
#  ['前天', 3, 538],
#  ['昨天', 3, 643],
#  ['昨天', 3, 662],
#  ['今天', 3, 673],
#  ['今天', 3, 748],
#  ['今天', 3, 817],
#  ['今天', 3, 821],
#  ['禮拜二', 3, 867],
#  ['禮拜三', 3, 871],
#  ['今年', 4, 24],
#  ['今天', 4, 45],
#  ['8月13號', 4, 187],
#  ['三個禮', 4, 365],
#  ['三個月', 4, 369],
#  ['半年', 4, 426],
#  ['半年', 4, 436],
#  ['31歲', 4, 495],
#  ['四月', 5, 53],
#  ['今天', 5, 697],
#  ['10月25號', 5, 726],
#  ['兩個月', 5, 1010],
#  ['兩個月', 5, 1035],
#  ['10月25號', 5, 1051],
#  ['10月底', 5, 1139],
#  ['11月初', 5, 1148],
#  ['兩個', 5, 1167],
# ...

# %%
'location': 176,
 'time': 2231,
 'med_exam': 451,
 'name': 261,
 'money': 146,
 'family': 41,
 'ID': 32,
 'contact': 51,
 'profession': 37,
 'education': 4}
