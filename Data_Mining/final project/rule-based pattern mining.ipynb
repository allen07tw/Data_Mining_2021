# %%
import re

# %%
len(new_rule_add_list)

# %%
all_regexes_4 = {#73
    'time': [
        re.compile(r'農曆除夕|除夕|春節|兒童節|民族掃墓節|清明|清明節|勞動節|浴佛節|佛陀誕辰紀念日|端午節|軍人節|中秋節|孔子誕辰紀念日|教師節|中華民國國慶日|國慶日|聖誕節|聖誕|母親節|父親節|七夕|中元節|盂蘭盆節|中元普渡|七夕情人節|情人節|白色情人節|重陽節|重陽|冬至|爸爸節|母親節|父親節|萬聖節|耶誕節|雙十節|元旦跨年|元旦|跨年|西洋情人節|過年|農曆春節|感恩節|聖誕夜|農曆七夕'),
#         acc=0.68 >> [17]/[25]
#         expected real label: 12.24
#         model test pred:  16
#         raw test raw:  18
#         acc=0.0 >> [0]/[8]
        re.compile(r'((?:上|下|這|每)個?)?(星期|禮拜|周)([一二三四五六日天、]{1,})(早上|下午|晚上)?(?:(一|二|三|四|五|六|七|八|九|十|十一|十二|[0-9]|10|11|12)|(1[3-9])|(2[0-4])|(十[三四五六七八九])|(二[十一二三四]))?(點)?(鐘|半|多)?'),   #(?:(一|二|三|四|五|(1[3-9])|([二三四五]?(十)?[零一二三四五六七八九])?(分)?                  
#         acc=0.7973950795947902 >> [551]/[691]
#         expected real label: 422.6193921852388
#         model test pred:  473
#         raw test raw:  530
#         acc=0.6987951807228916 >> [58]/[83]
#         expected real label: 157.22891566265062
#         model test pred:  204
#         raw test raw:  225
        re.compile(r'([1-5]?[0-9]|[二三四五]?十?[一二三四五六七八九十])(分)(鐘)'),
#         acc=0.8 >> [4]/[5]
#         expected real label: 4.0
#         model test pred:  5
#         raw test raw:  5
#         acc=0.0 >> [0]/[1]
#         expected real label: 0.0
#         model test pred:  5
#         raw test raw:  5
#         acc=
        
    ],
    
    'family': [
#         re.compile('(我)?(爸爸|媽媽|哥哥|叔叔|大姊|親戚|外公|外婆|爺爺|奶奶|表姊|表哥|表妹|表弟|堂哥|堂弟|堂姊|堂妹|孫子|孫女|阿公|弟弟|妹妹|姑姑|嬸嬸|舅舅|公公|婆婆|岳父|岳母|嫂嫂|媳婦|姪子|姪女|侄兒|弟妹|丈夫|妻子|祖母|祖父|伯公|伯祖|伯翁|叔公|叔祖|叔翁|伯婆|伯祖母|叔婆|叔祖母|太婆|伯母|叔母|外祖父|外祖母|舅媽|岳丈|弟媳|女婿|外孫|伯父|伯母|丈夫|姨丈|阿姨|外甥|外甥女|外甥孫|外甥孫女|外孫|外孫女|父親|母親|大伯)'),
#         acc=0.46464646464646464 >> [46]/[99]
#         expected real label: 23.232323232323232
#         model test pred:  35
#         raw test raw:  50
#         acc=0.029411764705882353 >> [1]/[34]
#         expected real label: 1.0
#         model test pred:  24
#         raw test raw:  34
#         acc=0.5074626865671642 >> [34]/[67]
        
        
#         re.compile('老[二三四五六七八九十]'),
#         acc=1.0 >> [2]/[2]
#         expected real label: 0.0
#         model test pred:  0
#         raw test raw:  0
        
        re.compile('([二三四五六七八九十大小])?(女兒|兒子)'),
#         acc=0.42105263157894735 >> [8]/[19]
#         expected real label: 8.421052631578947
#         model test pred:  19
#         raw test raw:  20
        
#         re.compile('(大)(哥|姐|姊)'),
#         acc=1.0 >> [3]/[3]
#         expected real label: 1.0
#         model test pred:  1
#         raw test raw:  1
#         acc=0.0 >> [0]/[11]
        
        re.compile('(爸爸|媽媽|哥哥|叔叔|大姊|親戚|外公|外婆|爺爺|奶奶|表姊|表哥|表妹|表弟|堂哥|堂弟|堂姊|堂妹|孫子|孫女|阿公|弟弟|妹妹|姑姑|嬸嬸|舅舅|公公|婆婆|岳父|岳母|嫂嫂|媳婦|姪子|姪女|侄兒|弟妹|丈夫|妻子|祖母|祖父|伯公|伯祖|伯翁|叔公|叔祖|叔翁|伯婆|伯祖母|叔婆|叔祖母|太婆|伯母|叔母|外祖父|外祖母|舅媽|岳丈|弟媳|女婿|外孫|伯父|伯母|丈夫|姨丈|外甥|外甥女|外甥孫|外甥孫女|外孫|外孫女|父親|母親|大伯)'),
#         acc=0.6296296296296297 >> [34]/[54]
#         expected real label: 15.11111111111111
#         model test pred:  21
#         raw test raw:  24
        
    ],
    
    'med_exam': [
        re.compile(r'\d+公斤'),  
    ],
    
    'contact': [
        re.compile(r'09[0-9]{8}'),
#         acc=1.0 >> [3]/[3]
#         expected real label: 3.0       
#         model test pred:  3
#         raw test raw:  3
        
        re.compile(r'mail|email|LINE|Grindr|Hornet|Surge|MEEFF|blued|Blued|Scruff|Jack’d|Tinder|Skout|LOVOO|Badoo|SweetRing|Paktor|緣圈|Pairs派愛族|Pairs|派愛族|OkCupid|weTouch|Omi|Aimm|meettheone|心理學交友|探探|Tantan|Bumble|咖啡遇上貝果|Coffee Meets Bagel|Goodnight|Partido|交杯酒|JustDating|Pikabu|皮卡布|slowly|wootalk|Cheers|WeDate|Eatgether|Rooit|Messenger|Facebook|Line|Telegram|WhatsApp|Signal', re.IGNORECASE),
#         acc=0.923
#         expected real label: 26.76923076923077
#         model test pred:  26
#         raw test raw:  29
#         acc=0.9230769230769231 >> [36]/[39]
#         expected real label: 26.76923076923077
#         model test pred:  25
#         raw test raw:  29
#         re.compile(r'(https?:\/\/)?(www\.)?[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)/[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)', re.IGNORECASE),
        re.compile(r'(http:\/\/www\.|https:\/\/www\.|http:\/\/|https:\/\/|www\.)([a-z0-9]+([\-\.]{1}[a-z0-9]+)*\.)([a-z]{2,5}(:[0-9]{1,5})?(\/.*)?)', re.IGNORECASE)
#         acc=1.0 >> [1]/[1]
#         expected real label: 1.0
#         model test pred:  1
#         raw test raw:  1
    ],
    
    'ID': [
        re.compile(r'[A-Z][0-9]{9}', re.IGNORECASE),
#         acc=0.0
#         expected real label: 0.0
#         model test pred:  18
#         raw test raw:  20
        re.compile(r'第(\d|[二三四五六七八九]?十?[一二三四五六七八九十])+(號)'),
#         acc=1.0 >> [5]/[5] 原文標錯
#         expected real label: 1.0
#         model test pred:  1
#         raw test raw:  1
#         acc=0.0
#         expected real label: 0.0
#         model test pred:  9
#         raw test raw:  20
#         re.compile(r'(\d|[一二三四五六七八九]?百?[二三四五六七八九]?十?[一二三四五六七八九十])+(號)'),#[\u4e00-\u8b1c\u8b1e-\u9fcc]
#         acc=0.7865853658536586 >> [258]/[328]
#         expected real label: 158.10365853658539
#         model test pred:  170
#         raw test raw:  201
#         acc=0.017605633802816902 >> [5]/[284]
#         acc=0.0071174377224199285 >> [2]/[281]
#         expected real label: 1.2241992882562276
#         model test pred:  0
#         raw test raw:  172
#         acc=0.017605633802816902 >> [5]/[284]
        
    ],
    
    'name': [
        re.compile(r'(王|李|張|劉|陳|楊|黃|趙|吳|周|徐|孫|馬|朱|胡|郭|何|高|林|鄭|羅|梁|宋|唐|許|韓|馮|鄧|曹|彭|曾|蕭|田|董|袁|潘|於|蔣|蔡|余|杜|葉|程|蘇|魏|呂|丁|任|沈|姚|盧|姜|崔|鍾|譚|陸|汪|范|金|石|廖|賈|夏|韋|付|方|白|鄒|孟|熊|秦|邱|江|尹|薛|閆|段|雷|侯|龍|史|陶|黎|賀|顧|毛|郝|龔|邵|萬|錢|嚴|覃|武|戴|莫|孔|向|湯)([\u4e00-\u8b1c\u8b1e-\u9fcc]{0,3})(醫生|醫師|先生|小姐|女士|同學)'),
#         acc=0.8689655172413793 >> [126]/[145]
#         expected real label: 132.95172413793102
#         model test pred:  153
#         raw test raw:  153
#         re.compile(r'(mr|dr|miss|mrs)?(James|David|Christopher|George|Ronald|John|Richard|Daniel|Kenneth|Anthony|Robert|Charles|Paul|Steven|Kevin|Michael|Joseph|Mark|Edward|Jason|William|Thomas|Donald|Brian|Jeff|Jason|Kevin|Eric|Alex|Jerry|Andy|Jack|Allen|Vincent|Sam|Ken|Chris|Tony|Leo|Peter|Ryan|Emily|Amy|Alice|Grace|Tina|Joyce|Vivian|Cindy|Ivy|Jenny|Claire|Annie|Vicky|Jessica|Peggy|Sandy|Irene|Iris|Maggie|WinnieMary|Jennifer|Lisa|Sandra|Michelle|Patricia|Maria|Nancy|Donna|Laura|Linda|Susan|Karen|Carol|Sarah|Barbara|Margaret|Betty|Ruth|Kimberly|Elizabeth|Dorothy|Helen|Sharon|Deborah)', re.IGNORECASE),
#         acc=0.0 >> [0]/[1]
#         expected real label: 0.0
#         model test pred:  0
#         raw test raw:
.compile(r'(亞洲|非洲|歐洲|美洲|南極洲|大洋洲|北美洲|中南美洲|南美洲|中美洲|阿富汗|奧蘭群島|阿爾巴尼亞|阿爾及利亞|美屬薩摩亞|安道爾|安哥拉|安圭拉|南極洲|安提瓜和巴布達|阿根廷|亞美尼亞|阿魯巴|澳大利亞|奧地利|阿塞拜疆|巴哈馬|巴林|孟加拉國|巴巴多斯|白俄羅斯|比利時|貝寧|百慕大|不丹|玻利維亞|波斯尼亞和黑塞哥維那|博茨瓦納|布韋島|巴西|英國印度洋領地|英屬維爾京群島|文萊|布基納|基那納基索|布隆迪|哥倫比亞加拿大|佛得角|加勒比海|開曼群島|中非共和國|乍得|智利|中國|聖誕節島|科克斯（基靈）群島|哥倫比亞|科摩羅|布拉索維爾，剛果|金沙薩，剛果|剛果|庫克群島|哥斯達黎加|科特迪瓦科特迪瓦|克羅地亞|克羅地亞|古巴|庫拉索島|塞浦路斯|捷克共和國|捷克共和國|丹麥|吉布提|多米尼加|多米尼加共和國|厄瓜多爾|埃及|薩爾瓦多|赤道|厄立特里亞|愛沙尼亞|埃斯瓦蒂尼|埃塞俄比亞|法羅群島芬蘭|法國|法屬圭亞那|法屬波利尼西亞|加蓬|岡比亞|喬治亞州|德國|加納|加納巴拉塔|希臘|格陵蘭|格林納達|關島|瓜德羅普島關島|瓜亞瓜根西島|幾內亞|幾內亞比紹|圭亞那|海地|希爾德和麥當勞群島|洪都拉斯|香港特別行政區|匈牙利|冰島|印度尼西亞|印度尼西亞|伊朗|伊拉克|伊拉克|愛爾蘭|曼島|以色列|意大利|牙買加|日本|澤西|約旦|哈薩克斯坦|肯尼亞|基里巴斯-科威特|吉爾吉斯斯坦|老撾|拉脫維亞|黎巴嫩|萊索托|利比里亞|利比亞|利希斯坦|中國澳門特別行政區|馬達加斯加|馬拉維|馬來西亞|馬爾代夫和馬紹爾群島|馬提尼克島|毛里求斯|毛里求斯|馬約特島|墨西哥|密克羅尼西亞|摩爾多瓦蒙古|黑山|蒙特塞拉特|沿海地區|蒙特塞拉特|摩洛哥|莫桑比克|緬甸|尼泊爾荷蘭|荷蘭|新喀裡多尼亞|新西蘭|尼加拉瓜|尼日爾|尼日利亞|紐埃|諾福克島|北朝鮮|馬其頓|北馬里亞納群島|挪威|阿曼|巴基斯坦|帕勞|巴勒斯坦領土|巴拿馬|巴布亞新幾內亞|巴拉圭|秘魯|菲律賓|皮特凱恩群島|波蘭|葡萄牙|波多黎各|卡塔爾|留尼汪|羅躁狂症|俄羅斯|盧旺達|薩摩亞|聖馬力諾|聖多美和普林西比|沙特阿拉伯|塞內加爾|塞爾維亞|塞舌爾|塞拉利昂|新加坡|聖馬丁|斯洛伐克|斯洛伐克|斯洛文尼亞|所羅門群島|索馬里|南非|喬治亞州和南桑威奇群島|韓國|南蘇丹|西班牙|斯里蘭卡|聖基茨和尼維斯|聖盧西亞|馬丁|聖皮埃爾和密克隆群島|聖文森特和格林納丁斯|蘇丹|蘇里南|斯瓦爾巴特和揚馬延|瑞典|瑞士|敘利亞|塔吉克斯坦|坦桑尼亞|泰國|東帝汶-多哥|托克羅|湯加|特立尼達和多巴哥|突尼斯|土耳其|土庫曼斯坦|特克斯和凱科斯群島|圖瓦盧|美國離島群島|美屬維爾京群島|烏干達|烏克蘭|阿聯酋|英國|烏拉圭|烏茲別克斯坦|瓦努阿圖|梵蒂岡|委內瑞拉|越南|沃利斯和富圖納群島|西撒哈拉|也門|贊比亞|津巴布韋|澳門)'),
#         去哪裡，哪個國家的藥，在哪裡，在哪裡的藥
#         acc=0.6721311475409836 >> [41]/[61]
#         expected real label: 26.21311475409836
#         model test pred:  22
#         raw test raw:  39
#         acc=0.8181818181818182 >> [36]/[44]
#         expected real label: 31.90909090909091
#         model test pred:  22
#         raw test raw:  39
#         re.compile(r''),
        
        
    ],
    
#     'name': [
#         re.compile(r''),
#         re.compile(r''),
#         re.compile(r''),
#         re.compile(r''),
#         re.compile(r''),
        
        
#     ],
    
}

# %%
all_regexes_3 = {#73
    'time': [
        re.compile(r'農曆除夕|除夕|春節|兒童節|民族掃墓節|清明|清明節|勞動節|浴佛節|佛陀誕辰紀念日|端午節|軍人節|中秋節|孔子誕辰紀念日|教師節|中華民國國慶日|國慶日|聖誕節|聖誕|母親節|父親節|七夕|中元節|盂蘭盆節|中元普渡|七夕情人節|情人節|白色情人節|重陽節|重陽|冬至|爸爸節|母親節|父親節|萬聖節|耶誕節|雙十節|元旦跨年|元旦|跨年|西洋情人節|過年|農曆春節|感恩節|聖誕夜|農曆七夕'),
#         acc=0.68 >> [17]/[25]
#         expected real label: 12.24
#         model test pred:  16
#         raw test raw:  18
#         acc=0.0 >> [0]/[8]
        re.compile(r'((?:上|下|這|每)個?)?(星期|禮拜|周)([一二三四五六日天、]{1,})(早上|下午|晚上)?(?:(一|二|三|四|五|六|七|八|九|十|十一|十二|[0-9]|10|11|12)|(1[3-9])|(2[0-4])|(十[三四五六七八九])|(二[十一二三四]))?(點)?(鐘|半|多)?'),   #(?:(一|二|三|四|五|(1[3-9])|([二三四五]?(十)?[零一二三四五六七八九])?(分)?                  
#         acc=0.7973950795947902 >> [551]/[691]
#         expected real label: 422.6193921852388
#         model test pred:  473
#         raw test raw:  530
#         acc=0.6987951807228916 >> [58]/[83]
#         expected real label: 157.22891566265062
#         model test pred:  204
#         raw test raw:  225
        re.compile(r'([1-5]?[0-9]|[二三四五]?十?[一二三四五六七八九十])(分)(鐘)'),
#         acc=0.8 >> [4]/[5]
#         expected real label: 4.0
#         model test pred:  5
#         raw test raw:  5
#         acc=0.0 >> [0]/[1]
#         expected real label: 0.0
#         model test pred:  5
#         raw test raw:  5
#         acc=
        
    ],
    
    'family': [
        re.compile('(我)?(爸爸|媽媽|哥哥|叔叔|大姊|親戚|外公|外婆|爺爺|奶奶|表姊|表哥|表妹|表弟|堂哥|堂弟|堂姊|堂妹|孫子|孫女|阿公|弟弟|妹妹|姑姑|嬸嬸|舅舅|公公|婆婆|岳父|岳母|嫂嫂|媳婦|姪子|姪女|侄兒|弟妹|丈夫|妻子|祖母|祖父|伯公|伯祖|伯翁|叔公|叔祖|叔翁|伯婆|伯祖母|叔婆|叔祖母|太婆|伯母|叔母|外祖父|外祖母|舅媽|岳丈|弟媳|女婿|外孫|伯父|伯母|丈夫|姨丈|阿姨|外甥|外甥女|外甥孫|外甥孫女|外孫|外孫女|父親|母親|大伯)'),
#         acc=0.46464646464646464 >> [46]/[99]
#         expected real label: 23.232323232323232
#         model test pred:  35
#         raw test raw:  50
#         acc=0.029411764705882353 >> [1]/[34]
#         expected real label: 1.0
#         model test pred:  24
#         raw test raw:  34
#         acc=0.5074626865671642 >> [34]/[67]
        
        
#         re.compile('老[二三四五六七八九十]'),
#         acc=1.0 >> [2]/[2]
#         expected real label: 0.0
#         model test pred:  0
#         raw test raw:  0
        
        re.compile('([二三四五六七八九十大小])?(女兒|兒子)'),
#         acc=0.42105263157894735 >> [8]/[19]
#         expected real label: 8.421052631578947
#         model test pred:  19
#         raw test raw:  20
        
#         re.compile('(大)(哥|姐|姊)'),
#         acc=1.0 >> [3]/[3]
#         expected real label: 1.0
#         model test pred:  1
#         raw test raw:  1
#         acc=0.0 >> [0]/[11]
        
        re.compile('(爸爸|媽媽|哥哥|叔叔|大姊|親戚|外公|外婆|爺爺|奶奶|表姊|表哥|表妹|表弟|堂哥|堂弟|堂姊|堂妹|孫子|孫女|阿公|弟弟|妹妹|姑姑|嬸嬸|舅舅|公公|婆婆|岳父|岳母|嫂嫂|媳婦|姪子|姪女|侄兒|弟妹|丈夫|妻子|祖母|祖父|伯公|伯祖|伯翁|叔公|叔祖|叔翁|伯婆|伯祖母|叔婆|叔祖母|太婆|伯母|叔母|外祖父|外祖母|舅媽|岳丈|弟媳|女婿|外孫|伯父|伯母|丈夫|姨丈|外甥|外甥女|外甥孫|外甥孫女|外孫|外孫女|父親|母親|大伯)'),
#         acc=0.6296296296296297 >> [34]/[54]
#         expected real label: 15.11111111111111
#         model test pred:  21
#         raw test raw:  24
        
    ],
    
    'med_exam': [
        re.compile(r'\d+公斤'),  
    ],
    
    'contact': [
        re.compile(r'09[0-9]{8}'),
#         acc=1.0 >> [3]/[3]
#         expected real label: 3.0       
#         model test pred:  3
#         raw test raw:  3
        
        re.compile(r'mail|email|LINE|Grindr|Hornet|Surge|MEEFF|blued|Blued|Scruff|Jack’d|Tinder|Skout|LOVOO|Badoo|SweetRing|Paktor|緣圈|Pairs派愛族|Pairs|派愛族|OkCupid|weTouch|Omi|Aimm|meettheone|心理學交友|探探|Tantan|Bumble|咖啡遇上貝果|Coffee Meets Bagel|Goodnight|Partido|交杯酒|JustDating|Pikabu|皮卡布|slowly|wootalk|Cheers|WeDate|Eatgether|Rooit|Messenger|Facebook|Line|Telegram|WhatsApp|Signal', re.IGNORECASE),
#         acc=0.923
#         expected real label: 26.76923076923077
#         model test pred:  26
#         raw test raw:  29
#         acc=0.9230769230769231 >> [36]/[39]
#         expected real label: 26.76923076923077
#         model test pred:  25
#         raw test raw:  29
#         re.compile(r'(https?:\/\/)?(www\.)?[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)/[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)', re.IGNORECASE),
        re.compile(r'(http:\/\/www\.|https:\/\/www\.|http:\/\/|https:\/\/|www\.)([a-z0-9]+([\-\.]{1}[a-z0-9]+)*\.)([a-z]{2,5}(:[0-9]{1,5})?(\/.*)?)', re.IGNORECASE)
#         acc=1.0 >> [1]/[1]
#         expected real label: 1.0
#         model test pred:  1
#         raw test raw:  1
    ],
    
    'ID': [
        re.compile(r'[A-Z][0-9]{9}', re.IGNORECASE),
#         acc=0.0
#         expected real label: 0.0
#         model test pred:  18
#         raw test raw:  20
        re.compile(r'第(\d|[二三四五六七八九]?十?[一二三四五六七八九十])+(號)'),
#         acc=1.0 >> [5]/[5] 原文標錯
#         expected real label: 1.0
#         model test pred:  1
#         raw test raw:  1
#         acc=0.0
#         expected real label: 0.0
#         model test pred:  9
#         raw test raw:  20
#         re.compile(r'(\d|[一二三四五六七八九]?百?[二三四五六七八九]?十?[一二三四五六七八九十])+(號)'),#[\u4e00-\u8b1c\u8b1e-\u9fcc]
#         acc=0.7865853658536586 >> [258]/[328]
#         expected real label: 158.10365853658539
#         model test pred:  170
#         raw test raw:  201
#         acc=0.017605633802816902 >> [5]/[284]
#         acc=0.0071174377224199285 >> [2]/[281]
#         expected real label: 1.2241992882562276
#         model test pred:  0
#         raw test raw:  172
#         acc=0.017605633802816902 >> [5]/[284]
        
    ],
    
    'name': [
        re.compile(r'(王|李|張|劉|陳|楊|黃|趙|吳|周|徐|孫|馬|朱|胡|郭|何|高|林|鄭|羅|梁|宋|唐|許|韓|馮|鄧|曹|彭|曾|蕭|田|董|袁|潘|於|蔣|蔡|余|杜|葉|程|蘇|魏|呂|丁|任|沈|姚|盧|姜|崔|鍾|譚|陸|汪|范|金|石|廖|賈|夏|韋|付|方|白|鄒|孟|熊|秦|邱|江|尹|薛|閆|段|雷|侯|龍|史|陶|黎|賀|顧|毛|郝|龔|邵|萬|錢|嚴|覃|武|戴|莫|孔|向|湯)([\u4e00-\u8b1c\u8b1e-\u9fcc]{0,3})(醫生|醫師|先生|小姐|女士|同學)'),
#         acc=0.8689655172413793 >> [126]/[145]
#         expected real label: 132.95172413793102
#         model test pred:  153
#         raw test raw:  153
#         re.compile(r'(mr|dr|miss|mrs)?(James|David|Christopher|George|Ronald|John|Richard|Daniel|Kenneth|Anthony|Robert|Charles|Paul|Steven|Kevin|Michael|Joseph|Mark|Edward|Jason|William|Thomas|Donald|Brian|Jeff|Jason|Kevin|Eric|Alex|Jerry|Andy|Jack|Allen|Vincent|Sam|Ken|Chris|Tony|Leo|Peter|Ryan|Emily|Amy|Alice|Grace|Tina|Joyce|Vivian|Cindy|Ivy|Jenny|Claire|Annie|Vicky|Jessica|Peggy|Sandy|Irene|Iris|Maggie|WinnieMary|Jennifer|Lisa|Sandra|Michelle|Patricia|Maria|Nancy|Donna|Laura|Linda|Susan|Karen|Carol|Sarah|Barbara|Margaret|Betty|Ruth|Kimberly|Elizabeth|Dorothy|Helen|Sharon|Deborah)', re.IGNORECASE),
#         acc=0.0 >> [0]/[1]
#         expected real label: 0.0
#         model test pred:  0
#         raw test raw:
#         acc=0.851063829787234 >> [80]/[94]
#         expected real label: 37.4468085106383
#         model test pred:  35
#         raw test raw:  44
#         acc=0.9634146341463414 >> [79]/[82]
#         expected real label: 34.68292682926829
#         model test pred:  34
#         raw test raw:  36
        re.compile(r'(亞洲|非洲|歐洲|美洲|南極洲|大洋洲|北美洲|中南美洲|南美洲|中美洲|阿富汗|奧蘭群島|阿爾巴尼亞|阿爾及利亞|美屬薩摩亞|安道爾|安哥拉|安圭拉|南極洲|安提瓜和巴布達|阿根廷|亞美尼亞|阿魯巴|澳大利亞|奧地利|阿塞拜疆|巴哈馬|巴林|孟加拉國|巴巴多斯|白俄羅斯|比利時|貝寧|百慕大|不丹|玻利維亞|波斯尼亞和黑塞哥維那|博茨瓦納|布韋島|巴西|英國印度洋領地|英屬維爾京群島|文萊|布基納|基那納基索|布隆迪|哥倫比亞加拿大|佛得角|加勒比海|開曼群島|中非共和國|乍得|智利|中國|聖誕節島|科克斯（基靈）群島|哥倫比亞|科摩羅|布拉索維爾，剛果|金沙薩，剛果|剛果|庫克群島|哥斯達黎加|科特迪瓦科特迪瓦|克羅地亞|克羅地亞|古巴|庫拉索島|塞浦路斯|捷克共和國|捷克共和國|丹麥|吉布提|多米尼加|多米尼加共和國|厄瓜多爾|埃及|薩爾瓦多|赤道|厄立特里亞|愛沙尼亞|埃斯瓦蒂尼|埃塞俄比亞|法羅群島芬蘭|法國|法屬圭亞那|法屬波利尼西亞|加蓬|岡比亞|喬治亞州|德國|加納|加納巴拉塔|希臘|格陵蘭|格林納達|關島|瓜德羅普島關島|瓜亞瓜根西島|幾內亞|幾內亞比紹|圭亞那|海地|希爾德和麥當勞群島|洪都拉斯|香港特別行政區|匈牙利|冰島|印度尼西亞|印度尼西亞|伊朗|伊拉克|伊拉克|愛爾蘭|曼島|以色列|意大利|牙買加|日本|澤西|約旦|哈薩克斯坦|肯尼亞|基里巴斯-科威特|吉爾吉斯斯坦|老撾|拉脫維亞|黎巴嫩|萊索托|利比里亞|利比亞|利希斯坦|中國澳門特別行政區|馬達加斯加|馬拉維|馬來西亞|馬爾代夫和馬紹爾群島|馬提尼克島|毛里求斯|毛里求斯|馬約特島|墨西哥|密克羅尼西亞|摩爾多瓦蒙古|黑山|蒙特塞拉特|沿海地區|蒙特塞拉特|摩洛哥|莫桑比克|緬甸|尼泊爾荷蘭|荷蘭|新喀裡多尼亞|新西蘭|尼加拉瓜|尼日爾|尼日利亞|紐埃|諾福克島|北朝鮮|馬其頓|北馬里亞納群島|挪威|阿曼|巴基斯坦|帕勞|巴勒斯坦領土|巴拿馬|巴布亞新幾內亞|巴拉圭|秘魯|菲律賓|皮特凱恩群島|波蘭|葡萄牙|波多黎各|卡塔爾|留尼汪|羅躁狂症|俄羅斯|盧旺達|薩摩亞|聖馬力諾|聖多美和普林西比|沙特阿拉伯|塞內加爾|塞爾維亞|塞舌爾|塞拉利昂|新加坡|聖馬丁|斯洛伐克|斯洛伐克|斯洛文尼亞|所羅門群島|索馬里|南非|喬治亞州和南桑威奇群島|韓國|南蘇丹|西班牙|斯里蘭卡|聖基茨和尼維斯|聖盧西亞|馬丁|聖皮埃爾和密克隆群島|聖文森特和格林納丁斯|蘇丹|蘇里南|斯瓦爾巴特和揚馬延|瑞典|瑞士|敘利亞|塔吉克斯坦|坦桑尼亞|泰國|東帝汶-多哥|托克羅|湯加|特立尼達和多巴哥|突尼斯|土耳其|土庫曼斯坦|特克斯和凱科斯群島|圖瓦盧|美國離島群島|美屬維爾京群島|烏干達|烏克蘭|阿聯酋|英國|烏拉圭|烏茲別克斯坦|瓦努阿圖|梵蒂岡|委內瑞拉|越南|沃利斯和富圖納群島|西撒哈拉|也門|贊比亞|津巴布韋|澳門)'),
#         去哪裡，哪個國家的藥，在哪裡，在哪裡的藥
#         acc=0.6721311475409836 >> [41]/[61]
#         expected real label: 26.21311475409836
#         model test pred:  22
#         raw test raw:  39
#         acc=0.8181818181818182 >> [36]/[44]
#         expected real label: 31.90909090909091
#         model test pred:  22
#         raw test raw:  39
#         re.compile(r''),
        
        
    ],
    
#     'name': [
#         re.compile(r''),
#         re.compile(r''),
#         re.compile(r''),
#         re.compile(r''),
#         re.compile(r''),
        
        
#     ],
    
}

# %%
all_regexes = {#73
    'time': [
        re.compile(r'農曆除夕|除夕|春節|兒童節|民族掃墓節|清明|清明節|勞動節|浴佛節|佛陀誕辰紀念日|端午節|軍人節|中秋節|孔子誕辰紀念日|教師節|中華民國國慶日|國慶日|聖誕節|聖誕|母親節|父親節|七夕|中元節|盂蘭盆節|中元普渡|七夕情人節|情人節|白色情人節|重陽節|重陽|冬至|爸爸節|母親節|父親節|萬聖節|耶誕節|雙十節|元旦跨年|元旦|跨年|西洋情人節|過年|農曆春節|感恩節|聖誕夜|農曆七夕'),
#         acc=0.68 >> [17]/[25]
#         expected real label: 12.24
#         model test pred:  16
#         raw test raw:  18
#         acc=0.0 >> [0]/[8]
        re.compile(r'((?:上|下|這|每)個?)?(星期|禮拜|周)([一二三四五六日天、]{1,})(早上|下午|晚上)?(?:(一|二|三|四|五|六|七|八|九|十|十一|十二|[0-9]|10|11|12)|(1[3-9])|(2[0-4])|(十[三四五六七八九])|(二[十一二三四]))?(點)?(鐘|半|多)?'),   #(?:(一|二|三|四|五|(1[3-9])|([二三四五]?(十)?[零一二三四五六七八九])?(分)?                  
#         acc=0.7973950795947902 >> [551]/[691]
#         expected real label: 422.6193921852388
#         model test pred:  473
#         raw test raw:  530
#         acc=0.6987951807228916 >> [58]/[83]
#         expected real label: 157.22891566265062
#         model test pred:  204
#         raw test raw:  225
        re.compile(r'([1-5]?[0-9]|[二三四五]?十?[一二三四五六七八九十])(分)(鐘)'),
#         acc=0.8 >> [4]/[5]
#         expected real label: 4.0
#         model test pred:  5
#         raw test raw:  5
#         acc=0.0 >> [0]/[1]
#         expected real label: 0.0
#         model test pred:  5
#         raw test raw:  5
#         acc=
        
    ],
    
    'family': [
        re.compile('(我)?(爸爸|媽媽|哥哥|叔叔|大姊|親戚|外公|外婆|爺爺|奶奶|表姊|表哥|表妹|表弟|堂哥|堂弟|堂姊|堂妹|孫子|孫女|阿公|弟弟|妹妹|姑姑|嬸嬸|舅舅|公公|婆婆|岳父|岳母|嫂嫂|媳婦|姪子|姪女|侄兒|弟妹|丈夫|妻子|祖母|祖父|伯公|伯祖|伯翁|叔公|叔祖|叔翁|伯婆|伯祖母|叔婆|叔祖母|太婆|伯母|叔母|外祖父|外祖母|舅媽|岳丈|弟媳|女婿|外孫|伯父|伯母|丈夫|姨丈|阿姨|外甥|外甥女|外甥孫|外甥孫女|外孫|外孫女|父親|母親|大伯)'),
#         acc=0.46464646464646464 >> [46]/[99]
#         expected real label: 23.232323232323232
#         model test pred:  35
#         raw test raw:  50
#         acc=0.029411764705882353 >> [1]/[34]
#         expected real label: 1.0
#         model test pred:  24
#         raw test raw:  34
#         acc=0.5074626865671642 >> [34]/[67]
        
        
#         re.compile('老[二三四五六七八九十]'),
#         acc=1.0 >> [2]/[2]
#         expected real label: 0.0
#         model test pred:  0
#         raw test raw:  0
        
        re.compile('([二三四五六七八九十大小])?(女兒|兒子)'),
#         acc=0.42105263157894735 >> [8]/[19]
#         expected real label: 8.421052631578947
#         model test pred:  19
#         raw test raw:  20
        
#         re.compile('(大)(哥|姐|姊)'),
#         acc=1.0 >> [3]/[3]
#         expected real label: 1.0
#         model test pred:  1
#         raw test raw:  1
#         acc=0.0 >> [0]/[11]
        
        re.compile('(爸爸|媽媽|哥哥|叔叔|大姊|親戚|外公|外婆|爺爺|奶奶|表姊|表哥|表妹|表弟|堂哥|堂弟|堂姊|堂妹|孫子|孫女|阿公|弟弟|妹妹|姑姑|嬸嬸|舅舅|公公|婆婆|岳父|岳母|嫂嫂|媳婦|姪子|姪女|侄兒|弟妹|丈夫|妻子|祖母|祖父|伯公|伯祖|伯翁|叔公|叔祖|叔翁|伯婆|伯祖母|叔婆|叔祖母|太婆|伯母|叔母|外祖父|外祖母|舅媽|岳丈|弟媳|女婿|外孫|伯父|伯母|丈夫|姨丈|外甥|外甥女|外甥孫|外甥孫女|外孫|外孫女|父親|母親|大伯)'),
#         acc=0.6296296296296297 >> [34]/[54]
#         expected real label: 15.11111111111111
#         model test pred:  21
#         raw test raw:  24
        
    ],
    
    'med_exam': [
        re.compile(r'\d+公斤'),  
    ],
    
    'contact': [
        re.compile(r'09[0-9]{8}'),
#         acc=1.0 >> [3]/[3]
#         expected real label: 3.0       
#         model test pred:  3
#         raw test raw:  3
        
        re.compile(r'mail|email|LINE|Grindr|Hornet|Surge|MEEFF|blued|Blued|Scruff|Jack’d|Tinder|Skout|LOVOO|Badoo|SweetRing|Paktor|緣圈|Pairs派愛族|Pairs|派愛族|OkCupid|weTouch|Omi|Aimm|meettheone|心理學交友|探探|Tantan|Bumble|咖啡遇上貝果|Coffee Meets Bagel|Goodnight|Partido|交杯酒|JustDating|Pikabu|皮卡布|slowly|wootalk|Cheers|WeDate|Eatgether|Rooit|Messenger|Facebook|Line|Telegram|WhatsApp|Signal', re.IGNORECASE),
#         acc=0.923
#         expected real label: 26.76923076923077
#         model test pred:  26
#         raw test raw:  29
#         acc=0.9230769230769231 >> [36]/[39]
#         expected real label: 26.76923076923077
#         model test pred:  25
#         raw test raw:  29
#         re.compile(r'(https?:\/\/)?(www\.)?[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)/[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)', re.IGNORECASE),
        re.compile(r'(http:\/\/www\.|https:\/\/www\.|http:\/\/|https:\/\/|www\.)([a-z0-9]+([\-\.]{1}[a-z0-9]+)*\.)([a-z]{2,5}(:[0-9]{1,5})?(\/.*)?)', re.IGNORECASE)
#         acc=1.0 >> [1]/[1]
#         expected real label: 1.0
#         model test pred:  1
#         raw test raw:  1
    ],
    
    'ID': [
        re.compile(r'[A-Z][0-9]{9}', re.IGNORECASE),
#         acc=0.0
#         expected real label: 0.0
#         model test pred:  18
#         raw test raw:  20
        re.compile(r'第(\d|[二三四五六七八九]?十?[一二三四五六七八九十])+(號)'),
#         acc=1.0 >> [5]/[5] 原文標錯
#         expected real label: 1.0
#         model test pred:  1
#         raw test raw:  1
#         acc=0.0
#         expected real label: 0.0
#         model test pred:  9
#         raw test raw:  20
#         re.compile(r'(\d|[一二三四五六七八九]?百?[二三四五六七八九]?十?[一二三四五六七八九十])+(號)'),#[\u4e00-\u8b1c\u8b1e-\u9fcc]
#         acc=0.7865853658536586 >> [258]/[328]
#         expected real label: 158.10365853658539
#         model test pred:  170
#         raw test raw:  201
#         acc=0.017605633802816902 >> [5]/[284]
#         acc=0.0071174377224199285 >> [2]/[281]
#         expected real label: 1.2241992882562276
#         model test pred:  0
#         raw test raw:  172
#         acc=0.017605633802816902 >> [5]/[284]
        
    ],
    
    'name': [
        re.compile(r'(王|李|張|劉|陳|楊|黃|趙|吳|周|徐|孫|馬|朱|胡|郭|何|高|林|鄭|羅|梁|宋|唐|許|韓|馮|鄧|曹|彭|曾|蕭|田|董|袁|潘|於|蔣|蔡|余|杜|葉|程|蘇|魏|呂|丁|任|沈|姚|盧|姜|崔|鍾|譚|陸|汪|范|金|石|廖|賈|夏|韋|付|方|白|鄒|孟|熊|秦|邱|江|尹|薛|閆|段|雷|侯|龍|史|陶|黎|賀|顧|毛|郝|龔|邵|萬|錢|嚴|覃|武|戴|莫|孔|向|湯)([\u4e00-\u8b1c\u8b1e-\u9fcc]{0,3})(醫生|醫師|先生|小姐|女士|同學)'),
#         acc=0.8689655172413793 >> [126]/[145]
#         expected real label: 132.95172413793102
#         model test pred:  153
#         raw test raw:  153
公市|馬公|三芝區|三芝|南化區|南化|士林區|士林|羅東鎮|羅東|蘆竹區|蘆竹|汐止區|汐止|關山鎮|關山|烈嶼鄉|烈嶼|土庫鎮|土庫|鹿谷鄉|鹿谷|田尾鄉|田尾|柳營區|柳營|小港區|小港|烏日區|烏日|北門區|北門|北屯區|北屯|北斗鎮|北斗|萬華區|萬華|金寧鄉|金寧|烏坵鄉|烏坵|泰武鄉|泰武|中區|中區|西嶼鄉|西嶼|通霄鎮|通霄|中山區|中山|永康區|永康|南港區|南港|大同區|大同)(國小|國中|高中|大學)?'),
#         acc=0.851063829787234 >> [80]/[94]
#         expected real label: 37.4468085106383
#         model test pred:  35
#         raw test raw:  44
#         acc=0.9634146341463414 >> [79]/[82]
#         expected real label: 34.68292682926829
#         model test pred:  34
#         raw test raw:  36
        re.compile(r'(亞洲|非洲|歐洲|美洲|南極洲|大洋洲|北美洲|中南美洲|南美洲|中美洲|阿富汗|奧蘭群島|阿爾巴尼亞|阿爾及利亞|美屬薩摩亞|安道爾|安哥拉|安圭拉|南極洲|安提瓜和巴布達|阿根廷|亞美尼亞|阿魯巴|澳大利亞|奧地利|阿塞拜疆|巴哈馬|巴林|孟加拉國|巴巴多斯|白俄羅斯|比利時|貝寧|百慕大|不丹|玻利維亞|波斯尼亞和黑塞哥維那|博茨瓦納|布韋島|巴西|英國印度洋領地|英屬維爾京群島|文萊|布基納|基那納基索|布隆迪|哥倫比亞加拿大|佛得角|加勒比海|開曼群島|中非共和國|乍得|智利|中國|聖誕節島|科克斯（基靈）群島|哥倫比亞|科摩羅|布拉索維爾，剛果|金沙薩，剛果|剛果|庫克群島|哥斯達黎加|科特迪瓦科特迪瓦|克羅地亞|克羅地亞|古巴|庫拉索島|塞浦路斯|捷克共和國|捷克共和國|丹麥|吉布提|多米尼加|多米尼加共和國|厄瓜多爾|埃及|薩爾瓦多|赤道|厄立特里亞|愛沙尼亞|埃斯瓦蒂尼|埃塞俄比亞|法羅群島芬蘭|法國|法屬圭亞那|法屬波利尼西亞|加蓬|岡比亞|喬治亞州|德國|加納|加納巴拉塔|希臘|格陵蘭|格林納達|關島|瓜德羅普島關島|瓜亞瓜根西島|幾內亞|幾內亞比紹|圭亞那|海地|希爾德和麥當勞群島|洪都拉斯|香港特別行政區|匈牙利|冰島|印度尼西亞|印度尼西亞|伊朗|伊拉克|伊拉克|愛爾蘭|曼島|以色列|意大利|牙買加|日本|澤西|約旦|哈薩克斯坦|肯尼亞|基里巴斯-科威特|吉爾吉斯斯坦|老撾|拉脫維亞|黎巴嫩|萊索托|利比里亞|利比亞|利希斯坦|中國澳門特別行政區|馬達加斯加|馬拉維|馬來西亞|馬爾代夫和馬紹爾群島|馬提尼克島|毛里求斯|毛里求斯|馬約特島|墨西哥|密克羅尼西亞|摩爾多瓦蒙古|黑山|蒙特塞拉特|沿海地區|蒙特塞拉特|摩洛哥|莫桑比克|緬甸|尼泊爾荷蘭|荷蘭|新喀裡多尼亞|新西蘭|尼加拉瓜|尼日爾|尼日利亞|紐埃|諾福克島|北朝鮮|馬其頓|北馬里亞納群島|挪威|阿曼|巴基斯坦|帕勞|巴勒斯坦領土|巴拿馬|巴布亞新幾內亞|巴拉圭|秘魯|菲律賓|皮特凱恩群島|波蘭|葡萄牙|波多黎各|卡塔爾|留尼汪|羅躁狂症|俄羅斯|盧旺達|薩摩亞|聖馬力諾|聖多美和普林西比|沙特阿拉伯|塞內加爾|塞爾維亞|塞舌爾|塞拉利昂|新加坡|聖馬丁|斯洛伐克|斯洛伐克|斯洛文尼亞|所羅門群島|索馬里|南非|喬治亞州和南桑威奇群島|韓國|南蘇丹|西班牙|斯里蘭卡|聖基茨和尼維斯|聖盧西亞|馬丁|聖皮埃爾和密克隆群島|聖文森特和格林納丁斯|蘇丹|蘇里南|斯瓦爾巴特和揚馬延|瑞典|瑞士|敘利亞|塔吉克斯坦|坦桑尼亞|泰國|東帝汶-多哥|托克羅|湯加|特立尼達和多巴哥|突尼斯|土耳其|土庫曼斯坦|特克斯和凱科斯群島|圖瓦盧|美國離島群島|美屬維爾京群島|烏干達|烏克蘭|阿聯酋|英國|烏拉圭|烏茲別克斯坦|瓦努阿圖|梵蒂岡|委內瑞拉|越南|沃利斯和富圖納群島|西撒哈拉|也門|贊比亞|津巴布韋|澳門)'),
#         去哪裡，哪個國家的藥，在哪裡，在哪裡的藥
#         acc=0.6721311475409836 >> [41]/[61]
#         expected real label: 26.21311475409836
#         model test pred:  22
#         raw test raw:  39
#         acc=0.8181818181818182 >> [36]/[44]
#         expected real label: 31.90909090909091
#         model test pred:  22
#         raw test raw:  39
#         re.compile(r''),
        
        
    ],
    
#     'name': [
#         re.compile(r''),
#         re.compile(r''),
#         re.compile(r''),
#         re.compile(r''),
#         re.compile(r''),
        
        
#     ],
    
}

# %%
all_regexes_2 = {
    'time': [
        re.compile(r'農曆除夕|除夕|春節|兒童節|民族掃墓節|清明|清明節|勞動節|浴佛節|佛陀誕辰紀念日|端午節|軍人節|中秋節|孔子誕辰紀念日|教師節|中華民國國慶日|國慶日|聖誕節|聖誕|母親節|父親節|七夕|中元節|盂蘭盆節|中元普渡|七夕情人節|情人節|白色情人節|重陽節|重陽|冬至|爸爸節|母親節|父親節|萬聖節|耶誕節|雙十節|元旦跨年|元旦|跨年|西洋情人節|過年|農曆春節|感恩節|聖誕夜|農曆七夕'),
#         acc=0.68 >> [17]/[25]
#         expected real label: 12.24
#         model test pred:  16
#         raw test raw:  18
#         acc=0.0 >> [0]/[8]
#         re.compile(r'((?:上|下|這|每)個?)?(星期|禮拜|周)([一二三四五六日天、]{1,})(早上|下午|晚上)?(?:(一|二|三|四|五|六|七|八|九|十|十一|十二|[0-9]|10|11|12)|(1[3-9])|(2[0-4])|(十[三四五六七八九])|(二[十一二三四]))?(點)?(鐘|半|多)?'),   #(?:(一|二|三|四|五|(1[3-9])|([二三四五]?(十)?[零一二三四五六七八九])?(分)?                  
#         acc=0.7973950795947902 >> [551]/[691]
#         expected real label: 422.6193921852388
#         model test pred:  473
#         raw test raw:  530
#         acc=0.6987951807228916 >> [58]/[83]
#         expected real label: 157.22891566265062
#         model test pred:  204
#         raw test raw:  225
        re.compile(r'([1-5]?[0-9]|[二三四五]?十?[一二三四五六七八九十])(分)(鐘)'),
#         acc=0.8 >> [4]/[5]
#         expected real label: 4.0
#         model test pred:  5
#         raw test raw:  5
#         acc=0.0 >> [0]/[1]
#         expected real label: 0.0
#         model test pred:  5
#         raw test raw:  5
#         acc=
        
    ],
    
    'family': [
#         re.compile('(我)?(爸爸|媽媽|哥哥|叔叔|大姊|親戚|外公|外婆|爺爺|奶奶|表姊|表哥|表妹|表弟|堂哥|堂弟|堂姊|堂妹|孫子|孫女|阿公||弟弟|妹妹|姑姑|嬸嬸|舅舅|公公|婆婆|岳父|岳母|嫂嫂|媳婦|姪子|姪女|侄兒|弟妹|丈夫|妻子|祖母|祖父|伯公|伯祖|伯翁|叔公|叔祖|叔翁|伯婆|伯祖母|叔婆|叔祖母|太婆|伯母|叔母|外祖父|外祖母|舅媽|岳丈|弟媳|女婿|外孫|伯父|伯母|丈夫|姨丈|阿姨|外甥|外甥女|外甥孫|外甥孫女|外孫|外孫女|父親|母親|大伯)'),
#         acc=0.46464646464646464 >> [46]/[99]
#         expected real label: 23.232323232323232
#         model test pred:  35
#         raw test raw:  50
#         acc=0.029411764705882353 >> [1]/[34]
#         expected real label: 1.0
#         model test pred:  24
#         raw test raw:  34
#         acc=0.5074626865671642 >> [34]/[67]
        
        
#         re.compile('老[二三四五六七八九十]'),
#         acc=1.0 >> [2]/[2]
#         expected real label: 0.0
#         model test pred:  0
#         raw test raw:  0
        
        re.compile('([二三四五六七八九十大小])?(女兒|兒子)'),
#         acc=0.42105263157894735 >> [8]/[19]
#         expected real label: 8.421052631578947
#         model test pred:  19
#         raw test raw:  20
        
#         re.compile('(大)(哥|姐|姊)'),
#         acc=1.0 >> [3]/[3]
#         expected real label: 1.0
#         model test pred:  1
#         raw test raw:  1
#         acc=0.0 >> [0]/[11]
        
        re.compile('(爸爸|媽媽|哥哥|叔叔|大姊|親戚|外公|外婆|爺爺|奶奶|表姊|表哥|表妹|表弟|堂哥|堂弟|堂姊|堂妹|孫子|孫女|阿公|弟弟|妹妹|姑姑|嬸嬸|舅舅|公公|婆婆|岳父|岳母|嫂嫂|媳婦|姪子|姪女|侄兒|弟妹|丈夫|妻子|祖母|祖父|伯公|伯祖|伯翁|叔公|叔祖|叔翁|伯婆|伯祖母|叔婆|叔祖母|太婆|伯母|叔母|外祖父|外祖母|舅媽|岳丈|弟媳|女婿|外孫|伯父|伯母|丈夫|姨丈|外甥|外甥女|外甥孫|外甥孫女|外孫|外孫女|父親|母親|大伯)'),
#         acc=0.6296296296296297 >> [34]/[54]
#         expected real label: 15.11111111111111
#         model test pred:  21
#         raw test raw:  24
        
    ],
    
    'med_exam': [
        re.compile(r'\d+公斤'),  
    ],
    
    'contact': [
        re.compile(r'09[0-9]{8}'),
#         acc=1.0 >> [3]/[3]
#         expected real label: 3.0       
#         model test pred:  3
#         raw test raw:  3
        
        re.compile(r'mail|email|LINE|Grindr|Hornet|Surge|MEEFF|blued|Blued|Scruff|Jack’d|Tinder|Skout|LOVOO|Badoo|SweetRing|Paktor|緣圈|Pairs派愛族|Pairs|派愛族|OkCupid|weTouch|Omi|Aimm|meettheone|心理學交友|探探|Tantan|Bumble|咖啡遇上貝果|Coffee Meets Bagel|Goodnight|Partido|交杯酒|JustDating|Pikabu|皮卡布|slowly|wootalk|Cheers|WeDate|Eatgether|Rooit|Messenger|Facebook|Line|Telegram|WhatsApp|Signal', re.IGNORECASE),
#         acc=0.923
#         expected real label: 26.76923076923077
#         model test pred:  26
#         raw test raw:  29
#         acc=0.9230769230769231 >> [36]/[39]
#         expected real label: 26.76923076923077
#         model test pred:  25
#         raw test raw:  29
#         re.compile(r'(https?:\/\/)?(www\.)?[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)/[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)', re.IGNORECASE),
        re.compile(r'(http:\/\/www\.|https:\/\/www\.|http:\/\/|https:\/\/|www\.)([a-z0-9]+([\-\.]{1}[a-z0-9]+)*\.)([a-z]{2,5}(:[0-9]{1,5})?(\/.*)?)', re.IGNORECASE)
#         acc=1.0 >> [1]/[1]
#         expected real label: 1.0
#         model test pred:  1
#         raw test raw:  1
    ],
    
    'ID': [
        re.compile(r'[A-Z][0-9]{9}', re.IGNORECASE),
#         acc=0.0
#         expected real label: 0.0
#         model test pred:  18
#         raw test raw:  20
        re.compile(r'第(\d|[二三四五六七八九]?十?[一二三四五六七八九十])+(號)'),
#         acc=1.0 >> [5]/[5] 原文標錯
#         expected real label: 1.0
#         model test pred:  1
#         raw test raw:  1
#         acc=0.0
#         expected real label: 0.0
#         model test pred:  9
#         raw test raw:  20
#         re.compile(r'(\d|[一二三四五六七八九]?百?[二三四五六七八九]?十?[一二三四五六七八九十])+(號)'),#[\u4e00-\u8b1c\u8b1e-\u9fcc]
#         acc=0.7865853658536586 >> [258]/[328]
#         expected real label: 158.10365853658539
#         model test pred:  170
#         raw test raw:  201
#         acc=0.017605633802816902 >> [5]/[284]
#         acc=0.0071174377224199285 >> [2]/[281]
#         expected real label: 1.2241992882562276
#         model test pred:  0
#         raw test raw:  172
#         acc=0.017605633802816902 >> [5]/[284]
        
    ],
    
    'name': [
        re.compile(r'(王|李|張|劉|陳|楊|黃|趙|吳|周|徐|孫|馬|朱|胡|郭|何|高|林|鄭|羅|梁|宋|唐|許|韓|馮|鄧|曹|彭|曾|蕭|田|董|袁|潘|於|蔣|蔡|余|杜|葉|程|蘇|魏|呂|丁|任|沈|姚|盧|姜|崔|鍾|譚|陸|汪|范|金|石|廖|賈|夏|韋|付|方|白|鄒|孟|熊|秦|邱|江|尹|薛|閆|段|雷|侯|龍|史|陶|黎|賀|顧|毛|郝|龔|邵|萬|錢|嚴|覃|武|戴|莫|孔|向|湯)([\u4e00-\u8b1c\u8b1e-\u9fcc]{0,3})(醫生|醫師|先生|小姐|女士|同學)'),
#         acc=0.8689655172413793 >> [126]/[145]
#         expected real label: 132.95172413793102
#         model test pred:  153
#         raw test raw:  153
#         re.compile(r'(mr|dr|miss|mrs)?(James|David|Christopher|George|Ronald|John|Richard|Daniel|Kenneth|Anthony|Robert|Charles|Paul|Steven|Kevin|Michael|Joseph|Mark|Edward|Jason|William|Thomas|Donald|Brian|Jeff|Jason|Kevin|Eric|Alex|Jerry|Andy|Jack|Allen|Vincent|Sam|Ken|Chris|Tony|Leo|Peter|Ryan|Emily|Amy|Alice|Grace|Tina|Joyce|Vivian|Cindy|Ivy|Jenny|Claire|Annie|Vicky|Jessica|Peggy|Sandy|Irene|Iris|Maggie|WinnieMary|Jennifer|Lisa|Sandra|Michelle|Patricia|Maria|Nancy|Donna|Laura|Linda|Susan|Karen|Carol|Sarah|Barbara|Margaret|Betty|Ruth|Kimberly|Elizabeth|Dorothy|Helen|Sharon|Deborah)', re.IGNORECASE),
#         acc=0.0 >> [0]/[1]
#         expected real label: 0.0
#         model test pred:  0
#         raw test raw:  1
#         re.compile(r'(亞洲|非洲|歐洲|美洲|南極洲|大洋洲|北美洲|中南美洲|南美洲|中美洲|阿富汗|奧蘭群島|阿爾巴尼亞|阿爾及利亞|美屬薩摩亞|安道爾|安哥拉|安圭拉|南極洲|安提瓜和巴布達|阿根廷|亞美尼亞|阿魯巴|澳大利亞|奧地利|阿塞拜疆|巴哈馬|巴林|孟加拉國|巴巴多斯|白俄羅斯|比利時|貝寧|百慕大|不丹|玻利維亞|波斯尼亞和黑塞哥維那|博茨瓦納|布韋島|巴西|英國印度洋領地|英屬維爾京群島|文萊|布基納|基那納基索|布隆迪|哥倫比亞加拿大|佛得角|加勒比海|開曼群島|中非共和國|乍得|智利|中國|聖誕節島|科克斯(基靈)群島|哥倫比亞|科摩羅|布拉索維爾，剛果|金沙薩，剛果|剛果|庫克群島|哥斯達黎加|科特迪瓦科特迪瓦|克羅地亞|克羅地亞|古巴|庫拉索島|塞浦路斯|捷克共和國|捷克共和國|丹麥|吉布提|多米尼加|多米尼加共和國|厄瓜多爾|埃及|薩爾瓦多|赤道|厄立特里亞|愛沙尼亞|埃斯瓦蒂尼|埃塞俄比亞|法羅群島芬蘭|法國|法屬圭亞那|法屬波利尼西亞|加蓬|岡比亞|喬治亞州|德國|加納|加納巴拉塔|希臘|格陵蘭|格林納達|關島|瓜德羅普島關島|瓜亞瓜根西島|幾內亞|幾內亞比紹|圭亞那|希爾德和麥當勞群島|洪都拉斯|香港特別行政區|匈牙利|冰島|印度尼西亞|印度尼西亞|伊朗|伊拉克|伊拉克|愛爾蘭|曼島|以色列|意大利|牙買加|日本|澤西|約旦|哈薩克斯坦|肯尼亞|基里巴斯-科威特|吉爾吉斯斯坦|老撾|拉脫維亞|黎巴嫩|萊索托|利比里亞|利比亞|利希斯坦|中國澳門特別行政區|馬達加斯加|馬拉維|馬來西亞|馬爾代夫和馬紹爾群島|馬提尼克島|毛里求斯|馬約特島|墨西哥|密克羅尼西亞|摩爾多瓦蒙古|黑山|蒙特塞拉特|蒙特塞拉特|摩洛哥|莫桑比克|緬甸|尼泊爾荷蘭|荷蘭|新喀裡多尼亞|新西蘭|尼加拉瓜|尼日爾|尼日利亞|紐埃|諾福克島|北朝鮮|馬其頓|北馬里亞納群島|挪威|阿曼|巴基斯坦|帕勞|巴勒斯坦領土|巴拿馬|巴布亞新幾內亞|巴拉圭|秘魯|菲律賓|皮特凱恩群島|波蘭|葡萄牙|波多黎各|卡塔爾|留尼汪|羅躁狂症|俄羅斯|盧旺達|薩摩亞|聖馬力諾|聖多美和普林西比|沙特阿拉伯|塞內加爾|塞爾維亞|塞舌爾|塞拉利昂|新加坡|聖馬丁|斯洛伐克|斯洛伐克|斯洛文尼亞|所羅門群島|索馬里|南非|喬治亞州和南桑威奇群島|韓國|南蘇丹|西班牙|斯里蘭卡|聖基茨和尼維斯|聖盧西亞|馬丁|聖皮埃爾和密克隆群島|聖文森特和格林納丁斯|蘇丹|蘇里南|斯瓦爾巴特和揚馬延|瑞典|瑞士|敘利亞|塔吉克斯坦|坦桑尼亞|泰國|東帝汶-多哥|托克羅|湯加|特立尼達和多巴哥|突尼斯|土耳其|土庫曼斯坦|特克斯和凱科斯群島|圖瓦盧|美國離島群島|美屬維爾京群島|烏干達|烏克蘭|阿聯酋|英國|烏拉圭|烏茲別克斯坦|瓦努阿圖|梵蒂岡|委內瑞拉|越南|沃利斯和富圖納群島|西撒哈拉|也門|贊比亞|津巴布韋|澳門)(人)?'),
#         
#         acc=0.6721311475409836 >> [41]/[61]
#         expected real label: 26.21311475409836
#         model test pred:  22
#         raw test raw:  39
#         rule=name_2 >> acc=0.11627906976744186 >> [5]/[43]
#         expected real label: 2.6744186046511627
#         model test pred:  0
#         raw test raw:  23
        
    ],
    
    'clinical_event': [
        re.compile(r'H([0-9]|10)N\d', re.IGNORECASE),
#         acc=1.0 >> [3]/[3]
#         expected real label: 0.0
#         model test pred:  0
#         raw test raw:  0
        re.compile(r'(SARS|covid19|登革熱|A型流感病毒|B型流感病毒)',re.IGNORECASE),
#         acc=1.0 >> [2]/[2]
#         expected real label: 0.0
#         model test pred:  0
#         raw test raw:  0
    ],
    
    'profession': [
        re.compile(r'(國立政治大學|國立臺灣大學|國立臺灣師範大學|國立陽明大學|國立臺灣科技大學|國立臺北科技大學|國立臺北藝術大學|國立臺北教育大學|國立臺北護理健康大學|國立臺北商業大學|東吳大學|中國文化大學|世新大學|銘傳大學|實踐大學|大同大學|臺北醫學大學|中國科技大學|德明財經科技大學|中華科技大學|臺北城市科技大學|康寧大學|臺北市立大學|國立臺灣戲曲學院|馬偕
#         re.compile(r''),
#         re.compile(r''),
#         re.compile(r''),
#         re.compile(r''),
#         re.compile(r''),
        
        
#     ],
    
}

# %% [markdown]
# # 讀出test

# %%
test_file_path = 'test_fianl.txt'
with open(test_file_path, 'r', encoding = 'utf8') as f:
    file_text = f.read().encode('utf-8').decode('utf-8-sig')
test_lines = [i.split('\n')[1] for i in file_text.split('\n\n--------------------\n\n')[:-1]]

# %% [markdown]
# # 讀出predict

# %%
predict_file_path = '(test)blc_rgr_lwld_sw_wc=T_rn=F_sv=T_ls=T_il=F_bies=F_tm=T_b16_fold0-5_es=e9_sw=vote_fix.tsv'
predict_lines = []
with open(predict_file_path, 'r', encoding='utf8') as f:
    for line in f:
        predict_lines.append(line.strip().replace('\t', ' '))
#predict_lines = '  '.join(predict_lines)

# predict_lines_parse = [[] for i in range(len(test_lines))]
# for i in predict_lines[1:]:
#     aid, _, _, term, entity = i.split(' ')
#     if entity == 
#         predict_lines_parse[int(aid)].append(term)

# %% [markdown]
# # 讀出train

# %%
train_file_path = 'train_2.txt'
with open(train_file_path,'r', encoding='utf8') as f:
    file_text = f.read().encode('utf-8').decode('utf-8-sig')
datas = file_text.split('\n\n--------------------\n\n')
train_lines = []
train_labels = []

# for d in datas:
#     d_split = d.split('\n')
#     train_lines.append(d_split[0])
#     curr_label = []
#     for l in d_split[2:]:
#         if l.strip().split('\t')[4] == 
#         curr_label.append(l.strip().split('\t')[3])
#     curr_label = '  '.join(curr_label)
#     train_labels.append(curr_label)

# for i in train_labels[1:]:
#     aid, _, _, term, entity = i.split(' ')
# #     if entity == 'ID':
#     predict_lines_parse[int(aid)].append(term)

# %%
# train_lines

# %%
# train_labels

# %%
all_regexes.keys()

# %% [markdown]
# # train_evaluation

# %%
rules_cat = 'time'
rules_idx = 3

total_real = 0
total_pred = 0

train_lines = []
train_labels = []

for d in datas:
    d_split = d.split('\n')
    train_lines.append(d_split[0])
    curr_label = []
    for l in d_split[2:]:
        if l.strip().split('\t')[4] == rules_cat:
            curr_label.append(l.strip().split('\t')[3])
    curr_label = '  '.join(curr_label)
    train_labels.append(curr_label)

for i in range(len(train_labels)):
    label_rlt = re.findall(all_regexes[rules_cat][rules_idx], train_labels[i])
    raw_rlt = re.findall(all_regexes[rules_cat][rules_idx], train_lines[i])
    
    if (len(label_rlt) or len(raw_rlt)):#and  (len(label_rlt) != len(raw_rlt) )
        total_real += len(label_rlt)
        total_pred += len(raw_rlt)
        print(f'>> article {i} <<')
        print(f'label: {len(label_rlt)}')
        print(f'raw: {len(raw_rlt)}')
        print(label_rlt)
        print(raw_rlt)
        print()
        
acc = total_real/total_pred if total_pred != 0 else total_real/1
print(f'>> rule={rules_cat}_{rules_idx} >> acc={acc} >> [{total_real}]/[{total_pred}]')

# %% [markdown]
# # test_evaluation

# %%
test_total_pred = 0
test_total_raw = 0

predict_lines_parse = [[] for i in range(len(test_lines))]
for i in predict_lines[1:]:
    aid, _, _, term, entity = i.split(' ')
    if entity == rules_cat:
        predict_lines_parse[int(aid)].append(term)


for i in range(len(predict_lines_parse)):
    test_pred_rlt = re.findall(all_regexes[rules_cat][rules_idx] , '  '.join(predict_lines_parse[i]))
    test_raw_rlt = re.findall(all_regexes[rules_cat][rules_idx] , test_lines[i])

    if len(test_pred_rlt) or len(test_raw_rlt):
        
        test_total_pred += len(test_pred_rlt)
        test_total_raw += len(test_raw_rlt)
        print(f'>> article {i} <<')
        print(test_pred_rlt)
        print(test_raw_rlt)
        print(f'pred: {len(test_pred_rlt)}')
        print(f'raw: {len(test_raw_rlt)}')
        print()
        
print(f'expected real label: {test_total_raw * acc}')
print('model test pred: ', test_total_pred)
print('raw test raw: ', test_total_raw)
# 十個20個以上

# %% [markdown]
# # add_regex

# %%
# rules_cat = 'time'
# rules_idx = 1
want_all_regexes = all_regexes_4
# test_total_pred = 0
# test_total_raw = 0

# predict_lines_parse = [[] for i in range(len(test_lines))]
# for i in predict_lines[1:]:
#     aid, _, _, term, entity = i.split(' ')
#     if entity == rules_cat:
#         predict_lines_parse[int(aid)].append(term)
rules_cats = list(want_all_regexes.keys())
rule_add_list = []
for i in range(len(test_lines)):
    for rules_cat in rules_cats:
        for rules_idx in range(len(want_all_regexes[rules_cat])):
#             print(rules_idx)
#             print(rules_cat)
            test_raw_rlt = re.findall(want_all_regexes[rules_cat][rules_idx] , test_lines[i])
            test_rule_pos_group = re.finditer(want_all_regexes[rules_cat][rules_idx] , test_lines[i])
            for idx,test_rule_pos in enumerate(test_rule_pos_group):
                if len(test_raw_rlt):
    #                     print(f'>> article {i} <<')
                    rule_add_list.append([str(i), str(test_rule_pos.start()), str(test_rule_pos.end()), ''.join(test_raw_rlt[idx]), rules_cat])

# %%
rule_add_list

# %%
import csv
import pandas as pd
version = 2
file_name = 'adamw_wmd13_metricesp3bert_bagging_fold5_es_voting_min1_cat1_fix.tsv'
f = open(file_name, 'r')
csvreader = csv.reader(f)
str_list = list(csvreader)
list_wo_regexs = []
for label_list in str_list[1:]:
    list_wo_regexs.append(label_list[0].split('\t'))
name_attribute = str_list[0][0].split('\t')
# writerCSV=pd.DataFrame(columns = name_attribute,data = fianl_predict_list)
# writerCSV.to_csv(f'./rule_add_prediction_v{version}.tsv',encoding='utf-8', sep = '\t',index=False)

# %%
list_wo_regexs

# %%
len(list_wo_regexs)
# Out:
# 3464

# %%
insert_idx = []
insert_label_idx = []
add_label_list = []
new_rule_add_list = []
for x in rule_add_list:
    if x in list_wo_regexs:
        continue
    else:
        new_rule_add_list.append(x)
# new_rule_add_list.reverse()

# %%
new_rule_add_list
# Out:
# [['3', '867', '871', '禮拜二、', 'time'],
#  ['15', '312', '315', '禮拜、', 'time'],
#  ['16', '368', '370', '過年', 'time'],
#  ['20', '198', '203', '這個禮拜四', 'time'],
#  ['20', '217', '222', '這個禮拜四', 'time'],
#  ['20', '391', '395', '這禮拜四', 'time'],
#  ['20', '1286', '1288', '中山', 'location'],
#  ['20', '1298', '1300', '中山', 'location'],
#  ['25', '602', '604', '兒子', 'family'],
#  ['25', '722', '724', '兒子', 'family'],
#  ['25', '652', '655', '法律系', 'profession'],
#  ['26', '613', '616', '餐飲', 'profession'],
#  ['32', '1037', '1040', '林醫師', 'name'],
#  ['33', '178', '180', '過年', 'time'],
#  ['37', '477', '479', '過年', 'time'],
#  ['37', '510', '512', '過年', 'time'],
#  ['38', '692', '696', '下禮拜三', 'time'],
#  ['39', '1202', '1204', '兒子', 'family'],
#  ['54', '704', '706', '叔叔', 'family'],
#  ['58', '1765', '1767', '兒子', 'family'],
#  ['62', '1771', '1773', '女兒', 'family'],
#  ['62', '1804', '1806', '女兒', 'family'],
#  ['62', '1768', '1770', '哥哥', 'family'],
# ...

# %%
new_rule_add_list
# Out:
# [['16', '368', '370', '過年', 'time'],
#  ['20', '1286', '1288', '中山', 'location'],
#  ['20', '1298', '1300', '中山', 'location'],
#  ['25', '602', '604', '兒子', 'family'],
#  ['25', '722', '724', '兒子', 'family'],
#  ['25', '652', '655', '法律系', 'profession'],
#  ['26', '613', '616', '餐飲', 'profession'],
#  ['32', '1037', '1040', '林醫師', 'name'],
#  ['33', '178', '180', '過年', 'time'],
#  ['37', '477', '479', '過年', 'time'],
#  ['37', '510', '512', '過年', 'time'],
#  ['39', '1202', '1204', '兒子', 'family'],
#  ['54', '704', '706', '叔叔', 'family'],
#  ['58', '1765', '1767', '兒子', 'family'],
#  ['62', '1771', '1773', '女兒', 'family'],
#  ['62', '1804', '1806', '女兒', 'family'],
#  ['62', '1768', '1770', '哥哥', 'family'],
#  ['63', '6', '16', 'R234526780', 'ID'],
#  ['64', '925', '929', 'line', 'contact'],
#  ['65', '1453', '1455', '德國', 'location'],
#  ['65', '1482', '1485', '西班牙', 'location'],
#  ['65', '1490', '1493', '西班牙', 'location'],
#  ['77', '1204', '1206', '過年', 'time'],
# ...

# %%
len(new_rule_add_list)
# Out:
# 42

# %%
list_wo_regexs
# Out:
# [['0', '198', '200', '新樓', 'location'],
#  ['0', '227', '229', '麻豆', 'location'],
#  ['0', '237', '239', '麻豆', 'location'],
#  ['0', '295', '297', '今年', 'time'],
#  ['1', '15', '18', '這學期', 'time'],
#  ['1', '31', '33', '今天', 'time'],
#  ['1', '40', '42', '昨天', 'time'],
#  ['1', '76', '80', '0.79', 'med_exam'],
#  ['1', '94', '96', '88', 'med_exam'],
#  ['1', '111', '113', '60', 'med_exam'],
#  ['1', '122', '124', '60', 'med_exam'],
#  ['1', '179', '181', '20', 'med_exam'],
#  ['1', '182', '184', '19', 'med_exam'],
#  ['1', '258', '261', '2.6', 'med_exam'],
#  ['1', '360', '363', '黃醫師', 'name'],
#  ['1', '366', '369', '6.6', 'med_exam'],
#  ['1', '385', '388', '6.6', 'med_exam'],
#  ['1', '394', '397', '8.3', 'med_exam'],
#  ['1', '407', '410', '8.3', 'med_exam'],
#  ['1', '414', '418', '四個月前', 'time'],
#  ['1', '418', '421', '8.3', 'med_exam'],
#  ['1', '463', '466', '6.2', 'med_exam'],
#  ['1', '469', '472', '三個月', 'time'],
#  ['1', '497', '500', '劉老師', 'name'],
# ...

# %%
len(list_wo_regexs)
# Out:
# 3464

# %%
# # for art_id in range(len(test_lines)):
# for i in range(len(list_wo_regexs)):
#     for rule_add_label in new_rule_add_list:
#         try:
            
#     #             print(rule_add_label[:])
#     #             print(list_wo_regex[:])
#     #             break
#             if rule_add_label[0] == list_wo_regexs[i][0]:
#                 if (rule_add_label[1] > list_wo_regexs[i][1]) and (rule_add_label[2] > list_wo_regexs[i][2]) and (rule_add_label[1] < list_wo_regexs[i+1][1]) and (rule_add_label[2] < list_wo_regexs[i+1][2]):
#         #                 print(rule_add_label[1], list_wo_regex[1])
#         #                 print(rule_add_label[2], list_wo_regex[2])
# #                     add_label_list.append(rule_add_label)
#                     insert_idx.append(list_wo_regexs.index(list_wo_regexs[i+1]))
#                     insert_label_idx.append(rule_add_list.index(rule_add_label))
#                 else:
#                     pass
#         #         break
#         except:
#             pass
# fianl_predict_list = list_wo_regexs
# for idx in range(len(insert_idx)):
#     add_idx = insert_idx[idx] +1
#     label = insert_label_idx[idx]
#     fianl_predict_list.insert(add_idx, rule_add_list[label])

# %%
for i in range(len(list_wo_regexs)):
    for rule_add_label in new_rule_add_list:
        try:
            
    #             print(rule_add_label[:])
    #             print(list_wo_regex[:])
    #             break
            if rule_add_label[0] == list_wo_regexs[i][0] == list_wo_regexs[i+1][0]:
                if (int(rule_add_label[1]) > int(list_wo_regexs[i][1])) and (int(rule_add_label[2]) > int(list_wo_regexs[i][2])) and (int(rule_add_label[1]) < int(list_wo_regexs[i+1][1])) and (int(rule_add_label[2]) < int(list_wo_regexs[i+1][2])):
        #                 print(rule_add_label[1], list_wo_regex[1])
        #                 print(rule_add_label[2], list_wo_regex[2])
                    add_label_list.append(rule_add_label)
                    insert_idx.append(list_wo_regexs.index(list_wo_regexs[i+1]))
                    insert_label_idx.append(rule_add_list.index(rule_add_label))
                else:
                    pass
        #         break
        except:
            pass

# %%
fianl_predict_list = list_wo_regexs
for idx in range(len(insert_idx)):
    add_idx = insert_idx[idx] + idx
    label = insert_label_idx[idx]
    fianl_predict_list.insert(add_idx, rule_add_list[label])

# %% [markdown]
# # all_regexes_add_list

# %%
len(add_label_list)
# Out:
# 28

# %%
add_label_list
# Out:
# [['15', '312', '315', '禮拜、', 'time'],
#  ['25', '602', '604', '兒子', 'family'],
#  ['25', '652', '655', '法律系', 'profession'],
#  ['26', '613', '616', '餐飲', 'profession'],
#  ['37', '477', '479', '過年', 'time'],
#  ['39', '1202', '1204', '兒子', 'family'],
#  ['54', '704', '706', '叔叔', 'family'],
#  ['58', '1765', '1767', '兒子', 'family'],
#  ['62', '1804', '1806', '女兒', 'family'],
#  ['65', '1453', '1455', '德國', 'location'],
#  ['65', '1482', '1485', '西班牙', 'location'],
#  ['65', '1490', '1493', '西班牙', 'location'],
#  ['77', '1204', '1206', '過年', 'time'],
#  ['79', '1901', '1903', '兒子', 'family'],
#  ['81', '1511', '1513', '親戚', 'family'],
#  ['93', '802', '812', 'E128739467', 'ID'],
#  ['117', '786', '789', '禮拜天', 'time'],
#  ['124', '329', '332', '禮拜一', 'time'],
#  ['124', '341', '344', '禮拜一', 'time'],
#  ['140', '911', '914', '禮拜一', 'time'],
#  ['140', '921', '924', '禮拜一', 'time'],
#  ['140', '931', '934', '禮拜一', 'time'],
#  ['142', '1347', '1350', '禮拜一', 'time'],
# ...

# %% [markdown]
# # all_regexes_2_add_list

# %%
add_label_list
# Out:
# [['25', '602', '604', '兒子', 'family'],
#  ['25', '652', '655', '法律系', 'profession'],
#  ['26', '613', '616', '餐飲', 'profession'],
#  ['37', '477', '479', '過年', 'time'],
#  ['39', '1202', '1204', '兒子', 'family'],
#  ['54', '704', '706', '叔叔', 'family'],
#  ['58', '1765', '1767', '兒子', 'family'],
#  ['62', '1804', '1806', '女兒', 'family'],
#  ['65', '1453', '1455', '德國', 'location'],
#  ['65', '1482', '1485', '西班牙', 'location'],
#  ['65', '1490', '1493', '西班牙', 'location'],
#  ['77', '1204', '1206', '過年', 'time'],
#  ['79', '1901', '1903', '兒子', 'family'],
#  ['81', '1511', '1513', '親戚', 'family'],
#  ['93', '802', '812', 'E128739467', 'ID'],
#  ['150', '6707', '6709', '跨年', 'time']]

# %%
fianl_predict_list
# Out:
# [['0', '198', '200', '新樓', 'location'],
#  ['0', '227', '229', '麻豆', 'location'],
#  ['0', '237', '239', '麻豆', 'location'],
#  ['0', '295', '297', '今年', 'time'],
#  ['1', '15', '18', '這學期', 'time'],
#  ['1', '31', '33', '今天', 'time'],
#  ['1', '40', '42', '昨天', 'time'],
#  ['1', '76', '80', '0.79', 'med_exam'],
#  ['1', '94', '96', '88', 'med_exam'],
#  ['1', '111', '113', '60', 'med_exam'],
#  ['1', '122', '124', '60', 'med_exam'],
#  ['1', '179', '181', '20', 'med_exam'],
#  ['1', '182', '184', '19', 'med_exam'],
#  ['1', '258', '261', '2.6', 'med_exam'],
#  ['1', '360', '363', '黃醫師', 'name'],
#  ['1', '366', '369', '6.6', 'med_exam'],
#  ['1', '385', '388', '6.6', 'med_exam'],
#  ['1', '394', '397', '8.3', 'med_exam'],
#  ['1', '407', '410', '8.3', 'med_exam'],
#  ['1', '414', '418', '四個月前', 'time'],
#  ['1', '418', '421', '8.3', 'med_exam'],
#  ['1', '463', '466', '6.2', 'med_exam'],
#  ['1', '469', '472', '三個月', 'time'],
#  ['1', '497', '500', '劉老師', 'name'],
# ...

# %% [markdown]
# # all_regexes_4_add_list

# %%
add_label_list
# Out:
# [['15', '312', '315', '禮拜、', 'time'],
#  ['25', '602', '604', '兒子', 'family'],
#  ['25', '652', '655', '法律系', 'profession'],
#  ['26', '613', '616', '餐飲', 'profession'],
#  ['37', '477', '479', '過年', 'time'],
#  ['39', '1202', '1204', '兒子', 'family'],
#  ['54', '704', '706', '叔叔', 'family'],
#  ['58', '1765', '1767', '兒子', 'family'],
#  ['62', '1804', '1806', '女兒', 'family'],
#  ['65', '1453', '1455', '德國', 'name'],
#  ['65', '1453', '1455', '德國', 'location'],
#  ['65', '1482', '1485', '西班牙', 'name'],
#  ['65', '1490', '1493', '西班牙', 'name'],
#  ['65', '1482', '1485', '西班牙', 'location'],
#  ['65', '1490', '1493', '西班牙', 'location'],
#  ['77', '1204', '1206', '過年', 'time'],
#  ['79', '1901', '1903', '兒子', 'family'],
#  ['81', '1511', '1513', '親戚', 'family'],
#  ['93', '802', '812', 'E128739467', 'ID'],
#  ['117', '786', '789', '禮拜天', 'time'],
#  ['124', '329', '332', '禮拜一', 'time'],
#  ['124', '341', '344', '禮拜一', 'time'],
#  ['140', '911', '914', '禮拜一', 'time'],
# ...

# %%
len(fianl_predict_list)
# Out:
# 3492

# %%
if ('2'>'1')and('2'>'1')and('2'<'3')and('2'<'3'):
    print(1)

# %%
int('2')

# %%
len(new_rule_add_list)

# %%
version = 5
writerCSV=pd.DataFrame(columns = name_attribute, data = fianl_predict_list)
writerCSV.to_csv(f'./rule_add_prediction_v{version}.tsv',encoding='utf-8', sep = '\t',index=False)

# %%
len(insert_idx)

# %%
('18' < '19')
# Out:
# True

# %%
len(fianl_predict_list)

# %%
import csv
import pandas as pd
file_name = '(test)blc_rgr_lwld_sw_wc=T_rn=F_sv=T_ls=T_il=F_bies=F_tm=T_b16_fold0-5_es=e9_sw=vote_fix.tsv'
f = open(file_name, 'r')
csvreader = csv.reader(f)
str_list = list(csvreader)
list_wo_regexs = []
for label_list in str_list[1:]:
    list_wo_regexs.append(label_list[0].split('\t'))
name_attribute = str_list[0][0].split('\t')
writerCSV=pd.DataFrame(columns = name_attribute,data = fianl_predict_list)
writerCSV.to_csv('./rule_add_prediction.tsv',encoding='utf-8', sep = '\t',index=False)

# %%
len(list_wo_regexs)

# %%
len(list_wo_regexs)

# %%
len(new_rule_add_list)

# %%
len(fianl_predict_list)

# %%
rule_add_list[0]

# %%
add_idx

# %%
insert_label_idx

# %%
insert_idx

# %%
rule_add_list[insert_label_idx[0]]

# %%
insert_idx

# %%
len(insert_label_idx)

# %%
rule_add_list[10]

# %%
insert_label_idx

# %%
a = [[1,2,3], [1,3,4], [1,6,7]]
b = [[1,2,3], [1,3,4], [1,4,5]]
idx = []
label_list = []
for i in range(len(a)):
    for y in b:
        try:
            if y[:] == a[i][:]:
                continue
            elif ((y[1] < a[i+1][1]) and (y[2] < a[i+1][2])) and ((y[1] > a[i][1]) and (y[2] > a[i][2])):
                idx.append(a.index(a[i+1]))
                label_list.append(b.index(y))
        except:
            pass

# %%
label_list

# %%
idx

# %%
for x in range(5):
    for y in range(5):
        if x == 4:
            continue
        else:
            print(x,y)

# %%
list_wo_regexs

# %%
rule_add_list

# %%
insert_idx

# %%
len(rule_add_list)

# %%
len(list_wo_regex)

# %%
import csv
import pandas as pd
file_name = '(test)blc_rgr_lwld_sw_wc=T_rn=F_sv=T_ls=T_il=F_bies=F_tm=T_b16_fold0-5_es=e9_sw=vote_fix.tsv'
f = open(file_name, 'r')
csvreader = csv.reader(f)
str_list = list(csvreader)
name_attribute = str_list[0][0].split('\t')
writerCSV=pd.DataFrame(columns = name_attribute, data = rule_add_list)
writerCSV.to_csv('./no_fre.tsv',encoding='utf-8', sep = '\t',index = False)
