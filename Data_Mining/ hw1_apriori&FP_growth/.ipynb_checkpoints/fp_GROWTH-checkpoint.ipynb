# %% [markdown]
# # FP-growth     small_minsup and small_minconf with groceries.csv

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c5d84736ba45> in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
import csv
import pandas as pd
from itertools import combinations
import time


#Read data from CSV
data = pd.read_csv('groceries.csv')
# data = pd.read_csv('Market_Basket_Optimisation.csv', header=None)
#
#Parameters
minsup = float(input("Support-Threshold: "))
minsup = minsup * len(data)
minconf = float(input("Confidence-Threshold: "))
print(len(data))#9835
time_start = time.time()

#Add all data in a list of lists
items = []  
# print(len(data.values[0]))#1列(ROW)有32的物品
for i in range(0, len(data)):  #將所有data中的物品一列一列放到items
     items.append([str(data.values[i, j]) for j in range(0, len(data.values[0]))])

#Creating a list of dictionaries
count = [dict() for x in range(len(data.values[0]) + 1)]
# print(items)
# #Count support for each individual items
s = []
for i in items:
    for j in i:      #讀取所有items
        s.append(j)
for i in s:                      #創字典 放在count[1]
    #If item is present in dictionary, increment its count by 1
    if i in count[1]:
        count[1][i] = count[1][i] + 1
    #If item is not present in dictionary, set its count to 1
    else:
        count[1][i] = 1     #{'i':1}

# #Remove infrequent and empty items #去除小於minsup,nan
for i in count[1].copy():
    if(count[1][i] < minsup):
        count[1].pop(i)
count[1].pop('nan') #去除以key = 'NAN'產生的值

# #Storing transactions as lists without infrequent items
a = list(count[1]) #列出所有符合的KEY
item = [list() for i in range(len(data))] #創造len(data) = 9835個list 
c = 0 
for i in range(0,len(items)): ##將所有data中的物品一列一列放到items
    for j in range(len(items[i])):
#         print(items[i][j])
        if(a.__contains__(items[i][j]) != 0): #確認物品是否存在
            item[i].append(items[i][j]) #將物品分成[['a', 'b', 'c'],[]]與itmes不同的地方是裡練已經沒有NAN了

#Function to sort list to support
def sort(a): #a = 所有符合的KEY的list
    for i in range(len(a) - 1):
        for j in range(len(a) - i - 1):
            if(count[1][a[j]] < count[1][a[j + 1]]): #如果下一個比上一個大則互換位子
                a[j],a[j + 1] = a[j + 1],a[j]
                
#Call function to sort all transactions in descending order of their support
for i in range(0,len(data)): #9835
    if(len(item[i]) > 1): #如果不只一個物件就排序他
        sort(item[i])

#Tree class for FP-Tree
class tree: #設計樹根，分支
    def __init__(self, name, sup, parent):
        self.name = name
        self.sup = sup
        self.nodeLink = None
        self.parent = parent
        self.children = []

#Function to check if the node is present is a child of the current node
def ispresent(node,name):    #確認是否有children
    f = -1               
    for i in node.children:
        f += 1
        if(i.name == name):
            return f
    return -1

#HeaderTable which stores the reference of last/first occurence of an item. Used as a linked list to generate candidate trees 
lastocc = count[1].copy() #符合sup的字典
for i in lastocc: #lastocc字典中所有值皆為NONE
    lastocc[i] = None
#Function to create FP-tree
root = tree("root", -1, None)
z = 0
for i in item: #item為沒有NAN的items
    current = root
    for j in range(len(i)): #len(i)9835
        if(ispresent(current,i[j]) >= 0): #第一次通常不符合此情形，直接執行else，看有沒有children
            current = current.children[ispresent(current, i[j])]
            current.sup = current.sup + 1
        else:
            child=tree(i[j], 1, current)    #創建i[j]子根
            current.children.append(child) #將子根放入children =[] 
            t = current #t 記錄柱上一層的tree1
            current = current.children[ispresent(current, i[j])] #現在current.children裡有子根，所以self.name = i[j]如下示意，
            #ispresent(current,i[j])回傳 0 ，現在的current為tree2
            current.parent = t #紀錄上一層tree1
            if(lastocc[current.name] == None):
                lastocc[current.name] = current #創建{'i[j]': tree2-1()} 
            else:#創出第一層並列樹枝
                current.nodeLink = lastocc[current.name] #將tree2-2連結到tree4
                lastocc[current.name] = current #CURRENT = TREE2-2 {'i[j]': tree2-2}
            
# class tree1:
#     def __init__(self, name, sup, parent):
#         self.name = 'root'
#         self.sup = -1
#         self.nodeLink = None
#         self.parent = none
#         self.children = [
#   class tree2-1:
#     def __init__(self, name, sup, parent):      [['A','B','C'],['C','A']]
#         self.name = 'A'
#         self.sup = 1
#         self.nodeLink = NONE
#         self.parent = parent
#         self.children = [
#                                     class tree3:
#                                         def __init__(self, name, sup, parent):
#                                             self.name = 'B'
#                                             self.sup = 1
#                                             self.nodeLink = None
#                                             self.parent = parent
#                                             self.children = [
#                                                                 class tree4:
#                                                                     def __init__(self, name, sup, parent):
#                                                                         self.name = 'B'
#                                                                         self.sup = 1
#                                                                         self.nodeLink = None
#                                                                         self.parent = parent
#                                                                         self.children = []
#                                                                 ]
#         ],
#   class tree2-2:
#     def __init__(self, name, sup, parent):
#         self.name = 'C'
#         self.sup = sup
#         self.nodeLink = TREE 4
#         self.parent = TREE1
#         self.children = []
# ]



#Function to get frequent itemsets with suffix 'node' and length n
def singlepath(node, n):
    c = 0
    sup = node.sup
    path = []
    pathname = []
    current = node
    
    #Get the path from current node to root
    while(current.parent != None): #查看目current是否為'root'，如果是則無parent，重複做直道回到最上層('root')
        path.append(current)     #將current內容紀錄(tree)
        pathname.append(current.name)      #('c')
        current = current.parent  #往上一層移動
    path.remove(node) #除了自己以外的路線
    pathname.remove(node.name) 
    candidatepath = []
    temp_candidatepath = []
   
    #Generate combinations of length n in the path
    a = (list(combinations(pathname, n))) #列出除了自己以外的長度為n的組合
    for j in a:
        temp_candidatepath.append(tuple(sorted(j)))   #以tuple形式存在temp_candidatapath裡
    #Append the suffix 'node.name' to the above paths
    for j in temp_candidatepath:
        j = list(j) #再次變回list
        j.append(node.name) #將原本剔除的當前TREE名加回去 變成包含當前的組合，就是在做freqent pattern
        candidatepath.append(sorted(j)) #在加回去變成 [['a','c'],['b','c']]
    #Update counts of the generated itemsets
    for j in candidatepath:
        j = tuple(j) #j = ('a','c')
        if j in count[n + 1]: #count[1]為符合minsup的字典，n至少會從1開始 
            count[n + 1][j] = count[n + 1][j] + sup  # 將之前已創好的value值，加上當前tree所有的sup
        else:
            count[n + 1][j] = sup #創建新字典,此sup為當前tree存有的sup
            
    #Iterating in the candidate tree recursively 
    if(node.nodeLink != None): #查看是否存在分支
        node=node.nodeLink
        singlepath(node, i) #i為組合長度
    
#Check if itemset is frequent
def frequent(n): #算出現次數
    f=0
    for i in count[n]:
        if(count[n][i] >= minsup):
            f = 1
    if(f == 1):
        return 1
    else:
        return 0

#Call singlepath function for all frequent nodes
for i in range(1, len(data.values[0]) + 1): #1列(ROW)有32的物品, +1是確保有32為一組的組合  #!
    if(frequent(i) == 1):
        for j in lastocc: #開始製造組合，將結果放到count[]裡，count唯有32空字典的list
            singlepath(lastocc[j], i)

#Remove infrequent itemsets
for z in range(len(data.values[0]) + 1):            
    for i in count[z].copy():
            if(count[z][i] < minsup): #查看所有的dict裡面的東西，是否符合minsup
                count[z].pop(i) #去掉不符合的

frequent_pattern = []
for items in count:
    for want in items:
        frequent_pattern.append(want)
                
#Get 'q', the length of the longest itemset
i=1 #設2是因為從第二筆的字典，才開始有東西
while(len(count[i]) != 0): #從這邊就能知道最大符合長度是多長，因為不符合的都被刪掉了，所以count最大的子矩陣
    i = i + 1
q = i - 1

#Find maximal and closed itemsets
maximal = []
closed = []
for i in range(1, q):
    for j in count[i]:
        fm = 0
        fc = 0
        for k in count[i + 1]:
            a = set(list([j]))
            b = set(list(k))
            #Set is maximal if no immediate superset is frequent
            if(a.intersection(b) == a): #如果兩者重疊則maximal
                fm = 1 
                #Set is closed if none of its immediate supersets have equal support
                if(count[i][j] == count[i + 1][k]): #出現次數相同
                    fc = 1
        if(fm == 0):
            maximal.append(j)
        if(fc == 0):
            closed.append(j)
#All sets at the top of the tree are automatically maximal and closed
for i in count[q]:
    maximal.append(i)
    closed.append(i)
print("frequent_pattern")
print(len(frequent_pattern))
print(frequent_pattern)
    
#Find Association Rules 
print("Association_Rules")
ant=count.copy()
for i in range(q, 0, -1): #從後面數回來
    for j in ant[i]:  #ant = count
        for k in range(i-1, 0, -1): # i = q(最大長度)
            s = list(combinations(list(j), k))  #將所有可能組出來 #!s = allco  
            #Traverse through list of all combinations of antecedants
            for n in s:
                #Sorting to prevent duplicate itemsets 
                r = tuple(sorted(set(j).difference(set(n))))
                l = len(n) #輸入進來的字元長度
                #Check if len(n) == 1 to be able to extract key to search in the support dictionary. 
                if(l == 1):
                    n = value(n)
                    l = 1 
                if(len(r) == 1):
                    r2 = value(r)
                if(n != None):
                    #If rule's confidence is greater than minconfidence, then print the rule
                    if((ant[len(j)][j] / ant[l][n]) >= minconf):
                        #Rule is only significant if it is present in CLOSED, otherwise it is redundant
                        if(closed.__contains__((n))):
                            c += 1
                            if(len(r) == 1):
                                print(n, "(", ant[l][n], ")", "--->", r2, "(", ant[len(r)][r2], ")", " - conf(", (ant[len(j)][j] / ant[l][n]), ")")
                            else:
                                print(n,"(", ant[l][n], ")", "--->", r, "(", ant[len(r)][r], ")", " conf(", (ant[len(j)][j] / ant[l][n]), ")")
print(c, "rules generated")


#Function to extract single item set from a tuple
def value(a):              #前面我們將用set差集，進行前處理，否則我們無法當index。
#     print(a) ('mineral water',)
    print(type(a))
    a = str(a)
#     print(a)('mineral water',)

    a = a[:-2]
#     print(a) ('mineral water'
    a = a[2:]
#     print(a)  mineral water'

    a = a[:-1]
#     print(a) mineral water
    return a


time_end = time.time()
print('FP_Growth_spent_time', time_end - time_start)
# print( time_end - time_start)
print(len(ant))
# Out:
# Support-Threshold: 0.045
# Confidence-Threshold: 0.1
# 9835
# frequent_pattern
# 35
# ['citrus fruit', 'margarine', 'tropical fruit', 'yogurt', 'coffee', 'whole milk', 'pip fruit', 'other vegetables', 'butter', 'rolls/buns', 'bottled beer', 'bottled water', 'chocolate', 'curd', 'beef', 'frankfurter', 'soda', 'fruit/vegetable juice', 'newspapers', 'pastry', 'root vegetables', 'canned beer', 'sausage', 'brown bread', 'shopping bags', 'napkins', 'pork', 'whipped/sour cream', 'domestic eggs', 'frozen vegetables', ('whole milk', 'yogurt'), ('other vegetables', 'whole milk'), ('rolls/buns', 'whole milk'), ('other vegetables', 'root vegetables'), ('root vegetables', 'whole milk')]
# Association_Rules
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f613b9559f19> in <module>
#     267                 #Check if len(n) == 1 to be able to extract key to search in the support dictionary.
#     268                 if(l == 1):
# --> 269                     n = value(n)
#     270                     l = 1
#     271                 if(len(r) == 1):
#
# NameError: name 'value' is not defined

# %% [markdown]
# # FP-growth     big_minsup and small_minconf with groceries.csv

# %%
import csv
import pandas as pd
from itertools import combinations
import time


#Read data from CSV
data = pd.read_csv('groceries.csv')
# data = pd.read_csv('Market_Basket_Optimisation.csv', header=None)
#
#Parameters
minsup = float(input("Support-Threshold: "))
minsup = minsup * len(data)
minconf = float(input("Confidence-Threshold: "))
print(len(data))#9835
time_start = time.time()

#Add all data in a list of lists
items = []  
# print(len(data.values[0]))#1列(ROW)有32的物品
for i in range(0, len(data)):  #將所有data中的物品一列一列放到items
     items.append([str(data.values[i, j]) for j in range(0, len(data.values[0]))])

#Creating a list of dictionaries
count = [dict() for x in range(len(data.values[0]) + 1)]
# print(items)
# #Count support for each individual items
s = []
for i in items:
    for j in i:      #讀取所有items
        s.append(j)
for i in s:                      #創字典 放在count[1]
    #If item is present in dictionary, increment its count by 1
    if i in count[1]:
        count[1][i] = count[1][i] + 1
    #If item is not present in dictionary, set its count to 1
    else:
        count[1][i] = 1     #{'i':1}

# #Remove infrequent and empty items #去除小於minsup,nan
for i in count[1].copy():
    if(count[1][i] < minsup):
        count[1].pop(i)
count[1].pop('nan') #去除以key = 'NAN'產生的值

# #Storing transactions as lists without infrequent items
a = list(count[1]) #列出所有符合的KEY
item = [list() for i in range(len(data))] #創造len(data) = 9835個list 
c = 0 
for i in range(0,len(items)): ##將所有data中的物品一列一列放到items
    for j in range(len(items[i])):
#         print(items[i][j])
        if(a.__contains__(items[i][j]) != 0): #確認物品是否存在
            item[i].append(items[i][j]) #將物品分成[['a', 'b', 'c'],[]]與itmes不同的地方是裡練已經沒有NAN了

#Function to sort list to support
def sort(a): #a = 所有符合的KEY的list
    for i in range(len(a) - 1):
        for j in range(len(a) - i - 1):
            if(count[1][a[j]] < count[1][a[j + 1]]): #如果下一個比上一個大則互換位子
                a[j],a[j + 1] = a[j + 1],a[j]
                
#Call function to sort all transactions in descending order of their support
for i in range(0,len(data)): #9835
    if(len(item[i]) > 1): #如果不只一個物件就排序他
        sort(item[i])

#Tree class for FP-Tree
class tree: #設計樹根，分支
    def __init__(self, name, sup, parent):
        self.name = name
        self.sup = sup
        self.nodeLink = None
        self.parent = parent
        self.children = []

#Function to check if the node is present is a child of the current node
def ispresent(node,name):    #確認是否有children
    f = -1               
    for i in node.children:
        f += 1
        if(i.name == name):
            return f
    return -1

#HeaderTable which stores the reference of last/first occurence of an item. Used as a linked list to generate candidate trees 
lastocc = count[1].copy() #符合sup的字典
for i in lastocc: #lastocc字典中所有值皆為NONE
    lastocc[i] = None
#Function to create FP-tree
root = tree("root", -1, None)
z = 0
for i in item: #item為沒有NAN的items
    current = root
    for j in range(len(i)): #len(i)9835
        if(ispresent(current,i[j]) >= 0): #第一次通常不符合此情形，直接執行else，看有沒有children
            current = current.children[ispresent(current, i[j])]
            current.sup = current.sup + 1
        else:
            child=tree(i[j], 1, current)    #創建i[j]子根
            current.children.append(child) #將子根放入children =[] 
            t = current #t 記錄柱上一層的tree1
            current = current.children[ispresent(current, i[j])] #現在current.children裡有子根，所以self.name = i[j]如下示意，
            #ispresent(current,i[j])回傳 0 ，現在的current為tree2
            current.parent = t #紀錄上一層tree1
            if(lastocc[current.name] == None):
                lastocc[current.name] = current #創建{'i[j]': tree2-1()} 
            else:#創出第一層並列樹枝
                current.nodeLink = lastocc[current.name] #將tree2-2連結到tree4
                lastocc[current.name] = current #CURRENT = TREE2-2 {'i[j]': tree2-2}
            
# class tree1:
#     def __init__(self, name, sup, parent):
#         self.name = 'root'
#         self.sup = -1
#         self.nodeLink = None
#         self.parent = none
#         self.children = [
#   class tree2-1:
#     def __init__(self, name, sup, parent):      [['A','B','C'],['C','A']]
#         self.name = 'A'
#         self.sup = 1
#         self.nodeLink = NONE
#         self.parent = parent
#         self.children = [
#                                     class tree3:
#                                         def __init__(self, name, sup, parent):
#                                             self.name = 'B'
#                                             self.sup = 1
#                                             self.nodeLink = None
#                                             self.parent = parent
#                                             self.children = [
#                                                                 class tree4:
#                                                                     def __init__(self, name, sup, parent):
#                                                                         self.name = 'B'
#                                                                         self.sup = 1
#                                                                         self.nodeLink = None
#                                                                         self.parent = parent
#                                                                         self.children = []
#                                                                 ]
#         ],
#   class tree2-2:
#     def __init__(self, name, sup, parent):
#         self.name = 'C'
#         self.sup = sup
#         self.nodeLink = TREE 4
#         self.parent = TREE1
#         self.children = []
# ]



#Function to get frequent itemsets with suffix 'node' and length n
def singlepath(node, n):
    c = 0
    sup = node.sup
    path = []
    pathname = []
    current = node
    
    #Get the path from current node to root
    while(current.parent != None): #查看目current是否為'root'，如果是則無parent，重複做直道回到最上層('root')
        path.append(current)     #將current內容紀錄(tree)
        pathname.append(current.name)      #('c')
        current = current.parent  #往上一層移動
    path.remove(node) #除了自己以外的路線
    pathname.remove(node.name) 
    candidatepath = []
    temp_candidatepath = []
   
    #Generate combinations of length n in the path
    a = (list(combinations(pathname, n))) #列出除了自己以外的長度為n的組合
    for j in a:
        temp_candidatepath.append(tuple(sorted(j)))   #以tuple形式存在temp_candidatapath裡
    #Append the suffix 'node.name' to the above paths
    for j in temp_candidatepath:
        j = list(j) #再次變回list
        j.append(node.name) #將原本剔除的當前TREE名加回去 變成包含當前的組合，就是在做freqent pattern
        candidatepath.append(sorted(j)) #在加回去變成 [['a','c'],['b','c']]
    #Update counts of the generated itemsets
    for j in candidatepath:
        j = tuple(j) #j = ('a','c')
        if j in count[n + 1]: #count[1]為符合minsup的字典，n至少會從1開始 
            count[n + 1][j] = count[n + 1][j] + sup  # 將之前已創好的value值，加上當前tree所有的sup
        else:
            count[n + 1][j] = sup #創建新字典,此sup為當前tree存有的sup
            
    #Iterating in the candidate tree recursively 
    if(node.nodeLink != None): #查看是否存在分支
        node=node.nodeLink
        singlepath(node, i) #i為組合長度
    
#Check if itemset is frequent
def frequent(n): #算出現次數
    f=0
    for i in count[n]:
        if(count[n][i] >= minsup):
            f = 1
    if(f == 1):
        return 1
    else:
        return 0

#Call singlepath function for all frequent nodes
for i in range(1, len(data.values[0]) + 1): #1列(ROW)有32的物品, +1是確保有32為一組的組合  #!
    if(frequent(i) == 1):
        for j in lastocc: #開始製造組合，將結果放到count[]裡，count唯有32空字典的list
            singlepath(lastocc[j], i)

#Remove infrequent itemsets
for z in range(len(data.values[0]) + 1):            
    for i in count[z].copy():
            if(count[z][i] < minsup): #查看所有的dict裡面的東西，是否符合minsup
                count[z].pop(i) #去掉不符合的

frequent_pattern = []
for items in count:
    for want in items:
        frequent_pattern.append(want)
                
#Get 'q', the length of the longest itemset
i=1 #設2是因為從第二筆的字典，才開始有東西
while(len(count[i]) != 0): #從這邊就能知道最大符合長度是多長，因為不符合的都被刪掉了，所以count最大的子矩陣
    i = i + 1
q = i - 1

#Find maximal and closed itemsets
maximal = []
closed = []
for i in range(1, q):
    for j in count[i]:
        fm = 0
        fc = 0
        for k in count[i + 1]:
            a = set(list([j]))
            b = set(list(k))
            #Set is maximal if no immediate superset is frequent
            if(a.intersection(b) == a): #如果兩者重疊則maximal
                fm = 1 
                #Set is closed if none of its immediate supersets have equal support
                if(count[i][j] == count[i + 1][k]): #出現次數相同
                    fc = 1
        if(fm == 0):
            maximal.append(j)
        if(fc == 0):
            closed.append(j)
#All sets at the top of the tree are automatically maximal and closed
for i in count[q]:
    maximal.append(i)
    closed.append(i)
print("frequent_pattern")
print(len(frequent_pattern))
print(frequent_pattern)
    
#Find Association Rules 
print("Association_Rules")
ant=count.copy()
for i in range(q, 0, -1): #從後面樹回來
    for j in ant[i]:  #ant = count
        for k in range(i-1, 0, -1): # i = q(最大長度)
            s = list(combinations(list(j), k))  #將所有可能組出來 #!s = allco  
            #Traverse through list of all combinations of antecedants
            for n in s:
                #Sorting to prevent duplicate itemsets 
                r = tuple(sorted(set(j).difference(set(n))))
                l = len(n) #輸入進來的字元長度
                #Check if len(n) == 1 to be able to extract key to search in the support dictionary. 
                if(l == 1):
                    n = value(n)
                    l = 1 
                if(len(r) == 1):
                    r2 = value(r)
                if(n != None):
                    #If rule's confidence is greater than minconfidence, then print the rule
                    if((ant[len(j)][j] / ant[l][n]) >= minconf):
                        #Rule is only significant if it is present in CLOSED, otherwise it is redundant
                        if(closed.__contains__((n))):
                            c += 1
                            if(len(r) == 1):
                                print(n, "(", ant[l][n], ")", "--->", r2, "(", ant[len(r)][r2], ")", " - conf(", (ant[len(j)][j] / ant[l][n]), ")")
                            else:
                                print(n,"(", ant[l][n], ")", "--->", r, "(", ant[len(r)][r], ")", " conf(", (ant[len(j)][j] / ant[l][n]), ")")
print(c, "rules generated")


#Function to extract single item set from a tuple
def value(a):              #前面我們將用set差集，進行前處理，否則我們無法當index。
#     print(a) ('mineral water',)
    print(type(a))
    a = str(a)
#     print(a) ('mineral water',)

    a = a[:-2]
#     print(a) ('mineral water'
    a = a[2:]
#     print(a)  mineral water'

    a = a[:-1]
#     print(a) mineral water
    return a


time_end = time.time()
print('FP_Growth_spent_time', time_end - time_start)
# print( time_end - time_start)
print(len(ant))
# Out:
# Support-Threshold: 0.045
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-c5ab8dc3c68c> in <module>
#      12 minsup = float(input("Support-Threshold: "))
#      13 minsup = minsup * len(data)
# ---> 14 minconf = float(input("Confidence-Threshold: "))
#      15 print(len(data))#9835
#      16 time_start = time.time()
#
# ~/python_test/python3/lib/python3.6/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# ~/python_test/python3/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # FP-growth     small_minsup and big_minconf with groceries.csv

# %%
import csv
import pandas as pd
from itertools import combinations
import time


#Read data from CSV
data = pd.read_csv('groceries.csv')
# data = pd.read_csv('Market_Basket_Optimisation.csv', header=None)
#
#Parameters
minsup = float(input("Support-Threshold: "))
minsup = minsup * len(data)
minconf = float(input("Confidence-Threshold: "))
print(len(data))#9835
time_start = time.time()

#Add all data in a list of lists
items = []  
# print(len(data.values[0]))#1列(ROW)有32的物品
for i in range(0, len(data)):  #將所有data中的物品一列一列放到items
     items.append([str(data.values[i, j]) for j in range(0, len(data.values[0]))])

#Creating a list of dictionaries
count = [dict() for x in range(len(data.values[0]) + 1)]
# print(items)
# #Count support for each individual items
s = []
for i in items:
    for j in i:      #讀取所有items
        s.append(j)
for i in s:                      #創字典 放在count[1]
    #If item is present in dictionary, increment its count by 1
    if i in count[1]:
        count[1][i] = count[1][i] + 1
    #If item is not present in dictionary, set its count to 1
    else:
        count[1][i] = 1     #{'i':1}

# #Remove infrequent and empty items #去除小於minsup,nan
for i in count[1].copy():
    if(count[1][i] < minsup):
        count[1].pop(i)
count[1].pop('nan') #去除以key = 'NAN'產生的值

# #Storing transactions as lists without infrequent items
a = list(count[1]) #列出所有符合的KEY
item = [list() for i in range(len(data))] #創造len(data) = 9835個list 
c = 0 
for i in range(0,len(items)): ##將所有data中的物品一列一列放到items
    for j in range(len(items[i])):
#         print(items[i][j])
        if(a.__contains__(items[i][j]) != 0): #確認物品是否存在
            item[i].append(items[i][j]) #將物品分成[['a', 'b', 'c'],[]]與itmes不同的地方是裡練已經沒有NAN了

#Function to sort list to support
def sort(a): #a = 所有符合的KEY的list
    for i in range(len(a) - 1):
        for j in range(len(a) - i - 1):
            if(count[1][a[j]] < count[1][a[j + 1]]): #如果下一個比上一個大則互換位子
                a[j],a[j + 1] = a[j + 1],a[j]
                
#Call function to sort all transactions in descending order of their support
for i in range(0,len(data)): #9835
    if(len(item[i]) > 1): #如果不只一個物件就排序他
        sort(item[i])

#Tree class for FP-Tree
class tree: #設計樹根，分支
    def __init__(self, name, sup, parent):
        self.name = name
        self.sup = sup
        self.nodeLink = None
        self.parent = parent
        self.children = []

#Function to check if the node is present is a child of the current node
def ispresent(node,name):    #確認是否有children
    f = -1               
    for i in node.children:
        f += 1
        if(i.name == name):
            return f
    return -1

#HeaderTable which stores the reference of last/first occurence of an item. Used as a linked list to generate candidate trees 
lastocc = count[1].copy() #符合sup的字典
for i in lastocc: #lastocc字典中所有值皆為NONE
    lastocc[i] = None
#Function to create FP-tree
root = tree("root", -1, None)
z = 0
for i in item: #item為沒有NAN的items
    current = root
    for j in range(len(i)): #len(i)9835
        if(ispresent(current,i[j]) >= 0): #第一次通常不符合此情形，直接執行else，看有沒有children
            current = current.children[ispresent(current, i[j])]
            current.sup = current.sup + 1
        else:
            child=tree(i[j], 1, current)    #創建i[j]子根
            current.children.append(child) #將子根放入children =[] 
            t = current #t 記錄柱上一層的tree1
            current = current.children[ispresent(current, i[j])] #現在current.children裡有子根，所以self.name = i[j]如下示意，
            #ispresent(current,i[j])回傳 0 ，現在的current為tree2
            current.parent = t #紀錄上一層tree1
            if(lastocc[current.name] == None):
                lastocc[current.name] = current #創建{'i[j]': tree2-1()} 
            else:#創出第一層並列樹枝
                current.nodeLink = lastocc[current.name] #將tree2-2連結到tree4
                lastocc[current.name] = current #CURRENT = TREE2-2 {'i[j]': tree2-2}
            
# class tree1:
#     def __init__(self, name, sup, parent):
#         self.name = 'root'
#         self.sup = -1
#         self.nodeLink = None
#         self.parent = none
#         self.children = [
#   class tree2-1:
#     def __init__(self, name, sup, parent):      [['A','B','C'],['C','A']]
#         self.name = 'A'
#         self.sup = 1
#         self.nodeLink = NONE
#         self.parent = parent
#         self.children = [
#                                     class tree3:
#                                         def __init__(self, name, sup, parent):
#                                             self.name = 'B'
#                                             self.sup = 1
#                                             self.nodeLink = None
#                                             self.parent = parent
#                                             self.children = [
#                                                                 class tree4:
#                                                                     def __init__(self, name, sup, parent):
#                                                                         self.name = 'B'
#                                                                         self.sup = 1
#                                                                         self.nodeLink = None
#                                                                         self.parent = parent
#                                                                         self.children = []
#                                                                 ]
#         ],
#   class tree2-2:
#     def __init__(self, name, sup, parent):
#         self.name = 'C'
#         self.sup = sup
#         self.nodeLink = TREE 4
#         self.parent = TREE1
#         self.children = []
# ]



#Function to get frequent itemsets with suffix 'node' and length n
def singlepath(node, n):
    c = 0
    sup = node.sup
    path = []
    pathname = []
    current = node
    
    #Get the path from current node to root
    while(current.parent != None): #查看目current是否為'root'，如果是則無parent，重複做直道回到最上層('root')
        path.append(current)     #將current內容紀錄(tree)
        pathname.append(current.name)      #('c')
        current = current.parent  #往上一層移動
    path.remove(node) #除了自己以外的路線
    pathname.remove(node.name) 
    candidatepath = []
    temp_candidatepath = []
   
    #Generate combinations of length n in the path
    a = (list(combinations(pathname, n))) #列出除了自己以外的長度為n的組合
    for j in a:
        temp_candidatepath.append(tuple(sorted(j)))   #以tuple形式存在temp_candidatapath裡
    #Append the suffix 'node.name' to the above paths
    for j in temp_candidatepath:
        j = list(j) #再次變回list
        j.append(node.name) #將原本剔除的當前TREE名加回去 變成包含當前的組合，就是在做freqent pattern
        candidatepath.append(sorted(j)) #在加回去變成 [['a','c'],['b','c']]
    #Update counts of the generated itemsets
    for j in candidatepath:
        j = tuple(j) #j = ('a','c')
        if j in count[n + 1]: #count[1]為符合minsup的字典，n至少會從1開始 
            count[n + 1][j] = count[n + 1][j] + sup  # 將之前已創好的value值，加上當前tree所有的sup
        else:
            count[n + 1][j] = sup #創建新字典,此sup為當前tree存有的sup
            
    #Iterating in the candidate tree recursively 
    if(node.nodeLink != None): #查看是否存在分支
        node=node.nodeLink
        singlepath(node, i) #i為組合長度
    
#Check if itemset is frequent
def frequent(n): #算出現次數
    f=0
    for i in count[n]:
        if(count[n][i] >= minsup):
            f = 1
    if(f == 1):
        return 1
    else:
        return 0

#Call singlepath function for all frequent nodes
for i in range(1, len(data.values[0]) + 1): #1列(ROW)有32的物品, +1是確保有32為一組的組合  #!
    if(frequent(i) == 1):
        for j in lastocc: #開始製造組合，將結果放到count[]裡，count唯有32空字典的list
            singlepath(lastocc[j], i)

#Remove infrequent itemsets
for z in range(len(data.values[0]) + 1):            
    for i in count[z].copy():
            if(count[z][i] < minsup): #查看所有的dict裡面的東西，是否符合minsup
                count[z].pop(i) #去掉不符合的

frequent_pattern = []
for items in count:
    for want in items:
        frequent_pattern.append(want)
                
#Get 'q', the length of the longest itemset
i=1 #設2是因為從第二筆的字典，才開始有東西
while(len(count[i]) != 0): #從這邊就能知道最大符合長度是多長，因為不符合的都被刪掉了，所以count最大的子矩陣
    i = i + 1
q = i - 1

#Find maximal and closed itemsets
maximal = []
closed = []
for i in range(1, q):
    for j in count[i]:
        fm = 0
        fc = 0
        for k in count[i + 1]:
            a = set(list([j]))
            b = set(list(k))
            #Set is maximal if no immediate superset is frequent
            if(a.intersection(b) == a): #如果兩者重疊則maximal
                fm = 1 
                #Set is closed if none of its immediate supersets have equal support
                if(count[i][j] == count[i + 1][k]): #出現次數相同
                    fc = 1
        if(fm == 0):
            maximal.append(j)
        if(fc == 0):
            closed.append(j)
#All sets at the top of the tree are automatically maximal and closed
for i in count[q]:
    maximal.append(i)
    closed.append(i)
print("frequent_pattern")
print(len(frequent_pattern))
print(frequent_pattern)
    
#Find Association Rules 
print("Association_Rules")
ant=count.copy()
for i in range(q, 0, -1): #從後面樹回來
    for j in ant[i]:  #ant = count
        for k in range(i-1, 0, -1): # i = q(最大長度)
            s = list(combinations(list(j), k))  #將所有可能組出來 #!s = allco  
            #Traverse through list of all combinations of antecedants
            for n in s:
                #Sorting to prevent duplicate itemsets 
                r = tuple(sorted(set(j).difference(set(n))))
                l = len(n) #輸入進來的字元長度
                #Check if len(n) == 1 to be able to extract key to search in the support dictionary. 
                if(l == 1):
                    n = value(n)
                    l = 1 
                if(len(r) == 1):
                    r2 = value(r)
                if(n != None):
                    #If rule's confidence is greater than minconfidence, then print the rule
                    if((ant[len(j)][j] / ant[l][n]) >= minconf):
                        #Rule is only significant if it is present in CLOSED, otherwise it is redundant
                        if(closed.__contains__((n))):
                            c += 1
                            if(len(r) == 1):
                                print(n, "(", ant[l][n], ")", "--->", r2, "(", ant[len(r)][r2], ")", " - conf(", (ant[len(j)][j] / ant[l][n]), ")")
                            else:
                                print(n,"(", ant[l][n], ")", "--->", r, "(", ant[len(r)][r], ")", " conf(", (ant[len(j)][j] / ant[l][n]), ")")
print(c, "rules generated")


#Function to extract single item set from a tuple
def value(a):              #前面我們將用set差集，進行前處理，否則我們無法當index。
#     print(a) ('mineral water',)
    print(type(a))
    a = str(a)
#     print(a)('mineral water',)

    a = a[:-2]
#     print(a) ('mineral water'
    a = a[2:]
#     print(a)  mineral water'

    a = a[:-1]
#     print(a) mineral water
    return a


time_end = time.time()
print('FP_Growth_spent_time', time_end - time_start)
# print( time_end - time_start)
print(len(ant))
# Out:
# Support-Threshold: 0.0045
# Confidence-Threshold: 0.1
# 9835
# frequent_pattern
# 1192
# ['citrus fruit', 'semi-finished bread', 'margarine', 'tropical fruit', 'yogurt', 'coffee', 'whole milk', 'pip fruit', 'cream cheese', 'other vegetables', 'condensed milk', 'long life bakery product', 'butter', 'rice', 'rolls/buns', 'UHT-milk', 'bottled beer', 'liquor (appetizer)', 'potted plants', 'cereals', 'white bread', 'bottled water', 'chocolate', 'curd', 'flour', 'dishes', 'beef', 'frankfurter', 'soda', 'chicken', 'sugar', 'fruit/vegetable juice', 'newspapers', 'packaged fruit/vegetables', 'specialty bar', 'butter milk', 'pastry', 'processed cheese', 'detergent', 'root vegetables', 'frozen dessert', 'sweet spreads', 'salty snack', 'waffles', 'candy', 'canned beer', 'sausage', 'brown bread', 'shopping bags', 'beverages', 'hamburger meat', 'spices', 'hygiene articles', 'napkins', 'pork', 'berries', 'whipped/sour cream', 'grapes', 'dessert', 'zwieback', 'domestic eggs', 'spread cheese', 'misc. beverages', 'hard cheese', 'cat food', 'ham', 'turkey', 'baking powder', 'pickled vegetables', 'oil', 'chewing gum', 'chocolate marshmallow', 'ice cream', 'frozen vegetables', 'canned fish', 'seasonal products', 'curd cheese', 'red/blush wine', 'frozen potato products', 'specialty chocolate', 'candles', 'flower (seeds)', 'sparkling wine', 'salt', 'frozen meals', 'canned vegetables', 'onions', 'herbs', 'white wine', 'photo/film', 'sliced cheese', 'pasta', 'softener', 'cling film/bags', 'male cosmetics', 'Instant food products', 'soft cheese', 'dental care', 'popcorn', 'cake bar', 'specialty cheese', 'finished products', 'dog food', 'frozen fish', 'cleaner', 'female sanitary products', 'dish cleaner', 'meat', 'mustard', 'house keeping products', 'liquor', 'pet care', 'soups', 'sauces', 'vinegar', 'instant coffee', 'roll products', 'mayonnaise', 'liver loaf', 'kitchen towels', 'jam', ('citrus fruit', 'pastry'), ('citrus fruit', 'sausage'), ('citrus fruit', 'shopping bags'), ('citrus fruit', 'tropical fruit'), ('citrus fruit', 'root vegetables'), ('citrus fruit', 'other vegetables'), ('citrus fruit', 'yogurt'), ('citrus fruit', 'soda'), ('citrus fruit', 'whole milk'), ('citrus fruit', 'rolls/buns'), ('bottled water', 'citrus fruit'), ('other vegetables', 'semi-finished bread'), ('semi-finished bread', 'whole milk'), ('fruit/vegetable juice', 'margarine'), ('margarine', 'newspapers'), ('bottled water', 'margarine'), ('frankfurter', 'margarine'), ('margarine', 'sausage'), ('margarine', 'rolls/buns'), ('domestic eggs', 'margarine'), ('margarine', 'whipped/sour cream'), ('margarine', 'tropical fruit'), ('margarine', 'whole milk'), ('margarine', 'pip fruit'), ('margarine', 'yogurt'), ('margarine', 'shopping bags'), ('brown bread', 'margarine'), ('margarine', 'root vegetables'), ('margarine', 'soda'), ('margarine', 'other vegetables'), ('margarine', 'pastry'), ('bottled beer', 'margarine'), ('citrus fruit', 'margarine'), ('bottled water', 'tropical fruit'), ('rolls/buns', 'tropical fruit'), ('other vegetables', 'tropical fruit'), ('tropical fruit', 'whole milk'), ('root vegetables', 'tropical fruit'), ('tropical fruit', 'yogurt'), ('soda', 'tropical fruit'), ('soda', 'yogurt'), ('rolls/buns', 'yogurt'), ('other vegetables', 'yogurt'), ('whole milk', 'yogurt'), ('coffee', 'whipped/sour cream'), ('citrus fruit', 'coffee'), ('coffee', 'sausage'), ('coffee', 'root vegetables'), ('coffee', 'whole milk'), ('coffee', 'newspapers'), ('bottled water', 'coffee'), ('coffee', 'yogurt'), ('coffee', 'rolls/buns'), ('coffee', 'soda'), ('coffee', 'pastry'), ('coffee', 'shopping bags'), ('coffee', 'frankfurter'), ('coffee', 'fruit/vegetable juice'), ('bottled beer', 'coffee'), ('coffee', 'other vegetables'), ('coffee', 'tropical fruit'), ('coffee', 'domestic eggs'), ('coffee', 'pip fruit'), ('coffee', 'margarine'), ('bottled water', 'pip fruit'), ('pip fruit', 'soda'), ('pip fruit', 'rolls/buns'), ('other vegetables', 'pip fruit'), ('pip fruit', 'whole milk'), ('newspapers', 'pip fruit'), ('pastry', 'pip fruit'), ('pip fruit', 'tropical fruit'), ('pip fruit', ' ...
# Association_Rules
# <class 'tuple'>
# ('citrus fruit', 'other vegetables', 'root vegetables') ( 102 ) ---> whole milk ( 2513 )  - conf( 0.5588235294117647 )
# <class 'tuple'>
# ('citrus fruit', 'other vegetables', 'whole milk') ( 128 ) ---> root vegetables ( 1072 )  - conf( 0.4453125 )
# <class 'tuple'>
# ('citrus fruit', 'root vegetables', 'whole milk') ( 90 ) ---> other vegetables ( 1903 )  - conf( 0.6333333333333333 )
# <class 'tuple'>
# ('other vegetables', 'root vegetables', 'whole milk') ( 228 ) ---> citrus fruit ( 814 )  - conf( 0.25 )
# ('citrus fruit', 'other vegetables') ( 284 ) ---> ('root vegetables', 'whole milk') ( 481 )  conf( 0.2007042253521127 )
# ('citrus fruit', 'root vegetables') ( 174 ) ---> ('other vegetables', 'whole milk') ( 736 )  conf( 0.3275862068965517 )
# ('citrus fruit', 'whole milk') ( 300 ) ---> ('other vegetables', 'root vegetables') ( 466 )  conf( 0.19 )
# ('other vegetables', 'root vegetables') ( 466 ) ---> ('citrus fruit', 'whole milk') ( 300 )  conf( 0.1223175965665236 )
# ('root vegetables', 'whole milk') ( 481 ) ---> ('citrus fruit', 'other vegetables') ( 284 )  conf( 0.11850311850311851 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('citrus fruit', 'other vegetables', 'whole milk') ( 128 ) ---> yogurt ( 1372 )  - conf( 0.3671875 )
# <class 'tuple'>
# ('citrus fruit', 'other vegetables', 'yogurt') ( 75 ) ---> whole milk ( 2513 )  - conf( 0.6266666666666667 )
# <class 'tuple'>
# ('citrus fruit', 'whole milk', 'yogurt') ( 101 ) ---> other vegetables ( 1903 )  - conf( 0.46534653465346537 )
# <class 'tuple'>
# ('other vegetables', 'whole milk', 'yogurt') ( 219 ) ---> citrus fruit ( 814 )  - conf( 0.2146118721461187 )
# ('citrus fruit', 'other vegetables') ( 284 ) ---> ('whole milk', 'yogurt') ( 551 )  conf( 0.16549295774647887 )
# ('citrus fruit', 'whole milk') ( 300 ) ---> ('other vegetables', 'yogurt') ( 427 )  conf( 0.15666666666666668 )
# ('citrus fruit', 'yogurt') ( 213 ) ---> ('other vegetables', 'whole milk') ( 736 )  conf( 0.22065727699530516 )
# ('other vegetables', 'yogurt') ( 427 ) ---> ('citrus fruit', 'whole milk') ( 300 )  conf( 0.11007025761124122 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('citrus fruit', 'other vegetables', 'tropical fruit') ( 89 ) ---> whole milk ( 2513 )  - conf( 0.550561797752809 )
# <class 'tuple'>
# ('citrus fruit', 'other vegetables', 'whole milk') ( 128 ) ---> tropical fruit ( 1032 )  - conf( 0.3828125 )
# <class 'tuple'>
# ('citrus fruit', 'tropical fruit', 'whole milk') ( 89 ) ---> other vegetables ( 1903 )  - conf( 0.550561797752809 )
# <class 'tuple'>
# ('other vegetables', 'tropical fruit', 'whole milk') ( 168 ) ---> citrus fruit ( 814 )  - conf( 0.2916666666666667 )
# ('citrus fruit', 'other vegetables') ( 284 ) ---> ('tropical fruit', 'whole milk') ( 416 )  conf( 0.17253521126760563 )
# ('citrus fruit', 'tropical fruit') ( 196 ) ---> ('other vegetables', 'whole milk') ( 736 )  conf( 0.25 )
# ('citrus fruit', 'whole milk') ( 300 ) ---> ('other vegetables', 'tropical fruit') ( 353 )  conf( 0.16333333333333333 )
# ('other vegetables', 'tropical fruit') ( 353 ) ---> ('citrus fruit', 'whole milk') ( 300 )  conf( 0.1388101983002833 )
# ('tropical fruit', 'whole milk') ( 416 ) ---> ('citrus fruit', 'other vegetables') ( 284 )  conf( 0.11778846153846154 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('other vegetables', 'root vegetables', 'tropical fruit') ( 121 ) ---> yogurt ( 1372 )  - conf( 0.4049586776859504 )
# <class 'tuple'>
# ('other vegetables', 'root vegetables', 'yogurt') ( 127 ) ---> tropical fruit ( 1032 )  - conf( 0.3858267716535433 )
# <class 'tuple'>
# ('other vegetables', 'tropical fruit', 'yogurt') ( 121 ) ---> root vegetables ( 1072 )  - conf( 0.4049586776859504 )
# <class 'tuple'>
# ('root vegetables', 'tropical fruit', 'yogurt') ( 80 ) ---> other vegetables ( 1903 )  - conf( 0.6125 )
# ('other vegetables', 'root vegetables') ( 466 ) ---> ('tropical fruit', 'yogurt') ( 288 )  conf( 0.10515021459227468 )
# ('other vegetables', 'tropical fruit') ( 353 ) ---> ('root vegetables', 'yogurt') ( 254 )  conf( 0.1388101983002833 )
# ('other vegetables', 'yogurt') ( 427 ) ---> ('root vegetables', 'tropical fruit') ( 207 )  conf( 0.11475409836065574 )
# ('root vegetables', 'tropical fruit') ( 207 ) ---> ('other vegetables', 'yogurt') ( 427 )  conf( 0.23671497584541062 )
# ('root vegetables', 'yogurt') ( 254 ) ---> ('other vegetables', 'tropical fruit') ( 353 )  conf( 0.19291338582677164 )
# ('tropical fruit', 'yogurt') ( 288 ) ---> ('other vegetables', 'root vegetables') ( 466 )  conf( 0.1701388888888889 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('root vegetables', 'tropical fruit', 'whole milk') ( 118 ) ---> yogurt ( 1372 )  - conf( 0.4745762711864407 )
# <class 'tuple'>
# ('root vegetables', 'tropical fruit', 'yogurt') ( 80 ) ---> whole milk ( 2513 )  - conf( 0.7 )
# <class 'tuple'>
# ('root vegetables', 'whole milk', 'yogurt') ( 143 ) ---> tropical fruit ( 1032 )  - conf( 0.3916083916083916 )
# <class 'tuple'>
# ('tropical fruit', 'whole milk', 'yogurt') ( 149 ) ---> root vegetables ( 1072 )  - conf( 0.37583892617449666 )
# ('root vegetables', 'tropical fruit') ( 207 ) ---> ('whole milk', 'yogurt') ( 551 )  conf( 0.27053140096618356 )
# ('root vegetables', 'whole milk') ( 481 ) ---> ('tropical fruit', 'yogurt') ( 288 )  conf( 0.11642411642411643 )
# ('root vegetables', 'yogurt') ( 254 ) ---> ('tropical fruit', 'whole milk') ( 416 )  conf( 0.2204724409448819 )
# ('tropical fruit', 'whole milk') ( 416 ) ---> ('root vegetables', 'yogurt') ( 254 )  conf( 0.1346153846153846 )
# ('tropical fruit', 'yogurt') ( 288 ) ---> ('root vegetables', 'whole milk') ( 481 )  conf( 0.19444444444444445 )
# ('whole milk', 'yogurt') ( 551 ) ---> ('root vegetables', 'tropical fruit') ( 207 )  conf( 0.10163339382940109 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('rolls/buns', 'tropical fruit', 'whole milk') ( 108 ) ---> yogurt ( 1372 )  - conf( 0.4444444444444444 )
# <class 'tuple'>
# ('rolls/buns', 'tropical fruit', 'yogurt') ( 86 ) ---> whole milk ( 2513 )  - conf( 0.5581395348837209 )
# <class 'tuple'>
# ('rolls/buns', 'whole milk', 'yogurt') ( 153 ) ---> tropical fruit ( 1032 )  - conf( 0.3137254901960784 )
# <class 'tuple'>
# ('tropical fruit', 'whole milk', 'yogurt') ( 149 ) ---> rolls/buns ( 1809 )  - conf( 0.3221476510067114 )
# ('rolls/buns', 'tropical fruit') ( 242 ) ---> ('whole milk', 'yogurt') ( 551 )  conf( 0.19834710743801653 )
# ('rolls/buns', 'yogurt') ( 338 ) ---> ('tropical fruit', 'whole milk') ( 416 )  conf( 0.14201183431952663 )
# ('tropical fruit', 'whole milk') ( 416 ) ---> ('rolls/buns', 'yogurt') ( 338 )  conf( 0.11538461538461539 )
# ('tropical fruit', 'yogurt') ( 288 ) ---> ('rolls/buns', 'whole milk') ( 557 )  conf( 0.16666666666666666 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('other vegetables', 'root vegetables', 'tropical fruit') ( 121 ) ---> whole milk ( 2513 )  - conf( 0.5702479338842975 )
# <class 'tuple'>
# ('other vegetables', 'root vegetables', 'whole milk') ( 228 ) ---> tropical fruit ( 1032 )  - conf( 0.3026315789473684 )
# <class 'tuple'>
# ('other vegetables', 'tropical fruit', 'whole milk') ( 168 ) ---> root vegetables ( 1072 )  - conf( 0.4107142857142857 )
# <class 'tuple'>
# ('root vegetables', 'tropical fruit', 'whole milk') ( 118 ) ---> other vegetables ( 1903 )  - conf( 0.5847457627118644 )
# ('other vegetables', 'root vegetables') ( 466 ) ---> ('tropical fruit', 'whole milk') ( 416 )  conf( 0.148068669527897 )
# ('other vegetables', 'tropical fruit') ( 353 ) ---> ('root vegetables', 'whole milk') ( 481 )  conf( 0.1954674220963173 )
# ('root vegetables', 'tropical fruit') ( 207 ) ---> ('other vegetables', 'whole milk') ( 736 )  conf( 0.3333333333333333 )
# ('root vegetables', 'whole milk') ( 481 ) ---> ('other vegetables', 'tropical fruit') ( 353 )  conf( 0.14345114345114346 )
# ('tropical fruit', 'whole milk') ( 416 ) ---> ('other vegetables', 'root vegetables') ( 466 )  conf( 0.1658653846153846 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('other vegetables', 'tropical fruit', 'whole milk') ( 168 ) ---> yogurt ( 1372 )  - conf( 0.44642857142857145 )
# <class 'tuple'>
# ('other vegetables', 'tropical fruit', 'yogurt') ( 121 ) ---> whole milk ( 2513 )  - conf( 0.6198347107438017 )
# <class 'tuple'>
# ('other vegetables', 'whole milk', 'yogurt') ( 219 ) ---> tropical fruit ( 1032 )  - conf( 0.3424657534246575 )
# <class 'tuple'>
# ('tropical fruit', 'whole milk', 'yogurt') ( 149 ) ---> other vegetables ( 1903 )  - conf( 0.5033557046979866 )
# ('other vegetables', 'tropical fruit') ( 353 ) ---> ('whole milk', 'yogurt') ( 551 )  conf( 0.21246458923512748 )
# ('other vegetables', 'whole milk') ( 736 ) ---> ('tropical fruit', 'yogurt') ( 288 )  conf( 0.10190217391304347 )
# ('other vegetables', 'yogurt') ( 427 ) ---> ('tropical fruit', 'whole milk') ( 416 )  conf( 0.1756440281030445 )
# ('tropical fruit', 'whole milk') ( 416 ) ---> ('other vegetables', 'yogurt') ( 427 )  conf( 0.18028846153846154 )
# ('tropical fruit', 'yogurt') ( 288 ) ---> ('other vegetables', 'whole milk') ( 736 )  conf( 0.2604166666666667 )
# ('whole milk', 'yogurt') ( 551 ) ---> ('other vegetables', 'tropical fruit') ( 353 )  conf( 0.13611615245009073 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('other vegetables', 'rolls/buns', 'whole milk') ( 176 ) ---> yogurt ( 1372 )  - conf( 0.3352272727272727 )
# <class 'tuple'>
# ('other vegetables', 'rolls/buns', 'yogurt') ( 113 ) ---> whole milk ( 2513 )  - conf( 0.5221238938053098 )
# <class 'tuple'>
# ('other vegetables', 'whole milk', 'yogurt') ( 219 ) ---> rolls/buns ( 1809 )  - conf( 0.2694063926940639 )
# <class 'tuple'>
# ('rolls/buns', 'whole milk', 'yogurt') ( 153 ) ---> other vegetables ( 1903 )  - conf( 0.38562091503267976 )
# ('other vegetables', 'rolls/buns') ( 419 ) ---> ('whole milk', 'yogurt') ( 551 )  conf( 0.14081145584725538 )
# ('other vegetables', 'yogurt') ( 427 ) ---> ('rolls/buns', 'whole milk') ( 557 )  conf( 0.13817330210772832 )
# ('rolls/buns', 'whole milk') ( 557 ) ---> ('other vegetables', 'yogurt') ( 427 )  conf( 0.1059245960502693 )
# ('rolls/buns', 'yogurt') ( 338 ) ---> ('other vegetables', 'whole milk') ( 736 )  conf( 0.17455621301775148 )
# ('whole milk', 'yogurt') ( 551 ) ---> ('other vegetables', 'rolls/buns') ( 419 )  conf( 0.10707803992740472 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('other vegetables', 'pip fruit', 'root vegetables') ( 80 ) ---> whole milk ( 2513 )  - conf( 0.675 )
# <class 'tuple'>
# ('other vegetables', 'pip fruit', 'whole milk') ( 133 ) ---> root vegetables ( 1072 )  - conf( 0.40601503759398494 )
# <class 'tuple'>
# ('other vegetables', 'root vegetables', 'whole milk') ( 228 ) ---> pip fruit ( 744 )  - conf( 0.23684210526315788 )
# <class 'tuple'>
# ('pip fruit', 'root vegetables', 'whole milk') ( 88 ) ---> other vegetables ( 1903 )  - conf( 0.6136363636363636 )
# ('other vegetables', 'pip fruit') ( 257 ) ---> ('root vegetables', 'whole milk') ( 481 )  conf( 0.21011673151750973 )
# ('other vegetables', 'root vegetables') ( 466 ) ---> ('pip fruit', 'whole milk') ( 296 )  conf( 0.11587982832618025 )
# ('pip fruit', 'root vegetables') ( 153 ) ---> ('other vegetables', 'whole milk') ( 736 )  conf( 0.35294117647058826 )
# ('pip fruit', 'whole milk') ( 296 ) ---> ('other vegetables', 'root vegetables') ( 466 )  conf( 0.18243243243243243 )
# ('root vegetables', 'whole milk') ( 481 ) ---> ('other vegetables', 'pip fruit') ( 257 )  conf( 0.11226611226611227 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('other vegetables', 'pip fruit', 'whole milk') ( 133 ) ---> yogurt ( 1372 )  - conf( 0.37593984962406013 )
# <class 'tuple'>
# ('other vegetables', 'pip fruit', 'yogurt') ( 80 ) ---> whole milk ( 2513 )  - conf( 0.625 )
# <class 'tuple'>
# ('other vegetables', 'whole milk', 'yogurt') ( 219 ) ---> pip fruit ( 744 )  - conf( 0.228310502283105 )
# <class 'tuple'>
# ('pip fruit', 'whole milk', 'yogurt') ( 94 ) ---> other vegetables ( 1903 )  - conf( 0.5319148936170213 )
# ('other vegetables', 'pip fruit') ( 257 ) ---> ('whole milk', 'yogurt') ( 551 )  conf( 0.19455252918287938 )
# ('other vegetables', 'yogurt') ( 427 ) ---> ('pip fruit', 'whole milk') ( 296 )  conf( 0.117096018735363 )
# ('pip fruit', 'whole milk') ( 296 ) ---> ('other vegetables', 'yogurt') ( 427 )  conf( 0.16891891891891891 )
# ('pip fruit', 'yogurt') ( 177 ) ---> ('other vegetables', 'whole milk') ( 736 )  conf( 0.2824858757062147 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('other vegetables', 'pip fruit', 'tropical fruit') ( 93 ) ---> whole milk ( 2513 )  - conf( 0.5053763440860215 )
# <class 'tuple'>
# ('other vegetables', 'pip fruit', 'whole milk') ( 133 ) ---> tropical fruit ( 1032 )  - conf( 0.3533834586466165 )
# <class 'tuple'>
# ('other vegetables', 'tropical fruit', 'whole milk') ( 168 ) ---> pip fruit ( 744 )  - conf( 0.27976190476190477 )
# <class 'tuple'>
# ('pip fruit', 'tropical fruit', 'whole milk') ( 83 ) ---> other vegetables ( 1903 )  - conf( 0.5662650602409639 )
# ('other vegetables', 'pip fruit') ( 257 ) ---> ('tropical fruit', 'whole milk') ( 416 )  conf( 0.1828793774319066 )
# ('other vegetables', 'tropical fruit') ( 353 ) ---> ('pip fruit', 'whole milk') ( 296 )  conf( 0.13314447592067988 )
# ('pip fruit', 'tropical fruit') ( 201 ) ---> ('other vegetables', 'whole milk') ( 736 )  conf( 0.23383084577114427 )
# ('pip fruit', 'whole milk') ( 296 ) ---> ('other vegetables', 'tropical fruit') ( 353 )  conf( 0.15878378378378377 )
# ('tropical fruit', 'whole milk') ( 416 ) ---> ('other vegetables', 'pip fruit') ( 257 )  conf( 0.11298076923076923 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('fruit/vegetable juice', 'other vegetables', 'whole milk') ( 103 ) ---> yogurt ( 1372 )  - conf( 0.4854368932038835 )
# <class 'tuple'>
# ('fruit/vegetable juice', 'other vegetables', 'yogurt') ( 81 ) ---> whole milk ( 2513 )  - conf( 0.6172839506172839 )
# <class 'tuple'>
# ('fruit/vegetable juice', 'whole milk', 'yogurt') ( 93 ) ---> other vegetables ( 1903 )  - conf( 0.5376344086021505 )
# <class 'tuple'>
# ('other vegetables', 'whole milk', 'yogurt') ( 219 ) ---> fruit/vegetable juice ( 711 )  - conf( 0.228310502283105 )
# ('fruit/vegetable juice', 'other vegetables') ( 207 ) ---> ('whole milk', 'yogurt') ( 551 )  conf( 0.24154589371980675 )
# ('fruit/vegetable juice', 'whole milk') ( 262 ) ---> ('other vegetables', 'yogurt') ( 427 )  conf( 0.19083969465648856 )
# ('fruit/vegetable juice', 'yogurt') ( 184 ) ---> ('other vegetables', 'whole milk') ( 736 )  conf( 0.2717391304347826 )
# ('other vegetables', 'yogurt') ( 427 ) ---> ('fruit/vegetable juice', 'whole milk') ( 262 )  conf( 0.117096018735363 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('other vegetables', 'root vegetables', 'whole milk') ( 228 ) ---> yogurt ( 1372 )  - conf( 0.33771929824561403 )
# <class 'tuple'>
# ('other vegetables', 'root vegetables', 'yogurt') ( 127 ) ---> whole milk ( 2513 )  - conf( 0.6062992125984252 )
# <class 'tuple'>
# ('other vegetables', 'whole milk', 'yogurt') ( 219 ) ---> root vegetables ( 1072 )  - conf( 0.3515981735159817 )
# <class 'tuple'>
# ('root vegetables', 'whole milk', 'yogurt') ( 143 ) ---> other vegetables ( 1903 )  - conf( 0.5384615384615384 )
# ('other vegetables', 'root vegetables') ( 466 ) ---> ('whole milk', 'yogurt') ( 551 )  conf( 0.16523605150214593 )
# ('other vegetables', 'whole milk') ( 736 ) ---> ('root vegetables', 'yogurt') ( 254 )  conf( 0.10461956521739131 )
# ('other vegetables', 'yogurt') ( 427 ) ---> ('root vegetables', 'whole milk') ( 481 )  conf( 0.18032786885245902 )
# ('root vegetables', 'whole milk') ( 481 ) ---> ('other vegetables', 'yogurt') ( 427 )  conf( 0.1600831600831601 )
# ('root vegetables', 'yogurt') ( 254 ) ---> ('other vegetables', 'whole milk') ( 736 )  conf( 0.3031496062992126 )
# ('whole milk', 'yogurt') ( 551 ) ---> ('other vegetables', 'root vegetables') ( 466 )  conf( 0.1397459165154265 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('other vegetables', 'rolls/buns', 'root vegetables') ( 120 ) ---> whole milk ( 2513 )  - conf( 0.5083333333333333 )
# <class 'tuple'>
# ('other vegetables', 'rolls/buns', 'whole milk') ( 176 ) ---> root vegetables ( 1072 )  - conf( 0.3465909090909091 )
# <class 'tuple'>
# ('other vegetables', 'root vegetables', 'whole milk') ( 228 ) ---> rolls/buns ( 1809 )  - conf( 0.2675438596491228 )
# <class 'tuple'>
# ('rolls/buns', 'root vegetables', 'whole milk') ( 125 ) ---> other vegetables ( 1903 )  - conf( 0.488 )
# ('other vegetables', 'rolls/buns') ( 419 ) ---> ('root vegetables', 'whole milk') ( 481 )  conf( 0.14558472553699284 )
# ('other vegetables', 'root vegetables') ( 466 ) ---> ('rolls/buns', 'whole milk') ( 557 )  conf( 0.13090128755364808 )
# ('rolls/buns', 'root vegetables') ( 239 ) ---> ('other vegetables', 'whole milk') ( 736 )  conf( 0.25523012552301255 )
# ('rolls/buns', 'whole milk') ( 557 ) ---> ('other vegetables', 'root vegetables') ( 466 )  conf( 0.10951526032315978 )
# ('root vegetables', 'whole milk') ( 481 ) ---> ('other vegetables', 'rolls/buns') ( 419 )  conf( 0.12681912681912683 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('rolls/buns', 'root vegetables', 'whole milk') ( 125 ) ---> yogurt ( 1372 )  - conf( 0.368 )
# <class 'tuple'>
# ('rolls/buns', 'root vegetables', 'yogurt') ( 71 ) ---> whole milk ( 2513 )  - conf( 0.647887323943662 )
# <class 'tuple'>
# ('rolls/buns', 'whole milk', 'yogurt') ( 153 ) ---> root vegetables ( 1072 )  - conf( 0.3006535947712418 )
# <class 'tuple'>
# ('root vegetables', 'whole milk', 'yogurt') ( 143 ) ---> rolls/buns ( 1809 )  - conf( 0.32167832167832167 )
# ('rolls/buns', 'root vegetables') ( 239 ) ---> ('whole milk', 'yogurt') ( 551 )  conf( 0.19246861924686193 )
# ('rolls/buns', 'yogurt') ( 338 ) ---> ('root vegetables', 'whole milk') ( 481 )  conf( 0.13609467455621302 )
# ('root vegetables', 'yogurt') ( 254 ) ---> ('rolls/buns', 'whole milk') ( 557 )  conf( 0.18110236220472442 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('other vegetables', 'whipped/sour cream', 'whole milk') ( 144 ) ---> yogurt ( 1372 )  - conf( 0.3819444444444444 )
# <class 'tuple'>
# ('other vegetables', 'whipped/sour cream', 'yogurt') ( 100 ) ---> whole milk ( 2513 )  - conf( 0.55 )
# <class 'tuple'>
# ('other vegetables', 'whole milk', 'yogurt') ( 219 ) ---> whipped/sour cream ( 705 )  - conf( 0.2511415525114155 )
# <class 'tuple'>
# ('whipped/sour cream', 'whole milk', 'yogurt') ( 107 ) ---> other vegetables ( 1903 )  - conf( 0.514018691588785 )
# ('other vegetables', 'whipped/sour cream') ( 284 ) ---> ('whole milk', 'yogurt') ( 551 )  conf( 0.1936619718309859 )
# ('other vegetables', 'yogurt') ( 427 ) ---> ('whipped/sour cream', 'whole milk') ( 317 )  conf( 0.1288056206088993 )
# ('whipped/sour cream', 'whole milk') ( 317 ) ---> ('other vegetables', 'yogurt') ( 427 )  conf( 0.17350157728706625 )
# ('whipped/sour cream', 'yogurt') ( 204 ) ---> ('other vegetables', 'whole milk') ( 736 )  conf( 0.2696078431372549 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('other vegetables', 'root vegetables', 'whipped/sour cream') ( 84 ) ---> whole milk ( 2513 )  - conf( 0.6071428571428571 )
# <class 'tuple'>
# ('other vegetables', 'root vegetables', 'whole milk') ( 228 ) ---> whipped/sour cream ( 705 )  - conf( 0.2236842105263158 )
# <class 'tuple'>
# ('other vegetables', 'whipped/sour cream', 'whole milk') ( 144 ) ---> root vegetables ( 1072 )  - conf( 0.3541666666666667 )
# <class 'tuple'>
# ('root vegetables', 'whipped/sour cream', 'whole milk') ( 93 ) ---> other vegetables ( 1903 )  - conf( 0.5483870967741935 )
# ('other vegetables', 'root vegetables') ( 466 ) ---> ('whipped/sour cream', 'whole milk') ( 317 )  conf( 0.10944206008583691 )
# ('other vegetables', 'whipped/sour cream') ( 284 ) ---> ('root vegetables', 'whole milk') ( 481 )  conf( 0.1795774647887324 )
# ('root vegetables', 'whipped/sour cream') ( 168 ) ---> ('other vegetables', 'whole milk') ( 736 )  conf( 0.30357142857142855 )
# ('root vegetables', 'whole milk') ( 481 ) ---> ('other vegetables', 'whipped/sour cream') ( 284 )  conf( 0.10602910602910603 )
# ('whipped/sour cream', 'whole milk') ( 317 ) ---> ('other vegetables', 'root vegetables') ( 466 )  conf( 0.1608832807570978 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('domestic eggs', 'other vegetables', 'root vegetables') ( 72 ) ---> whole milk ( 2513 )  - conf( 0.625 )
# <class 'tuple'>
# ('domestic eggs', 'other vegetables', 'whole milk') ( 121 ) ---> root vegetables ( 1072 )  - conf( 0.371900826446281 )
# <class 'tuple'>
# ('domestic eggs', 'root vegetables', 'whole milk') ( 84 ) ---> other vegetables ( 1903 )  - conf( 0.5357142857142857 )
# <class 'tuple'>
# ('other vegetables', 'root vegetables', 'whole milk') ( 228 ) ---> domestic eggs ( 624 )  - conf( 0.19736842105263158 )
# ('domestic eggs', 'other vegetables') ( 219 ) ---> ('root vegetables', 'whole milk') ( 481 )  conf( 0.2054794520547945 )
# ('domestic eggs', 'root vegetables') ( 141 ) ---> ('other vegetables', 'whole milk') ( 736 )  conf( 0.3191489361702128 )
# ('domestic eggs', 'whole milk') ( 295 ) ---> ('other vegetables', 'root vegetables') ( 466 )  conf( 0.15254237288135594 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('citrus fruit', 'root vegetables') ( 174 ) ---> tropical fruit ( 1032 )  - conf( 0.3218390804597701 )
# <class 'tuple'>
# ('citrus fruit', 'tropical fruit') ( 196 ) ---> root vegetables ( 1072 )  - conf( 0.2857142857142857 )
# <class 'tuple'>
# ('root vegetables', 'tropical fruit') ( 207 ) ---> citrus fruit ( 814 )  - conf( 0.27053140096618356 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('citrus fruit', 'other vegetables') ( 284 ) ---> tropical fruit ( 1032 )  - conf( 0.31338028169014087 )
# <class 'tuple'>
# ('citrus fruit', 'tropical fruit') ( 196 ) ---> other vegetables ( 1903 )  - conf( 0.45408163265306123 )
# <class 'tuple'>
# ('other vegetables', 'tropical fruit') ( 353 ) ---> citrus fruit ( 814 )  - conf( 0.2521246458923513 )
# <class 'tuple'>
# citrus fruit ( 814 ) ---> ('other vegetables', 'tropical fruit') ( 353 )  conf( 0.10933660933660934 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('citrus fruit', 'other vegetables') ( 284 ) ---> root vegetables ( 1072 )  - conf( 0.3591549295774648 )
# <class 'tuple'>
# ('citrus fruit', 'root vegetables') ( 174 ) ---> other vegetables ( 1903 )  - conf( 0.5862068965517241 )
# <class 'tuple'>
# ('other vegetables', 'root vegetables') ( 466 ) ---> citrus fruit ( 814 )  - conf( 0.21888412017167383 )
# <class 'tuple'>
# citrus fruit ( 814 ) ---> ('other vegetables', 'root vegetables') ( 466 )  conf( 0.12530712530712532 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('citrus fruit', 'pastry') ( 96 ) ---> whole milk ( 2513 )  - conf( 0.5 )
# <class 'tuple'>
# ('citrus fruit', 'whole milk') ( 300 ) ---> pastry ( 875 )  - conf( 0.16 )
# <class 'tuple'>
# ('pastry', 'whole milk') ( 327 ) ---> citrus fruit ( 814 )  - conf( 0.14678899082568808 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('citrus fruit', 'whole milk') ( 300 ) ---> yogurt ( 1372 )  - conf( 0.33666666666666667 )
# <class 'tuple'>
# ('citrus fruit', 'yogurt') ( 213 ) ---> whole milk ( 2513 )  - conf( 0.47417840375586856 )
# <class 'tuple'>
# ('whole milk', 'yogurt') ( 551 ) ---> citrus fruit ( 814 )  - conf( 0.18330308529945555 )
# <class 'tuple'>
# citrus fruit ( 814 ) ---> ('whole milk', 'yogurt') ( 551 )  conf( 0.12407862407862408 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('citrus fruit', 'root vegetables') ( 174 ) ---> whole milk ( 2513 )  - conf( 0.5172413793103449 )
# <class 'tuple'>
# ('citrus fruit', 'whole milk') ( 300 ) ---> root vegetables ( 1072 )  - conf( 0.3 )
# <class 'tuple'>
# ('root vegetables', 'whole milk') ( 481 ) ---> citrus fruit ( 814 )  - conf( 0.18711018711018712 )
# <class 'tuple'>
# citrus fruit ( 814 ) ---> ('root vegetables', 'whole milk') ( 481 )  conf( 0.11056511056511056 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('citrus fruit', 'rolls/buns') ( 165 ) ---> yogurt ( 1372 )  - conf( 0.34545454545454546 )
# <class 'tuple'>
# ('citrus fruit', 'yogurt') ( 213 ) ---> rolls/buns ( 1809 )  - conf( 0.2676056338028169 )
# <class 'tuple'>
# ('rolls/buns', 'yogurt') ( 338 ) ---> citrus fruit ( 814 )  - conf( 0.16863905325443787 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('citrus fruit', 'sausage') ( 111 ) ---> whole milk ( 2513 )  - conf( 0.44144144144144143 )
# <class 'tuple'>
# ('citrus fruit', 'whole milk') ( 300 ) ---> sausage ( 924 )  - conf( 0.16333333333333333 )
# <class 'tuple'>
# ('sausage', 'whole milk') ( 294 ) ---> citrus fruit ( 814 )  - conf( 0.16666666666666666 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('citrus fruit', 'root vegetables') ( 174 ) ---> yogurt ( 1372 )  - conf( 0.27586206896551724 )
# <class 'tuple'>
# ('citrus fruit', 'yogurt') ( 213 ) ---> root vegetables ( 1072 )  - conf( 0.22535211267605634 )
# <class 'tuple'>
# ('root vegetables', 'yogurt') ( 254 ) ---> citrus fruit ( 814 )  - conf( 0.1889763779527559 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('citrus fruit', 'other vegetables') ( 284 ) ---> yogurt ( 1372 )  - conf( 0.2640845070422535 )
# <class 'tuple'>
# ('citrus fruit', 'yogurt') ( 213 ) ---> other vegetables ( 1903 )  - conf( 0.352112676056338 )
# <class 'tuple'>
# ('other vegetables', 'yogurt') ( 427 ) ---> citrus fruit ( 814 )  - conf( 0.1756440281030445 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('citrus fruit', 'other vegetables') ( 284 ) ---> whole milk ( 2513 )  - conf( 0.4507042253521127 )
# <class 'tuple'>
# ('citrus fruit', 'whole milk') ( 300 ) ---> other vegetables ( 1903 )  - conf( 0.4266666666666667 )
# <class 'tuple'>
# ('other vegetables', 'whole milk') ( 736 ) ---> citrus fruit ( 814 )  - conf( 0.17391304347826086 )
# <class 'tuple'>
# citrus fruit ( 814 ) ---> ('other vegetables', 'whole milk') ( 736 )  conf( 0.15724815724815724 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('bottled water', 'citrus fruit') ( 133 ) ---> other vegetables ( 1903 )  - conf( 0.37593984962406013 )
# <class 'tuple'>
# ('bottled water', 'other vegetables') ( 244 ) ---> citrus fruit ( 814 )  - conf( 0.20491803278688525 )
# <class 'tuple'>
# ('citrus fruit', 'other vegetables') ( 284 ) ---> bottled water ( 1087 )  - conf( 0.176056338028169 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('bottled water', 'citrus fruit') ( 133 ) ---> whole milk ( 2513 )  - conf( 0.43609022556390975 )
# <class 'tuple'>
# ('bottled water', 'whole milk') ( 338 ) ---> citrus fruit ( 814 )  - conf( 0.17159763313609466 )
# <class 'tuple'>
# ('citrus fruit', 'whole milk') ( 300 ) ---> bottled water ( 1087 )  - conf( 0.19333333333333333 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('citrus fruit', 'rolls/buns') ( 165 ) ---> whole milk ( 2513 )  - conf( 0.4303030303030303 )
# <class 'tuple'>
# ('citrus fruit', 'whole milk') ( 300 ) ---> rolls/buns ( 1809 )  - conf( 0.23666666666666666 )
# <class 'tuple'>
# ('rolls/buns', 'whole milk') ( 557 ) ---> citrus fruit ( 814 )  - conf( 0.12746858168761221 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('citrus fruit', 'tropical fruit') ( 196 ) ---> yogurt ( 1372 )  - conf( 0.3163265306122449 )
# <class 'tuple'>
# ('citrus fruit', 'yogurt') ( 213 ) ---> tropical fruit ( 1032 )  - conf( 0.29107981220657275 )
# <class 'tuple'>
# ('tropical fruit', 'yogurt') ( 288 ) ---> citrus fruit ( 814 )  - conf( 0.2152777777777778 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('citrus fruit', 'other vegetables') ( 284 ) ---> rolls/buns ( 1809 )  - conf( 0.20774647887323944 )
# <class 'tuple'>
# ('citrus fruit', 'rolls/buns') ( 165 ) ---> other vegetables ( 1903 )  - conf( 0.3575757575757576 )
# <class 'tuple'>
# ('other vegetables', 'rolls/buns') ( 419 ) ---> citrus fruit ( 814 )  - conf( 0.14081145584725538 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('citrus fruit', 'tropical fruit') ( 196 ) ---> whole milk ( 2513 )  - conf( 0.45408163265306123 )
# <class 'tuple'>
# ('citrus fruit', 'whole milk') ( 300 ) ---> tropical fruit ( 1032 )  - conf( 0.2966666666666667 )
# <class 'tuple'>
# ('tropical fruit', 'whole milk') ( 416 ) ---> citrus fruit ( 814 )  - conf( 0.21394230769230768 )
# <class 'tuple'>
# citrus fruit ( 814 ) ---> ('tropical fruit', 'whole milk') ( 416 )  conf( 0.10933660933660934 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('domestic eggs', 'margarine') ( 82 ) ---> whole milk ( 2513 )  - conf( 0.6219512195121951 )
# <class 'tuple'>
# ('domestic eggs', 'whole milk') ( 295 ) ---> margarine ( 576 )  - conf( 0.17288135593220338 )
# <class 'tuple'>
# ('margarine', 'whole milk') ( 238 ) ---> domestic eggs ( 624 )  - conf( 0.21428571428571427 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('bottled water', 'margarine') ( 101 ) ---> whole milk ( 2513 )  - conf( 0.48514851485148514 )
# <class 'tuple'>
# ('bottled water', 'whole milk') ( 338 ) ---> margarine ( 576 )  - conf( 0.14497041420118342 )
# <class 'tuple'>
# ('margarine', 'whole milk') ( 238 ) ---> bottled water ( 1087 )  - conf( 0.20588235294117646 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('margarine', 'rolls/buns') ( 145 ) ---> whole milk ( 2513 )  - conf( 0.5379310344827586 )
# <class 'tuple'>
# ('margarine', 'whole milk') ( 238 ) ---> rolls/buns ( 1809 )  - conf( 0.3277310924369748 )
# <class 'tuple'>
# ('rolls/buns', 'whole milk') ( 557 ) ---> margarine ( 576 )  - conf( 0.1400359066427289 )
# <class 'tuple'>
# margarine ( 576 ) ---> ('rolls/buns', 'whole milk') ( 557 )  conf( 0.13541666666666666 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('margarine', 'whole milk') ( 238 ) ---> yogurt ( 1372 )  - conf( 0.28991596638655465 )
# <class 'tuple'>
# ('margarine', 'yogurt') ( 140 ) ---> whole milk ( 2513 )  - conf( 0.4928571428571429 )
# <class 'tuple'>
# ('whole milk', 'yogurt') ( 551 ) ---> margarine ( 576 )  - conf( 0.12522686025408347 )
# <class 'tuple'>
# margarine ( 576 ) ---> ('whole milk', 'yogurt') ( 551 )  conf( 0.11979166666666667 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('margarine', 'rolls/buns') ( 145 ) ---> yogurt ( 1372 )  - conf( 0.3103448275862069 )
# <class 'tuple'>
# ('margarine', 'yogurt') ( 140 ) ---> rolls/buns ( 1809 )  - conf( 0.32142857142857145 )
# <class 'tuple'>
# ('rolls/buns', 'yogurt') ( 338 ) ---> margarine ( 576 )  - conf( 0.13313609467455623 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('margarine', 'other vegetables') ( 194 ) ---> yogurt ( 1372 )  - conf( 0.28865979381443296 )
# <class 'tuple'>
# ('margarine', 'yogurt') ( 140 ) ---> other vegetables ( 1903 )  - conf( 0.4 )
# <class 'tuple'>
# ('other vegetables', 'yogurt') ( 427 ) ---> margarine ( 576 )  - conf( 0.13114754098360656 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('margarine', 'other vegetables') ( 194 ) ---> rolls/buns ( 1809 )  - conf( 0.26288659793814434 )
# <class 'tuple'>
# ('margarine', 'rolls/buns') ( 145 ) ---> other vegetables ( 1903 )  - conf( 0.35172413793103446 )
# <class 'tuple'>
# ('other vegetables', 'rolls/buns') ( 419 ) ---> margarine ( 576 )  - conf( 0.12171837708830549 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('margarine', 'other vegetables') ( 194 ) ---> whole milk ( 2513 )  - conf( 0.4690721649484536 )
# <class 'tuple'>
# ('margarine', 'whole milk') ( 238 ) ---> other vegetables ( 1903 )  - conf( 0.38235294117647056 )
# <class 'tuple'>
# ('other vegetables', 'whole milk') ( 736 ) ---> margarine ( 576 )  - conf( 0.12364130434782608 )
# <class 'tuple'>
# margarine ( 576 ) ---> ('other vegetables', 'whole milk') ( 736 )  conf( 0.1579861111111111 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('margarine', 'other vegetables') ( 194 ) ---> root vegetables ( 1072 )  - conf( 0.29896907216494845 )
# <class 'tuple'>
# ('margarine', 'root vegetables') ( 109 ) ---> other vegetables ( 1903 )  - conf( 0.5321100917431193 )
# <class 'tuple'>
# ('other vegetables', 'root vegetables') ( 466 ) ---> margarine ( 576 )  - conf( 0.12446351931330472 )
# <class 'tuple'>
# margarine ( 576 ) ---> ('other vegetables', 'root vegetables') ( 466 )  conf( 0.10069444444444445 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('margarine', 'root vegetables') ( 109 ) ---> whole milk ( 2513 )  - conf( 0.44954128440366975 )
# <class 'tuple'>
# ('margarine', 'whole milk') ( 238 ) ---> root vegetables ( 1072 )  - conf( 0.20588235294117646 )
# <class 'tuple'>
# ('root vegetables', 'whole milk') ( 481 ) ---> margarine ( 576 )  - conf( 0.10187110187110188 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('bottled water', 'rolls/buns') ( 238 ) ---> tropical fruit ( 1032 )  - conf( 0.22268907563025211 )
# <class 'tuple'>
# ('bottled water', 'tropical fruit') ( 182 ) ---> rolls/buns ( 1809 )  - conf( 0.29120879120879123 )
# <class 'tuple'>
# ('rolls/buns', 'tropical fruit') ( 242 ) ---> bottled water ( 1087 )  - conf( 0.2190082644628099 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('bottled water', 'other vegetables') ( 244 ) ---> tropical fruit ( 1032 )  - conf( 0.25 )
# <class 'tuple'>
# ('bottled water', 'tropical fruit') ( 182 ) ---> other vegetables ( 1903 )  - conf( 0.33516483516483514 )
# <class 'tuple'>
# ('other vegetables', 'tropical fruit') ( 353 ) ---> bottled water ( 1087 )  - conf( 0.17280453257790368 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('bottled water', 'tropical fruit') ( 182 ) ---> whole milk ( 2513 )  - conf( 0.4340659340659341 )
# <class 'tuple'>
# ('bottled water', 'whole milk') ( 338 ) ---> tropical fruit ( 1032 )  - conf( 0.23372781065088757 )
# <class 'tuple'>
# ('tropical fruit', 'whole milk') ( 416 ) ---> bottled water ( 1087 )  - conf( 0.18990384615384615 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('other vegetables', 'rolls/buns') ( 419 ) ---> tropical fruit ( 1032 )  - conf( 0.18377088305489261 )
# <class 'tuple'>
# ('other vegetables', 'tropical fruit') ( 353 ) ---> rolls/buns ( 1809 )  - conf( 0.21813031161473087 )
# <class 'tuple'>
# ('rolls/buns', 'tropical fruit') ( 242 ) ---> other vegetables ( 1903 )  - conf( 0.3181818181818182 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('rolls/buns', 'tropical fruit') ( 242 ) ---> whole milk ( 2513 )  - conf( 0.4462809917355372 )
# <class 'tuple'>
# ('rolls/buns', 'whole milk') ( 557 ) ---> tropical fruit ( 1032 )  - conf( 0.19389587073608616 )
# <class 'tuple'>
# ('tropical fruit', 'whole milk') ( 416 ) ---> rolls/buns ( 1809 )  - conf( 0.25961538461538464 )
# <class 'tuple'>
# <class 'tuple'>
# tropical fruit ( 1032 ) ---> ('rolls/buns', 'whole milk') ( 557 )  conf( 0.10465116279069768 )
# <class 'tuple'>
# <class 'tuple'>
# ('other vegetables', 'tropical fruit') ( 353 ) ---> whole milk ( 2513 )  - conf( 0.47592067988668557 )
# <class 'tuple'>
# ('other vegetables', 'whole milk') ( 736 ) ---> tropical fruit ( 1032 )  - conf( 0.22826086956521738 )
# <class 'tuple'>
# ('tropical fruit', 'whole milk') ( 416 ) ---> other vegetables ( 1903 )  - conf( 0.40384615384615385 )
# <class 'tuple'>
# <class 'tuple'>
# tropical fruit ( 1032 ) ---> ('other vegetables', 'whole milk') ( 736 )  conf( 0.16279069767441862 )
# <class 'tuple'>
# <class 'tuple'>
# ('bottled water', 'root vegetables') ( 154 ) ---> tropical fruit ( 1032 )  - conf( 0.2922077922077922 )
# <class 'tuple'>
# ('bottled water', 'tropical fruit') ( 182 ) ---> root vegetables ( 1072 )  - conf( 0.24725274725274726 )
# <class 'tuple'>
# ('root vegetables', 'tropical fruit') ( 207 ) ---> bottled water ( 1087 )  - conf( 0.21739130434782608 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('root vegetables', 'tropical fruit') ( 207 ) ---> yogurt ( 1372 )  - conf( 0.3864734299516908 )
# <class 'tuple'>
# ('root vegetables', 'yogurt') ( 254 ) ---> tropical fruit ( 1032 )  - conf( 0.31496062992125984 )
# <class 'tuple'>
# ('tropical fruit', 'yogurt') ( 288 ) ---> root vegetables ( 1072 )  - conf( 0.2777777777777778 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('other vegetables', 'root vegetables') ( 466 ) ---> tropical fruit ( 1032 )  - conf( 0.259656652360515 )
# <class 'tuple'>
# ('other vegetables', 'tropical fruit') ( 353 ) ---> root vegetables ( 1072 )  - conf( 0.34277620396600567 )
# <class 'tuple'>
# ('root vegetables', 'tropical fruit') ( 207 ) ---> other vegetables ( 1903 )  - conf( 0.5845410628019324 )
# <class 'tuple'>
# <class 'tuple'>
# root vegetables ( 1072 ) ---> ('other vegetables', 'tropical fruit') ( 353 )  conf( 0.11287313432835822 )
# <class 'tuple'>
# tropical fruit ( 1032 ) ---> ('other vegetables', 'root vegetables') ( 466 )  conf( 0.11724806201550388 )
# <class 'tuple'>
# ('bottled water', 'tropical fruit') ( 182 ) ---> yogurt ( 1372 )  - conf( 0.38461538461538464 )
# <class 'tuple'>
# ('bottled water', 'yogurt') ( 226 ) ---> tropical fruit ( 1032 )  - conf( 0.30973451327433627 )
# <class 'tuple'>
# ('tropical fruit', 'yogurt') ( 288 ) ---> bottled water ( 1087 )  - conf( 0.24305555555555555 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('bottled water', 'soda') ( 285 ) ---> tropical fruit ( 1032 )  - conf( 0.17894736842105263 )
# <class 'tuple'>
# ('bottled water', 'tropical fruit') ( 182 ) ---> soda ( 1715 )  - conf( 0.2802197802197802 )
# <class 'tuple'>
# ('soda', 'tropical fruit') ( 205 ) ---> bottled water ( 1087 )  - conf( 0.24878048780487805 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('soda', 'tropical fruit') ( 205 ) ---> yogurt ( 1372 )  - conf( 0.3170731707317073 )
# <class 'tuple'>
# ('soda', 'yogurt') ( 269 ) ---> tropical fruit ( 1032 )  - conf( 0.241635687732342 )
# <class 'tuple'>
# ('tropical fruit', 'yogurt') ( 288 ) ---> soda ( 1715 )  - conf( 0.22569444444444445 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('other vegetables', 'tropical fruit') ( 353 ) ---> yogurt ( 1372 )  - conf( 0.34277620396600567 )
# <class 'tuple'>
# ('other vegetables', 'yogurt') ( 427 ) ---> tropical fruit ( 1032 )  - conf( 0.28337236533957844 )
# <class 'tuple'>
# ('tropical fruit', 'yogurt') ( 288 ) ---> other vegetables ( 1903 )  - conf( 0.4201388888888889 )
# <class 'tuple'>
# <class 'tuple'>
# tropical fruit ( 1032 ) ---> ('other vegetables', 'yogurt') ( 427 )  conf( 0.11724806201550388 )
# <class 'tuple'>
# <class 'tuple'>
# ('other vegetables', 'soda') ( 322 ) ---> tropical fruit ( 1032 )  - conf( 0.2204968944099379 )
# <class 'tuple'>
# ('other vegetables', 'tropical fruit') ( 353 ) ---> soda ( 1715 )  - conf( 0.20113314447592068 )
# <class 'tuple'>
# ('soda', 'tropical fruit') ( 205 ) ---> other vegetables ( 1903 )  - conf( 0.3463414634146341 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('rolls/buns', 'root vegetables') ( 239 ) ---> tropical fruit ( 1032 )  - conf( 0.24267782426778242 )
# <class 'tuple'>
# ('rolls/buns', 'tropical fruit') ( 242 ) ---> root vegetables ( 1072 )  - conf( 0.2396694214876033 )
# <class 'tuple'>
# ('root vegetables', 'tropical fruit') ( 207 ) ---> rolls/buns ( 1809 )  - conf( 0.28019323671497587 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('rolls/buns', 'soda') ( 377 ) ---> tropical fruit ( 1032 )  - conf( 0.14058355437665782 )
# <class 'tuple'>
# ('rolls/buns', 'tropical fruit') ( 242 ) ---> soda ( 1715 )  - conf( 0.2190082644628099 )
# <class 'tuple'>
# ('soda', 'tropical fruit') ( 205 ) ---> rolls/buns ( 1809 )  - conf( 0.25853658536585367 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('root vegetables', 'tropical fruit') ( 207 ) ---> whole milk ( 2513 )  - conf( 0.5700483091787439 )
# <class 'tuple'>
# ('root vegetables', 'whole milk') ( 481 ) ---> tropical fruit ( 1032 )  - conf( 0.24532224532224534 )
# <class 'tuple'>
# ('tropical fruit', 'whole milk') ( 416 ) ---> root vegetables ( 1072 )  - conf( 0.28365384615384615 )
# <class 'tuple'>
# root vegetables ( 1072 ) ---> ('tropical fruit', 'whole milk') ( 416 )  conf( 0.11007462686567164 )
# <class 'tuple'>
# tropical fruit ( 1032 ) ---> ('root vegetables', 'whole milk') ( 481 )  conf( 0.11434108527131782 )
# <class 'tuple'>
# <class 'tuple'>
# ('tropical fruit', 'whole milk') ( 416 ) ---> yogurt ( 1372 )  - conf( 0.3581730769230769 )
# <class 'tuple'>
# ('tropical fruit', 'yogurt') ( 288 ) ---> whole milk ( 2513 )  - conf( 0.5173611111111112 )
# <class 'tuple'>
# ('whole milk', 'yogurt') ( 551 ) ---> tropical fruit ( 1032 )  - conf( 0.27041742286751363 )
# <class 'tuple'>
# tropical fruit ( 1032 ) ---> ('whole milk', 'yogurt') ( 551 )  conf( 0.14437984496124032 )
# <class 'tuple'>
# <class 'tuple'>
# yogurt ( 1372 ) ---> ('tropical fruit', 'whole milk') ( 416 )  conf( 0.10860058309037901 )
# <class 'tuple'>
# ('rolls/buns', 'tropical fruit') ( 242 ) ---> yogurt ( 1372 )  - conf( 0.35537190082644626 )
# <class 'tuple'>
# ('rolls/buns', 'yogurt') ( 338 ) ---> tropical fruit ( 1032 )  - conf( 0.25443786982248523 )
# <class 'tuple'>
# ('tropical fruit', 'yogurt') ( 288 ) ---> rolls/buns ( 1809 )  - conf( 0.2986111111111111 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('soda', 'tropical fruit') ( 205 ) ---> whole milk ( 2513 )  - conf( 0.375609756097561 )
# <class 'tuple'>
# ('soda', 'whole milk') ( 394 ) ---> tropical fruit ( 1032 )  - conf( 0.19543147208121828 )
# <class 'tuple'>
# ('tropical fruit', 'whole milk') ( 416 ) ---> soda ( 1715 )  - conf( 0.18509615384615385 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('rolls/buns', 'soda') ( 377 ) ---> yogurt ( 1372 )  - conf( 0.22546419098143236 )
# <class 'tuple'>
# ('rolls/buns', 'yogurt') ( 338 ) ---> soda ( 1715 )  - conf( 0.2514792899408284 )
# <class 'tuple'>
# ('soda', 'yogurt') ( 269 ) ---> rolls/buns ( 1809 )  - conf( 0.3159851301115242 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('other vegetables', 'soda') ( 322 ) ---> yogurt ( 1372 )  - conf( 0.2546583850931677 )
# <class 'tuple'>
# ('other vegetables', 'yogurt') ( 427 ) ---> soda ( 1715 )  - conf( 0.1920374707259953 )
# <class 'tuple'>
# ('soda', 'yogurt') ( 269 ) ---> other vegetables ( 1903 )  - conf( 0.3048327137546468 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('other vegetables', 'rolls/buns') ( 419 ) ---> yogurt ( 1372 )  - conf( 0.26968973747016706 )
# <class 'tuple'>
# ('other vegetables', 'yogurt') ( 427 ) ---> rolls/buns ( 1809 )  - conf( 0.2646370023419204 )
# <class 'tuple'>
# ('rolls/buns', 'yogurt') ( 338 ) ---> other vegetables ( 1903 )  - conf( 0.3343195266272189 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('soda', 'whole milk') ( 394 ) ---> yogurt ( 1372 )  - conf( 0.2614213197969543 )
# <class 'tuple'>
# ('soda', 'yogurt') ( 269 ) ---> whole milk ( 2513 )  - conf( 0.3828996282527881 )
# <class 'tuple'>
# ('whole milk', 'yogurt') ( 551 ) ---> soda ( 1715 )  - conf( 0.1869328493647913 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('rolls/buns', 'whole milk') ( 557 ) ---> yogurt ( 1372 )  - conf( 0.2746858168761221 )
# <class 'tuple'>
# ('rolls/buns', 'yogurt') ( 338 ) ---> whole milk ( 2513 )  - conf( 0.4526627218934911 )
# <class 'tuple'>
# ('whole milk', 'yogurt') ( 551 ) ---> rolls/buns ( 1809 )  - conf( 0.2776769509981851 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# yogurt ( 1372 ) ---> ('rolls/buns', 'whole milk') ( 557 )  conf( 0.11151603498542274 )
# <class 'tuple'>
# ('other vegetables', 'whole milk') ( 736 ) ---> yogurt ( 1372 )  - conf( 0.297554347826087 )
# <class 'tuple'>
# ('other vegetables', 'yogurt') ( 427 ) ---> whole milk ( 2513 )  - conf( 0.5128805620608899 )
# <class 'tuple'>
# ('whole milk', 'yogurt') ( 551 ) ---> other vegetables ( 1903 )  - conf( 0.397459165154265 )
# <class 'tuple'>
# other vegetables ( 1903 ) ---> ('whole milk', 'yogurt') ( 551 )  conf( 0.11508145034156594 )
# <class 'tuple'>
# <class 'tuple'>
# yogurt ( 1372 ) ---> ('other vegetables', 'whole milk') ( 736 )  conf( 0.15962099125364432 )
# <class 'tuple'>
# ('coffee', 'whole milk') ( 184 ) ---> yogurt ( 1372 )  - conf( 0.2717391304347826 )
# <class 'tuple'>
# ...
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# cat food ( 229 ) ---> yogurt ( 1372 )  - conf( 0.2663755458515284 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# cat food ( 229 ) ---> soda ( 1715 )  - conf( 0.1965065502183406 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ham ( 256 ) ---> other vegetables ( 1903 )  - conf( 0.3515625 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ham ( 256 ) ---> whole milk ( 2513 )  - conf( 0.44140625 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ham ( 256 ) ---> yogurt ( 1372 )  - conf( 0.2578125 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ham ( 256 ) ---> rolls/buns ( 1809 )  - conf( 0.265625 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ham ( 256 ) ---> sausage ( 924 )  - conf( 0.19140625 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ham ( 256 ) ---> soda ( 1715 )  - conf( 0.19140625 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ham ( 256 ) ---> tropical fruit ( 1032 )  - conf( 0.20703125 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ham ( 256 ) ---> white bread ( 414 )  - conf( 0.1953125 )
# <class 'tuple'>
# <class 'tuple'>
# white bread ( 414 ) ---> ham ( 256 )  - conf( 0.12077294685990338 )
# <class 'tuple'>
# <class 'tuple'>
# baking powder ( 174 ) ---> other vegetables ( 1903 )  - conf( 0.41379310344827586 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# baking powder ( 174 ) ---> whole milk ( 2513 )  - conf( 0.5229885057471264 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# baking powder ( 174 ) ---> yogurt ( 1372 )  - conf( 0.25862068965517243 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# baking powder ( 174 ) ---> whipped/sour cream ( 705 )  - conf( 0.25862068965517243 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# pickled vegetables ( 176 ) ---> other vegetables ( 1903 )  - conf( 0.35795454545454547 )
# <class 'tuple'>
# <class 'tuple'>
# pickled vegetables ( 176 ) ---> whole milk ( 2513 )  - conf( 0.3977272727272727 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# oil ( 276 ) ---> other vegetables ( 1903 )  - conf( 0.35507246376811596 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# oil ( 276 ) ---> whole milk ( 2513 )  - conf( 0.40217391304347827 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# oil ( 276 ) ---> root vegetables ( 1072 )  - conf( 0.25 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# oil ( 276 ) ---> rolls/buns ( 1809 )  - conf( 0.18115942028985507 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# oil ( 276 ) ---> yogurt ( 1372 )  - conf( 0.18840579710144928 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# oil ( 276 ) ---> citrus fruit ( 814 )  - conf( 0.17753623188405798 )
# <class 'tuple'>
# <class 'tuple'>
# oil ( 276 ) ---> tropical fruit ( 1032 )  - conf( 0.16666666666666666 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# oil ( 276 ) ---> soda ( 1715 )  - conf( 0.16666666666666666 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# chewing gum ( 207 ) ---> other vegetables ( 1903 )  - conf( 0.21739130434782608 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# chewing gum ( 207 ) ---> whole milk ( 2513 )  - conf( 0.24154589371980675 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# chewing gum ( 207 ) ---> soda ( 1715 )  - conf( 0.2560386473429952 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ice cream ( 246 ) ---> soda ( 1715 )  - conf( 0.24390243902439024 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ice cream ( 246 ) ---> whole milk ( 2513 )  - conf( 0.23577235772357724 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ice cream ( 246 ) ---> other vegetables ( 1903 )  - conf( 0.2032520325203252 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# frozen vegetables ( 473 ) ---> domestic eggs ( 624 )  - conf( 0.10782241014799154 )
# <class 'tuple'>
# <class 'tuple'>
# frozen vegetables ( 473 ) ---> root vegetables ( 1072 )  - conf( 0.24101479915433405 )
# <class 'tuple'>
# <class 'tuple'>
# root vegetables ( 1072 ) ---> frozen vegetables ( 473 )  - conf( 0.10634328358208955 )
# <class 'tuple'>
# <class 'tuple'>
# frozen vegetables ( 473 ) ---> other vegetables ( 1903 )  - conf( 0.3699788583509514 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# frozen vegetables ( 473 ) ---> whipped/sour cream ( 705 )  - conf( 0.1649048625792812 )
# <class 'tuple'>
# <class 'tuple'>
# whipped/sour cream ( 705 ) ---> frozen vegetables ( 473 )  - conf( 0.11063829787234042 )
# <class 'tuple'>
# <class 'tuple'>
# frozen vegetables ( 473 ) ---> yogurt ( 1372 )  - conf( 0.25792811839323465 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# frozen vegetables ( 473 ) ---> soda ( 1715 )  - conf( 0.17970401691331925 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# frozen vegetables ( 473 ) ---> fruit/vegetable juice ( 711 )  - conf( 0.16279069767441862 )
# <class 'tuple'>
# <class 'tuple'>
# fruit/vegetable juice ( 711 ) ---> frozen vegetables ( 473 )  - conf( 0.10829817158931083 )
# <class 'tuple'>
# <class 'tuple'>
# frozen vegetables ( 473 ) ---> whole milk ( 2513 )  - conf( 0.4249471458773784 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# frozen vegetables ( 473 ) ---> sausage ( 924 )  - conf( 0.12473572938689217 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# frozen vegetables ( 473 ) ---> bottled water ( 1087 )  - conf( 0.12896405919661733 )
# <class 'tuple'>
# <class 'tuple'>
# frozen vegetables ( 473 ) ---> margarine ( 576 )  - conf( 0.10570824524312897 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# frozen vegetables ( 473 ) ---> frankfurter ( 580 )  - conf( 0.10570824524312897 )
# <class 'tuple'>
# <class 'tuple'>
# frozen vegetables ( 473 ) ---> pip fruit ( 744 )  - conf( 0.1522198731501057 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# frozen vegetables ( 473 ) ---> tropical fruit ( 1032 )  - conf( 0.18181818181818182 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# frozen vegetables ( 473 ) ---> rolls/buns ( 1809 )  - conf( 0.21141649048625794 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# butter ( 545 ) ---> frozen vegetables ( 473 )  - conf( 0.10458715596330276 )
# <class 'tuple'>
# <class 'tuple'>
# frozen vegetables ( 473 ) ---> butter ( 545 )  - conf( 0.12050739957716702 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# frozen vegetables ( 473 ) ---> pork ( 567 )  - conf( 0.1331923890063425 )
# <class 'tuple'>
# <class 'tuple'>
# pork ( 567 ) ---> frozen vegetables ( 473 )  - conf( 0.1111111111111111 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# frozen vegetables ( 473 ) ---> citrus fruit ( 814 )  - conf( 0.13742071881606766 )
# <class 'tuple'>
# <class 'tuple'>
# canned fish ( 148 ) ---> other vegetables ( 1903 )  - conf( 0.33783783783783783 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# canned fish ( 148 ) ---> whole milk ( 2513 )  - conf( 0.31756756756756754 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# red/blush wine ( 189 ) ---> soda ( 1715 )  - conf( 0.23809523809523808 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# red/blush wine ( 189 ) ---> other vegetables ( 1903 )  - conf( 0.25925925925925924 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# red/blush wine ( 189 ) ---> bottled beer ( 792 )  - conf( 0.25396825396825395 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# specialty chocolate ( 299 ) ---> other vegetables ( 1903 )  - conf( 0.20066889632107024 )
# <class 'tuple'>
# <class 'tuple'>
# specialty chocolate ( 299 ) ---> whole milk ( 2513 )  - conf( 0.26421404682274247 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# specialty chocolate ( 299 ) ---> soda ( 1715 )  - conf( 0.20735785953177258 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# specialty chocolate ( 299 ) ---> rolls/buns ( 1809 )  - conf( 0.18394648829431437 )
# <class 'tuple'>
# <class 'tuple'>
# specialty chocolate ( 299 ) ---> yogurt ( 1372 )  - conf( 0.15719063545150502 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# specialty chocolate ( 299 ) ---> shopping bags ( 969 )  - conf( 0.15719063545150502 )
# <class 'tuple'>
# <class 'tuple'>
# frozen meals ( 279 ) ---> tropical fruit ( 1032 )  - conf( 0.1935483870967742 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# frozen meals ( 279 ) ---> rolls/buns ( 1809 )  - conf( 0.17204301075268819 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# frozen meals ( 279 ) ---> other vegetables ( 1903 )  - conf( 0.26523297491039427 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# frozen meals ( 279 ) ---> whole milk ( 2513 )  - conf( 0.34767025089605735 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# frozen meals ( 279 ) ---> yogurt ( 1372 )  - conf( 0.21863799283154123 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# frozen meals ( 279 ) ---> soda ( 1715 )  - conf( 0.21863799283154123 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# frozen meals ( 279 ) ---> pip fruit ( 744 )  - conf( 0.16129032258064516 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# frozen meals ( 279 ) ---> shopping bags ( 969 )  - conf( 0.16487455197132617 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# canned vegetables ( 106 ) ---> other vegetables ( 1903 )  - conf( 0.4339622641509434 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# onions ( 305 ) ---> domestic eggs ( 624 )  - conf( 0.15737704918032788 )
# <class 'tuple'>
# <class 'tuple'>
# onions ( 305 ) ---> whipped/sour cream ( 705 )  - conf( 0.16393442622950818 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# onions ( 305 ) ---> root vegetables ( 1072 )  - conf( 0.30491803278688523 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# onions ( 305 ) ---> other vegetables ( 1903 )  - conf( 0.45901639344262296 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# onions ( 305 ) ---> whole milk ( 2513 )  - conf( 0.3901639344262295 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# onions ( 305 ) ---> bottled water ( 1087 )  - conf( 0.1901639344262295 )
# <class 'tuple'>
# <class 'tuple'>
# onions ( 305 ) ---> rolls/buns ( 1809 )  - conf( 0.21967213114754097 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# onions ( 305 ) ---> tropical fruit ( 1032 )  - conf( 0.18360655737704917 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# onions ( 305 ) ---> yogurt ( 1372 )  - conf( 0.23278688524590163 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# onions ( 305 ) ---> soda ( 1715 )  - conf( 0.17049180327868851 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# onions ( 305 ) ---> citrus fruit ( 814 )  - conf( 0.18032786885245902 )
# <class 'tuple'>
# <class 'tuple'>
# herbs ( 160 ) ---> other vegetables ( 1903 )  - conf( 0.475 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# herbs ( 160 ) ---> whole milk ( 2513 )  - conf( 0.475 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# herbs ( 160 ) ---> root vegetables ( 1072 )  - conf( 0.43125 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# sliced cheese ( 241 ) ---> sausage ( 924 )  - conf( 0.2863070539419087 )
# <class 'tuple'>
# <class 'tuple'>
# sliced cheese ( 241 ) ---> whole milk ( 2513 )  - conf( 0.43983402489626555 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# sliced cheese ( 241 ) ---> tropical fruit ( 1032 )  - conf( 0.2157676348547718 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# sliced cheese ( 241 ) ---> soda ( 1715 )  - conf( 0.2074688796680498 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# sliced cheese ( 241 ) ---> other vegetables ( 1903 )  - conf( 0.36929460580912865 )
# <class 'tuple'>
# <class 'tuple'>
# sliced cheese ( 241 ) ---> yogurt ( 1372 )  - conf( 0.3278008298755187 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# sliced cheese ( 241 ) ---> rolls/buns ( 1809 )  - conf( 0.3112033195020747 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# sliced cheese ( 241 ) ---> root vegetables ( 1072 )  - conf( 0.22821576763485477 )
# <class 'tuple'>
# <class 'tuple'>
# pasta ( 148 ) ---> whole milk ( 2513 )  - conf( 0.40540540540540543 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# soft cheese ( 168 ) ---> other vegetables ( 1903 )  - conf( 0.4166666666666667 )
# <class 'tuple'>
# <class 'tuple'>
# soft cheese ( 168 ) ---> whole milk ( 2513 )  - conf( 0.44047619047619047 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# soft cheese ( 168 ) ---> yogurt ( 1372 )  - conf( 0.35119047619047616 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# soft cheese ( 168 ) ---> rolls/buns ( 1809 )  - conf( 0.31547619047619047 )
# <class 'tuple'>
# <class 'tuple'>
# cake bar ( 130 ) ---> whole milk ( 2513 )  - conf( 0.4230769230769231 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# frozen fish ( 115 ) ---> other vegetables ( 1903 )  - conf( 0.4 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# frozen fish ( 115 ) ---> whole milk ( 2513 )  - conf( 0.4260869565217391 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# meat ( 254 ) ---> soda ( 1715 )  - conf( 0.2125984251968504 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# meat ( 254 ) ---> rolls/buns ( 1809 )  - conf( 0.2677165354330709 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# meat ( 254 ) ---> whole milk ( 2513 )  - conf( 0.3858267716535433 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# meat ( 254 ) ---> sausage ( 924 )  - conf( 0.2047244094488189 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# meat ( 254 ) ---> other vegetables ( 1903 )  - conf( 0.3858267716535433 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# meat ( 254 ) ---> root vegetables ( 1072 )  - conf( 0.1968503937007874 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# meat ( 254 ) ---> yogurt ( 1372 )  - conf( 0.2047244094488189 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# mustard ( 118 ) ---> whole milk ( 2513 )  - conf( 0.4322033898305085 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# liquor ( 109 ) ---> bottled beer ( 792 )  - conf( 0.42201834862385323 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# roll products ( 101 ) ---> other vegetables ( 1903 )  - conf( 0.46534653465346537 )
# <class 'tuple'>
# <class 'tuple'>
# roll products ( 101 ) ---> whole milk ( 2513 )  - conf( 0.45544554455445546 )
# <class 'tuple'>
# <class 'tuple'>
# 2123 rules generated
# FP_Growth_spent_time 24.654345512390137
# 33

# %% [markdown]
# # FP-growth     big_minsup and big_minconf with groceries.csv

# %%
import csv
import pandas as pd
from itertools import combinations
import time


#Read data from CSV
data = pd.read_csv('groceries.csv')
# data = pd.read_csv('Market_Basket_Optimisation.csv', header=None)
#
#Parameters
minsup = float(input("Support-Threshold: "))
minsup = minsup * len(data)
minconf = float(input("Confidence-Threshold: "))
print(len(data))#9835
time_start = time.time()
#Add all data in a list of lists
items = []  
# print(len(data.values[0]))#1列(ROW)有32的物品
for i in range(0, len(data)):  #將所有data中的物品一列一列放到items
     items.append([str(data.values[i, j]) for j in range(0, len(data.values[0]))])

#Creating a list of dictionaries
count = [dict() for x in range(len(data.values[0]) + 1)]
# print(items)
# #Count support for each individual items
s=[]
for i in items:
    for j in i:      #讀取所有items
        s.append(j)
for i in s:                      #創字典 放在count[1]
    #If item is present in dictionary, increment its count by 1
    if i in count[1]:
        count[1][i] = count[1][i] + 1
    #If item is not present in dictionary, set its count to 1
    else:
        count[1][i] = 1     #{'i':1}

# #Remove infrequent and empty items #去除小於minsup,nan
for i in count[1].copy():
    if(count[1][i] < minsup):
        count[1].pop(i)
count[1].pop('nan') #去除以key = 'NAN'產生的值

# #Storing transactions as lists without infrequent items
a = list(count[1]) #列出所有符合的KEY
item = [list() for i in range(len(data))] #創造len(data) = 9835個list 
c = 0 
for i in range(0,len(items)): ##將所有data中的物品一列一列放到items
    for j in range(len(items[i])):
#         print(items[i][j])
        if(a.__contains__(items[i][j]) != 0): #確認物品是否存在
            item[i].append(items[i][j]) #將物品分成[['a', 'b', 'c'],[]]與itmes不同的地方是裡練已經沒有NAN了

#Function to sort list to support
def sort(a): #a = 所有符合的KEY的list
    for i in range(len(a) - 1):
        for j in range(len(a) - i - 1):
            if(count[1][a[j]] < count[1][a[j + 1]]): #如果下一個比上一個大則互換位子
                a[j],a[j + 1] = a[j + 1],a[j]
                
#Call function to sort all transactions in descending order of their support
for i in range(0,len(data)): #9835
    if(len(item[i]) > 1): #如果不只一個物件就排序他
        sort(item[i])

#Tree class for FP-Tree
class tree: #設計樹根，分支
    def __init__(self, name, sup, parent):
        self.name = name
        self.sup = sup
        self.nodeLink = None
        self.parent = parent
        self.children = []

#Function to check if the node is present is a child of the current node
def ispresent(node,name):    #確認是否有children
    f = -1               
    for i in node.children:
        f += 1
        if(i.name == name):
            return f
    return -1

#HeaderTable which stores the reference of last/first occurence of an item. Used as a linked list to generate candidate trees 
lastocc = count[1].copy() #符合sup的字典
for i in lastocc: #lastocc字典中所有值皆為NONE
    lastocc[i] = None
#Function to create FP-tree
root = tree("root", -1, None)
z = 0
for i in item: #item為沒有NAN的items
    current = root
    for j in range(len(i)): #len(i)9835
        if(ispresent(current,i[j])>=0): #第一次通常不符合此情形，直接執行else，看有沒有children
            current = current.children[ispresent(current, i[j])]
            current.sup=current.sup + 1
        else:
            child=tree(i[j], 1, current)    #創建i[j]子根
            current.children.append(child) #將子根放入children =[] 
            t = current #t 記錄柱上一層的tree1
            current = current.children[ispresent(current, i[j])] #現在current.children裡有子根，所以self.name = i[j]如下示意，
            #ispresent(current,i[j])回傳 0 ，現在的current為tree2
            current.parent = t #紀錄上一層tree1
            if(lastocc[current.name] == None):
                lastocc[current.name] = current #創建{'i[j]': tree2-1()} 
            else:#創出第一層並列樹枝
                current.nodeLink = lastocc[current.name] #將tree2-2連結到tree4
                lastocc[current.name] = current #CURRENT = TREE2-2 {'i[j]': tree2-2}
            
# class tree1:
#     def __init__(self, name, sup, parent):
#         self.name = 'root'
#         self.sup = -1
#         self.nodeLink = None
#         self.parent = none
#         self.children = [
#   class tree2-1:
#     def __init__(self, name, sup, parent):      [['A','B','C'],['C','A']]
#         self.name = 'A'
#         self.sup = 1
#         self.nodeLink = NONE
#         self.parent = parent
#         self.children = [
#                                     class tree3:
#                                         def __init__(self, name, sup, parent):
#                                             self.name = 'B'
#                                             self.sup = 1
#                                             self.nodeLink = None
#                                             self.parent = parent
#                                             self.children = [
#                                                                 class tree4:
#                                                                     def __init__(self, name, sup, parent):
#                                                                         self.name = 'B'
#                                                                         self.sup = 1
#                                                                         self.nodeLink = None
#                                                                         self.parent = parent
#                                                                         self.children = []
#                                                                 ]
#         ],
#   class tree2-2:
#     def __init__(self, name, sup, parent):
#         self.name = 'C'
#         self.sup = sup
#         self.nodeLink = TREE 4
#         self.parent = TREE1
#         self.children = []
# ]

#Function to extract single item set from a tuple
def value(a):
    a = str(a)
    a = a[:-2]
    a = a[2:]
    a = a[:-1]
    return a

#Function to get frequent itemsets with suffix 'node' and length n
def singlepath(node, n):
    c = 0
    sup = node.sup
    path = []
    pathname = []
    current = node
    
    #Get the path from current node to root
    while(current.parent!=None): #查看目current是否為'root'，如果是則無parent，重複做直道回到最上層('root')
        path.append(current)     #將current內容紀錄(tree)
        pathname.append(current.name)      #('c')
        current = current.parent  #往上一層移動
    path.remove(node) #除了自己以外的路線
    pathname.remove(node.name) 
    candidatepath = []
    temp_candidatepath = []
   
    #Generate combinations of length n in the path
    a = (list(combinations(pathname, n))) #列出除了自己以外的長度為n的組合
    for j in a:
        temp_candidatepath.append(tuple(sorted(j)))   #以tuple形式存在temp_candidatapath裡
    #Append the suffix 'node.name' to the above paths
    for j in temp_candidatepath:
        j = list(j) #再次變回list
        j.append(node.name) #將原本剔除的當前TREE名加回去 變成包含當前的組合，就是在做freqent pattern
        candidatepath.append(sorted(j)) #在加回去變成 [['a','c'],['b','c']]
    #Update counts of the generated itemsets
    for j in candidatepath:
        j = tuple(j) #j = ('a','c')
        if j in count[n+1]: #count[1]為符合minsup的字典，n至少會從1開始 
            count[n + 1][j] = count[n+1][j] + sup  # 將之前已創好的value值，加上當前tree所有的sup
        else:
            count[n + 1][j] = sup #創建新字典,此sup為當前tree存有的sup
            
    #Iterating in the candidate tree recursively 
    if(node.nodeLink != None): #查看是否存在分支
        node=node.nodeLink
        singlepath(node, i) #i為組合長度
    
#Check if itemset is frequent
def frequent(n): #算出現次數
    f=0
    for i in count[n]:
        if(count[n][i] >= minsup):
            f=1
    if(f == 1):
        return 1
    else:
        return 0

#Call singlepath function for all frequent nodes
for i in range(1, len(data.values[0]) + 1): #1列(ROW)有32的物品, +1是確保有32為一組的組合  #!
    if(frequent(i) == 1):
        for j in lastocc: #開始製造組合，將結果放到count[]裡，count唯有32空字典的list
            singlepath(lastocc[j], i)

#Remove infrequent itemsets
for z in range(len(data.values[0]) + 1):            
    for i in count[z].copy():
            if(count[z][i] < minsup): #查看所有的dict裡面的東西，是否符合minsup
                count[z].pop(i) #去掉不符合的
frequent_pattern = []
for items in count:
    for want in items:
        frequent_pattern.append(want)
                
#Get 'q', the length of the longest itemset
i=2
while(len(count[i-1]) != 0): #從這邊就能知道最大符合長度是多長，因為不符合的都被刪掉了
    i = i + 1
q = i - 2

#Find maximal and closed itemsets
maximal = []
closed = []
for i in range(1, q):
    for j in count[i]:
        fm = 0
        fc = 0
        for k in count[i+1]:
            a = set(list([j]))
            b = set(list(k))
            #Set is maximal if no immediate superset is frequent
            if(a.intersection(b) == a): #如果兩者重疊則maximal
                fm = 1 
                #Set is closed if none of its immediate supersets have equal support
                if(count[i][j] == count[i+1][k]): #出現次數相同
                    fc = 1
        if(fm == 0):
            maximal.append(j)
        if(fc == 0):
            closed.append(j)
#All sets at the top of the tree are automatically maximal and closed
for i in count[q]:
    maximal.append(i)
    closed.append(i)
print("frequent_pattern")
print(len(frequent_pattern))
print(frequent_pattern)
    
#Find Association Rules 
print("Association_Rules")
ant=count.copy()
for i in range(q, 0, -1): #從後面樹回來
    for j in ant[i]:  #ant = count
        for k in range(i-1, 0, -1): # i = q(最大長度)
            s = list(combinations(list(j), k))  #將所有可能組出來   
            #Traverse through list of all combinations of antecedants
            for n in s:
                #Sorting to prevent duplicate itemsets 
                r=tuple(sorted(set(j).difference(set(n))))
                l=len(n) #輸入進來的字元長度
                #Check if len(n)==1 to be able to extract key to search in the support dictionary. 
                if(l == 1):
                    n=value(n)
                    l=1
                if(len(r) == 1):
                    r2=value(r)
                if(n != None):
                    #If rule's confidence is greater than minconfidence, then print the rule
                    if((ant[len(j)][j] / ant[l][n]) >= minconf):
                        #Rule is only significant if it is present in CLOSED, otherwise it is redundant
                        if(closed.__contains__((n))):
                            c += 1
                            if(len(r) == 1):
                                print(n,"(",ant[l][n],")","--->",r2,"(",ant[len(r)][r2],")", " - conf(",(ant[len(j)][j]/ant[l][n]),")")
                            else:
                                print(n,"(",ant[l][n],")","--->",r,"(",ant[len(r)][r],")", " conf(",(ant[len(j)][j]/ant[l][n]),")")
print(c, "rules generated")
time_end = time.time()
print('FP_Growth_spent_time', time_end - time_start)
# print( time_end - time_start)
# Out:
# Support-Threshold: 0.045
# Confidence-Threshold: 0.1
# 9835
# frequent_pattern
# 35
# ['citrus fruit', 'margarine', 'tropical fruit', 'yogurt', 'coffee', 'whole milk', 'pip fruit', 'other vegetables', 'butter', 'rolls/buns', 'bottled beer', 'bottled water', 'chocolate', 'curd', 'beef', 'frankfurter', 'soda', 'fruit/vegetable juice', 'newspapers', 'pastry', 'root vegetables', 'canned beer', 'sausage', 'brown bread', 'shopping bags', 'napkins', 'pork', 'whipped/sour cream', 'domestic eggs', 'frozen vegetables', ('whole milk', 'yogurt'), ('other vegetables', 'whole milk'), ('rolls/buns', 'whole milk'), ('other vegetables', 'root vegetables'), ('root vegetables', 'whole milk')]
# Association_Rules
# whole milk ( 2513 ) ---> yogurt ( 1372 )  - conf( 0.2192598487863112 )
# yogurt ( 1372 ) ---> whole milk ( 2513 )  - conf( 0.40160349854227406 )
# other vegetables ( 1903 ) ---> whole milk ( 2513 )  - conf( 0.38675775091960063 )
# whole milk ( 2513 ) ---> other vegetables ( 1903 )  - conf( 0.29287703939514526 )
# rolls/buns ( 1809 ) ---> whole milk ( 2513 )  - conf( 0.30790491984521834 )
# whole milk ( 2513 ) ---> rolls/buns ( 1809 )  - conf( 0.2216474333465977 )
# other vegetables ( 1903 ) ---> root vegetables ( 1072 )  - conf( 0.24487651077246453 )
# root vegetables ( 1072 ) ---> other vegetables ( 1903 )  - conf( 0.43470149253731344 )
# root vegetables ( 1072 ) ---> whole milk ( 2513 )  - conf( 0.44869402985074625 )
# whole milk ( 2513 ) ---> root vegetables ( 1072 )  - conf( 0.19140469558296858 )
# 10 rules generated
# FP_Growth_spent_time 3.5098350048065186

# %% [markdown]
# # FP-growth     small_minsup and small_minconf with Market_Basket_Optimisation.csv

# %%
import csv
import pandas as pd
from itertools import combinations
import time


#Read data from CSV
# data = pd.read_csv('groceries.csv')
data = pd.read_csv('Market_Basket_Optimisation.csv', header=None)
#
#Parameters
minsup = float(input("Support-Threshold: "))
minsup = minsup * len(data)
minconf = float(input("Confidence-Threshold: "))
print(len(data))#9835
time_start = time.time()

#Add all data in a list of lists
items = []  
# print(len(data.values[0]))#1列(ROW)有32的物品
for i in range(0, len(data)):  #將所有data中的物品一列一列放到items
     items.append([str(data.values[i, j]) for j in range(0, len(data.values[0]))])

#Creating a list of dictionaries
count = [dict() for x in range(len(data.values[0]) + 1)]
# print(items)
# #Count support for each individual items
s=[]
for i in items:
    for j in i:      #讀取所有items
        s.append(j)
for i in s:                      #創字典 放在count[1]
    #If item is present in dictionary, increment its count by 1
    if i in count[1]:
        count[1][i] = count[1][i] + 1
    #If item is not present in dictionary, set its count to 1
    else:
        count[1][i] = 1     #{'i':1}

# #Remove infrequent and empty items #去除小於minsup,nan
for i in count[1].copy():
    if(count[1][i] < minsup):
        count[1].pop(i)
count[1].pop('nan') #去除以key = 'NAN'產生的值

# #Storing transactions as lists without infrequent items
a = list(count[1]) #列出所有符合的KEY
item = [list() for i in range(len(data))] #創造len(data) = 9835個list 
c = 0 
for i in range(0,len(items)): ##將所有data中的物品一列一列放到items
    for j in range(len(items[i])):
#         print(items[i][j])
        if(a.__contains__(items[i][j]) != 0): #確認物品是否存在
            item[i].append(items[i][j]) #將物品分成[['a', 'b', 'c'],[]]與itmes不同的地方是裡練已經沒有NAN了

#Function to sort list to support
def sort(a): #a = 所有符合的KEY的list
    for i in range(len(a) - 1):
        for j in range(len(a) - i - 1):
            if(count[1][a[j]] < count[1][a[j + 1]]): #如果下一個比上一個大則互換位子
                a[j],a[j + 1] = a[j + 1],a[j]
                
#Call function to sort all transactions in descending order of their support
for i in range(0,len(data)): #9835
    if(len(item[i]) > 1): #如果不只一個物件就排序他
        sort(item[i])

#Tree class for FP-Tree
class tree: #設計樹根，分支
    def __init__(self, name, sup, parent):
        self.name = name
        self.sup = sup
        self.nodeLink = None
        self.parent = parent
        self.children = []

#Function to check if the node is present is a child of the current node
def ispresent(node,name):    #確認是否有children
    f = -1               
    for i in node.children:
        f += 1
        if(i.name == name):
            return f
    return -1

#HeaderTable which stores the reference of last/first occurence of an item. Used as a linked list to generate candidate trees 
lastocc = count[1].copy() #符合sup的字典
for i in lastocc: #lastocc字典中所有值皆為NONE
    lastocc[i] = None
#Function to create FP-tree
root = tree("root", -1, None)
z = 0
for i in item: #item為沒有NAN的items
    current = root
    for j in range(len(i)): #len(i)9835
        if(ispresent(current,i[j])>=0): #第一次通常不符合此情形，直接執行else，看有沒有children
            current = current.children[ispresent(current, i[j])]
            current.sup=current.sup + 1
        else:
            child=tree(i[j], 1, current)    #創建i[j]子根
            current.children.append(child) #將子根放入children =[] 
            t = current #t 記錄柱上一層的tree1
            current = current.children[ispresent(current, i[j])] #現在current.children裡有子根，所以self.name = i[j]如下示意，
            #ispresent(current,i[j])回傳 0 ，現在的current為tree2
            current.parent = t #紀錄上一層tree1
            if(lastocc[current.name] == None):
                lastocc[current.name] = current #創建{'i[j]': tree2-1()} 
            else:#創出第一層並列樹枝
                current.nodeLink = lastocc[current.name] #將tree2-2連結到tree4
                lastocc[current.name] = current #CURRENT = TREE2-2 {'i[j]': tree2-2}
            
# class tree1:
#     def __init__(self, name, sup, parent):
#         self.name = 'root'
#         self.sup = -1
#         self.nodeLink = None
#         self.parent = none
#         self.children = [
#   class tree2-1:
#     def __init__(self, name, sup, parent):      [['A','B','C'],['C','A']]
#         self.name = 'A'
#         self.sup = 1
#         self.nodeLink = NONE
#         self.parent = parent
#         self.children = [
#                                     class tree3:
#                                         def __init__(self, name, sup, parent):
#                                             self.name = 'B'
#                                             self.sup = 1
#                                             self.nodeLink = None
#                                             self.parent = parent
#                                             self.children = [
#                                                                 class tree4:
#                                                                     def __init__(self, name, sup, parent):
#                                                                         self.name = 'B'
#                                                                         self.sup = 1
#                                                                         self.nodeLink = None
#                                                                         self.parent = parent
#                                                                         self.children = []
#                                                                 ]
#         ],
#   class tree2-2:
#     def __init__(self, name, sup, parent):
#         self.name = 'C'
#         self.sup = sup
#         self.nodeLink = TREE 4
#         self.parent = TREE1
#         self.children = []
# ]

#Function to extract single item set from a tuple
def value(a):
    a = str(a)
    a = a[:-2]
    a = a[2:]
    a = a[:-1]
    return a

#Function to get frequent itemsets with suffix 'node' and length n
def singlepath(node, n):
    c = 0
    sup = node.sup
    path = []
    pathname = []
    current = node
    
    #Get the path from current node to root
    while(current.parent!=None): #查看目current是否為'root'，如果是則無parent，重複做直道回到最上層('root')
        path.append(current)     #將current內容紀錄(tree)
        pathname.append(current.name)      #('c')
        current = current.parent  #往上一層移動
    path.remove(node) #除了自己以外的路線
    pathname.remove(node.name) 
    candidatepath = []
    temp_candidatepath = []
   
    #Generate combinations of length n in the path
    a = (list(combinations(pathname, n))) #列出除了自己以外的長度為n的組合
    for j in a:
        temp_candidatepath.append(tuple(sorted(j)))   #以tuple形式存在temp_candidatapath裡
    #Append the suffix 'node.name' to the above paths
    for j in temp_candidatepath:
        j = list(j) #再次變回list
        j.append(node.name) #將原本剔除的當前TREE名加回去 變成包含當前的組合，就是在做freqent pattern
        candidatepath.append(sorted(j)) #在加回去變成 [['a','c'],['b','c']]
    #Update counts of the generated itemsets
    for j in candidatepath:
        j = tuple(j) #j = ('a','c')
        if j in count[n+1]: #count[1]為符合minsup的字典，n至少會從1開始 
            count[n + 1][j] = count[n+1][j] + sup  # 將之前已創好的value值，加上當前tree所有的sup
        else:
            count[n + 1][j] = sup #創建新字典,此sup為當前tree存有的sup
            
    #Iterating in the candidate tree recursively 
    if(node.nodeLink != None): #查看是否存在分支
        node=node.nodeLink
        singlepath(node, i) #i為組合長度
    
#Check if itemset is frequent
def frequent(n): #算出現次數
    f=0
    for i in count[n]:
        if(count[n][i] >= minsup):
            f=1
    if(f == 1):
        return 1
    else:
        return 0

#Call singlepath function for all frequent nodes
for i in range(1, len(data.values[0]) + 1): #1列(ROW)有32的物品, +1是確保有32為一組的組合  #!
    if(frequent(i) == 1):
        for j in lastocc: #開始製造組合，將結果放到count[]裡，count唯有32空字典的list
            singlepath(lastocc[j], i)

#Remove infrequent itemsets
for z in range(len(data.values[0]) + 1):            
    for i in count[z].copy():
            if(count[z][i] < minsup): #查看所有的dict裡面的東西，是否符合minsup
                count[z].pop(i) #去掉不符合的
frequent_pattern = []
for items in count:
    for want in items:
        frequent_pattern.append(want)
                
#Get 'q', the length of the longest itemset
i=2
while(len(count[i-1]) != 0): #從這邊就能知道最大符合長度是多長，因為不符合的都被刪掉了
    i = i + 1
q = i - 2

#Find maximal and closed itemsets
maximal = []
closed = []
for i in range(1, q):
    for j in count[i]:
        fm = 0
        fc = 0
        for k in count[i+1]:
            a = set(list([j]))
            b = set(list(k))
            #Set is maximal if no immediate superset is frequent
            if(a.intersection(b) == a): #如果兩者重疊則maximal
                fm = 1 
                #Set is closed if none of its immediate supersets have equal support
                if(count[i][j] == count[i+1][k]): #出現次數相同
                    fc = 1
        if(fm == 0):
            maximal.append(j)
        if(fc == 0):
            closed.append(j)
#All sets at the top of the tree are automatically maximal and closed
for i in count[q]:
    maximal.append(i)
    closed.append(i)
print("frequent_pattern")
print(len(frequent_pattern))
print(frequent_pattern)
    
#Find Association Rules 
print("Association_Rules")
ant=count.copy()
for i in range(q, 0, -1): #從後面數回來
    for j in ant[i]:  #ant = count
        for k in range(i-1, 0, -1): # i = q(最大長度)
            s = list(combinations(list(j), k))  #將所有可能組出來   
            #Traverse through list of all combinations of antecedants
            for n in s:
                #Sorting to prevent duplicate itemsets 
                r=tuple(sorted(set(j).difference(set(n))))
                l=len(n) #輸入進來的字元長度
                #Check if len(n)==1 to be able to extract key to search in the support dictionary. 
                if(l == 1):
                    n=value(n)
                    l=1
                if(len(r) == 1):
                    r2=value(r)
                if(n != None):
                    #If rule's confidence is greater than minconfidence, then print the rule
                    if((ant[len(j)][j] / ant[l][n]) >= minconf):
                        #Rule is only significant if it is present in CLOSED, otherwise it is redundant
                        if(closed.__contains__((n))):
                            c += 1
                            if(len(r) == 1):
                                print(n,"(",ant[l][n],")","--->",r2,"(",ant[len(r)][r2],")", " - conf(",(ant[len(j)][j]/ant[l][n]),")")
                            else:
                                print(n,"(",ant[l][n],")","--->",r,"(",ant[len(r)][r],")", " conf(",(ant[len(j)][j]/ant[l][n]),")")
print(c, "rules generated")
time_end = time.time()
print('FP_Growth_spent_time', time_end - time_start)
# print( time_end - time_start)
# Out:
# Support-Threshold: 0.0045
# Confidence-Threshold: 0.01
# 7501
# frequent_pattern
# 843
# ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes', 'whole weat flour', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad', 'mineral water', 'salmon', 'antioxydant juice', 'frozen smoothie', 'spinach', 'olive oil', 'burgers', 'meatballs', 'eggs', 'turkey', 'milk', 'energy bar', 'whole wheat rice', 'whole wheat pasta', 'french fries', 'soup', 'light cream', 'shallot', 'frozen vegetables', 'spaghetti', 'pet food', 'cookies', 'cooking oil', 'champagne', 'chocolate', 'chicken', 'oil', 'fresh tuna', 'tomatoes', 'black tea', 'extra dark chocolate', 'protein bar', 'red wine', 'pasta', 'pepper', 'shampoo', 'rice', 'sparkling water', 'ham', 'body spray', 'pancakes', 'grated cheese', 'white wine', 'toothpaste', 'parmesan cheese', 'fresh bread', 'ground beef', 'escalope', 'herb & pepper', 'tomato sauce', 'magazines', 'strawberries', 'strong cheese', 'pickles', 'cake', 'hot dogs', 'brownies', 'cereals', 'clothes accessories', 'bug spray', 'muffins', 'light mayo', 'gums', 'soda', 'cider', 'corn', 'yogurt cake', 'mint', 'butter', 'asparagus', 'french wine', 'salt', 'barbecue sauce', 'mayonnaise', 'zucchini', 'carrots', 'mushroom cream sauce', 'candy bars', 'chili', 'nonfat milk', 'mint green tea', 'eggplant', 'blueberries', 'bacon', 'fromage blanc', 'gluten free bar', 'flax seed', 'hand protein bar', 'sandwich', 'babies food', 'melons', 'cauliflower', 'green beans', 'burger sauce', ('burgers', 'shrimp'), ('pancakes', 'shrimp'), ('milk', 'shrimp'), ('low fat yogurt', 'shrimp'), ('mineral water', 'shrimp'), ('chocolate', 'shrimp'), ('eggs', 'shrimp'), ('shrimp', 'spaghetti'), ('french fries', 'shrimp'), ('ground beef', 'shrimp'), ('cake', 'shrimp'), ('frozen vegetables', 'shrimp'), ('green tea', 'shrimp'), ('almonds', 'spaghetti'), ('almonds', 'green tea'), ('almonds', 'eggs'), ('almonds', 'chocolate'), ('almonds', 'milk'), ('almonds', 'mineral water'), ('almonds', 'burgers'), ('avocado', 'milk'), ('avocado', 'mineral water'), ('avocado', 'frozen vegetables'), ('avocado', 'green tea'), ('avocado', 'french fries'), ('avocado', 'burgers'), ('avocado', 'chocolate'), ('avocado', 'frozen smoothie'), ('avocado', 'spaghetti'), ('avocado', 'eggs'), ('chocolate', 'vegetables mix'), ('eggs', 'vegetables mix'), ('mineral water', 'vegetables mix'), ('green tea', 'vegetables mix'), ('french fries', 'vegetables mix'), ('spaghetti', 'vegetables mix'), ('cottage cheese', 'green tea'), ('cottage cheese', 'milk'), ('cottage cheese', 'french fries'), ('cottage cheese', 'mineral water'), ('cottage cheese', 'pancakes'), ('chocolate', 'cottage cheese'), ('cottage cheese', 'frozen smoothie'), ('cottage cheese', 'spaghetti'), ('cottage cheese', 'eggs'), ('energy drink', 'french fries'), ('eggs', 'energy drink'), ('energy drink', 'mineral water'), ('milk', 'tomato juice'), ('french fries', 'tomato juice'), ('green tea', 'tomato juice'), ('mineral water', 'tomato juice'), ('pancakes', 'tomato juice'), ('frozen vegetables', 'tomato juice'), ('spaghetti', 'tomato juice'), ('eggs', 'tomato juice'), ('chocolate', 'tomato juice'), ('cake', 'low fat yogurt'), ('ground beef', 'low fat yogurt'), ('eggs', 'low fat yogurt'), ('low fat yogurt', 'spaghetti'), ('low fat yogurt', 'mineral water'), ('low fat yogurt', 'milk'), ('low fat yogurt', 'pancakes'), ('french fries', 'low fat yogurt'), ('frozen vegetables', 'low fat yogurt'), ('green tea', 'low fat yogurt'), ('chocolate', 'low fat yogurt'), ('escalope', 'low fat yogurt'), ('burgers', 'low fat yogurt'), ('cookies', 'low fat yogurt'), ('french fries', 'green tea'), ('green tea', 'spaghetti'), ('eggs', 'green tea'), ('green tea', 'mineral water'), ('chocolate', 'green tea'), ('honey', 'spaghetti'), ('frozen vegetables', 'honey'), ('honey', 'mineral water'), ('frozen smoothie', 'honey'), ('honey', 'pancakes'), ('honey', 'milk'), ('green tea', 'honey'), ('honey', 'turkey'), ('burgers', 'honey'), ('chocolate', 'honey'), ('french fries', 'honey'), ('eggs', 'honey' ...
# Association_Rules
# ('chocolate', 'milk', 'mineral water') ( 105 ) ---> spaghetti ( 1306 )  - conf( 0.3523809523809524 )
# ('chocolate', 'milk', 'spaghetti') ( 82 ) ---> mineral water ( 1788 )  - conf( 0.45121951219512196 )
# ('chocolate', 'mineral water', 'spaghetti') ( 120 ) ---> milk ( 972 )  - conf( 0.30833333333333335 )
# ('milk', 'mineral water', 'spaghetti') ( 118 ) ---> chocolate ( 1230 )  - conf( 0.3135593220338983 )
# ('chocolate', 'milk') ( 241 ) ---> ('mineral water', 'spaghetti') ( 448 )  conf( 0.15352697095435686 )
# ('chocolate', 'mineral water') ( 396 ) ---> ('milk', 'spaghetti') ( 266 )  conf( 0.09343434343434344 )
# ('chocolate', 'spaghetti') ( 295 ) ---> ('milk', 'mineral water') ( 360 )  conf( 0.12542372881355932 )
# ('milk', 'mineral water') ( 360 ) ---> ('chocolate', 'spaghetti') ( 295 )  conf( 0.10277777777777777 )
# ('milk', 'spaghetti') ( 266 ) ---> ('chocolate', 'mineral water') ( 396 )  conf( 0.13909774436090225 )
# ('mineral water', 'spaghetti') ( 448 ) ---> ('chocolate', 'milk') ( 241 )  conf( 0.08258928571428571 )
# chocolate ( 1230 ) ---> ('milk', 'mineral water', 'spaghetti') ( 118 )  conf( 0.03008130081300813 )
# milk ( 972 ) ---> ('chocolate', 'mineral water', 'spaghetti') ( 120 )  conf( 0.03806584362139918 )
# mineral water ( 1788 ) ---> ('chocolate', 'milk', 'spaghetti') ( 82 )  conf( 0.02069351230425056 )
# spaghetti ( 1306 ) ---> ('chocolate', 'milk', 'mineral water') ( 105 )  conf( 0.028330781010719754 )
# ('frozen vegetables', 'milk', 'mineral water') ( 83 ) ---> spaghetti ( 1306 )  - conf( 0.40963855421686746 )
# ('frozen vegetables', 'milk', 'spaghetti') ( 62 ) ---> mineral water ( 1788 )  - conf( 0.5483870967741935 )
# ('frozen vegetables', 'mineral water', 'spaghetti') ( 90 ) ---> milk ( 972 )  - conf( 0.37777777777777777 )
# ('milk', 'mineral water', 'spaghetti') ( 118 ) ---> frozen vegetables ( 715 )  - conf( 0.288135593220339 )
# ('frozen vegetables', 'milk') ( 177 ) ---> ('mineral water', 'spaghetti') ( 448 )  conf( 0.192090395480226 )
# ('frozen vegetables', 'mineral water') ( 268 ) ---> ('milk', 'spaghetti') ( 266 )  conf( 0.12686567164179105 )
# ('frozen vegetables', 'spaghetti') ( 209 ) ---> ('milk', 'mineral water') ( 360 )  conf( 0.16267942583732056 )
# ('milk', 'mineral water') ( 360 ) ---> ('frozen vegetables', 'spaghetti') ( 209 )  conf( 0.09444444444444444 )
# ('milk', 'spaghetti') ( 266 ) ---> ('frozen vegetables', 'mineral water') ( 268 )  conf( 0.12781954887218044 )
# ('mineral water', 'spaghetti') ( 448 ) ---> ('frozen vegetables', 'milk') ( 177 )  conf( 0.07589285714285714 )
# frozen vegetables ( 715 ) ---> ('milk', 'mineral water', 'spaghetti') ( 118 )  conf( 0.04755244755244755 )
# milk ( 972 ) ---> ('frozen vegetables', 'mineral water', 'spaghetti') ( 90 )  conf( 0.03497942386831276 )
# mineral water ( 1788 ) ---> ('frozen vegetables', 'milk', 'spaghetti') ( 62 )  conf( 0.01901565995525727 )
# spaghetti ( 1306 ) ---> ('frozen vegetables', 'milk', 'mineral water') ( 83 )  conf( 0.026033690658499236 )
# ('chocolate', 'eggs', 'mineral water') ( 101 ) ---> spaghetti ( 1306 )  - conf( 0.33663366336633666 )
# ('chocolate', 'eggs', 'spaghetti') ( 79 ) ---> mineral water ( 1788 )  - conf( 0.43037974683544306 )
# ('chocolate', 'mineral water', 'spaghetti') ( 120 ) ---> eggs ( 1348 )  - conf( 0.2833333333333333 )
# ('eggs', 'mineral water', 'spaghetti') ( 107 ) ---> chocolate ( 1230 )  - conf( 0.3177570093457944 )
# ('chocolate', 'eggs') ( 249 ) ---> ('mineral water', 'spaghetti') ( 448 )  conf( 0.13654618473895583 )
# ('chocolate', 'mineral water') ( 396 ) ---> ('eggs', 'spaghetti') ( 274 )  conf( 0.08585858585858586 )
# ('chocolate', 'spaghetti') ( 295 ) ---> ('eggs', 'mineral water') ( 382 )  conf( 0.1152542372881356 )
# ('eggs', 'mineral water') ( 382 ) ---> ('chocolate', 'spaghetti') ( 295 )  conf( 0.08900523560209424 )
# ('eggs', 'spaghetti') ( 274 ) ---> ('chocolate', 'mineral water') ( 396 )  conf( 0.12408759124087591 )
# ('mineral water', 'spaghetti') ( 448 ) ---> ('chocolate', 'eggs') ( 249 )  conf( 0.07589285714285714 )
# chocolate ( 1230 ) ---> ('eggs', 'mineral water', 'spaghetti') ( 107 )  conf( 0.027642276422764227 )
# eggs ( 1348 ) ---> ('chocolate', 'mineral water', 'spaghetti') ( 120 )  conf( 0.025222551928783383 )
# mineral water ( 1788 ) ---> ('chocolate', 'eggs', 'spaghetti') ( 79 )  conf( 0.01901565995525727 )
# spaghetti ( 1306 ) ---> ('chocolate', 'eggs', 'mineral water') ( 101 )  conf( 0.026033690658499236 )
# ('mineral water', 'pancakes') ( 253 ) ---> shrimp ( 536 )  - conf( 0.13438735177865613 )
# ('mineral water', 'shrimp') ( 177 ) ---> pancakes ( 713 )  - conf( 0.192090395480226 )
# ('pancakes', 'shrimp') ( 79 ) ---> mineral water ( 1788 )  - conf( 0.43037974683544306 )
# mineral water ( 1788 ) ---> ('pancakes', 'shrimp') ( 79 )  conf( 0.01901565995525727 )
# pancakes ( 713 ) ---> ('mineral water', 'shrimp') ( 177 )  conf( 0.047685834502103785 )
# shrimp ( 536 ) ---> ('mineral water', 'pancakes') ( 253 )  conf( 0.06343283582089553 )
# ('chocolate', 'milk') ( 241 ) ---> shrimp ( 536 )  - conf( 0.17012448132780084 )
# ('chocolate', 'shrimp') ( 135 ) ---> milk ( 972 )  - conf( 0.3037037037037037 )
# ('milk', 'shrimp') ( 132 ) ---> chocolate ( 1230 )  - conf( 0.3106060606060606 )
# chocolate ( 1230 ) ---> ('milk', 'shrimp') ( 132 )  conf( 0.03333333333333333 )
# milk ( 972 ) ---> ('chocolate', 'shrimp') ( 135 )  conf( 0.04218106995884774 )
# shrimp ( 536 ) ---> ('chocolate', 'milk') ( 241 )  conf( 0.07649253731343283 )
# ('milk', 'mineral water') ( 360 ) ---> shrimp ( 536 )  - conf( 0.1638888888888889 )
# ('milk', 'shrimp') ( 132 ) ---> mineral water ( 1788 )  - conf( 0.44696969696969696 )
# ('mineral water', 'shrimp') ( 177 ) ---> milk ( 972 )  - conf( 0.3333333333333333 )
# milk ( 972 ) ---> ('mineral water', 'shrimp') ( 177 )  conf( 0.060699588477366256 )
# mineral water ( 1788 ) ---> ('milk', 'shrimp') ( 132 )  conf( 0.032997762863534674 )
# shrimp ( 536 ) ---> ('milk', 'mineral water') ( 360 )  conf( 0.11007462686567164 )
# ('chocolate', 'mineral water') ( 396 ) ---> shrimp ( 536 )  - conf( 0.14393939393939395 )
# ('chocolate', 'shrimp') ( 135 ) ---> mineral water ( 1788 )  - conf( 0.4222222222222222 )
# ('mineral water', 'shrimp') ( 177 ) ---> chocolate ( 1230 )  - conf( 0.3220338983050847 )
# chocolate ( 1230 ) ---> ('mineral water', 'shrimp') ( 177 )  conf( 0.046341463414634146 )
# mineral water ( 1788 ) ---> ('chocolate', 'shrimp') ( 135 )  conf( 0.031879194630872486 )
# shrimp ( 536 ) ---> ('chocolate', 'mineral water') ( 396 )  conf( 0.10634328358208955 )
# ('eggs', 'mineral water') ( 382 ) ---> shrimp ( 536 )  - conf( 0.10209424083769633 )
# ('eggs', 'shrimp') ( 106 ) ---> mineral water ( 1788 )  - conf( 0.36792452830188677 )
# ('mineral water', 'shrimp') ( 177 ) ---> eggs ( 1348 )  - conf( 0.22033898305084745 )
# eggs ( 1348 ) ---> ('mineral water', 'shrimp') ( 177 )  conf( 0.028931750741839762 )
# mineral water ( 1788 ) ---> ('eggs', 'shrimp') ( 106 )  conf( 0.02181208053691275 )
# shrimp ( 536 ) ---> ('eggs', 'mineral water') ( 382 )  conf( 0.07276119402985075 )
# ('chocolate', 'shrimp') ( 135 ) ---> spaghetti ( 1306 )  - conf( 0.35555555555555557 )
# ('chocolate', 'spaghetti') ( 295 ) ---> shrimp ( 536 )  - conf( 0.16271186440677965 )
# ('shrimp', 'spaghetti') ( 159 ) ---> chocolate ( 1230 )  - conf( 0.3018867924528302 )
# chocolate ( 1230 ) ---> ('shrimp', 'spaghetti') ( 159 )  conf( 0.03902439024390244 )
# shrimp ( 536 ) ---> ('chocolate', 'spaghetti') ( 295 )  conf( 0.08955223880597014 )
# spaghetti ( 1306 ) ---> ('chocolate', 'shrimp') ( 135 )  conf( 0.036753445635528334 )
# ('mineral water', 'shrimp') ( 177 ) ---> spaghetti ( 1306 )  - conf( 0.3615819209039548 )
# ('mineral water', 'spaghetti') ( 448 ) ---> shrimp ( 536 )  - conf( 0.14285714285714285 )
# ('shrimp', 'spaghetti') ( 159 ) ---> mineral water ( 1788 )  - conf( 0.4025157232704403 )
# mineral water ( 1788 ) ---> ('shrimp', 'spaghetti') ( 159 )  conf( 0.035794183445190156 )
# shrimp ( 536 ) ---> ('mineral water', 'spaghetti') ( 448 )  conf( 0.11940298507462686 )
# spaghetti ( 1306 ) ---> ('mineral water', 'shrimp') ( 177 )  conf( 0.04900459418070444 )
# ('ground beef', 'mineral water') ( 307 ) ---> shrimp ( 536 )  - conf( 0.1237785016286645 )
# ('ground beef', 'shrimp') ( 86 ) ---> mineral water ( 1788 )  - conf( 0.4418604651162791 )
# ('mineral water', 'shrimp') ( 177 ) ---> ground beef ( 737 )  - conf( 0.21468926553672316 )
# ground beef ( 737 ) ---> ('mineral water', 'shrimp') ( 177 )  conf( 0.051560379918588875 )
# mineral water ( 1788 ) ---> ('ground beef', 'shrimp') ( 86 )  conf( 0.021252796420581657 )
# shrimp ( 536 ) ---> ('ground beef', 'mineral water') ( 307 )  conf( 0.0708955223880597 )
# ('frozen vegetables', 'shrimp') ( 125 ) ---> spaghetti ( 1306 )  - conf( 0.36 )
# ('frozen vegetables', 'spaghetti') ( 209 ) ---> shrimp ( 536 )  - conf( 0.215311004784689 )
# ('shrimp', 'spaghetti') ( 159 ) ---> frozen vegetables ( 715 )  - conf( 0.2830188679245283 )
# frozen vegetables ( 715 ) ---> ('shrimp', 'spaghetti') ( 159 )  conf( 0.06293706293706294 )
# shrimp ( 536 ) ---> ('frozen vegetables', 'spaghetti') ( 209 )  conf( 0.08395522388059702 )
# spaghetti ( 1306 ) ---> ('frozen vegetables', 'shrimp') ( 125 )  conf( 0.03445635528330781 )
# ('frozen vegetables', 'milk') ( 177 ) ---> shrimp ( 536 )  - conf( 0.1977401129943503 )
# ('frozen vegetables', 'shrimp') ( 125 ) ---> milk ( 972 )  - conf( 0.28 )
# ('milk', 'shrimp') ( 132 ) ---> frozen vegetables ( 715 )  - conf( 0.26515151515151514 )
# frozen vegetables ( 715 ) ---> ('milk', 'shrimp') ( 132 )  conf( 0.04895104895104895 )
# milk ( 972 ) ---> ('frozen vegetables', 'shrimp') ( 125 )  conf( 0.0360082304526749 )
# shrimp ( 536 ) ---> ('frozen vegetables', 'milk') ( 177 )  conf( 0.06529850746268656 )
# ('chocolate', 'frozen vegetables') ( 172 ) ---> shrimp ( 536 )  - conf( 0.23255813953488372 )
# ('chocolate', 'shrimp') ( 135 ) ---> frozen vegetables ( 715 )  - conf( 0.2962962962962963 )
# ('frozen vegetables', 'shrimp') ( 125 ) ---> chocolate ( 1230 )  - conf( 0.32 )
# chocolate ( 1230 ) ---> ('frozen vegetables', 'shrimp') ( 125 )  conf( 0.032520325203252036 )
# frozen vegetables ( 715 ) ---> ('chocolate', 'shrimp') ( 135 )  conf( 0.055944055944055944 )
# shrimp ( 536 ) ---> ('chocolate', 'frozen vegetables') ( 172 )  conf( 0.07462686567164178 )
# ('frozen vegetables', 'mineral water') ( 268 ) ---> shrimp ( 536 )  - conf( 0.20149253731343283 )
# ('frozen vegetables', 'shrimp') ( 125 ) ---> mineral water ( 1788 )  - conf( 0.432 )
# ('mineral water', 'shrimp') ( 177 ) ---> frozen vegetables ( 715 )  - conf( 0.3050847457627119 )
# frozen vegetables ( 715 ) ---> ('mineral water', 'shrimp') ( 177 )  conf( 0.07552447552447553 )
# mineral water ( 1788 ) ---> ('frozen vegetables', 'shrimp') ( 125 )  conf( 0.030201342281879196 )
# shrimp ( 536 ) ---> ('frozen vegetables', 'mineral water') ( 268 )  conf( 0.10074626865671642 )
# ('ground beef', 'shrimp') ( 86 ) ---> spaghetti ( 1306 )  - conf( 0.5232558139534884 )
# ('ground beef', 'spaghetti') ( 294 ) ---> shrimp ( 536 )  - conf( 0.15306122448979592 )
# ('shrimp', 'spaghetti') ( 159 ) ---> ground beef ( 737 )  - conf( 0.2830188679245283 )
# ground beef ( 737 ) ---> ('shrimp', 'spaghetti') ( 159 )  conf( 0.06105834464043419 )
# shrimp ( 536 ) ---> ('ground beef', 'spaghetti') ( 294 )  conf( 0.08395522388059702 )
# spaghetti ( 1306 ) ---> ('ground beef', 'shrimp') ( 86 )  conf( 0.03445635528330781 )
# ('milk', 'shrimp') ( 132 ) ---> spaghetti ( 1306 )  - conf( 0.2803030303030303 )
# ('milk', 'spaghetti') ( 266 ) ---> shrimp ( 536 )  - conf( 0.13909774436090225 )
# ('shrimp', 'spaghetti') ( 159 ) ---> milk ( 972 )  - conf( 0.23270440251572327 )
# milk ( 972 ) ---> ('shrimp', 'spaghetti') ( 159 )  conf( 0.03806584362139918 )
# shrimp ( 536 ) ---> ('milk', 'spaghetti') ( 266 )  conf( 0.06902985074626866 )
# spaghetti ( 1306 ) ---> ('milk', 'shrimp') ( 132 )  conf( 0.028330781010719754 )
# ('ground beef', 'low fat yogurt') ( 72 ) ---> mineral water ( 1788 )  - conf( 0.5 )
# ('ground beef', 'mineral water') ( 307 ) ---> low fat yogurt ( 574 )  - conf( 0.11726384364820847 )
# ('low fat yogurt', 'mineral water') ( 180 ) ---> ground beef ( 737 )  - conf( 0.2 )
# ground beef ( 737 ) ---> ('low fat yogurt', 'mineral water') ( 180 )  conf( 0.048846675712347354 )
# low fat yogurt ( 574 ) ---> ('ground beef', 'mineral water') ( 307 )  conf( 0.0627177700348432 )
# mineral water ( 1788 ) ---> ('ground beef', 'low fat yogurt') ( 72 )  conf( 0.020134228187919462 )
# ('low fat yogurt', 'mineral water') ( 180 ) ---> spaghetti ( 1306 )  - conf( 0.23333333333333334 )
# ('low fat yogurt', 'spaghetti') ( 114 ) ---> mineral water ( 1788 )  - conf( 0.3684210526315789 )
# ('mineral water', 'spaghetti') ( 448 ) ---> low fat yogurt ( 574 )  - conf( 0.09375 )
# low fat yogurt ( 574 ) ---> ('mineral water', 'spaghetti') ( 448 )  conf( 0.07317073170731707 )
# mineral water ( 1788 ) ---> ('low fat yogurt', 'spaghetti') ( 114 )  conf( 0.02348993288590604 )
# spaghetti ( 1306 ) ---> ('low fat yogurt', 'mineral water') ( 180 )  conf( 0.03215926493108729 )
# ('low fat yogurt', 'milk') ( 99 ) ---> mineral water ( 1788 )  - conf( 0.36363636363636365 )
# ('low fat yogurt', 'mineral water') ( 180 ) ---> milk ( 972 )  - conf( 0.2 )
# ('milk', 'mineral water') ( 360 ) ---> low fat yogurt ( 574 )  - conf( 0.1 )
# low fat yogurt ( 574 ) ---> ('milk', 'mineral water') ( 360 )  conf( 0.0627177700348432 )
# milk ( 972 ) ---> ('low fat yogurt', 'mineral water') ( 180 )  conf( 0.037037037037037035 )
# mineral water ( 1788 ) ---> ('low fat yogurt', 'milk') ( 99 )  conf( 0.020134228187919462 )
# ('frozen vegetables', 'low fat yogurt') ( 76 ) ---> mineral water ( 1788 )  - conf( 0.4473684210526316 )
# ('frozen vegetables', 'mineral water') ( 268 ) ---> low fat yogurt ( 574 )  - conf( 0.12686567164179105 )
# ('low fat yogurt', 'mineral water') ( 180 ) ---> frozen vegetables ( 715 )  - conf( 0.18888888888888888 )
# frozen vegetables ( 715 ) ---> ('low fat yogurt', 'mineral water') ( 180 )  conf( 0.04755244755244755 )
# low fat yogurt ( 574 ) ---> ('frozen vegetables', 'mineral water') ( 268 )  conf( 0.059233449477351915 )
# mineral water ( 1788 ) ---> ('frozen vegetables', 'low fat yogurt') ( 76 )  conf( 0.01901565995525727 )
# ('eggs', 'low fat yogurt') ( 126 ) ---> mineral water ( 1788 )  - conf( 0.36507936507936506 )
# ('eggs', 'mineral water') ( 382 ) ---> low fat yogurt ( 574 )  - conf( 0.12041884816753927 )
# ('low fat yogurt', 'mineral water') ( 180 ) ---> eggs ( 1348 )  - conf( 0.25555555555555554 )
# eggs ( 1348 ) ---> ('low fat yogurt', 'mineral water') ( 180 )  conf( 0.03412462908011869 )
# low fat yogurt ( 574 ) ---> ('eggs', 'mineral water') ( 382 )  conf( 0.08013937282229965 )
# mineral water ( 1788 ) ---> ('eggs', 'low fat yogurt') ( 126 )  conf( 0.025727069351230425 )
# ('chocolate', 'low fat yogurt') ( 111 ) ---> mineral water ( 1788 )  - conf( 0.38738738738738737 )
# ('chocolate', 'mineral water') ( 396 ) ---> low fat yogurt ( 574 )  - conf( 0.10858585858585859 )
# ('low fat yogurt', 'mineral water') ( 180 ) ---> chocolate ( 1230 )  - conf( 0.2388888888888889 )
# chocolate ( 1230 ) ---> ('low fat yogurt', 'mineral water') ( 180 )  conf( 0.034959349593495934 )
# low fat yogurt ( 574 ) ---> ('chocolate', 'mineral water') ( 396 )  conf( 0.07491289198606271 )
# mineral water ( 1788 ) ---> ('chocolate', 'low fat yogurt') ( 111 )  conf( 0.024049217002237135 )
# ('french fries', 'green tea') ( 214 ) ---> spaghetti ( 1306 )  - conf( 0.18691588785046728 )
# ('french fries', 'spaghetti') ( 207 ) ---> green tea ( 991 )  - conf( 0.1932367149758454 )
# ('green tea', 'spaghetti') ( 199 ) ---> french fries ( 1282 )  - conf( 0.20100502512562815 )
# french fries ( 1282 ) ---> ('green tea', 'spaghetti') ( 199 )  conf( 0.031201248049921998 )
# green tea ( 991 ) ---> ('french fries', 'spaghetti') ( 207 )  conf( 0.04036326942482341 )
# spaghetti ( 1306 ) ---> ('french fries', 'green tea') ( 214 )  conf( 0.030627871362940276 )
# ('eggs', 'french fries') ( 273 ) ---> green tea ( 991 )  - conf( 0.19413919413919414 )
# ('eggs', 'green tea') ( 191 ) ---> french fries ( 1282 )  - conf( 0.2774869109947644 )
# ('french fries', 'green tea') ( 214 ) ---> eggs ( 1348 )  - conf( 0.24766355140186916 )
# eggs ( 1348 ) ---> ('french fries', 'green tea') ( 214 )  conf( 0.039317507418397624 )
# french fries ( 1282 ) ---> ('eggs', 'green tea') ( 191 )  conf( 0.041341653666146644 )
# green tea ( 991 ) ---> ('eggs', 'french fries') ( 273 )  conf( 0.05348133198789102 )
# ('french fries', 'green tea') ( 214 ) ---> mineral water ( 1788 )  - conf( 0.21495327102803738 )
# ('french fries', 'mineral water') ( 253 ) ---> green tea ( 991 )  - conf( 0.18181818181818182 )
# ('green tea', 'mineral water') ( 233 ) ---> french fries ( 1282 )  - conf( 0.19742489270386265 )
# french fries ( 1282 ) ---> ('green tea', 'mineral water') ( 233 )  conf( 0.0358814352574103 )
# green tea ( 991 ) ---> ('french fries', 'mineral water') ( 253 )  conf( 0.04641775983854692 )
# mineral water ( 1788 ) ---> ('french fries', 'green tea') ( 214 )  conf( 0.025727069351230425 )
# ('eggs', 'green tea') ( 191 ) ---> spaghetti ( 1306 )  - conf( 0.225130890052356 )
# ('eggs', 'spaghetti') ( 274 ) ---> green tea ( 991 )  - conf( 0.15693430656934307 )
# ('green tea', 'spaghetti') ( 199 ) ---> eggs ( 1348 )  - conf( 0.21608040201005024 )
# eggs ( 1348 ) ---> ('green tea', 'spaghetti') ( 199 )  conf( 0.031899109792284865 )
# green tea ( 991 ) ---> ('eggs', 'spaghetti') ( 274 )  conf( 0.04339051463168517 )
# spaghetti ( 1306 ) ---> ('eggs', 'green tea') ( 191 )  conf( 0.032924961715160794 )
# ('green tea', 'mineral water') ( 233 ) ---> spaghetti ( 1306 )  - conf( 0.26609442060085836 )
# ('green tea', 'spaghetti') ( 199 ) ---> mineral water ( 1788 )  - conf( 0.31155778894472363 )
# ('mineral water', 'spaghetti') ( 448 ) ---> green tea ( 991 )  - conf( 0.13839285714285715 )
# green tea ( 991 ) ---> ('mineral water', 'spaghetti') ( 448 )  conf( 0.06256306760847628 )
# mineral water ( 1788 ) ---> ('green tea', 'spaghetti') ( 199 )  conf( 0.03467561521252797 )
# spaghetti ( 1306 ) ---> ('green tea', 'mineral water') ( 233 )  conf( 0.04747320061255743 )
# ('eggs', 'green tea') ( 191 ) ---> mineral water ( 1788 )  - conf( 0.27225130890052357 )
# ('eggs', 'mineral water') ( 382 ) ---> green tea ( 991 )  - conf( 0.13612565445026178 )
# ('green tea', 'mineral water') ( 233 ) ---> eggs ( 1348 )  - conf( 0.22317596566523606 )
# eggs ( 1348 ) ---> ('green tea', 'mineral water') ( 233 )  conf( 0.03857566765578635 )
# green tea ( 991 ) ---> ('eggs', 'mineral water') ( 382 )  conf( 0.05247225025227043 )
# mineral water ( 1788 ) ---> ('eggs', 'green tea') ( 191 )  conf( 0.029082774049217 )
# ('chocolate', 'french fries') ( 258 ) ---> green tea ( 991 )  - conf( 0.1511627906976744 )
# ('chocolate', 'green tea') ( 176 ) ---> french fries ( 1282 )  - conf( 0.2215909090909091 )
# ('french fries', 'green tea') ( 214 ) ---> chocolate ( 1230 )  - conf( 0.1822429906542056 )
# chocolate ( 1230 ) ---> ('french fries', 'green tea') ( 214 )  conf( 0.03170731707317073 )
# french fries ( 1282 ) ---> ('chocolate', 'green tea') ( 176 )  conf( 0.030421216848673948 )
# green tea ( 991 ) ---> ('chocolate', 'french fries') ( 258 )  conf( 0.039354187689202826 )
# ('chocolate', 'green tea') ( 176 ) ---> spaghetti ( 1306 )  - conf( 0.30113636363636365 )
# ('chocolate', 'spaghetti') ( 295 ) ---> green tea ( 991 )  - conf( 0.17966101694915254 )
# ('green tea', 'spaghetti') ( 199 ) ---> chocolate ( 1230 )  - conf( 0.2663316582914573 )
# chocolate ( 1230 ) ---> ('green tea', 'spaghetti') ( 199 )  conf( 0.043089430894308944 )
# green tea ( 991 ) ---> ('chocolate', 'spaghetti') ( 295 )  conf( 0.05348133198789102 )
# spaghetti ( 1306 ) ---> ('chocolate', 'green tea') ( 176 )  conf( 0.04058192955589587 )
# ('chocolate', 'eggs') ( 249 ) ---> green tea ( 991 )  - conf( 0.1646586345381526 )
# ('chocolate', 'green tea') ( 176 ) ---> eggs ( 1348 )  - conf( 0.23295454545454544 )
# ('eggs', 'green tea') ( 191 ) ---> chocolate ( 1230 )  - conf( 0.21465968586387435 )
# chocolate ( 1230 ) ---> ('eggs', 'green tea') ( 191 )  conf( 0.03333333333333333 )
# eggs ( 1348 ) ---> ('chocolate', 'green tea') ( 176 )  conf( 0.030415430267062313 )
# green tea ( 991 ) ---> ('chocolate', 'eggs') ( 249 )  conf( 0.04137235116044399 )
# ('chocolate', 'green tea') ( 176 ) ---> mineral water ( 1788 )  - conf( 0.29545454545454547 )
# ('chocolate', 'mineral water') ( 396 ) ---> green tea ( 991 )  - conf( 0.13131313131313133 )
# ('green tea', 'mineral water') ( 233 ) ---> chocolate ( 1230 )  - conf( 0.22317596566523606 )
# chocolate ( 1230 ) ---> ('green tea', 'mineral water') ( 233 )  conf( 0.04227642276422764 )
# green tea ( 991 ) ---> ('chocolate', 'mineral water') ( 396 )  conf( 0.05247225025227043 )
# mineral water ( 1788 ) ---> ('chocolate', 'green tea') ( 176 )  conf( 0.029082774049217 )
# ('chocolate', 'mineral water') ( 396 ) ---> salmon ( 319 )  - conf( 0.08838383838383838 )
# ('chocolate', 'salmon') ( 81 ) ---> mineral water ( 1788 )  - conf( 0.43209876543209874 )
# ('mineral water', 'salmon') ( 128 ) ---> chocolate ( 1230 )  - conf( 0.2734375 )
# chocolate ( 1230 ) ---> ('mineral water', 'salmon') ( 128 )  conf( 0.028455284552845527 )
# mineral water ( 1788 ) ---> ('chocolate', 'salmon') ( 81 )  conf( 0.019574944071588368 )
# salmon ( 319 ) ---> ('chocolate', 'mineral water') ( 396 )  conf( 0.109717868338558 )
# ('mineral water', 'salmon') ( 128 ) ---> spaghetti ( 1306 )  - conf( 0.3984375 )
# ('mineral water', 'spaghetti') ( 448 ) ---> salmon ( 319 )  - conf( 0.11383928571428571 )
# ('salmon', 'spaghetti') ( 101 ) ---> mineral water ( 1788 )  - conf( 0.504950495049505 )
# mineral water ( 1788 ) ---> ('salmon', 'spaghetti') ( 101 )  conf( 0.028523489932885907 )
# salmon ( 319 ) ---> ('mineral water', 'spaghetti') ( 448 )  conf( 0.15987460815047022 )
# spaghetti ( 1306 ) ---> ('mineral water', 'salmon') ( 128 )  conf( 0.03905053598774885 )
# ('chocolate', 'frozen smoothie') ( 113 ) ---> mineral water ( 1788 )  - conf( 0.34513274336283184 )
# ('chocolate', 'mineral water') ( 396 ) ---> frozen smoothie ( 475 )  - conf( 0.09848484848484848 )
# ('frozen smoothie', 'mineral water') ( 152 ) ---> chocolate ( 1230 )  - conf( 0.2565789473684211 )
# chocolate ( 1230 ) ---> ('frozen smoothie', 'mineral water') ( 152 )  conf( 0.03170731707317073 )
# frozen smoothie ( 475 ) ---> ('chocolate', 'mineral water') ( 396 )  conf( 0.08210526315789474 )
# mineral water ( 1788 ) ---> ('chocolate', 'frozen smoothie') ( 113 )  conf( 0.02181208053691275 )
# ('frozen smoothie', 'milk') ( 107 ) ---> spaghetti ( 1306 )  - conf( 0.3925233644859813 )
# ('frozen smoothie', 'spaghetti') ( 117 ) ---> milk ( 972 )  - conf( 0.358974358974359 )
# ('milk', 'spaghetti') ( 266 ) ---> frozen smoothie ( 475 )  - conf( 0.15789473684210525 )
# frozen smoothie ( 475 ) ---> ('milk', 'spaghetti') ( 266 )  conf( 0.08842105263157894 )
# milk ( 972 ) ---> ('frozen smoothie', 'spaghetti') ( 117 )  conf( 0.043209876543209874 )
# spaghetti ( 1306 ) ---> ('frozen smoothie', 'milk') ( 107 )  conf( 0.03215926493108729 )
# ('frozen smoothie', 'milk') ( 107 ) ---> mineral water ( 1788 )  - conf( 0.42990654205607476 )
# ('frozen smoothie', 'mineral water') ( 152 ) ---> milk ( 972 )  - conf( 0.3026315789473684 )
# ('milk', 'mineral water') ( 360 ) ---> frozen smoothie ( 475 )  - conf( 0.12777777777777777 )
# frozen smoothie ( 475 ) ---> ('milk', 'mineral water') ( 360 )  conf( 0.0968421052631579 )
# milk ( 972 ) ---> ('frozen smoothie', 'mineral water') ( 152 )  conf( 0.047325102880658436 )
# mineral water ( 1788 ) ---> ('frozen smoothie', 'milk') ( 107 )  conf( 0.025727069351230425 )
# ('frozen smoothie', 'mineral water') ( 152 ) ---> spaghetti ( 1306 )  - conf( 0.3355263157894737 )
# ('frozen smoothie', 'spaghetti') ( 117 ) ---> mineral water ( 1788 )  - conf( 0.4358974358974359 )
# ('mineral water', 'spaghetti') ( 448 ) ---> frozen smoothie ( 475 )  - conf( 0.11383928571428571 )
# frozen smoothie ( 475 ) ---> ('mineral water', 'spaghetti') ( 448 )  conf( 0.10736842105263159 )
# mineral water ( 1788 ) ---> ('frozen smoothie', 'spaghetti') ( 117 )  conf( 0.028523489932885907 )
# spaghetti ( 1306 ) ---> ('frozen smoothie', 'mineral water') ( 152 )  conf( 0.03905053598774885 )
# ('chocolate', 'frozen smoothie') ( 113 ) ---> spaghetti ( 1306 )  - conf( 0.3185840707964602 )
# ('chocolate', 'spaghetti') ( 295 ) ---> frozen smoothie ( 475 )  - conf( 0.12203389830508475 )
# ('frozen smoothie', 'spaghetti') ( 117 ) ---> chocolate ( 1230 )  - conf( 0.3076923076923077 )
# chocolate ( 1230 ) ---> ('frozen smoothie', 'spaghetti') ( 117 )  conf( 0.02926829268292683 )
# frozen smoothie ( 475 ) ---> ('chocolate', 'spaghetti') ( 295 )  conf( 0.07578947368421053 )
# spaghetti ( 1306 ) ---> ('chocolate', 'frozen smoothie') ( 113 )  conf( 0.027565084226646247 )
# ('mineral water', 'olive oil') ( 207 ) ---> shrimp ( 536 )  - conf( 0.1642512077294686 )
# ('mineral water', 'shrimp') ( 177 ) ---> olive oil ( 494 )  - conf( 0.192090395480226 )
# ('olive oil', 'shrimp') ( 61 ) ---> mineral water ( 1788 )  - conf( 0.5573770491803278 )
# mineral water ( 1788 ) ---> ('olive oil', 'shrimp') ( 61 )  conf( 0.01901565995525727 )
# olive oil ( 494 ) ---> ('mineral water', 'shrimp') ( 177 )  conf( 0.06882591093117409 )
# shrimp ( 536 ) ---> ('mineral water', 'olive oil') ( 207 )  conf( 0.06343283582089553 )
# ('mineral water', 'olive oil') ( 207 ) ---> pancakes ( 713 )  - conf( 0.16908212560386474 )
# ('mineral water', 'pancakes') ( 253 ) ---> olive oil ( 494 )  - conf( 0.1383399209486166 )
# ('olive oil', 'pancakes') ( 81 ) ---> mineral water ( 1788 )  - conf( 0.43209876543209874 )
# mineral water ( 1788 ) ---> ('olive oil', 'pancakes') ( 81 )  conf( 0.019574944071588368 )
# olive oil ( 494 ) ---> ('mineral water', 'pancakes') ( 253 )  conf( 0.0708502024291498 )
# pancakes ( 713 ) ---> ('mineral water', 'olive oil') ( 207 )  conf( 0.04908835904628331 )
# ('chocolate', 'mineral water') ( 396 ) ---> olive oil ( 494 )  - conf( 0.15656565656565657 )
# ('chocolate', 'olive oil') ( 123 ) ---> mineral water ( 1788 )  - conf( 0.5040650406504065 )
# ('mineral water', 'olive oil') ( 207 ) ---> chocolate ( 1230 )  - conf( 0.2995169082125604 )
# chocolate ( 1230 ) ---> ('mineral water', 'olive oil') ( 207 )  conf( 0.05040650406504065 )
# mineral water ( 1788 ) ---> ('chocolate', 'olive oil') ( 123 )  conf( 0.03467561521252797 )
# olive oil ( 494 ) ---> ('chocolate', 'mineral water') ( 396 )  conf( 0.12550607287449392 )
# ('milk', 'olive oil') ( 128 ) ---> spaghetti ( 1306 )  - conf( 0.421875 )
# ('milk', 'spaghetti') ( 266 ) ---> olive oil ( 494 )  - conf( 0.20300751879699247 )
# ('olive oil', 'spaghetti') ( 172 ) ---> milk ( 972 )  - conf( 0.313953488372093 )
# milk ( 972 ) ---> ('olive oil', 'spaghetti') ( 172 )  conf( 0.05555555555555555 )
# olive oil ( 494 ) ---> ('milk', 'spaghetti') ( 266 )  conf( 0.10931174089068826 )
# spaghetti ( 1306 ) ---> ('milk', 'olive oil') ( 128 )  conf( 0.04134762633996937 )
# ('milk', 'mineral water') ( 360 ) ---> olive oil ( 494 )  - conf( 0.17777777777777778 )
# ('milk', 'olive oil') ( 128 ) ---> mineral water ( 1788 )  - conf( 0.5 )
# ('mineral water', 'olive oil') ( 207 ) ---> milk ( 972 )  - conf( 0.30917874396135264 )
# milk ( 972 ) ---> ('mineral water', 'olive oil') ( 207 )  conf( 0.06584362139917696 )
# mineral water ( 1788 ) ---> ('milk', 'olive oil') ( 128 )  conf( 0.035794183445190156 )
# olive oil ( 494 ) ---> ('milk', 'mineral water') ( 360 )  conf( 0.12955465587044535 )
# ('mineral water', 'olive oil') ( 207 ) ---> spaghetti ( 1306 )  - conf( 0.3719806763285024 )
# ('mineral water', 'spaghetti') ( 448 ) ---> olive oil ( 494 )  - conf( 0.171875 )
# ('olive oil', 'spaghetti') ( 172 ) ---> mineral water ( 1788 )  - conf( 0.4476744186046512 )
# mineral water ( 1788 ) ---> ('olive oil', 'spaghetti') ( 172 )  conf( 0.043064876957494405 )
# olive oil ( 494 ) ---> ('mineral water', 'spaghetti') ( 448 )  conf( 0.15587044534412955 )
# spaghetti ( 1306 ) ---> ('mineral water', 'olive oil') ( 207 )  conf( 0.058958652373660034 )
# ('ground beef', 'olive oil') ( 106 ) ---> spaghetti ( 1306 )  - conf( 0.4339622641509434 )
# ('ground beef', 'spaghetti') ( 294 ) ---> olive oil ( 494 )  - conf( 0.1564625850340136 )
# ('olive oil', 'spaghetti') ( 172 ) ---> ground beef ( 737 )  - conf( 0.26744186046511625 )
# ground beef ( 737 ) ---> ('olive oil', 'spaghetti') ( 172 )  conf( 0.06241519674355495 )
# olive oil ( 494 ) ---> ('ground beef', 'spaghetti') ( 294 )  conf( 0.0931174089068826 )
# spaghetti ( 1306 ) ---> ('ground beef', 'olive oil') ( 106 )  conf( 0.03522205206738132 )
# ('eggs', 'olive oil') ( 90 ) ---> spaghetti ( 1306 )  - conf( 0.4222222222222222 )
# ('eggs', 'spaghetti') ( 274 ) ---> olive oil ( 494 )  - conf( 0.1386861313868613 )
# ('olive oil', 'spaghetti') ( 172 ) ---> eggs ( 1348 )  - conf( 0.22093023255813954 )
# eggs ( 1348 ) ---> ('olive oil', 'spaghetti') ( 172 )  conf( 0.028189910979228485 )
# olive oil ( 494 ) ---> ('eggs', 'spaghetti') ( 274 )  conf( 0.07692307692307693 )
# spaghetti ( 1306 ) ---> ('eggs', 'olive oil') ( 90 )  conf( 0.02909647779479326 )
# ('ground beef', 'milk') ( 165 ) ---> olive oil ( 494 )  - conf( 0.22424242424242424 )
# ('ground beef', 'olive oil') ( 106 ) ---> milk ( 972 )  - conf( 0.3490566037735849 )
# ('milk', 'olive oil') ( 128 ) ---> ground beef ( 737 )  - conf( 0.2890625 )
# ground beef ( 737 ) ---> ('milk', 'olive oil') ( 128 )  conf( 0.050203527815468114 )
# milk ( 972 ) ---> ('ground beef', 'olive oil') ( 106 )  conf( 0.03806584362139918 )
# olive oil ( 494 ) ---> ('ground beef', 'milk') ( 165 )  conf( 0.07489878542510121 )
# ('ground beef', 'mineral water') ( 307 ) ---> olive oil ( 494 )  - conf( 0.16286644951140064 )
# ('ground beef', 'olive oil') ( 106 ) ---> mineral water ( 1788 )  - conf( 0.4716981132075472 )
# ('mineral water', 'olive oil') ( 207 ) ---> ground beef ( 737 )  - conf( 0.24154589371980675 )
# ground beef ( 737 ) ---> ('mineral water', 'olive oil') ( 207 )  conf( 0.06784260515603799 )
# mineral water ( 1788 ) ---> ('ground beef', 'olive oil') ( 106 )  conf( 0.02796420581655481 )
# olive oil ( 494 ) ---> ('ground beef', 'mineral water') ( 307 )  conf( 0.10121457489878542 )
# ('frozen vegetables', 'milk') ( 177 ) ---> olive oil ( 494 )  - conf( 0.2033898305084746 )
# ('frozen vegetables', 'olive oil') ( 85 ) ---> milk ( 972 )  - conf( 0.4235294117647059 )
# ('milk', 'olive oil') ( 128 ) ---> frozen vegetables ( 715 )  - conf( 0.28125 )
# frozen vegetables ( 715 ) ---> ('milk', 'olive oil') ( 128 )  conf( 0.05034965034965035 )
# milk ( 972 ) ---> ('frozen vegetables', 'olive oil') ( 85 )  conf( 0.037037037037037035 )
# olive oil ( 494 ) ---> ('frozen vegetables', 'milk') ( 177 )  conf( 0.0728744939271255 )
# ('frozen vegetables', 'mineral water') ( 268 ) ---> olive oil ( 494 )  - conf( 0.1828358208955224 )
# ('frozen vegetables', 'olive oil') ( 85 ) ---> mineral water ( 1788 )  - conf( 0.5764705882352941 )
# ('mineral water', 'olive oil') ( 207 ) ---> frozen vegetables ( 715 )  - conf( 0.23671497584541062 )
# frozen vegetables ( 715 ) ---> ('mineral water', 'olive oil') ( 207 )  conf( 0.06853146853146853 )
# mineral water ( 1788 ) ---> ('frozen vegetables', 'olive oil') ( 85 )  conf( 0.027404921700223715 )
# olive oil ( 494 ) ---> ('frozen vegetables', 'mineral water') ( 268 )  conf( 0.09919028340080972 )
# ('eggs', 'mineral water') ( 382 ) ---> olive oil ( 494 )  - conf( 0.11518324607329843 )
# ('eggs', 'olive oil') ( 90 ) ---> mineral water ( 1788 )  - conf( 0.4888888888888889 )
# ('mineral water', 'olive oil') ( 207 ) ---> eggs ( 1348 )  - conf( 0.21256038647342995 )
# eggs ( 1348 ) ---> ('mineral water', 'olive oil') ( 207 )  conf( 0.032640949554896145 )
# mineral water ( 1788 ) ---> ('eggs', 'olive oil') ( 90 )  conf( 0.024608501118568233 )
# olive oil ( 494 ) ---> ('eggs', 'mineral water') ( 382 )  conf( 0.08906882591093117 )
# ('chocolate', 'olive oil') ( 123 ) ---> spaghetti ( 1306 )  - conf( 0.43089430894308944 )
# ('chocolate', 'spaghetti') ( 295 ) ---> olive oil ( 494 )  - conf( 0.17966101694915254 )
# ('olive oil', 'spaghetti') ( 172 ) ---> chocolate ( 1230 )  - conf( 0.3081395348837209 )
# chocolate ( 1230 ) ---> ('olive oil', 'spaghetti') ( 172 )  conf( 0.043089430894308944 )
# olive oil ( 494 ) ---> ('chocolate', 'spaghetti') ( 295 )  conf( 0.10728744939271255 )
# spaghetti ( 1306 ) ---> ('chocolate', 'olive oil') ( 123 )  conf( 0.04058192955589587 )
# ('frozen vegetables', 'olive oil') ( 85 ) ---> spaghetti ( 1306 )  - conf( 0.5058823529411764 )
# ('frozen vegetables', 'spaghetti') ( 209 ) ---> olive oil ( 494 )  - conf( 0.20574162679425836 )
# ('olive oil', 'spaghetti') ( 172 ) ---> frozen vegetables ( 715 )  - conf( 0.25 )
# frozen vegetables ( 715 ) ---> ('olive oil', 'spaghetti') ( 172 )  conf( 0.06013986013986014 )
# olive oil ( 494 ) ---> ('frozen vegetables', 'spaghetti') ( 209 )  conf( 0.08704453441295547 )
# spaghetti ( 1306 ) ---> ('frozen vegetables', 'olive oil') ( 85 )  conf( 0.032924961715160794 )
# ('olive oil', 'pancakes') ( 81 ) ---> spaghetti ( 1306 )  - conf( 0.4691358024691358 )
# ('olive oil', 'spaghetti') ( 172 ) ---> pancakes ( 713 )  - conf( 0.22093023255813954 )
# ('pancakes', 'spaghetti') ( 189 ) ---> olive oil ( 494 )  - conf( 0.20105820105820105 )
# olive oil ( 494 ) ---> ('pancakes', 'spaghetti') ( 189 )  conf( 0.07692307692307693 )
# pancakes ( 713 ) ---> ('olive oil', 'spaghetti') ( 172 )  conf( 0.05329593267882188 )
# spaghetti ( 1306 ) ---> ('olive oil', 'pancakes') ( 81 )  conf( 0.02909647779479326 )
# ('green tea', 'olive oil') ( 75 ) ---> spaghetti ( 1306 )  - conf( 0.4533333333333333 )
# ('green tea', 'spaghetti') ( 199 ) ---> olive oil ( 494 )  - conf( 0.1708542713567839 )
# ('olive oil', 'spaghetti') ( 172 ) ---> green tea ( 991 )  - conf( 0.19767441860465115 )
# green tea ( 991 ) ---> ('olive oil', 'spaghetti') ( 172 )  conf( 0.034308779011099896 )
# olive oil ( 494 ) ---> ('green tea', 'spaghetti') ( 199 )  conf( 0.06882591093117409 )
# spaghetti ( 1306 ) ---> ('green tea', 'olive oil') ( 75 )  conf( 0.026033690658499236 )
# ('chocolate', 'milk') ( 241 ) ---> olive oil ( 494 )  - conf( 0.16182572614107885 )
# ('chocolate', 'olive oil') ( 123 ) ---> milk ( 972 )  - conf( 0.3170731707317073 )
# ('milk', 'olive oil') ( 128 ) ---> chocolate ( 1230 )  - conf( 0.3046875 )
# chocolate ( 1230 ) ---> ('milk', 'olive oil') ( 128 )  conf( 0.03170731707317073 )
# milk ( 972 ) ---> ('chocolate', 'olive oil') ( 123 )  conf( 0.040123456790123455 )
# olive oil ( 494 ) ---> ('chocolate', 'milk') ( 241 )  conf( 0.07894736842105263 )
# ('burgers', 'chocolate') ( 128 ) ---> spaghetti ( 1306 )  - conf( 0.375 )
# ('burgers', 'spaghetti') ( 161 ) ---> chocolate ( 1230 )  - conf( 0.2981366459627329 )
# ('chocolate', 'spaghetti') ( 295 ) ---> burgers ( 654 )  - conf( 0.16271186440677965 )
# burgers ( 654 ) ---> ('chocolate', 'spaghetti') ( 295 )  conf( 0.07339449541284404 )
# chocolate ( 1230 ) ---> ('burgers', 'spaghetti') ( 161 )  conf( 0.03902439024390244 )
# spaghetti ( 1306 ) ---> ('burgers', 'chocolate') ( 128 )  conf( 0.036753445635528334 )
# ('burgers', 'chocolate') ( 128 ) ---> eggs ( 1348 )  - conf( 0.3203125 )
# ('burgers', 'eggs') ( 216 ) ---> chocolate ( 1230 )  - conf( 0.18981481481481483 )
# ('chocolate', 'eggs') ( 249 ) ---> burgers ( 654 )  - conf( 0.1646586345381526 )
# burgers ( 654 ) ---> ('chocolate', 'eggs') ( 249 )  conf( 0.06269113149847094 )
# chocolate ( 1230 ) ---> ('burgers', 'eggs') ( 216 )  conf( 0.03333333333333333 )
# eggs ( 1348 ) ---> ('burgers', 'chocolate') ( 128 )  conf( 0.030415430267062313 )
# ('burgers', 'chocolate') ( 128 ) ---> mineral water ( 1788 )  - conf( 0.3359375 )
# ('burgers', 'mineral water') ( 183 ) ---> chocolate ( 1230 )  - conf( 0.23497267759562843 )
# ('chocolate', 'mineral water') ( 396 ) ---> burgers ( 654 )  - conf( 0.10858585858585859 )
# burgers ( 654 ) ---> ('chocolate', 'mineral water') ( 396 )  conf( 0.06574923547400612 )
# chocolate ( 1230 ) ---> ('burgers', 'mineral water') ( 183 )  conf( 0.034959349593495934 )
# mineral water ( 1788 ) ---> ('burgers', 'chocolate') ( 128 )  conf( 0.024049217002237135 )
# ('burgers', 'eggs') ( 216 ) ---> spaghetti ( 1306 )  - conf( 0.25 )
# ('burgers', 'spaghetti') ( 161 ) ---> eggs ( 1348 )  - conf( 0.33540372670807456 )
# ('eggs', 'spaghetti') ( 274 ) ---> burgers ( 654 )  - conf( 0.19708029197080293 )
# burgers ( 654 ) ---> ('eggs', 'spaghetti') ( 274 )  conf( 0.08256880733944955 )
# eggs ( 1348 ) ---> ('burgers', 'spaghetti') ( 161 )  conf( 0.040059347181008904 )
# spaghetti ( 1306 ) ---> ('burgers', 'eggs') ( 216 )  conf( 0.04134762633996937 )
# ('burgers', 'mineral water') ( 183 ) ---> spaghetti ( 1306 )  - conf( 0.2677595628415301 )
# ('burgers', 'spaghetti') ( 161 ) ---> mineral water ( 1788 )  - conf( 0.30434782608695654 )
# ('mineral water', 'spaghetti') ( 448 ) ---> burgers ( 654 )  - conf( 0.109375 )
# burgers ( 654 ) ---> ('mineral water', 'spaghetti') ( 448 )  conf( 0.07492354740061162 )
# mineral water ( 1788 ) ---> ('burgers', 'spaghetti') ( 161 )  conf( 0.027404921700223715 )
# spaghetti ( 1306 ) ---> ('burgers', 'mineral water') ( 183 )  conf( 0.03751914241960184 )
# ('burgers', 'eggs') ( 216 ) ---> mineral water ( 1788 )  - conf( 0.27314814814814814 )
# ('burgers', 'mineral water') ( 183 ) ---> eggs ( 1348 )  - conf( 0.3224043715846995 )
# ('eggs', 'mineral water') ( 382 ) ---> burgers ( 654 )  - conf( 0.1544502617801047 )
# burgers ( 654 ) ---> ('eggs', 'mineral water') ( 382 )  conf( 0.09021406727828746 )
# eggs ( 1348 ) ---> ('burgers', 'mineral water') ( 183 )  conf( 0.04376854599406528 )
# mineral water ( 1788 ) ---> ('burgers', 'eggs') ( 216 )  conf( 0.032997762863534674 )
# ('burgers', 'french fries') ( 165 ) ---> spaghetti ( 1306 )  - conf( 0.2545454545454545 )
# ('burgers', 'spaghetti') ( 161 ) ---> french fries ( 1282 )  - conf( 0.2608695652173913 )
# ('french fries', 'spaghetti') ( 207 ) ---> burgers ( 654 )  - conf( 0.2028985507246377 )
# burgers ( 654 ) ---> ('french fries', 'spaghetti') ( 207 )  conf( 0.06422018348623854 )
# french fries ( 1282 ) ---> ('burgers', 'spaghetti') ( 161 )  conf( 0.0327613104524181 )
# spaghetti ( 1306 ) ---> ('burgers', 'french fries') ( 165 )  conf( 0.03215926493108729 )
# ('burgers', 'frozen vegetables') ( 79 ) ---> mineral water ( 1788 )  - conf( 0.46835443037974683 )
# ('burgers', 'mineral water') ( 183 ) ---> frozen vegetables ( 715 )  - conf( 0.20218579234972678 )
# ('frozen vegetables', 'mineral water') ( 268 ) ---> burgers ( 654 )  - conf( 0.13805970149253732 )
# burgers ( 654 ) ---> ('frozen vegetables', 'mineral water') ( 268 )  conf( 0.05657492354740061 )
# frozen vegetables ( 715 ) ---> ('burgers', 'mineral water') ( 183 )  conf( 0.05174825174825175 )
# mineral water ( 1788 ) ---> ('burgers', 'frozen vegetables') ( 79 )  conf( 0.02069351230425056 )
# ('burgers', 'chocolate') ( 128 ) ---> milk ( 972 )  - conf( 0.3203125 )
# ('burgers', 'milk') ( 134 ) ---> chocolate ( 1230 )  - conf( 0.30597014925373134 )
# ('chocolate', 'milk') ( 241 ) ---> burgers ( 654 )  - conf( 0.17012448132780084 )
# burgers ( 654 ) ---> ('chocolate', 'milk') ( 241 )  conf( 0.06269113149847094 )
# chocolate ( 1230 ) ---> ('burgers', 'milk') ( 134 )  conf( 0.03333333333333333 )
# milk ( 972 ) ---> ('burgers', 'chocolate') ( 128 )  conf( 0.04218106995884774 )
# ('burgers', 'milk') ( 134 ) ---> spaghetti ( 1306 )  - conf( 0.3582089552238806 )
# ('burgers', 'spaghetti') ( 161 ) ---> milk ( 972 )  - conf( 0.2981366459627329 )
# ('milk', 'spaghetti') ( 266 ) ---> burgers ( 654 )  - conf( 0.18045112781954886 )
# burgers ( 654 ) ---> ('milk', 'spaghetti') ( 266 )  conf( 0.07339449541284404 )
# milk ( 972 ) ---> ('burgers', 'spaghetti') ( 161 )  conf( 0.04938271604938271 )
# spaghetti ( 1306 ) ---> ('burgers', 'milk') ( 134 )  conf( 0.036753445635528334 )
# ('burgers', 'milk') ( 134 ) ---> mineral water ( 1788 )  - conf( 0.3880597014925373 )
# ('burgers', 'mineral water') ( 183 ) ---> milk ( 972 )  - conf( 0.28415300546448086 )
# ('milk', 'mineral water') ( 360 ) ---> burgers ( 654 )  - conf( 0.14444444444444443 )
# burgers ( 654 ) ---> ('milk', 'mineral water') ( 360 )  conf( 0.07951070336391437 )
# milk ( 972 ) ---> ('burgers', 'mineral water') ( 183 )  conf( 0.053497942386831275 )
# mineral water ( 1788 ) ---> ('burgers', 'milk') ( 134 )  conf( 0.029082774049217 )
# ('burgers', 'ground beef') ( 90 ) ---> mineral water ( 1788 )  - conf( 0.4444444444444444 )
# ('burgers', 'mineral water') ( 183 ) ---> ground beef ( 737 )  - conf( 0.2185792349726776 )
# ('ground beef', 'mineral water') ( 307 ) ---> burgers ( 654 )  - conf( 0.13029315960912052 )
# burgers ( 654 ) ---> ('ground beef', 'mineral water') ( 307 )  conf( 0.06116207951070336 )
# ground beef ( 737 ) ---> ('burgers', 'mineral water') ( 183 )  conf( 0.054274084124830396 )
# mineral water ( 1788 ) ---> ('burgers', 'ground beef') ( 90 )  conf( 0.02237136465324385 )
# ('burgers', 'french fries') ( 165 ) ---> green tea ( 991 )  - conf( 0.24848484848484848 )
# ('burgers', 'green tea') ( 131 ) ---> french fries ( 1282 )  - conf( 0.31297709923664124 )
# ('french fries', 'green tea') ( 214 ) ---> burgers ( 654 )  - conf( 0.19158878504672897 )
# burgers ( 654 ) ---> ('french fries', 'green tea') ( 214 )  conf( 0.06269113149847094 )
# french fries ( 1282 ) ---> ('burgers', 'green tea') ( 131 )  conf( 0.031981279251170044 )
# green tea ( 991 ) ---> ('burgers', 'french fries') ( 165 )  conf( 0.04137235116044399 )
# ('burgers', 'eggs') ( 216 ) ---> green tea ( 991 )  - conf( 0.20833333333333334 )
# ('burgers', 'green tea') ( 131 ) ---> eggs ( 1348 )  - conf( 0.3435114503816794 )
# ('eggs', 'green tea') ( 191 ) ---> burgers ( 654 )  - conf( 0.2356020942408377 )
# burgers ( 654 ) ---> ('eggs', 'green tea') ( 191 )  conf( 0.06880733944954129 )
# eggs ( 1348 ) ---> ('burgers', 'green tea') ( 131 )  conf( 0.03338278931750742 )
# green tea ( 991 ) ---> ('burgers', 'eggs') ( 216 )  conf( 0.045408678102926335 )
# ('burgers', 'eggs') ( 216 ) ---> french fries ( 1282 )  - conf( 0.3148148148148148 )
# ('burgers', 'french fries') ( 165 ) ---> eggs ( 1348 )  - conf( 0.4121212121212121 )
# ('eggs', 'french fries') ( 273 ) ---> burgers ( 654 )  - conf( 0.2490842490842491 )
# burgers ( 654 ) ---> ('eggs', 'french fries') ( 273 )  conf( 0.10397553516819572 )
# eggs ( 1348 ) ---> ('burgers', 'french fries') ( 165 )  conf( 0.050445103857566766 )
# french fries ( 1282 ) ---> ('burgers', 'eggs') ( 216 )  conf( 0.0530421216848674 )
# ('burgers', 'ground beef') ( 90 ) ---> spaghetti ( 1306 )  - conf( 0.45555555555555555 )
# ('burgers', 'spaghetti') ( 161 ) ---> ground beef ( 737 )  - conf( 0.2546583850931677 )
# ('ground beef', 'spaghetti') ( 294 ) ---> burgers ( 654 )  - conf( 0.13945578231292516 )
# burgers ( 654 ) ---> ('ground beef', 'spaghetti') ( 294 )  conf( 0.06269113149847094 )
# ground beef ( 737 ) ---> ('burgers', 'spaghetti') ( 161 )  conf( 0.05563093622795115 )
# spaghetti ( 1306 ) ---> ('burgers', 'ground beef') ( 90 )  conf( 0.03139356814701378 )
# ('burgers', 'eggs') ( 216 ) ---> milk ( 972 )  - conf( 0.18518518518518517 )
# ('burgers', 'milk') ( 134 ) ---> eggs ( 1348 )  - conf( 0.29850746268656714 )
# ('eggs', 'milk') ( 231 ) ---> burgers ( 654 )  - conf( 0.17316017316017315 )
# burgers ( 654 ) ---> ('eggs', 'milk') ( 231 )  conf( 0.06116207951070336 )
# eggs ( 1348 ) ---> ('burgers', 'milk') ( 134 )  conf( 0.02967359050445104 )
# milk ( 972 ) ---> ('burgers', 'eggs') ( 216 )  conf( 0.0411522633744856 )
# ('burgers', 'french fries') ( 165 ) ---> milk ( 972 )  - conf( 0.2545454545454545 )
# ('burgers', 'milk') ( 134 ) ---> french fries ( 1282 )  - conf( 0.31343283582089554 )
# ('french fries', 'milk') ( 178 ) ---> burgers ( 654 )  - conf( 0.23595505617977527 )
# burgers ( 654 ) ---> ('french fries', 'milk') ( 178 )  conf( 0.06422018348623854 )
# french fries ( 1282 ) ---> ('burgers', 'milk') ( 134 )  conf( 0.0327613104524181 )
# milk ( 972 ) ---> ('burgers', 'french fries') ( 165 )  conf( 0.043209876543209874 )
# ('burgers', 'chocolate') ( 128 ) ---> french fries ( 1282 )  - conf( 0.28125 )
# ('burgers', 'french fries') ( 165 ) ---> chocolate ( 1230 )  - conf( 0.21818181818181817 )
# ('chocolate', 'french fries') ( 258 ) ---> burgers ( 654 )  - conf( 0.13953488372093023 )
# burgers ( 654 ) ---> ('chocolate', 'french fries') ( 258 )  conf( 0.05504587155963303 )
# chocolate ( 1230 ) ---> ('burgers', 'french fries') ( 165 )  conf( 0.02926829268292683 )
# french fries ( 1282 ) ---> ('burgers', 'chocolate') ( 128 )  conf( 0.028081123244929798 )
# ('burgers', 'french fries') ( 165 ) ---> mineral water ( 1788 )  - conf( 0.23636363636363636 )
# ('burgers', 'mineral water') ( 183 ) ---> french fries ( 1282 )  - conf( 0.21311475409836064 )
# ...
# fresh bread ( 323 ) ---> milk ( 972 )  - conf( 0.21362229102167182 )
# milk ( 972 ) ---> fresh bread ( 323 )  - conf( 0.07098765432098765 )
# fresh bread ( 323 ) ---> frozen vegetables ( 715 )  - conf( 0.15789473684210525 )
# frozen vegetables ( 715 ) ---> fresh bread ( 323 )  - conf( 0.07132867132867132 )
# chocolate ( 1230 ) ---> fresh bread ( 323 )  - conf( 0.05772357723577236 )
# fresh bread ( 323 ) ---> chocolate ( 1230 )  - conf( 0.21981424148606812 )
# chicken ( 450 ) ---> fresh bread ( 323 )  - conf( 0.08666666666666667 )
# fresh bread ( 323 ) ---> chicken ( 450 )  - conf( 0.12074303405572756 )
# chocolate ( 1230 ) ---> ground beef ( 737 )  - conf( 0.14146341463414633 )
# ground beef ( 737 ) ---> chocolate ( 1230 )  - conf( 0.23609226594301222 )
# ground beef ( 737 ) ---> spaghetti ( 1306 )  - conf( 0.3989145183175034 )
# spaghetti ( 1306 ) ---> ground beef ( 737 )  - conf( 0.225114854517611 )
# ground beef ( 737 ) ---> mineral water ( 1788 )  - conf( 0.41655359565807326 )
# mineral water ( 1788 ) ---> ground beef ( 737 )  - conf( 0.17170022371364654 )
# ground beef ( 737 ) ---> milk ( 972 )  - conf( 0.22388059701492538 )
# milk ( 972 ) ---> ground beef ( 737 )  - conf( 0.1697530864197531 )
# green tea ( 991 ) ---> ground beef ( 737 )  - conf( 0.11200807265388496 )
# ground beef ( 737 ) ---> green tea ( 991 )  - conf( 0.15061058344640435 )
# french fries ( 1282 ) ---> ground beef ( 737 )  - conf( 0.0811232449297972 )
# ground beef ( 737 ) ---> french fries ( 1282 )  - conf( 0.14111261872455902 )
# eggs ( 1348 ) ---> ground beef ( 737 )  - conf( 0.11127596439169139 )
# ground beef ( 737 ) ---> eggs ( 1348 )  - conf( 0.20352781546811397 )
# escalope ( 595 ) ---> pancakes ( 713 )  - conf( 0.07394957983193277 )
# pancakes ( 713 ) ---> escalope ( 595 )  - conf( 0.061711079943899017 )
# escalope ( 595 ) ---> frozen vegetables ( 715 )  - conf( 0.0957983193277311 )
# frozen vegetables ( 715 ) ---> escalope ( 595 )  - conf( 0.07972027972027972 )
# escalope ( 595 ) ---> ground beef ( 737 )  - conf( 0.10420168067226891 )
# ground beef ( 737 ) ---> escalope ( 595 )  - conf( 0.08412483039348712 )
# escalope ( 595 ) ---> spaghetti ( 1306 )  - conf( 0.17647058823529413 )
# spaghetti ( 1306 ) ---> escalope ( 595 )  - conf( 0.08039816232771822 )
# escalope ( 595 ) ---> mineral water ( 1788 )  - conf( 0.21512605042016808 )
# mineral water ( 1788 ) ---> escalope ( 595 )  - conf( 0.07158836689038031 )
# eggs ( 1348 ) ---> escalope ( 595 )  - conf( 0.06157270029673591 )
# escalope ( 595 ) ---> eggs ( 1348 )  - conf( 0.13949579831932774 )
# burgers ( 654 ) ---> escalope ( 595 )  - conf( 0.08103975535168195 )
# escalope ( 595 ) ---> burgers ( 654 )  - conf( 0.08907563025210084 )
# escalope ( 595 ) ---> milk ( 972 )  - conf( 0.09747899159663866 )
# milk ( 972 ) ---> escalope ( 595 )  - conf( 0.059670781893004114 )
# escalope ( 595 ) ---> green tea ( 991 )  - conf( 0.11260504201680673 )
# green tea ( 991 ) ---> escalope ( 595 )  - conf( 0.06760847628657922 )
# chocolate ( 1230 ) ---> escalope ( 595 )  - conf( 0.1073170731707317 )
# escalope ( 595 ) ---> chocolate ( 1230 )  - conf( 0.2218487394957983 )
# escalope ( 595 ) ---> french fries ( 1282 )  - conf( 0.20672268907563024 )
# french fries ( 1282 ) ---> escalope ( 595 )  - conf( 0.09594383775351015 )
# herb & pepper ( 371 ) ---> low fat yogurt ( 574 )  - conf( 0.11859838274932614 )
# low fat yogurt ( 574 ) ---> herb & pepper ( 371 )  - conf( 0.07665505226480836 )
# cake ( 608 ) ---> herb & pepper ( 371 )  - conf( 0.05592105263157895 )
# herb & pepper ( 371 ) ---> cake ( 608 )  - conf( 0.09164420485175202 )
# ground beef ( 737 ) ---> herb & pepper ( 371 )  - conf( 0.1628222523744912 )
# herb & pepper ( 371 ) ---> ground beef ( 737 )  - conf( 0.32345013477088946 )
# eggs ( 1348 ) ---> herb & pepper ( 371 )  - conf( 0.06973293768545995 )
# herb & pepper ( 371 ) ---> eggs ( 1348 )  - conf( 0.25336927223719674 )
# cooking oil ( 383 ) ---> herb & pepper ( 371 )  - conf( 0.10443864229765012 )
# herb & pepper ( 371 ) ---> cooking oil ( 383 )  - conf( 0.1078167115902965 )
# herb & pepper ( 371 ) ---> shrimp ( 536 )  - conf( 0.14285714285714285 )
# shrimp ( 536 ) ---> herb & pepper ( 371 )  - conf( 0.09888059701492537 )
# herb & pepper ( 371 ) ---> milk ( 972 )  - conf( 0.18598382749326145 )
# milk ( 972 ) ---> herb & pepper ( 371 )  - conf( 0.07098765432098765 )
# french fries ( 1282 ) ---> herb & pepper ( 371 )  - conf( 0.0405616224648986 )
# herb & pepper ( 371 ) ---> french fries ( 1282 )  - conf( 0.14016172506738545 )
# herb & pepper ( 371 ) ---> olive oil ( 494 )  - conf( 0.10242587601078167 )
# olive oil ( 494 ) ---> herb & pepper ( 371 )  - conf( 0.07692307692307693 )
# herb & pepper ( 371 ) ---> spaghetti ( 1306 )  - conf( 0.3288409703504043 )
# spaghetti ( 1306 ) ---> herb & pepper ( 371 )  - conf( 0.09341500765696784 )
# chocolate ( 1230 ) ---> herb & pepper ( 371 )  - conf( 0.055284552845528454 )
# herb & pepper ( 371 ) ---> chocolate ( 1230 )  - conf( 0.18328840970350405 )
# herb & pepper ( 371 ) ---> mineral water ( 1788 )  - conf( 0.3450134770889488 )
# mineral water ( 1788 ) ---> herb & pepper ( 371 )  - conf( 0.07158836689038031 )
# herb & pepper ( 371 ) ---> turkey ( 469 )  - conf( 0.09703504043126684 )
# turkey ( 469 ) ---> herb & pepper ( 371 )  - conf( 0.0767590618336887 )
# green tea ( 991 ) ---> herb & pepper ( 371 )  - conf( 0.04843592330978809 )
# herb & pepper ( 371 ) ---> green tea ( 991 )  - conf( 0.1293800539083558 )
# frozen vegetables ( 715 ) ---> herb & pepper ( 371 )  - conf( 0.06293706293706294 )
# herb & pepper ( 371 ) ---> frozen vegetables ( 715 )  - conf( 0.12129380053908356 )
# grated cheese ( 393 ) ---> herb & pepper ( 371 )  - conf( 0.12468193384223919 )
# herb & pepper ( 371 ) ---> grated cheese ( 393 )  - conf( 0.1320754716981132 )
# herb & pepper ( 371 ) ---> pancakes ( 713 )  - conf( 0.14824797843665768 )
# pancakes ( 713 ) ---> herb & pepper ( 371 )  - conf( 0.07713884992987377 )
# chicken ( 450 ) ---> herb & pepper ( 371 )  - conf( 0.08222222222222222 )
# herb & pepper ( 371 ) ---> chicken ( 450 )  - conf( 0.09973045822102426 )
# chocolate ( 1230 ) ---> tomato sauce ( 106 )  - conf( 0.030894308943089432 )
# tomato sauce ( 106 ) ---> chocolate ( 1230 )  - conf( 0.3584905660377358 )
# spaghetti ( 1306 ) ---> tomato sauce ( 106 )  - conf( 0.03598774885145482 )
# tomato sauce ( 106 ) ---> spaghetti ( 1306 )  - conf( 0.44339622641509435 )
# mineral water ( 1788 ) ---> tomato sauce ( 106 )  - conf( 0.024049217002237135 )
# tomato sauce ( 106 ) ---> mineral water ( 1788 )  - conf( 0.4056603773584906 )
# ground beef ( 737 ) ---> tomato sauce ( 106 )  - conf( 0.054274084124830396 )
# tomato sauce ( 106 ) ---> ground beef ( 737 )  - conf( 0.37735849056603776 )
# french fries ( 1282 ) ---> strawberries ( 160 )  - conf( 0.033541341653666144 )
# strawberries ( 160 ) ---> french fries ( 1282 )  - conf( 0.26875 )
# mineral water ( 1788 ) ---> strawberries ( 160 )  - conf( 0.021252796420581657 )
# strawberries ( 160 ) ---> mineral water ( 1788 )  - conf( 0.2375 )
# burgers ( 654 ) ---> cake ( 608 )  - conf( 0.13149847094801223 )
# cake ( 608 ) ---> burgers ( 654 )  - conf( 0.14144736842105263 )
# cake ( 608 ) ---> eggs ( 1348 )  - conf( 0.23519736842105263 )
# eggs ( 1348 ) ---> cake ( 608 )  - conf( 0.10608308605341246 )
# cake ( 608 ) ---> ground beef ( 737 )  - conf( 0.10032894736842106 )
# ground beef ( 737 ) ---> cake ( 608 )  - conf( 0.08276797829036635 )
# cake ( 608 ) ---> spaghetti ( 1306 )  - conf( 0.2236842105263158 )
# spaghetti ( 1306 ) ---> cake ( 608 )  - conf( 0.10413476263399694 )
# cake ( 608 ) ---> mineral water ( 1788 )  - conf( 0.33881578947368424 )
# mineral water ( 1788 ) ---> cake ( 608 )  - conf( 0.11521252796420582 )
# cake ( 608 ) ---> chocolate ( 1230 )  - conf( 0.16776315789473684 )
# chocolate ( 1230 ) ---> cake ( 608 )  - conf( 0.08292682926829269 )
# cake ( 608 ) ---> pancakes ( 713 )  - conf( 0.14638157894736842 )
# pancakes ( 713 ) ---> cake ( 608 )  - conf( 0.12482468443197756 )
# cake ( 608 ) ---> frozen vegetables ( 715 )  - conf( 0.12664473684210525 )
# frozen vegetables ( 715 ) ---> cake ( 608 )  - conf( 0.1076923076923077 )
# cake ( 608 ) ---> french fries ( 1282 )  - conf( 0.22039473684210525 )
# french fries ( 1282 ) ---> cake ( 608 )  - conf( 0.10452418096723869 )
# cake ( 608 ) ---> green tea ( 991 )  - conf( 0.17434210526315788 )
# green tea ( 991 ) ---> cake ( 608 )  - conf( 0.10696266397578204 )
# cake ( 608 ) ---> milk ( 972 )  - conf( 0.16447368421052633 )
# milk ( 972 ) ---> cake ( 608 )  - conf( 0.102880658436214 )
# french fries ( 1282 ) ---> hot dogs ( 243 )  - conf( 0.042901716068642744 )
# hot dogs ( 243 ) ---> french fries ( 1282 )  - conf( 0.22633744855967078 )
# chocolate ( 1230 ) ---> hot dogs ( 243 )  - conf( 0.03333333333333333 )
# hot dogs ( 243 ) ---> chocolate ( 1230 )  - conf( 0.16872427983539096 )
# hot dogs ( 243 ) ---> mineral water ( 1788 )  - conf( 0.2839506172839506 )
# mineral water ( 1788 ) ---> hot dogs ( 243 )  - conf( 0.03859060402684564 )
# frozen smoothie ( 475 ) ---> hot dogs ( 243 )  - conf( 0.07578947368421053 )
# hot dogs ( 243 ) ---> frozen smoothie ( 475 )  - conf( 0.14814814814814814 )
# green tea ( 991 ) ---> hot dogs ( 243 )  - conf( 0.050454086781029264 )
# hot dogs ( 243 ) ---> green tea ( 991 )  - conf( 0.205761316872428 )
# hot dogs ( 243 ) ---> spaghetti ( 1306 )  - conf( 0.2674897119341564 )
# spaghetti ( 1306 ) ---> hot dogs ( 243 )  - conf( 0.04977029096477795 )
# brownies ( 253 ) ---> french fries ( 1282 )  - conf( 0.233201581027668 )
# french fries ( 1282 ) ---> brownies ( 253 )  - conf( 0.046021840873634944 )
# brownies ( 253 ) ---> eggs ( 1348 )  - conf( 0.21739130434782608 )
# eggs ( 1348 ) ---> brownies ( 253 )  - conf( 0.04080118694362018 )
# brownies ( 253 ) ---> cake ( 608 )  - conf( 0.16205533596837945 )
# cake ( 608 ) ---> brownies ( 253 )  - conf( 0.06743421052631579 )
# brownies ( 253 ) ---> chocolate ( 1230 )  - conf( 0.14624505928853754 )
# chocolate ( 1230 ) ---> brownies ( 253 )  - conf( 0.03008130081300813 )
# brownies ( 253 ) ---> green tea ( 991 )  - conf( 0.1976284584980237 )
# green tea ( 991 ) ---> brownies ( 253 )  - conf( 0.050454086781029264 )
# brownies ( 253 ) ---> milk ( 972 )  - conf( 0.16205533596837945 )
# milk ( 972 ) ---> brownies ( 253 )  - conf( 0.04218106995884774 )
# brownies ( 253 ) ---> spaghetti ( 1306 )  - conf( 0.21739130434782608 )
# spaghetti ( 1306 ) ---> brownies ( 253 )  - conf( 0.04211332312404288 )
# brownies ( 253 ) ---> ground beef ( 737 )  - conf( 0.14624505928853754 )
# ground beef ( 737 ) ---> brownies ( 253 )  - conf( 0.050203527815468114 )
# brownies ( 253 ) ---> pancakes ( 713 )  - conf( 0.16205533596837945 )
# pancakes ( 713 ) ---> brownies ( 253 )  - conf( 0.05750350631136045 )
# brownies ( 253 ) ---> mineral water ( 1788 )  - conf( 0.2845849802371542 )
# mineral water ( 1788 ) ---> brownies ( 253 )  - conf( 0.040268456375838924 )
# cereals ( 193 ) ---> pancakes ( 713 )  - conf( 0.18134715025906736 )
# pancakes ( 713 ) ---> cereals ( 193 )  - conf( 0.04908835904628331 )
# cereals ( 193 ) ---> ground beef ( 737 )  - conf( 0.17616580310880828 )
# ground beef ( 737 ) ---> cereals ( 193 )  - conf( 0.04613297150610583 )
# cereals ( 193 ) ---> spaghetti ( 1306 )  - conf( 0.25906735751295334 )
# spaghetti ( 1306 ) ---> cereals ( 193 )  - conf( 0.03828483920367534 )
# cereals ( 193 ) ---> mineral water ( 1788 )  - conf( 0.39896373056994816 )
# mineral water ( 1788 ) ---> cereals ( 193 )  - conf( 0.043064876957494405 )
# cereals ( 193 ) ---> chocolate ( 1230 )  - conf( 0.21761658031088082 )
# chocolate ( 1230 ) ---> cereals ( 193 )  - conf( 0.03414634146341464 )
# cereals ( 193 ) ---> french fries ( 1282 )  - conf( 0.18652849740932642 )
# french fries ( 1282 ) ---> cereals ( 193 )  - conf( 0.028081123244929798 )
# cereals ( 193 ) ---> milk ( 972 )  - conf( 0.27461139896373055 )
# milk ( 972 ) ---> cereals ( 193 )  - conf( 0.05452674897119342 )
# cereals ( 193 ) ---> green tea ( 991 )  - conf( 0.2538860103626943 )
# green tea ( 991 ) ---> cereals ( 193 )  - conf( 0.04944500504540868 )
# french fries ( 1282 ) ---> muffins ( 181 )  - conf( 0.031201248049921998 )
# muffins ( 181 ) ---> french fries ( 1282 )  - conf( 0.22099447513812154 )
# chocolate ( 1230 ) ---> light mayo ( 204 )  - conf( 0.030894308943089432 )
# light mayo ( 204 ) ---> chocolate ( 1230 )  - conf( 0.18627450980392157 )
# french fries ( 1282 ) ---> light mayo ( 204 )  - conf( 0.042901716068642744 )
# light mayo ( 204 ) ---> french fries ( 1282 )  - conf( 0.2696078431372549 )
# eggs ( 1348 ) ---> light mayo ( 204 )  - conf( 0.030415430267062313 )
# light mayo ( 204 ) ---> eggs ( 1348 )  - conf( 0.20098039215686275 )
# light mayo ( 204 ) ---> mineral water ( 1788 )  - conf( 0.23039215686274508 )
# mineral water ( 1788 ) ---> light mayo ( 204 )  - conf( 0.026286353467561523 )
# light mayo ( 204 ) ---> pancakes ( 713 )  - conf( 0.20098039215686275 )
# pancakes ( 713 ) ---> light mayo ( 204 )  - conf( 0.05750350631136045 )
# gums ( 101 ) ---> mineral water ( 1788 )  - conf( 0.36633663366336633 )
# mineral water ( 1788 ) ---> gums ( 101 )  - conf( 0.02069351230425056 )
# eggs ( 1348 ) ---> yogurt cake ( 205 )  - conf( 0.025222551928783383 )
# yogurt cake ( 205 ) ---> eggs ( 1348 )  - conf( 0.16585365853658537 )
# mineral water ( 1788 ) ---> yogurt cake ( 205 )  - conf( 0.02348993288590604 )
# yogurt cake ( 205 ) ---> mineral water ( 1788 )  - conf( 0.2048780487804878 )
# french fries ( 1282 ) ---> yogurt cake ( 205 )  - conf( 0.029641185647425898 )
# yogurt cake ( 205 ) ---> french fries ( 1282 )  - conf( 0.18536585365853658 )
# mineral water ( 1788 ) ---> mint ( 131 )  - conf( 0.024608501118568233 )
# mint ( 131 ) ---> mineral water ( 1788 )  - conf( 0.33587786259541985 )
# butter ( 226 ) ---> chocolate ( 1230 )  - conf( 0.2743362831858407 )
# chocolate ( 1230 ) ---> butter ( 226 )  - conf( 0.05040650406504065 )
# butter ( 226 ) ---> french fries ( 1282 )  - conf( 0.20353982300884957 )
# french fries ( 1282 ) ---> butter ( 226 )  - conf( 0.0358814352574103 )
# butter ( 226 ) ---> spaghetti ( 1306 )  - conf( 0.2079646017699115 )
# spaghetti ( 1306 ) ---> butter ( 226 )  - conf( 0.03598774885145482 )
# butter ( 226 ) ---> green tea ( 991 )  - conf( 0.24336283185840707 )
# green tea ( 991 ) ---> butter ( 226 )  - conf( 0.055499495459132187 )
# butter ( 226 ) ---> milk ( 972 )  - conf( 0.20353982300884957 )
# milk ( 972 ) ---> butter ( 226 )  - conf( 0.047325102880658436 )
# butter ( 226 ) ---> eggs ( 1348 )  - conf( 0.20353982300884957 )
# eggs ( 1348 ) ---> butter ( 226 )  - conf( 0.03412462908011869 )
# french wine ( 169 ) ---> milk ( 972 )  - conf( 0.21893491124260356 )
# milk ( 972 ) ---> french wine ( 169 )  - conf( 0.03806584362139918 )
# chocolate ( 1230 ) ---> french wine ( 169 )  - conf( 0.03170731707317073 )
# french wine ( 169 ) ---> chocolate ( 1230 )  - conf( 0.23076923076923078 )
# eggs ( 1348 ) ---> french wine ( 169 )  - conf( 0.03338278931750742 )
# french wine ( 169 ) ---> eggs ( 1348 )  - conf( 0.26627218934911245 )
# french wine ( 169 ) ---> spaghetti ( 1306 )  - conf( 0.3431952662721893 )
# spaghetti ( 1306 ) ---> french wine ( 169 )  - conf( 0.0444104134762634 )
# french wine ( 169 ) ---> mineral water ( 1788 )  - conf( 0.3668639053254438 )
# mineral water ( 1788 ) ---> french wine ( 169 )  - conf( 0.03467561521252797 )
# carrots ( 115 ) ---> mineral water ( 1788 )  - conf( 0.34782608695652173 )
# mineral water ( 1788 ) ---> carrots ( 115 )  - conf( 0.02237136465324385 )
# carrots ( 115 ) ---> spaghetti ( 1306 )  - conf( 0.30434782608695654 )
# spaghetti ( 1306 ) ---> carrots ( 115 )  - conf( 0.02679938744257274 )
# escalope ( 595 ) ---> mushroom cream sauce ( 143 )  - conf( 0.07226890756302522 )
# mushroom cream sauce ( 143 ) ---> escalope ( 595 )  - conf( 0.3006993006993007 )
# french fries ( 1282 ) ---> mushroom cream sauce ( 143 )  - conf( 0.027301092043681748 )
# mushroom cream sauce ( 143 ) ---> french fries ( 1282 )  - conf( 0.24475524475524477 )
# mineral water ( 1788 ) ---> nonfat milk ( 78 )  - conf( 0.021252796420581657 )
# nonfat milk ( 78 ) ---> mineral water ( 1788 )  - conf( 0.48717948717948717 )
# fromage blanc ( 102 ) ---> mineral water ( 1788 )  - conf( 0.3333333333333333 )
# mineral water ( 1788 ) ---> fromage blanc ( 102 )  - conf( 0.01901565995525727 )
# 2370 rules generated
# FP_Growth_spent_time 7.164990663528442

# %% [markdown]
# # !!!! FP-growth     big_minsup and small_minconf with Market_Basket_Optimisation.csv

# %%
import csv
import pandas as pd
from itertools import combinations
import time


#Read data from CSV
# data = pd.read_csv('groceries.csv')
data = pd.read_csv('Market_Basket_Optimisation.csv', header=None)
#
#Parameters
minsup = float(input("Support-Threshold: "))
minsup = minsup * len(data)
minconf = float(input("Confidence-Threshold: "))
print(len(data))#9835
time_start = time.time()

#Add all data in a list of lists
items = []  
# print(len(data.values[0]))#1列(ROW)有32的物品
for i in range(0, len(data)):  #將所有data中的物品一列一列放到items
     items.append([str(data.values[i, j]) for j in range(0, len(data.values[0]))])

#Creating a list of dictionaries
count = [dict() for x in range(len(data.values[0]) + 1)]
# print(items)
# #Count support for each individual items
s = []
for i in items:
    for j in i:      #讀取所有items
        s.append(j)
for i in s:                      #創字典 放在count[1]
    #If item is present in dictionary, increment its count by 1
    if i in count[1]:
        count[1][i] = count[1][i] + 1
    #If item is not present in dictionary, set its count to 1
    else:
        count[1][i] = 1     #{'i':1}

# #Remove infrequent and empty items #去除小於minsup,nan
for i in count[1].copy():
    if(count[1][i] < minsup):
        count[1].pop(i)
count[1].pop('nan') #去除以key = 'NAN'產生的值

# #Storing transactions as lists without infrequent items
a = list(count[1]) #列出所有符合的KEY
item = [list() for i in range(len(data))] #創造len(data) = 9835個list 
c = 0 
for i in range(0,len(items)): ##將所有data中的物品一列一列放到items
    for j in range(len(items[i])):
#         print(items[i][j])
        if(a.__contains__(items[i][j]) != 0): #確認物品是否存在
            item[i].append(items[i][j]) #將物品分成[['a', 'b', 'c'],[]]與itmes不同的地方是裡練已經沒有NAN了

#Function to sort list to support
def sort(a): #a = 所有符合的KEY的list
    for i in range(len(a) - 1):
        for j in range(len(a) - i - 1):
            if(count[1][a[j]] < count[1][a[j + 1]]): #如果下一個比上一個大則互換位子
                a[j],a[j + 1] = a[j + 1],a[j]
                
#Call function to sort all transactions in descending order of their support
for i in range(0,len(data)): #9835
    if(len(item[i]) > 1): #如果不只一個物件就排序他
        sort(item[i])

#Tree class for FP-Tree
class tree: #設計樹根，分支
    def __init__(self, name, sup, parent):
        self.name = name
        self.sup = sup
        self.nodeLink = None
        self.parent = parent
        self.children = []

#Function to check if the node is present is a child of the current node
def ispresent(node,name):    #確認是否有children
    f = -1               
    for i in node.children:
        f += 1
        if(i.name == name):
            return f
    return -1

#HeaderTable which stores the reference of last/first occurence of an item. Used as a linked list to generate candidate trees 
lastocc = count[1].copy() #符合sup的字典
for i in lastocc: #lastocc字典中所有值皆為NONE
    lastocc[i] = None
#Function to create FP-tree
root = tree("root", -1, None)
z = 0
for i in item: #item為沒有NAN的items
    current = root
    for j in range(len(i)): #len(i)9835
        if(ispresent(current,i[j]) >= 0): #第一次通常不符合此情形，直接執行else，看有沒有children
            current = current.children[ispresent(current, i[j])]
            current.sup = current.sup + 1
        else:
            child=tree(i[j], 1, current)    #創建i[j]子根
            current.children.append(child) #將子根放入children =[] 
            t = current #t 記錄柱上一層的tree1
            current = current.children[ispresent(current, i[j])] #現在current.children裡有子根，所以self.name = i[j]如下示意，
            #ispresent(current,i[j])回傳 0 ，現在的current為tree2
            current.parent = t #紀錄上一層tree1
            if(lastocc[current.name] == None):
                lastocc[current.name] = current #創建{'i[j]': tree2-1()} 
            else:#創出第一層並列樹枝
                current.nodeLink = lastocc[current.name] #將tree2-2連結到tree4
                lastocc[current.name] = current #CURRENT = TREE2-2 {'i[j]': tree2-2}
            
# class tree1:
#     def __init__(self, name, sup, parent):
#         self.name = 'root'
#         self.sup = -1
#         self.nodeLink = None
#         self.parent = none
#         self.children = [
#   class tree2-1:
#     def __init__(self, name, sup, parent):      [['A','B','C'],['C','A']]
#         self.name = 'A'
#         self.sup = 1
#         self.nodeLink = NONE
#         self.parent = parent
#         self.children = [
#                                     class tree3:
#                                         def __init__(self, name, sup, parent):
#                                             self.name = 'B'
#                                             self.sup = 1
#                                             self.nodeLink = None
#                                             self.parent = parent
#                                             self.children = [
#                                                                 class tree4:
#                                                                     def __init__(self, name, sup, parent):
#                                                                         self.name = 'B'
#                                                                         self.sup = 1
#                                                                         self.nodeLink = None
#                                                                         self.parent = parent
#                                                                         self.children = []
#                                                                 ]
#         ],
#   class tree2-2:
#     def __init__(self, name, sup, parent):
#         self.name = 'C'
#         self.sup = sup
#         self.nodeLink = TREE 4
#         self.parent = TREE1
#         self.children = []
# ]



#Function to get frequent itemsets with suffix 'node' and length n
def singlepath(node, n):
    c = 0
    sup = node.sup
    path = []
    pathname = []
    current = node
    
    #Get the path from current node to root
    while(current.parent != None): #查看目current是否為'root'，如果是則無parent，重複做直道回到最上層('root')
        path.append(current)     #將current內容紀錄(tree)
        pathname.append(current.name)      #('c')
        current = current.parent  #往上一層移動
    path.remove(node) #除了自己以外的路線
    pathname.remove(node.name) 
    candidatepath = []
    temp_candidatepath = []
   
    #Generate combinations of length n in the path
    a = (list(combinations(pathname, n))) #列出除了自己以外的長度為n的組合
    for j in a:
        temp_candidatepath.append(tuple(sorted(j)))   #以tuple形式存在temp_candidatapath裡
    #Append the suffix 'node.name' to the above paths
    for j in temp_candidatepath:
        j = list(j) #再次變回list
        j.append(node.name) #將原本剔除的當前TREE名加回去 變成包含當前的組合，就是在做freqent pattern
        candidatepath.append(sorted(j)) #在加回去變成 [['a','c'],['b','c']]
    #Update counts of the generated itemsets
    for j in candidatepath:
        j = tuple(j) #j = ('a','c')
        if j in count[n + 1]: #count[1]為符合minsup的字典，n至少會從1開始 
            count[n + 1][j] = count[n + 1][j] + sup  # 將之前已創好的value值，加上當前tree所有的sup
        else:
            count[n + 1][j] = sup #創建新字典,此sup為當前tree存有的sup
            
    #Iterating in the candidate tree recursively 
    if(node.nodeLink != None): #查看是否存在分支
        node=node.nodeLink
        singlepath(node, i) #i為組合長度
    
#Check if itemset is frequent
def frequent(n): #算出現次數
    f=0
    for i in count[n]:
        if(count[n][i] >= minsup):
            f = 1
    if(f == 1):
        return 1
    else:
        return 0

#Call singlepath function for all frequent nodes
for i in range(1, len(data.values[0]) + 1): #1列(ROW)有32的物品, +1是確保有32為一組的組合  #!
    if(frequent(i) == 1):
        for j in lastocc: #開始製造組合，將結果放到count[]裡，count唯有32空字典的list
            singlepath(lastocc[j], i)

#Remove infrequent itemsets
for z in range(len(data.values[0]) + 1):            
    for i in count[z].copy():
            if(count[z][i] < minsup): #查看所有的dict裡面的東西，是否符合minsup
                count[z].pop(i) #去掉不符合的

frequent_pattern = []
for items in count:
    for want in items:
        frequent_pattern.append(want)
                
#Get 'q', the length of the longest itemset
i=1 #設2是因為從第二筆的字典，才開始有東西
while(len(count[i]) != 0): #從這邊就能知道最大符合長度是多長，因為不符合的都被刪掉了，所以count最大的子矩陣
    i = i + 1
q = i - 1

#Find maximal and closed itemsets
maximal = []
closed = []
for i in range(1, q):
    for j in count[i]:
        fm = 0
        fc = 0
        for k in count[i + 1]:
            a = set(list([j]))
            b = set(list(k))
            #Set is maximal if no immediate superset is frequent
            if(a.intersection(b) == a): #如果兩者重疊則maximal
                fm = 1 
                #Set is closed if none of its immediate supersets have equal support
                if(count[i][j] == count[i + 1][k]): #出現次數相同
                    fc = 1
        if(fm == 0):
            maximal.append(j)
        if(fc == 0):
            closed.append(j)
#All sets at the top of the tree are automatically maximal and closed
for i in count[q]:
    maximal.append(i)
    closed.append(i)
print("frequent_pattern")
print(len(frequent_pattern))
print(frequent_pattern)
    
#Find Association Rules 
print("Association_Rules")
ant=count.copy()
for i in range(q, 0, -1): #從後面樹回來
    for j in ant[i]:  #ant = count
        for k in range(i-1, 0, -1): # i = q(最大長度)
            s = list(combinations(list(j), k))  #將所有可能組出來 #!s = allco  
            #Traverse through list of all combinations of antecedants
            for n in s:
                #Sorting to prevent duplicate itemsets 
                r = tuple(sorted(set(j).difference(set(n))))
                l = len(n) #輸入進來的字元長度
                #Check if len(n) == 1 to be able to extract key to search in the support dictionary. 
                if(l == 1):
                    n = value(n)
                    l = 1 
                if(len(r) == 1):
                    r2 = value(r)
                if(n != None):
                    #If rule's confidence is greater than minconfidence, then print the rule
                    if((ant[len(j)][j] / ant[l][n]) >= minconf):
                        #Rule is only significant if it is present in CLOSED, otherwise it is redundant
                        if(closed.__contains__((n))):
                            c += 1
                            if(len(r) == 1):
                                print(n, "(", ant[l][n], ")", "--->", r2, "(", ant[len(r)][r2], ")", " - conf(", (ant[len(j)][j] / ant[l][n]), ")")
                            else:
                                print(n,"(", ant[l][n], ")", "--->", r, "(", ant[len(r)][r], ")", " conf(", (ant[len(j)][j] / ant[l][n]), ")")
print(c, "rules generated")


#Function to extract single item set from a tuple
def value(a):              #前面我們將用set差集，進行前處理，否則我們無法當index。
#     print(a) ('mineral water',)
    print(type(a))
    a = str(a)
#     print(a)('mineral water',)

    a = a[:-2]
#     print(a) ('mineral water'
    a = a[2:]
#     print(a)  mineral water'

    a = a[:-1]
#     print(a) mineral water
    return a


time_end = time.time()
print('FP_Growth_spent_time', time_end - time_start)
# print( time_end - time_start)
print(len(ant))
# Out:
# Support-Threshold: 0.045
# Confidence-Threshold: 0.01
# 7501
# frequent_pattern
# 32
# ['shrimp', 'low fat yogurt', 'green tea', 'honey', 'mineral water', 'frozen smoothie', 'olive oil', 'burgers', 'eggs', 'turkey', 'milk', 'whole wheat rice', 'french fries', 'soup', 'frozen vegetables', 'spaghetti', 'cookies', 'cooking oil', 'champagne', 'chocolate', 'chicken', 'tomatoes', 'pancakes', 'grated cheese', 'ground beef', 'escalope', 'herb & pepper', 'cake', ('eggs', 'mineral water'), ('milk', 'mineral water'), ('mineral water', 'spaghetti'), ('chocolate', 'mineral water')]
# Association_Rules
# eggs ( 1348 ) ---> mineral water ( 1788 )  - conf( 0.28338278931750743 )
# mineral water ( 1788 ) ---> eggs ( 1348 )  - conf( 0.21364653243847875 )
# milk ( 972 ) ---> mineral water ( 1788 )  - conf( 0.37037037037037035 )
# mineral water ( 1788 ) ---> milk ( 972 )  - conf( 0.20134228187919462 )
# mineral water ( 1788 ) ---> spaghetti ( 1306 )  - conf( 0.2505592841163311 )
# spaghetti ( 1306 ) ---> mineral water ( 1788 )  - conf( 0.3430321592649311 )
# chocolate ( 1230 ) ---> mineral water ( 1788 )  - conf( 0.32195121951219513 )
# mineral water ( 1788 ) ---> chocolate ( 1230 )  - conf( 0.2214765100671141 )
# 8 rules generated
# FP_Growth_spent_time 1.6889994144439697
# 21

# %% [markdown]
# # FP-growth     small_minsup and big_minconf with Market_Basket_Optimisation.csv

# %%
import csv
import pandas as pd
from itertools import combinations
import time


#Read data from CSV
# data = pd.read_csv('groceries.csv')
data = pd.read_csv('Market_Basket_Optimisation.csv', header=None)
#
#Parameters
minsup = float(input("Support-Threshold: "))
minsup = minsup * len(data)
minconf = float(input("Confidence-Threshold: "))
print(len(data))#9835
time_start = time.time()

#Add all data in a list of lists
items = []  
# print(len(data.values[0]))#1列(ROW)有32的物品
for i in range(0, len(data)):  #將所有data中的物品一列一列放到items
     items.append([str(data.values[i, j]) for j in range(0, len(data.values[0]))])

#Creating a list of dictionaries
count = [dict() for x in range(len(data.values[0]) + 1)]
# print(items)
# #Count support for each individual items
s = []
for i in items:
    for j in i:      #讀取所有items
        s.append(j)
for i in s:                      #創字典 放在count[1]
    #If item is present in dictionary, increment its count by 1
    if i in count[1]:
        count[1][i] = count[1][i] + 1
    #If item is not present in dictionary, set its count to 1
    else:
        count[1][i] = 1     #{'i':1}

# #Remove infrequent and empty items #去除小於minsup,nan
for i in count[1].copy():
    if(count[1][i] < minsup):
        count[1].pop(i)
count[1].pop('nan') #去除以key = 'NAN'產生的值

# #Storing transactions as lists without infrequent items
a = list(count[1]) #列出所有符合的KEY
item = [list() for i in range(len(data))] #創造len(data) = 9835個list 
c = 0 
for i in range(0,len(items)): ##將所有data中的物品一列一列放到items
    for j in range(len(items[i])):
#         print(items[i][j])
        if(a.__contains__(items[i][j]) != 0): #確認物品是否存在
            item[i].append(items[i][j]) #將物品分成[['a', 'b', 'c'],[]]與itmes不同的地方是裡練已經沒有NAN了

#Function to sort list to support
def sort(a): #a = 所有符合的KEY的list
    for i in range(len(a) - 1):
        for j in range(len(a) - i - 1):
            if(count[1][a[j]] < count[1][a[j + 1]]): #如果下一個比上一個大則互換位子
                a[j],a[j + 1] = a[j + 1],a[j]
                
#Call function to sort all transactions in descending order of their support
for i in range(0,len(data)): #9835
    if(len(item[i]) > 1): #如果不只一個物件就排序他
        sort(item[i])

#Tree class for FP-Tree
class tree: #設計樹根，分支
    def __init__(self, name, sup, parent):
        self.name = name
        self.sup = sup
        self.nodeLink = None
        self.parent = parent
        self.children = []

#Function to check if the node is present is a child of the current node
def ispresent(node,name):    #確認是否有children
    f = -1               
    for i in node.children:
        f += 1
        if(i.name == name):
            return f
    return -1

#HeaderTable which stores the reference of last/first occurence of an item. Used as a linked list to generate candidate trees 
lastocc = count[1].copy() #符合sup的字典
for i in lastocc: #lastocc字典中所有值皆為NONE
    lastocc[i] = None
#Function to create FP-tree
root = tree("root", -1, None)
z = 0
for i in item: #item為沒有NAN的items
    current = root
    for j in range(len(i)): #len(i)9835
        if(ispresent(current,i[j]) >= 0): #第一次通常不符合此情形，直接執行else，看有沒有children
            current = current.children[ispresent(current, i[j])]
            current.sup = current.sup + 1
        else:
            child=tree(i[j], 1, current)    #創建i[j]子根
            current.children.append(child) #將子根放入children =[] 
            t = current #t 記錄柱上一層的tree1
            current = current.children[ispresent(current, i[j])] #現在current.children裡有子根，所以self.name = i[j]如下示意，
            #ispresent(current,i[j])回傳 0 ，現在的current為tree2
            current.parent = t #紀錄上一層tree1
            if(lastocc[current.name] == None):
                lastocc[current.name] = current #創建{'i[j]': tree2-1()} 
            else:#創出第一層並列樹枝
                current.nodeLink = lastocc[current.name] #將tree2-2連結到tree4
                lastocc[current.name] = current #CURRENT = TREE2-2 {'i[j]': tree2-2}
            
# class tree1:
#     def __init__(self, name, sup, parent):
#         self.name = 'root'
#         self.sup = -1
#         self.nodeLink = None
#         self.parent = none
#         self.children = [
#   class tree2-1:
#     def __init__(self, name, sup, parent):      [['A','B','C'],['C','A']]
#         self.name = 'A'
#         self.sup = 1
#         self.nodeLink = NONE
#         self.parent = parent
#         self.children = [
#                                     class tree3:
#                                         def __init__(self, name, sup, parent):
#                                             self.name = 'B'
#                                             self.sup = 1
#                                             self.nodeLink = None
#                                             self.parent = parent
#                                             self.children = [
#                                                                 class tree4:
#                                                                     def __init__(self, name, sup, parent):
#                                                                         self.name = 'B'
#                                                                         self.sup = 1
#                                                                         self.nodeLink = None
#                                                                         self.parent = parent
#                                                                         self.children = []
#                                                                 ]
#         ],
#   class tree2-2:
#     def __init__(self, name, sup, parent):
#         self.name = 'C'
#         self.sup = sup
#         self.nodeLink = TREE 4
#         self.parent = TREE1
#         self.children = []
# ]



#Function to get frequent itemsets with suffix 'node' and length n
def singlepath(node, n):
    c = 0
    sup = node.sup
    path = []
    pathname = []
    current = node
    
    #Get the path from current node to root
    while(current.parent != None): #查看目current是否為'root'，如果是則無parent，重複做直道回到最上層('root')
        path.append(current)     #將current內容紀錄(tree)
        pathname.append(current.name)      #('c')
        current = current.parent  #往上一層移動
    path.remove(node) #除了自己以外的路線
    pathname.remove(node.name) 
    candidatepath = []
    temp_candidatepath = []
   
    #Generate combinations of length n in the path
    a = (list(combinations(pathname, n))) #列出除了自己以外的長度為n的組合
    for j in a:
        temp_candidatepath.append(tuple(sorted(j)))   #以tuple形式存在temp_candidatapath裡
    #Append the suffix 'node.name' to the above paths
    for j in temp_candidatepath:
        j = list(j) #再次變回list
        j.append(node.name) #將原本剔除的當前TREE名加回去 變成包含當前的組合，就是在做freqent pattern
        candidatepath.append(sorted(j)) #在加回去變成 [['a','c'],['b','c']]
    #Update counts of the generated itemsets
    for j in candidatepath:
        j = tuple(j) #j = ('a','c')
        if j in count[n + 1]: #count[1]為符合minsup的字典，n至少會從1開始 
            count[n + 1][j] = count[n + 1][j] + sup  # 將之前已創好的value值，加上當前tree所有的sup
        else:
            count[n + 1][j] = sup #創建新字典,此sup為當前tree存有的sup
            
    #Iterating in the candidate tree recursively 
    if(node.nodeLink != None): #查看是否存在分支
        node=node.nodeLink
        singlepath(node, i) #i為組合長度
    
#Check if itemset is frequent
def frequent(n): #算出現次數
    f=0
    for i in count[n]:
        if(count[n][i] >= minsup):
            f = 1
    if(f == 1):
        return 1
    else:
        return 0

#Call singlepath function for all frequent nodes
for i in range(1, len(data.values[0]) + 1): #1列(ROW)有32的物品, +1是確保有32為一組的組合  #!
    if(frequent(i) == 1):
        for j in lastocc: #開始製造組合，將結果放到count[]裡，count唯有32空字典的list
            singlepath(lastocc[j], i)

#Remove infrequent itemsets
for z in range(len(data.values[0]) + 1):            
    for i in count[z].copy():
            if(count[z][i] < minsup): #查看所有的dict裡面的東西，是否符合minsup
                count[z].pop(i) #去掉不符合的

frequent_pattern = []
for items in count:
    for want in items:
        frequent_pattern.append(want)
                
#Get 'q', the length of the longest itemset
i=1 #設2是因為從第二筆的字典，才開始有東西
while(len(count[i]) != 0): #從這邊就能知道最大符合長度是多長，因為不符合的都被刪掉了，所以count最大的子矩陣
    i = i + 1
q = i - 1

#Find maximal and closed itemsets
maximal = []
closed = []
for i in range(1, q):
    for j in count[i]:
        fm = 0
        fc = 0
        for k in count[i + 1]:
            a = set(list([j]))
            b = set(list(k))
            #Set is maximal if no immediate superset is frequent
            if(a.intersection(b) == a): #如果兩者重疊則maximal
                fm = 1 
                #Set is closed if none of its immediate supersets have equal support
                if(count[i][j] == count[i + 1][k]): #出現次數相同
                    fc = 1
        if(fm == 0):
            maximal.append(j)
        if(fc == 0):
            closed.append(j)
#All sets at the top of the tree are automatically maximal and closed
for i in count[q]:
    maximal.append(i)
    closed.append(i)
print("frequent_pattern")
print(len(frequent_pattern))
print(frequent_pattern)
    
#Find Association Rules 
print("Association_Rules")
ant=count.copy()
for i in range(q, 0, -1): #從後面樹回來
    for j in ant[i]:  #ant = count
        for k in range(i-1, 0, -1): # i = q(最大長度)
            s = list(combinations(list(j), k))  #將所有可能組出來 #!s = allco  
            #Traverse through list of all combinations of antecedants
            for n in s:
                #Sorting to prevent duplicate itemsets 
                r = tuple(sorted(set(j).difference(set(n))))
                l = len(n) #輸入進來的字元長度
                #Check if len(n) == 1 to be able to extract key to search in the support dictionary. 
                if(l == 1):
                    n = value(n)
                    l = 1 
                if(len(r) == 1):
                    r2 = value(r)
                if(n != None):
                    #If rule's confidence is greater than minconfidence, then print the rule
                    if((ant[len(j)][j] / ant[l][n]) >= minconf):
                        #Rule is only significant if it is present in CLOSED, otherwise it is redundant
                        if(closed.__contains__((n))):
                            c += 1
                            if(len(r) == 1):
                                print(n, "(", ant[l][n], ")", "--->", r2, "(", ant[len(r)][r2], ")", " - conf(", (ant[len(j)][j] / ant[l][n]), ")")
                            else:
                                print(n,"(", ant[l][n], ")", "--->", r, "(", ant[len(r)][r], ")", " conf(", (ant[len(j)][j] / ant[l][n]), ")")
print(c, "rules generated")


#Function to extract single item set from a tuple
def value(a):              #前面我們將用set差集，進行前處理，否則我們無法當index。
#     print(a) ('mineral water',)
    print(type(a))
    a = str(a)
#     print(a)('mineral water',)

    a = a[:-2]
#     print(a) ('mineral water'
    a = a[2:]
#     print(a)  mineral water'

    a = a[:-1]
#     print(a) mineral water
    return a


time_end = time.time()
print('FP_Growth_spent_time', time_end - time_start)
# print( time_end - time_start)
print(len(ant))
# Out:
# Support-Threshold: 0.0045
# Confidence-Threshold: 0.1
# 7501
# frequent_pattern
# 843
# ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes', 'whole weat flour', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad', 'mineral water', 'salmon', 'antioxydant juice', 'frozen smoothie', 'spinach', 'olive oil', 'burgers', 'meatballs', 'eggs', 'turkey', 'milk', 'energy bar', 'whole wheat rice', 'whole wheat pasta', 'french fries', 'soup', 'light cream', 'shallot', 'frozen vegetables', 'spaghetti', 'pet food', 'cookies', 'cooking oil', 'champagne', 'chocolate', 'chicken', 'oil', 'fresh tuna', 'tomatoes', 'black tea', 'extra dark chocolate', 'protein bar', 'red wine', 'pasta', 'pepper', 'shampoo', 'rice', 'sparkling water', 'ham', 'body spray', 'pancakes', 'grated cheese', 'white wine', 'toothpaste', 'parmesan cheese', 'fresh bread', 'ground beef', 'escalope', 'herb & pepper', 'tomato sauce', 'magazines', 'strawberries', 'strong cheese', 'pickles', 'cake', 'hot dogs', 'brownies', 'cereals', 'clothes accessories', 'bug spray', 'muffins', 'light mayo', 'gums', 'soda', 'cider', 'corn', 'yogurt cake', 'mint', 'butter', 'asparagus', 'french wine', 'salt', 'barbecue sauce', 'mayonnaise', 'zucchini', 'carrots', 'mushroom cream sauce', 'candy bars', 'chili', 'nonfat milk', 'mint green tea', 'eggplant', 'blueberries', 'bacon', 'fromage blanc', 'gluten free bar', 'flax seed', 'hand protein bar', 'sandwich', 'babies food', 'melons', 'cauliflower', 'green beans', 'burger sauce', ('burgers', 'shrimp'), ('pancakes', 'shrimp'), ('milk', 'shrimp'), ('low fat yogurt', 'shrimp'), ('mineral water', 'shrimp'), ('chocolate', 'shrimp'), ('eggs', 'shrimp'), ('shrimp', 'spaghetti'), ('french fries', 'shrimp'), ('ground beef', 'shrimp'), ('cake', 'shrimp'), ('frozen vegetables', 'shrimp'), ('green tea', 'shrimp'), ('almonds', 'spaghetti'), ('almonds', 'green tea'), ('almonds', 'eggs'), ('almonds', 'chocolate'), ('almonds', 'milk'), ('almonds', 'mineral water'), ('almonds', 'burgers'), ('avocado', 'milk'), ('avocado', 'mineral water'), ('avocado', 'frozen vegetables'), ('avocado', 'green tea'), ('avocado', 'french fries'), ('avocado', 'burgers'), ('avocado', 'chocolate'), ('avocado', 'frozen smoothie'), ('avocado', 'spaghetti'), ('avocado', 'eggs'), ('chocolate', 'vegetables mix'), ('eggs', 'vegetables mix'), ('mineral water', 'vegetables mix'), ('green tea', 'vegetables mix'), ('french fries', 'vegetables mix'), ('spaghetti', 'vegetables mix'), ('cottage cheese', 'green tea'), ('cottage cheese', 'milk'), ('cottage cheese', 'french fries'), ('cottage cheese', 'mineral water'), ('cottage cheese', 'pancakes'), ('chocolate', 'cottage cheese'), ('cottage cheese', 'frozen smoothie'), ('cottage cheese', 'spaghetti'), ('cottage cheese', 'eggs'), ('energy drink', 'french fries'), ('eggs', 'energy drink'), ('energy drink', 'mineral water'), ('milk', 'tomato juice'), ('french fries', 'tomato juice'), ('green tea', 'tomato juice'), ('mineral water', 'tomato juice'), ('pancakes', 'tomato juice'), ('frozen vegetables', 'tomato juice'), ('spaghetti', 'tomato juice'), ('eggs', 'tomato juice'), ('chocolate', 'tomato juice'), ('cake', 'low fat yogurt'), ('ground beef', 'low fat yogurt'), ('eggs', 'low fat yogurt'), ('low fat yogurt', 'spaghetti'), ('low fat yogurt', 'mineral water'), ('low fat yogurt', 'milk'), ('low fat yogurt', 'pancakes'), ('french fries', 'low fat yogurt'), ('frozen vegetables', 'low fat yogurt'), ('green tea', 'low fat yogurt'), ('chocolate', 'low fat yogurt'), ('escalope', 'low fat yogurt'), ('burgers', 'low fat yogurt'), ('cookies', 'low fat yogurt'), ('french fries', 'green tea'), ('green tea', 'spaghetti'), ('eggs', 'green tea'), ('green tea', 'mineral water'), ('chocolate', 'green tea'), ('honey', 'spaghetti'), ('frozen vegetables', 'honey'), ('honey', 'mineral water'), ('frozen smoothie', 'honey'), ('honey', 'pancakes'), ('honey', 'milk'), ('green tea', 'honey'), ('honey', 'turkey'), ('burgers', 'honey'), ('chocolate', 'honey'), ('french fries', 'honey'), ('eggs', 'honey' ...
# Association_Rules
# <class 'tuple'>
# ('chocolate', 'milk', 'mineral water') ( 105 ) ---> spaghetti ( 1306 )  - conf( 0.3523809523809524 )
# <class 'tuple'>
# ('chocolate', 'milk', 'spaghetti') ( 82 ) ---> mineral water ( 1788 )  - conf( 0.45121951219512196 )
# <class 'tuple'>
# ('chocolate', 'mineral water', 'spaghetti') ( 120 ) ---> milk ( 972 )  - conf( 0.30833333333333335 )
# <class 'tuple'>
# ('milk', 'mineral water', 'spaghetti') ( 118 ) ---> chocolate ( 1230 )  - conf( 0.3135593220338983 )
# ('chocolate', 'milk') ( 241 ) ---> ('mineral water', 'spaghetti') ( 448 )  conf( 0.15352697095435686 )
# ('chocolate', 'spaghetti') ( 295 ) ---> ('milk', 'mineral water') ( 360 )  conf( 0.12542372881355932 )
# ('milk', 'mineral water') ( 360 ) ---> ('chocolate', 'spaghetti') ( 295 )  conf( 0.10277777777777777 )
# ('milk', 'spaghetti') ( 266 ) ---> ('chocolate', 'mineral water') ( 396 )  conf( 0.13909774436090225 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('frozen vegetables', 'milk', 'mineral water') ( 83 ) ---> spaghetti ( 1306 )  - conf( 0.40963855421686746 )
# <class 'tuple'>
# ('frozen vegetables', 'milk', 'spaghetti') ( 62 ) ---> mineral water ( 1788 )  - conf( 0.5483870967741935 )
# <class 'tuple'>
# ('frozen vegetables', 'mineral water', 'spaghetti') ( 90 ) ---> milk ( 972 )  - conf( 0.37777777777777777 )
# <class 'tuple'>
# ('milk', 'mineral water', 'spaghetti') ( 118 ) ---> frozen vegetables ( 715 )  - conf( 0.288135593220339 )
# ('frozen vegetables', 'milk') ( 177 ) ---> ('mineral water', 'spaghetti') ( 448 )  conf( 0.192090395480226 )
# ('frozen vegetables', 'mineral water') ( 268 ) ---> ('milk', 'spaghetti') ( 266 )  conf( 0.12686567164179105 )
# ('frozen vegetables', 'spaghetti') ( 209 ) ---> ('milk', 'mineral water') ( 360 )  conf( 0.16267942583732056 )
# ('milk', 'spaghetti') ( 266 ) ---> ('frozen vegetables', 'mineral water') ( 268 )  conf( 0.12781954887218044 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('chocolate', 'eggs', 'mineral water') ( 101 ) ---> spaghetti ( 1306 )  - conf( 0.33663366336633666 )
# <class 'tuple'>
# ('chocolate', 'eggs', 'spaghetti') ( 79 ) ---> mineral water ( 1788 )  - conf( 0.43037974683544306 )
# <class 'tuple'>
# ('chocolate', 'mineral water', 'spaghetti') ( 120 ) ---> eggs ( 1348 )  - conf( 0.2833333333333333 )
# <class 'tuple'>
# ('eggs', 'mineral water', 'spaghetti') ( 107 ) ---> chocolate ( 1230 )  - conf( 0.3177570093457944 )
# ('chocolate', 'eggs') ( 249 ) ---> ('mineral water', 'spaghetti') ( 448 )  conf( 0.13654618473895583 )
# ('chocolate', 'spaghetti') ( 295 ) ---> ('eggs', 'mineral water') ( 382 )  conf( 0.1152542372881356 )
# ('eggs', 'spaghetti') ( 274 ) ---> ('chocolate', 'mineral water') ( 396 )  conf( 0.12408759124087591 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('mineral water', 'pancakes') ( 253 ) ---> shrimp ( 536 )  - conf( 0.13438735177865613 )
# <class 'tuple'>
# ('mineral water', 'shrimp') ( 177 ) ---> pancakes ( 713 )  - conf( 0.192090395480226 )
# <class 'tuple'>
# ('pancakes', 'shrimp') ( 79 ) ---> mineral water ( 1788 )  - conf( 0.43037974683544306 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('chocolate', 'milk') ( 241 ) ---> shrimp ( 536 )  - conf( 0.17012448132780084 )
# <class 'tuple'>
# ('chocolate', 'shrimp') ( 135 ) ---> milk ( 972 )  - conf( 0.3037037037037037 )
# <class 'tuple'>
# ('milk', 'shrimp') ( 132 ) ---> chocolate ( 1230 )  - conf( 0.3106060606060606 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('milk', 'mineral water') ( 360 ) ---> shrimp ( 536 )  - conf( 0.1638888888888889 )
# <class 'tuple'>
# ('milk', 'shrimp') ( 132 ) ---> mineral water ( 1788 )  - conf( 0.44696969696969696 )
# <class 'tuple'>
# ('mineral water', 'shrimp') ( 177 ) ---> milk ( 972 )  - conf( 0.3333333333333333 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# shrimp ( 536 ) ---> ('milk', 'mineral water') ( 360 )  conf( 0.11007462686567164 )
# <class 'tuple'>
# ('chocolate', 'mineral water') ( 396 ) ---> shrimp ( 536 )  - conf( 0.14393939393939395 )
# <class 'tuple'>
# ('chocolate', 'shrimp') ( 135 ) ---> mineral water ( 1788 )  - conf( 0.4222222222222222 )
# <class 'tuple'>
# ('mineral water', 'shrimp') ( 177 ) ---> chocolate ( 1230 )  - conf( 0.3220338983050847 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# shrimp ( 536 ) ---> ('chocolate', 'mineral water') ( 396 )  conf( 0.10634328358208955 )
# <class 'tuple'>
# ('eggs', 'mineral water') ( 382 ) ---> shrimp ( 536 )  - conf( 0.10209424083769633 )
# <class 'tuple'>
# ('eggs', 'shrimp') ( 106 ) ---> mineral water ( 1788 )  - conf( 0.36792452830188677 )
# <class 'tuple'>
# ('mineral water', 'shrimp') ( 177 ) ---> eggs ( 1348 )  - conf( 0.22033898305084745 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('chocolate', 'shrimp') ( 135 ) ---> spaghetti ( 1306 )  - conf( 0.35555555555555557 )
# <class 'tuple'>
# ('chocolate', 'spaghetti') ( 295 ) ---> shrimp ( 536 )  - conf( 0.16271186440677965 )
# <class 'tuple'>
# ('shrimp', 'spaghetti') ( 159 ) ---> chocolate ( 1230 )  - conf( 0.3018867924528302 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('mineral water', 'shrimp') ( 177 ) ---> spaghetti ( 1306 )  - conf( 0.3615819209039548 )
# <class 'tuple'>
# ('mineral water', 'spaghetti') ( 448 ) ---> shrimp ( 536 )  - conf( 0.14285714285714285 )
# <class 'tuple'>
# ('shrimp', 'spaghetti') ( 159 ) ---> mineral water ( 1788 )  - conf( 0.4025157232704403 )
# <class 'tuple'>
# <class 'tuple'>
# shrimp ( 536 ) ---> ('mineral water', 'spaghetti') ( 448 )  conf( 0.11940298507462686 )
# <class 'tuple'>
# <class 'tuple'>
# ('ground beef', 'mineral water') ( 307 ) ---> shrimp ( 536 )  - conf( 0.1237785016286645 )
# <class 'tuple'>
# ('ground beef', 'shrimp') ( 86 ) ---> mineral water ( 1788 )  - conf( 0.4418604651162791 )
# <class 'tuple'>
# ('mineral water', 'shrimp') ( 177 ) ---> ground beef ( 737 )  - conf( 0.21468926553672316 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('frozen vegetables', 'shrimp') ( 125 ) ---> spaghetti ( 1306 )  - conf( 0.36 )
# <class 'tuple'>
# ('frozen vegetables', 'spaghetti') ( 209 ) ---> shrimp ( 536 )  - conf( 0.215311004784689 )
# <class 'tuple'>
# ('shrimp', 'spaghetti') ( 159 ) ---> frozen vegetables ( 715 )  - conf( 0.2830188679245283 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('frozen vegetables', 'milk') ( 177 ) ---> shrimp ( 536 )  - conf( 0.1977401129943503 )
# <class 'tuple'>
# ('frozen vegetables', 'shrimp') ( 125 ) ---> milk ( 972 )  - conf( 0.28 )
# <class 'tuple'>
# ('milk', 'shrimp') ( 132 ) ---> frozen vegetables ( 715 )  - conf( 0.26515151515151514 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('chocolate', 'frozen vegetables') ( 172 ) ---> shrimp ( 536 )  - conf( 0.23255813953488372 )
# <class 'tuple'>
# ('chocolate', 'shrimp') ( 135 ) ---> frozen vegetables ( 715 )  - conf( 0.2962962962962963 )
# <class 'tuple'>
# ('frozen vegetables', 'shrimp') ( 125 ) ---> chocolate ( 1230 )  - conf( 0.32 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('frozen vegetables', 'mineral water') ( 268 ) ---> shrimp ( 536 )  - conf( 0.20149253731343283 )
# <class 'tuple'>
# ('frozen vegetables', 'shrimp') ( 125 ) ---> mineral water ( 1788 )  - conf( 0.432 )
# <class 'tuple'>
# ('mineral water', 'shrimp') ( 177 ) ---> frozen vegetables ( 715 )  - conf( 0.3050847457627119 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# shrimp ( 536 ) ---> ('frozen vegetables', 'mineral water') ( 268 )  conf( 0.10074626865671642 )
# <class 'tuple'>
# ('ground beef', 'shrimp') ( 86 ) ---> spaghetti ( 1306 )  - conf( 0.5232558139534884 )
# <class 'tuple'>
# ('ground beef', 'spaghetti') ( 294 ) ---> shrimp ( 536 )  - conf( 0.15306122448979592 )
# <class 'tuple'>
# ('shrimp', 'spaghetti') ( 159 ) ---> ground beef ( 737 )  - conf( 0.2830188679245283 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('milk', 'shrimp') ( 132 ) ---> spaghetti ( 1306 )  - conf( 0.2803030303030303 )
# <class 'tuple'>
# ('milk', 'spaghetti') ( 266 ) ---> shrimp ( 536 )  - conf( 0.13909774436090225 )
# <class 'tuple'>
# ('shrimp', 'spaghetti') ( 159 ) ---> milk ( 972 )  - conf( 0.23270440251572327 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('ground beef', 'low fat yogurt') ( 72 ) ---> mineral water ( 1788 )  - conf( 0.5 )
# <class 'tuple'>
# ('ground beef', 'mineral water') ( 307 ) ---> low fat yogurt ( 574 )  - conf( 0.11726384364820847 )
# <class 'tuple'>
# ('low fat yogurt', 'mineral water') ( 180 ) ---> ground beef ( 737 )  - conf( 0.2 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('low fat yogurt', 'mineral water') ( 180 ) ---> spaghetti ( 1306 )  - conf( 0.23333333333333334 )
# <class 'tuple'>
# ('low fat yogurt', 'spaghetti') ( 114 ) ---> mineral water ( 1788 )  - conf( 0.3684210526315789 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('low fat yogurt', 'milk') ( 99 ) ---> mineral water ( 1788 )  - conf( 0.36363636363636365 )
# <class 'tuple'>
# ('low fat yogurt', 'mineral water') ( 180 ) ---> milk ( 972 )  - conf( 0.2 )
# <class 'tuple'>
# ('milk', 'mineral water') ( 360 ) ---> low fat yogurt ( 574 )  - conf( 0.1 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('frozen vegetables', 'low fat yogurt') ( 76 ) ---> mineral water ( 1788 )  - conf( 0.4473684210526316 )
# <class 'tuple'>
# ('frozen vegetables', 'mineral water') ( 268 ) ---> low fat yogurt ( 574 )  - conf( 0.12686567164179105 )
# <class 'tuple'>
# ('low fat yogurt', 'mineral water') ( 180 ) ---> frozen vegetables ( 715 )  - conf( 0.18888888888888888 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('eggs', 'low fat yogurt') ( 126 ) ---> mineral water ( 1788 )  - conf( 0.36507936507936506 )
# <class 'tuple'>
# ('eggs', 'mineral water') ( 382 ) ---> low fat yogurt ( 574 )  - conf( 0.12041884816753927 )
# <class 'tuple'>
# ('low fat yogurt', 'mineral water') ( 180 ) ---> eggs ( 1348 )  - conf( 0.25555555555555554 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('chocolate', 'low fat yogurt') ( 111 ) ---> mineral water ( 1788 )  - conf( 0.38738738738738737 )
# <class 'tuple'>
# ('chocolate', 'mineral water') ( 396 ) ---> low fat yogurt ( 574 )  - conf( 0.10858585858585859 )
# <class 'tuple'>
# ('low fat yogurt', 'mineral water') ( 180 ) ---> chocolate ( 1230 )  - conf( 0.2388888888888889 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('french fries', 'green tea') ( 214 ) ---> spaghetti ( 1306 )  - conf( 0.18691588785046728 )
# <class 'tuple'>
# ('french fries', 'spaghetti') ( 207 ) ---> green tea ( 991 )  - conf( 0.1932367149758454 )
# <class 'tuple'>
# ('green tea', 'spaghetti') ( 199 ) ---> french fries ( 1282 )  - conf( 0.20100502512562815 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('eggs', 'french fries') ( 273 ) ---> green tea ( 991 )  - conf( 0.19413919413919414 )
# <class 'tuple'>
# ('eggs', 'green tea') ( 191 ) ---> french fries ( 1282 )  - conf( 0.2774869109947644 )
# <class 'tuple'>
# ('french fries', 'green tea') ( 214 ) ---> eggs ( 1348 )  - conf( 0.24766355140186916 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('french fries', 'green tea') ( 214 ) ---> mineral water ( 1788 )  - conf( 0.21495327102803738 )
# <class 'tuple'>
# ('french fries', 'mineral water') ( 253 ) ---> green tea ( 991 )  - conf( 0.18181818181818182 )
# <class 'tuple'>
# ('green tea', 'mineral water') ( 233 ) ---> french fries ( 1282 )  - conf( 0.19742489270386265 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('eggs', 'green tea') ( 191 ) ---> spaghetti ( 1306 )  - conf( 0.225130890052356 )
# <class 'tuple'>
# ('eggs', 'spaghetti') ( 274 ) ---> green tea ( 991 )  - conf( 0.15693430656934307 )
# <class 'tuple'>
# ('green tea', 'spaghetti') ( 199 ) ---> eggs ( 1348 )  - conf( 0.21608040201005024 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('green tea', 'mineral water') ( 233 ) ---> spaghetti ( 1306 )  - conf( 0.26609442060085836 )
# <class 'tuple'>
# ('green tea', 'spaghetti') ( 199 ) ---> mineral water ( 1788 )  - conf( 0.31155778894472363 )
# <class 'tuple'>
# ('mineral water', 'spaghetti') ( 448 ) ---> green tea ( 991 )  - conf( 0.13839285714285715 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('eggs', 'green tea') ( 191 ) ---> mineral water ( 1788 )  - conf( 0.27225130890052357 )
# <class 'tuple'>
# ('eggs', 'mineral water') ( 382 ) ---> green tea ( 991 )  - conf( 0.13612565445026178 )
# <class 'tuple'>
# ('green tea', 'mineral water') ( 233 ) ---> eggs ( 1348 )  - conf( 0.22317596566523606 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('chocolate', 'french fries') ( 258 ) ---> green tea ( 991 )  - conf( 0.1511627906976744 )
# <class 'tuple'>
# ('chocolate', 'green tea') ( 176 ) ---> french fries ( 1282 )  - conf( 0.2215909090909091 )
# <class 'tuple'>
# ('french fries', 'green tea') ( 214 ) ---> chocolate ( 1230 )  - conf( 0.1822429906542056 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('chocolate', 'green tea') ( 176 ) ---> spaghetti ( 1306 )  - conf( 0.30113636363636365 )
# <class 'tuple'>
# ('chocolate', 'spaghetti') ( 295 ) ---> green tea ( 991 )  - conf( 0.17966101694915254 )
# <class 'tuple'>
# ('green tea', 'spaghetti') ( 199 ) ---> chocolate ( 1230 )  - conf( 0.2663316582914573 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('chocolate', 'eggs') ( 249 ) ---> green tea ( 991 )  - conf( 0.1646586345381526 )
# <class 'tuple'>
# ('chocolate', 'green tea') ( 176 ) ---> eggs ( 1348 )  - conf( 0.23295454545454544 )
# <class 'tuple'>
# ('eggs', 'green tea') ( 191 ) ---> chocolate ( 1230 )  - conf( 0.21465968586387435 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('chocolate', 'green tea') ( 176 ) ---> mineral water ( 1788 )  - conf( 0.29545454545454547 )
# <class 'tuple'>
# ('chocolate', 'mineral water') ( 396 ) ---> green tea ( 991 )  - conf( 0.13131313131313133 )
# <class 'tuple'>
# ('green tea', 'mineral water') ( 233 ) ---> chocolate ( 1230 )  - conf( 0.22317596566523606 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('chocolate', 'salmon') ( 81 ) ---> mineral water ( 1788 )  - conf( 0.43209876543209874 )
# <class 'tuple'>
# ('mineral water', 'salmon') ( 128 ) ---> chocolate ( 1230 )  - conf( 0.2734375 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# salmon ( 319 ) ---> ('chocolate', 'mineral water') ( 396 )  conf( 0.109717868338558 )
# <class 'tuple'>
# ('mineral water', 'salmon') ( 128 ) ---> spaghetti ( 1306 )  - conf( 0.3984375 )
# <class 'tuple'>
# ('mineral water', 'spaghetti') ( 448 ) ---> salmon ( 319 )  - conf( 0.11383928571428571 )
# <class 'tuple'>
# ('salmon', 'spaghetti') ( 101 ) ---> mineral water ( 1788 )  - conf( 0.504950495049505 )
# <class 'tuple'>
# <class 'tuple'>
# salmon ( 319 ) ---> ('mineral water', 'spaghetti') ( 448 )  conf( 0.15987460815047022 )
# <class 'tuple'>
# <class 'tuple'>
# ('chocolate', 'frozen smoothie') ( 113 ) ---> mineral water ( 1788 )  - conf( 0.34513274336283184 )
# <class 'tuple'>
# <class 'tuple'>
# ('frozen smoothie', 'mineral water') ( 152 ) ---> chocolate ( 1230 )  - conf( 0.2565789473684211 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('frozen smoothie', 'milk') ( 107 ) ---> spaghetti ( 1306 )  - conf( 0.3925233644859813 )
# <class 'tuple'>
# ('frozen smoothie', 'spaghetti') ( 117 ) ---> milk ( 972 )  - conf( 0.358974358974359 )
# <class 'tuple'>
# ('milk', 'spaghetti') ( 266 ) ---> frozen smoothie ( 475 )  - conf( 0.15789473684210525 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('frozen smoothie', 'milk') ( 107 ) ---> mineral water ( 1788 )  - conf( 0.42990654205607476 )
# <class 'tuple'>
# ('frozen smoothie', 'mineral water') ( 152 ) ---> milk ( 972 )  - conf( 0.3026315789473684 )
# <class 'tuple'>
# ('milk', 'mineral water') ( 360 ) ---> frozen smoothie ( 475 )  - conf( 0.12777777777777777 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('frozen smoothie', 'mineral water') ( 152 ) ---> spaghetti ( 1306 )  - conf( 0.3355263157894737 )
# <class 'tuple'>
# ('frozen smoothie', 'spaghetti') ( 117 ) ---> mineral water ( 1788 )  - conf( 0.4358974358974359 )
# <class 'tuple'>
# ('mineral water', 'spaghetti') ( 448 ) ---> frozen smoothie ( 475 )  - conf( 0.11383928571428571 )
# <class 'tuple'>
# frozen smoothie ( 475 ) ---> ('mineral water', 'spaghetti') ( 448 )  conf( 0.10736842105263159 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('chocolate', 'frozen smoothie') ( 113 ) ---> spaghetti ( 1306 )  - conf( 0.3185840707964602 )
# <class 'tuple'>
# ('chocolate', 'spaghetti') ( 295 ) ---> frozen smoothie ( 475 )  - conf( 0.12203389830508475 )
# <class 'tuple'>
# ('frozen smoothie', 'spaghetti') ( 117 ) ---> chocolate ( 1230 )  - conf( 0.3076923076923077 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('mineral water', 'olive oil') ( 207 ) ---> shrimp ( 536 )  - conf( 0.1642512077294686 )
# <class 'tuple'>
# ('mineral water', 'shrimp') ( 177 ) ---> olive oil ( 494 )  - conf( 0.192090395480226 )
# <class 'tuple'>
# ('olive oil', 'shrimp') ( 61 ) ---> mineral water ( 1788 )  - conf( 0.5573770491803278 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('mineral water', 'olive oil') ( 207 ) ---> pancakes ( 713 )  - conf( 0.16908212560386474 )
# <class 'tuple'>
# ('mineral water', 'pancakes') ( 253 ) ---> olive oil ( 494 )  - conf( 0.1383399209486166 )
# <class 'tuple'>
# ('olive oil', 'pancakes') ( 81 ) ---> mineral water ( 1788 )  - conf( 0.43209876543209874 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('chocolate', 'mineral water') ( 396 ) ---> olive oil ( 494 )  - conf( 0.15656565656565657 )
# <class 'tuple'>
# ('chocolate', 'olive oil') ( 123 ) ---> mineral water ( 1788 )  - conf( 0.5040650406504065 )
# <class 'tuple'>
# ('mineral water', 'olive oil') ( 207 ) ---> chocolate ( 1230 )  - conf( 0.2995169082125604 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# olive oil ( 494 ) ---> ('chocolate', 'mineral water') ( 396 )  conf( 0.12550607287449392 )
# <class 'tuple'>
# ('milk', 'olive oil') ( 128 ) ---> spaghetti ( 1306 )  - conf( 0.421875 )
# <class 'tuple'>
# ('milk', 'spaghetti') ( 266 ) ---> olive oil ( 494 )  - conf( 0.20300751879699247 )
# <class 'tuple'>
# ('olive oil', 'spaghetti') ( 172 ) ---> milk ( 972 )  - conf( 0.313953488372093 )
# <class 'tuple'>
# <class 'tuple'>
# olive oil ( 494 ) ---> ('milk', 'spaghetti') ( 266 )  conf( 0.10931174089068826 )
# <class 'tuple'>
# <class 'tuple'>
# ('milk', 'mineral water') ( 360 ) ---> olive oil ( 494 )  - conf( 0.17777777777777778 )
# <class 'tuple'>
# ('milk', 'olive oil') ( 128 ) ---> mineral water ( 1788 )  - conf( 0.5 )
# <class 'tuple'>
# ('mineral water', 'olive oil') ( 207 ) ---> milk ( 972 )  - conf( 0.30917874396135264 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# olive oil ( 494 ) ---> ('milk', 'mineral water') ( 360 )  conf( 0.12955465587044535 )
# <class 'tuple'>
# ('mineral water', 'olive oil') ( 207 ) ---> spaghetti ( 1306 )  - conf( 0.3719806763285024 )
# <class 'tuple'>
# ('mineral water', 'spaghetti') ( 448 ) ---> olive oil ( 494 )  - conf( 0.171875 )
# <class 'tuple'>
# ('olive oil', 'spaghetti') ( 172 ) ---> mineral water ( 1788 )  - conf( 0.4476744186046512 )
# <class 'tuple'>
# <class 'tuple'>
# olive oil ( 494 ) ---> ('mineral water', 'spaghetti') ( 448 )  conf( 0.15587044534412955 )
# <class 'tuple'>
# <class 'tuple'>
# ('ground beef', 'olive oil') ( 106 ) ---> spaghetti ( 1306 )  - conf( 0.4339622641509434 )
# <class 'tuple'>
# ('ground beef', 'spaghetti') ( 294 ) ---> olive oil ( 494 )  - conf( 0.1564625850340136 )
# <class 'tuple'>
# ('olive oil', 'spaghetti') ( 172 ) ---> ground beef ( 737 )  - conf( 0.26744186046511625 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('eggs', 'olive oil') ( 90 ) ---> spaghetti ( 1306 )  - conf( 0.4222222222222222 )
# <class 'tuple'>
# ('eggs', 'spaghetti') ( 274 ) ---> olive oil ( 494 )  - conf( 0.1386861313868613 )
# <class 'tuple'>
# ('olive oil', 'spaghetti') ( 172 ) ---> eggs ( 1348 )  - conf( 0.22093023255813954 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('ground beef', 'milk') ( 165 ) ---> olive oil ( 494 )  - conf( 0.22424242424242424 )
# <class 'tuple'>
# ('ground beef', 'olive oil') ( 106 ) ---> milk ( 972 )  - conf( 0.3490566037735849 )
# <class 'tuple'>
# ('milk', 'olive oil') ( 128 ) ---> ground beef ( 737 )  - conf( 0.2890625 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('ground beef', 'mineral water') ( 307 ) ---> olive oil ( 494 )  - conf( 0.16286644951140064 )
# <class 'tuple'>
# ('ground beef', 'olive oil') ( 106 ) ---> mineral water ( 1788 )  - conf( 0.4716981132075472 )
# <class 'tuple'>
# ('mineral water', 'olive oil') ( 207 ) ---> ground beef ( 737 )  - conf( 0.24154589371980675 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# olive oil ( 494 ) ---> ('ground beef', 'mineral water') ( 307 )  conf( 0.10121457489878542 )
# <class 'tuple'>
# ('frozen vegetables', 'milk') ( 177 ) ---> olive oil ( 494 )  - conf( 0.2033898305084746 )
# <class 'tuple'>
# ('frozen vegetables', 'olive oil') ( 85 ) ---> milk ( 972 )  - conf( 0.4235294117647059 )
# <class 'tuple'>
# ('milk', 'olive oil') ( 128 ) ---> frozen vegetables ( 715 )  - conf( 0.28125 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('frozen vegetables', 'mineral water') ( 268 ) ---> olive oil ( 494 )  - conf( 0.1828358208955224 )
# <class 'tuple'>
# ('frozen vegetables', 'olive oil') ( 85 ) ---> mineral water ( 1788 )  - conf( 0.5764705882352941 )
# <class 'tuple'>
# ('mineral water', 'olive oil') ( 207 ) ---> frozen vegetables ( 715 )  - conf( 0.23671497584541062 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('eggs', 'mineral water') ( 382 ) ---> olive oil ( 494 )  - conf( 0.11518324607329843 )
# <class 'tuple'>
# ('eggs', 'olive oil') ( 90 ) ---> mineral water ( 1788 )  - conf( 0.4888888888888889 )
# <class 'tuple'>
# ('mineral water', 'olive oil') ( 207 ) ---> eggs ( 1348 )  - conf( 0.21256038647342995 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('chocolate', 'olive oil') ( 123 ) ---> spaghetti ( 1306 )  - conf( 0.43089430894308944 )
# <class 'tuple'>
# ('chocolate', 'spaghetti') ( 295 ) ---> olive oil ( 494 )  - conf( 0.17966101694915254 )
# <class 'tuple'>
# ('olive oil', 'spaghetti') ( 172 ) ---> chocolate ( 1230 )  - conf( 0.3081395348837209 )
# <class 'tuple'>
# <class 'tuple'>
# olive oil ( 494 ) ---> ('chocolate', 'spaghetti') ( 295 )  conf( 0.10728744939271255 )
# <class 'tuple'>
# <class 'tuple'>
# ('frozen vegetables', 'olive oil') ( 85 ) ---> spaghetti ( 1306 )  - conf( 0.5058823529411764 )
# <class 'tuple'>
# ('frozen vegetables', 'spaghetti') ( 209 ) ---> olive oil ( 494 )  - conf( 0.20574162679425836 )
# <class 'tuple'>
# ('olive oil', 'spaghetti') ( 172 ) ---> frozen vegetables ( 715 )  - conf( 0.25 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('olive oil', 'pancakes') ( 81 ) ---> spaghetti ( 1306 )  - conf( 0.4691358024691358 )
# <class 'tuple'>
# ('olive oil', 'spaghetti') ( 172 ) ---> pancakes ( 713 )  - conf( 0.22093023255813954 )
# <class 'tuple'>
# ('pancakes', 'spaghetti') ( 189 ) ---> olive oil ( 494 )  - conf( 0.20105820105820105 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('green tea', 'olive oil') ( 75 ) ---> spaghetti ( 1306 )  - conf( 0.4533333333333333 )
# <class 'tuple'>
# ('green tea', 'spaghetti') ( 199 ) ---> olive oil ( 494 )  - conf( 0.1708542713567839 )
# <class 'tuple'>
# ('olive oil', 'spaghetti') ( 172 ) ---> green tea ( 991 )  - conf( 0.19767441860465115 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('chocolate', 'milk') ( 241 ) ---> olive oil ( 494 )  - conf( 0.16182572614107885 )
# <class 'tuple'>
# ('chocolate', 'olive oil') ( 123 ) ---> milk ( 972 )  - conf( 0.3170731707317073 )
# <class 'tuple'>
# ('milk', 'olive oil') ( 128 ) ---> chocolate ( 1230 )  - conf( 0.3046875 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('burgers', 'chocolate') ( 128 ) ---> spaghetti ( 1306 )  - conf( 0.375 )
# <class 'tuple'>
# ('burgers', 'spaghetti') ( 161 ) ---> chocolate ( 1230 )  - conf( 0.2981366459627329 )
# <class 'tuple'>
# ('chocolate', 'spaghetti') ( 295 ) ---> burgers ( 654 )  - conf( 0.16271186440677965 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('burgers', 'chocolate') ( 128 ) ---> eggs ( 1348 )  - conf( 0.3203125 )
# <class 'tuple'>
# ('burgers', 'eggs') ( 216 ) ---> chocolate ( 1230 )  - conf( 0.18981481481481483 )
# <class 'tuple'>
# ('chocolate', 'eggs') ( 249 ) ---> burgers ( 654 )  - conf( 0.1646586345381526 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('burgers', 'chocolate') ( 128 ) ---> mineral water ( 1788 )  - conf( 0.3359375 )
# <class 'tuple'>
# ('burgers', 'mineral water') ( 183 ) ---> chocolate ( 1230 )  - conf( 0.23497267759562843 )
# <class 'tuple'>
# ('chocolate', 'mineral water') ( 396 ) ---> burgers ( 654 )  - conf( 0.10858585858585859 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('burgers', 'eggs') ( 216 ) ---> spaghetti ( 1306 )  - conf( 0.25 )
# <class 'tuple'>
# ('burgers', 'spaghetti') ( 161 ) ---> eggs ( 1348 )  - conf( 0.33540372670807456 )
# <class 'tuple'>
# ('eggs', 'spaghetti') ( 274 ) ---> burgers ( 654 )  - conf( 0.19708029197080293 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('burgers', 'mineral water') ( 183 ) ---> spaghetti ( 1306 )  - conf( 0.2677595628415301 )
# <class 'tuple'>
# ('burgers', 'spaghetti') ( 161 ) ---> mineral water ( 1788 )  - conf( 0.30434782608695654 )
# <class 'tuple'>
# ('mineral water', 'spaghetti') ( 448 ) ---> burgers ( 654 )  - conf( 0.109375 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('burgers', 'eggs') ( 216 ) ---> mineral water ( 1788 )  - conf( 0.27314814814814814 )
# <class 'tuple'>
# ('burgers', 'mineral water') ( 183 ) ---> eggs ( 1348 )  - conf( 0.3224043715846995 )
# <class 'tuple'>
# ('eggs', 'mineral water') ( 382 ) ---> burgers ( 654 )  - conf( 0.1544502617801047 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('burgers', 'french fries') ( 165 ) ---> spaghetti ( 1306 )  - conf( 0.2545454545454545 )
# <class 'tuple'>
# ('burgers', 'spaghetti') ( 161 ) ---> french fries ( 1282 )  - conf( 0.2608695652173913 )
# <class 'tuple'>
# ('french fries', 'spaghetti') ( 207 ) ---> burgers ( 654 )  - conf( 0.2028985507246377 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('burgers', 'frozen vegetables') ( 79 ) ---> mineral water ( 1788 )  - conf( 0.46835443037974683 )
# <class 'tuple'>
# ('burgers', 'mineral water') ( 183 ) ---> frozen vegetables ( 715 )  - conf( 0.20218579234972678 )
# <class 'tuple'>
# ('frozen vegetables', 'mineral water') ( 268 ) ---> burgers ( 654 )  - conf( 0.13805970149253732 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('burgers', 'chocolate') ( 128 ) ---> milk ( 972 )  - conf( 0.3203125 )
# <class 'tuple'>
# ('burgers', 'milk') ( 134 ) ---> chocolate ( 1230 )  - conf( 0.30597014925373134 )
# <class 'tuple'>
# ('chocolate', 'milk') ( 241 ) ---> burgers ( 654 )  - conf( 0.17012448132780084 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('burgers', 'milk') ( 134 ) ---> spaghetti ( 1306 )  - conf( 0.3582089552238806 )
# <class 'tuple'>
# ('burgers', 'spaghetti') ( 161 ) ---> milk ( 972 )  - conf( 0.2981366459627329 )
# <class 'tuple'>
# ('milk', 'spaghetti') ( 266 ) ---> burgers ( 654 )  - conf( 0.18045112781954886 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('burgers', 'milk') ( 134 ) ---> mineral water ( 1788 )  - conf( 0.3880597014925373 )
# <class 'tuple'>
# ('burgers', 'mineral water') ( 183 ) ---> milk ( 972 )  - conf( 0.28415300546448086 )
# <class 'tuple'>
# ('milk', 'mineral water') ( 360 ) ---> burgers ( 654 )  - conf( 0.14444444444444443 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('burgers', 'ground beef') ( 90 ) ---> mineral water ( 1788 )  - conf( 0.4444444444444444 )
# <class 'tuple'>
# ('burgers', 'mineral water') ( 183 ) ---> ground beef ( 737 )  - conf( 0.2185792349726776 )
# <class 'tuple'>
# ('ground beef', 'mineral water') ( 307 ) ---> burgers ( 654 )  - conf( 0.13029315960912052 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('burgers', 'french fries') ( 165 ) ---> green tea ( 991 )  - conf( 0.24848484848484848 )
# <class 'tuple'>
# ('burgers', 'green tea') ( 131 ) ---> french fries ( 1282 )  - conf( 0.31297709923664124 )
# <class 'tuple'>
# ('french fries', 'green tea') ( 214 ) ---> burgers ( 654 )  - conf( 0.19158878504672897 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('burgers', 'eggs') ( 216 ) ---> green tea ( 991 )  - conf( 0.20833333333333334 )
# <class 'tuple'>
# ('burgers', 'green tea') ( 131 ) ---> eggs ( 1348 )  - conf( 0.3435114503816794 )
# <class 'tuple'>
# ('eggs', 'green tea') ( 191 ) ---> burgers ( 654 )  - conf( 0.2356020942408377 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('burgers', 'eggs') ( 216 ) ---> french fries ( 1282 )  - conf( 0.3148148148148148 )
# <class 'tuple'>
# ('burgers', 'french fries') ( 165 ) ---> eggs ( 1348 )  - conf( 0.4121212121212121 )
# <class 'tuple'>
# ('eggs', 'french fries') ( 273 ) ---> burgers ( 654 )  - conf( 0.2490842490842491 )
# <class 'tuple'>
# burgers ( 654 ) ---> ('eggs', 'french fries') ( 273 )  conf( 0.10397553516819572 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('burgers', 'ground beef') ( 90 ) ---> spaghetti ( 1306 )  - conf( 0.45555555555555555 )
# <class 'tuple'>
# ('burgers', 'spaghetti') ( 161 ) ---> ground beef ( 737 )  - conf( 0.2546583850931677 )
# <class 'tuple'>
# ('ground beef', 'spaghetti') ( 294 ) ---> burgers ( 654 )  - conf( 0.13945578231292516 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('burgers', 'eggs') ( 216 ) ---> milk ( 972 )  - conf( 0.18518518518518517 )
# <class 'tuple'>
# ('burgers', 'milk') ( 134 ) ---> eggs ( 1348 )  - conf( 0.29850746268656714 )
# <class 'tuple'>
# ('eggs', 'milk') ( 231 ) ---> burgers ( 654 )  - conf( 0.17316017316017315 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('burgers', 'french fries') ( 165 ) ---> milk ( 972 )  - conf( 0.2545454545454545 )
# <class 'tuple'>
# ('burgers', 'milk') ( 134 ) ---> french fries ( 1282 )  - conf( 0.31343283582089554 )
# <class 'tuple'>
# ('french fries', 'milk') ( 178 ) ---> burgers ( 654 )  - conf( 0.23595505617977527 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('burgers', 'chocolate') ( 128 ) ---> french fries ( 1282 )  - conf( 0.28125 )
# <class 'tuple'>
# ('burgers', 'french fries') ( 165 ) ---> chocolate ( 1230 )  - conf( 0.21818181818181817 )
# <class 'tuple'>
# ('chocolate', 'french fries') ( 258 ) ---> burgers ( 654 )  - conf( 0.13953488372093023 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('burgers', 'french fries') ( 165 ) ---> mineral water ( 1788 )  - conf( 0.23636363636363636 )
# <class 'tuple'>
# ('burgers', 'mineral water') ( 183 ) ---> french fries ( 1282 )  - conf( 0.21311475409836064 )
# <class 'tuple'>
# ('french fries', 'mineral water') ( 253 ) ---> burgers ( 654 )  - conf( 0.1541501976284585 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('burgers', 'green tea') ( 131 ) ---> spaghetti ( 1306 )  - conf( 0.2748091603053435 )
# <class 'tuple'>
# ('burgers', 'spaghetti') ( 161 ) ---> green tea ( 991 )  - conf( 0.2236024844720497 )
# <class 'tuple'>
# ('green tea', 'spaghetti') ( 199 ) ---> burgers ( 654 )  - conf( 0.18090452261306533 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('milk', 'mineral water') ( 360 ) ---> turkey ( 469 )  - conf( 0.12777777777777777 )
# <class 'tuple'>
# ('milk', 'turkey') ( 85 ) ---> mineral water ( 1788 )  - conf( 0.5411764705882353 )
# <class 'tuple'>
# ('mineral water', 'turkey') ( 144 ) ---> milk ( 972 )  - conf( 0.3194444444444444 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('eggs', 'mineral water') ( 382 ) ---> turkey ( 469 )  - conf( 0.1099476439790576 )
# <class 'tuple'>
# ('eggs', 'turkey') ( 146 ) ---> mineral water ( 1788 )  - conf( 0.2876712328767123 )
# <class 'tuple'>
# ('mineral water', 'turkey') ( 144 ) ---> eggs ( 1348 )  - conf( 0.2916666666666667 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('eggs', 'spaghetti') ( 274 ) ---> turkey ( 469 )  - conf( 0.14233576642335766 )
# <class 'tuple'>
# ('eggs', 'turkey') ( 146 ) ---> spaghetti ( 1306 )  - conf( 0.2671232876712329 )
# <class 'tuple'>
# ('spaghetti', 'turkey') ( 124 ) ---> eggs ( 1348 )  - conf( 0.31451612903225806 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('mineral water', 'spaghetti') ( 448 ) ---> turkey ( 469 )  - conf( 0.10714285714285714 )
# <class 'tuple'>
# ('mineral water', 'turkey') ( 144 ) ---> spaghetti ( 1306 )  - conf( 0.3333333333333333 )
# <class 'tuple'>
# ('spaghetti', 'turkey') ( 124 ) ---> mineral water ( 1788 )  - conf( 0.3870967741935484 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# turkey ( 469 ) ---> ('mineral water', 'spaghetti') ( 448 )  conf( 0.1023454157782516 )
# <class 'tuple'>
# ('milk', 'spaghetti') ( 266 ) ---> turkey ( 469 )  - conf( 0.13533834586466165 )
# <class 'tuple'>
# ('milk', 'turkey') ( 85 ) ---> spaghetti ( 1306 )  - conf( 0.4235294117647059 )
# <class 'tuple'>
# ('spaghetti', 'turkey') ( 124 ) ---> milk ( 972 )  - conf( 0.2903225806451613 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('chocolate', 'green tea') ( 176 ) ---> milk ( 972 )  - conf( 0.19886363636363635 )
# <class 'tuple'>
# ('chocolate', 'milk') ( 241 ) ---> green tea ( 991 )  - conf( 0.14522821576763487 )
# <class 'tuple'>
# ('green tea', 'milk') ( 132 ) ---> chocolate ( 1230 )  - conf( 0.26515151515151514 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('green tea', 'milk') ( 132 ) ---> spaghetti ( 1306 )  - conf( 0.29545454545454547 )
# <class 'tuple'>
# ('green tea', 'spaghetti') ( 199 ) ---> milk ( 972 )  - conf( 0.19597989949748743 )
# <class 'tuple'>
# ('milk', 'spaghetti') ( 266 ) ---> green tea ( 991 )  - conf( 0.14661654135338345 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('chocolate', 'milk') ( 241 ) ---> spaghetti ( 1306 )  - conf( 0.34024896265560167 )
# <class 'tuple'>
# ('chocolate', 'spaghetti') ( 295 ) ---> milk ( 972 )  - conf( 0.27796610169491526 )
# <class 'tuple'>
# ('milk', 'spaghetti') ( 266 ) ---> chocolate ( 1230 )  - conf( 0.3082706766917293 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('chocolate', 'eggs') ( 249 ) ---> milk ( 972 )  - conf( 0.27710843373493976 )
# <class 'tuple'>
# ('chocolate', 'milk') ( 241 ) ---> eggs ( 1348 )  - conf( 0.2863070539419087 )
# <class 'tuple'>
# ('eggs', 'milk') ( 231 ) ---> chocolate ( 1230 )  - conf( 0.2987012987012987 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('eggs', 'milk') ( 231 ) ---> spaghetti ( 1306 )  - conf( 0.29004329004329005 )
# <class 'tuple'>
# ('eggs', 'spaghetti') ( 274 ) ---> milk ( 972 )  - conf( 0.24452554744525548 )
# <class 'tuple'>
# ('milk', 'spaghetti') ( 266 ) ---> eggs ( 1348 )  - conf( 0.2518796992481203 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('green tea', 'milk') ( 132 ) ---> mineral water ( 1788 )  - conf( 0.32575757575757575 )
# <class 'tuple'>
# ('green tea', 'mineral water') ( 233 ) ---> milk ( 972 )  - conf( 0.18454935622317598 )
# <class 'tuple'>
# ('milk', 'mineral water') ( 360 ) ---> green tea ( 991 )  - conf( 0.11944444444444445 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('french fries', 'milk') ( 178 ) ---> spaghetti ( 1306 )  - conf( 0.2696629213483146 )
# <class 'tuple'>
# ('french fries', 'spaghetti') ( 207 ) ---> milk ( 972 )  - conf( 0.2318840579710145 )
# <class 'tuple'>
# ('milk', 'spaghetti') ( 266 ) ---> french fries ( 1282 )  - conf( 0.18045112781954886 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('french fries', 'milk') ( 178 ) ---> mineral water ( 1788 )  - conf( 0.34831460674157305 )
# <class 'tuple'>
# ('french fries', 'mineral water') ( 253 ) ---> milk ( 972 )  - conf( 0.2450592885375494 )
# <class 'tuple'>
# ('milk', 'mineral water') ( 360 ) ---> french fries ( 1282 )  - conf( 0.17222222222222222 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('milk', 'mineral water') ( 360 ) ---> spaghetti ( 1306 )  - conf( 0.3277777777777778 )
# <class 'tuple'>
# ('milk', 'spaghetti') ( 266 ) ---> mineral water ( 1788 )  - conf( 0.44360902255639095 )
# <class 'tuple'>
# ('mineral water', 'spaghetti') ( 448 ) ---> milk ( 972 )  - conf( 0.26339285714285715 )
# <class 'tuple'>
# milk ( 972 ) ---> ('mineral water', 'spaghetti') ( 448 )  conf( 0.12139917695473251 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('chocolate', 'french fries') ( 258 ) ---> milk ( 972 )  - conf( 0.2131782945736434 )
# <class 'tuple'>
# ('chocolate', 'milk') ( 241 ) ---> french fries ( 1282 )  - conf( 0.22821576763485477 )
# <class 'tuple'>
# ('french fries', 'milk') ( 178 ) ---> chocolate ( 1230 )  - conf( 0.3089887640449438 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('chocolate', 'milk') ( 241 ) ---> mineral water ( 1788 )  - conf( 0.43568464730290457 )
# <class 'tuple'>
# ('chocolate', 'mineral water') ( 396 ) ---> milk ( 972 )  - conf( 0.26515151515151514 )
# <class 'tuple'>
# ('milk', 'mineral water') ( 360 ) ---> chocolate ( 1230 )  - conf( 0.2916666666666667 )
# <class 'tuple'>
# <class 'tuple'>
# milk ( 972 ) ---> ('chocolate', 'mineral water') ( 396 )  conf( 0.10802469135802469 )
# <class 'tuple'>
# <class 'tuple'>
# ('eggs', 'milk') ( 231 ) ---> mineral water ( 1788 )  - conf( 0.42424242424242425 )
# <class 'tuple'>
# ('eggs', 'mineral water') ( 382 ) ---> milk ( 972 )  - conf( 0.25654450261780104 )
# <class 'tuple'>
# ('milk', 'mineral water') ( 360 ) ---> eggs ( 1348 )  - conf( 0.2722222222222222 )
# <class 'tuple'>
# <class 'tuple'>
# milk ( 972 ) ---> ('eggs', 'mineral water') ( 382 )  conf( 0.10082304526748971 )
# <class 'tuple'>
# <class 'tuple'>
# ('eggs', 'french fries') ( 273 ) ---> milk ( 972 )  - conf( 0.1978021978021978 )
# <class 'tuple'>
# ('eggs', 'milk') ( 231 ) ---> french fries ( 1282 )  - conf( 0.23376623376623376 )
# <class 'tuple'>
# ('french fries', 'milk') ( 178 ) ---> eggs ( 1348 )  - conf( 0.30337078651685395 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('mineral water', 'spaghetti') ( 448 ) ---> whole wheat rice ( 439 )  - conf( 0.10491071428571429 )
# <class 'tuple'>
# ('mineral water', 'whole wheat rice') ( 151 ) ---> spaghetti ( 1306 )  - conf( 0.31125827814569534 )
# <class 'tuple'>
# ('spaghetti', 'whole wheat rice') ( 106 ) ---> mineral water ( 1788 )  - conf( 0.44339622641509435 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# whole wheat rice ( 439 ) ---> ('mineral water', 'spaghetti') ( 448 )  conf( 0.1070615034168565 )
# <class 'tuple'>
# ('milk', 'mineral water') ( 360 ) ---> whole wheat rice ( 439 )  - conf( 0.10555555555555556 )
# <class 'tuple'>
# ('milk', 'whole wheat rice') ( 89 ) ---> mineral water ( 1788 )  - conf( 0.42696629213483145 )
# <class 'tuple'>
# ('mineral water', 'whole wheat rice') ( 151 ) ---> milk ( 972 )  - conf( 0.25165562913907286 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('eggs', 'french fries') ( 273 ) ---> spaghetti ( 1306 )  - conf( 0.21978021978021978 )
# <class 'tuple'>
# ('eggs', 'spaghetti') ( 274 ) ---> french fries ( 1282 )  - conf( 0.21897810218978103 )
# <class 'tuple'>
# ('french fries', 'spaghetti') ( 207 ) ---> eggs ( 1348 )  - conf( 0.2898550724637681 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('french fries', 'mineral water') ( 253 ) ---> spaghetti ( 1306 )  - conf( 0.30039525691699603 )
# <class 'tuple'>
# ('french fries', 'spaghetti') ( 207 ) ---> mineral water ( 1788 )  - conf( 0.3671497584541063 )
# <class 'tuple'>
# ('mineral water', 'spaghetti') ( 448 ) ---> french fries ( 1282 )  - conf( 0.16964285714285715 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('eggs', 'french fries') ( 273 ) ---> mineral water ( 1788 )  - conf( 0.19047619047619047 )
# <class 'tuple'>
# ('eggs', 'mineral water') ( 382 ) ---> french fries ( 1282 )  - conf( 0.13612565445026178 )
# <class 'tuple'>
# ('french fries', 'mineral water') ( 253 ) ---> eggs ( 1348 )  - conf( 0.20553359683794467 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('ground beef', 'mineral water') ( 307 ) ---> soup ( 379 )  - conf( 0.1237785016286645 )
# <class 'tuple'>
# ('ground beef', 'soup') ( 73 ) ---> mineral water ( 1788 )  - conf( 0.5205479452054794 )
# <class 'tuple'>
# ('mineral water', 'soup') ( 173 ) ---> ground beef ( 737 )  - conf( 0.21965317919075145 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# soup ( 379 ) ---> ('ground beef', 'mineral water') ( 307 )  conf( 0.10026385224274406 )
# <class 'tuple'>
# ('chocolate', 'mineral water') ( 396 ) ---> soup ( 379 )  - conf( 0.10606060606060606 )
# <class 'tuple'>
# ('chocolate', 'soup') ( 76 ) ---> mineral water ( 1788 )  - conf( 0.5526315789473685 )
# <class 'tuple'>
# ('mineral water', 'soup') ( 173 ) ---> chocolate ( 1230 )  - conf( 0.24277456647398843 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# soup ( 379 ) ---> ('chocolate', 'mineral water') ( 396 )  conf( 0.11081794195250659 )
# <class 'tuple'>
# ('mineral water', 'olive oil') ( 207 ) ---> soup ( 379 )  - conf( 0.18840579710144928 )
# <class 'tuple'>
# ('mineral water', 'soup') ( 173 ) ---> olive oil ( 494 )  - conf( 0.2254335260115607 )
# <class 'tuple'>
# ('olive oil', 'soup') ( 67 ) ---> mineral water ( 1788 )  - conf( 0.582089552238806 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# soup ( 379 ) ---> ('mineral water', 'olive oil') ( 207 )  conf( 0.10290237467018469 )
# <class 'tuple'>
# ('mineral water', 'soup') ( 173 ) ---> spaghetti ( 1306 )  - conf( 0.3236994219653179 )
# <class 'tuple'>
# ('mineral water', 'spaghetti') ( 448 ) ---> soup ( 379 )  - conf( 0.125 )
# <class 'tuple'>
# ('soup', 'spaghetti') ( 107 ) ---> mineral water ( 1788 )  - conf( 0.5233644859813084 )
# <class 'tuple'>
# <class 'tuple'>
# soup ( 379 ) ---> ('mineral water', 'spaghetti') ( 448 )  conf( 0.14775725593667546 )
# <class 'tuple'>
# <class 'tuple'>
# ('frozen vegetables', 'mineral water') ( 268 ) ---> soup ( 379 )  - conf( 0.1417910447761194 )
# <class 'tuple'>
# ('frozen vegetables', 'soup') ( 60 ) ---> mineral water ( 1788 )  - conf( 0.6333333333333333 )
# <class 'tuple'>
# ('mineral water', 'soup') ( 173 ) ---> frozen vegetables ( 715 )  - conf( 0.21965317919075145 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# soup ( 379 ) ---> ('frozen vegetables', 'mineral water') ( 268 )  conf( 0.10026385224274406 )
# <class 'tuple'>
# <class 'tuple'>
# ('eggs', 'soup') ( 68 ) ---> mineral water ( 1788 )  - conf( 0.5441176470588235 )
# <class 'tuple'>
# ('mineral water', 'soup') ( 173 ) ---> eggs ( 1348 )  - conf( 0.2138728323699422 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('milk', 'mineral water') ( 360 ) ---> soup ( 379 )  - conf( 0.17777777777777778 )
# <class 'tuple'>
# ('milk', 'soup') ( 114 ) ---> mineral water ( 1788 )  - conf( 0.5614035087719298 )
# <class 'tuple'>
# ('mineral water', 'soup') ( 173 ) ---> milk ( 972 )  - conf( 0.3699421965317919 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# soup ( 379 ) ---> ('milk', 'mineral water') ( 360 )  conf( 0.16886543535620052 )
# <class 'tuple'>
# ('milk', 'soup') ( 114 ) ---> spaghetti ( 1306 )  - conf( 0.2982456140350877 )
# <class 'tuple'>
# ('milk', 'spaghetti') ( 266 ) ---> soup ( 379 )  - conf( 0.12781954887218044 )
# <class 'tuple'>
# ('soup', 'spaghetti') ( 107 ) ---> milk ( 972 )  - conf( 0.3177570093457944 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('chocolate', 'frozen vegetables') ( 172 ) ---> milk ( 972 )  - conf( 0.3488372093023256 )
# <class 'tuple'>
# ('chocolate', 'milk') ( 241 ) ---> frozen vegetables ( 715 )  - conf( 0.24896265560165975 )
# <class 'tuple'>
# ('frozen vegetables', 'milk') ( 177 ) ---> chocolate ( 1230 )  - conf( 0.3389830508474576 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ('eggs', 'frozen vegetables') ( 163 ) ---> milk ( 972 )  - conf( 0.3374233128834356 )
# <class 'tuple'>
# ('eggs', 'milk') ( 231 ) ---> frozen vegetables ( 715 )  - conf( 0.23809523809523808 )
# <class 'tuple'>
# ('frozen vegetables', 'milk') ( 177 ) ---> eggs ( 1348 )  - conf( 0.3107344632768362 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ...
# <class 'tuple'>
# <class 'tuple'>
# fresh bread ( 323 ) ---> shrimp ( 536 )  - conf( 0.12074303405572756 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# fresh bread ( 323 ) ---> milk ( 972 )  - conf( 0.21362229102167182 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# fresh bread ( 323 ) ---> frozen vegetables ( 715 )  - conf( 0.15789473684210525 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# fresh bread ( 323 ) ---> chocolate ( 1230 )  - conf( 0.21981424148606812 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# fresh bread ( 323 ) ---> chicken ( 450 )  - conf( 0.12074303405572756 )
# <class 'tuple'>
# <class 'tuple'>
# chocolate ( 1230 ) ---> ground beef ( 737 )  - conf( 0.14146341463414633 )
# <class 'tuple'>
# <class 'tuple'>
# ground beef ( 737 ) ---> chocolate ( 1230 )  - conf( 0.23609226594301222 )
# <class 'tuple'>
# <class 'tuple'>
# ground beef ( 737 ) ---> spaghetti ( 1306 )  - conf( 0.3989145183175034 )
# <class 'tuple'>
# <class 'tuple'>
# spaghetti ( 1306 ) ---> ground beef ( 737 )  - conf( 0.225114854517611 )
# <class 'tuple'>
# <class 'tuple'>
# ground beef ( 737 ) ---> mineral water ( 1788 )  - conf( 0.41655359565807326 )
# <class 'tuple'>
# <class 'tuple'>
# mineral water ( 1788 ) ---> ground beef ( 737 )  - conf( 0.17170022371364654 )
# <class 'tuple'>
# <class 'tuple'>
# ground beef ( 737 ) ---> milk ( 972 )  - conf( 0.22388059701492538 )
# <class 'tuple'>
# <class 'tuple'>
# milk ( 972 ) ---> ground beef ( 737 )  - conf( 0.1697530864197531 )
# <class 'tuple'>
# <class 'tuple'>
# green tea ( 991 ) ---> ground beef ( 737 )  - conf( 0.11200807265388496 )
# <class 'tuple'>
# <class 'tuple'>
# ground beef ( 737 ) ---> green tea ( 991 )  - conf( 0.15061058344640435 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ground beef ( 737 ) ---> french fries ( 1282 )  - conf( 0.14111261872455902 )
# <class 'tuple'>
# <class 'tuple'>
# eggs ( 1348 ) ---> ground beef ( 737 )  - conf( 0.11127596439169139 )
# <class 'tuple'>
# <class 'tuple'>
# ground beef ( 737 ) ---> eggs ( 1348 )  - conf( 0.20352781546811397 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# escalope ( 595 ) ---> ground beef ( 737 )  - conf( 0.10420168067226891 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# escalope ( 595 ) ---> spaghetti ( 1306 )  - conf( 0.17647058823529413 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# escalope ( 595 ) ---> mineral water ( 1788 )  - conf( 0.21512605042016808 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# escalope ( 595 ) ---> eggs ( 1348 )  - conf( 0.13949579831932774 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# escalope ( 595 ) ---> green tea ( 991 )  - conf( 0.11260504201680673 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# chocolate ( 1230 ) ---> escalope ( 595 )  - conf( 0.1073170731707317 )
# <class 'tuple'>
# <class 'tuple'>
# escalope ( 595 ) ---> chocolate ( 1230 )  - conf( 0.2218487394957983 )
# <class 'tuple'>
# <class 'tuple'>
# escalope ( 595 ) ---> french fries ( 1282 )  - conf( 0.20672268907563024 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# herb & pepper ( 371 ) ---> low fat yogurt ( 574 )  - conf( 0.11859838274932614 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ground beef ( 737 ) ---> herb & pepper ( 371 )  - conf( 0.1628222523744912 )
# <class 'tuple'>
# <class 'tuple'>
# herb & pepper ( 371 ) ---> ground beef ( 737 )  - conf( 0.32345013477088946 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# herb & pepper ( 371 ) ---> eggs ( 1348 )  - conf( 0.25336927223719674 )
# <class 'tuple'>
# <class 'tuple'>
# cooking oil ( 383 ) ---> herb & pepper ( 371 )  - conf( 0.10443864229765012 )
# <class 'tuple'>
# <class 'tuple'>
# herb & pepper ( 371 ) ---> cooking oil ( 383 )  - conf( 0.1078167115902965 )
# <class 'tuple'>
# <class 'tuple'>
# herb & pepper ( 371 ) ---> shrimp ( 536 )  - conf( 0.14285714285714285 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# herb & pepper ( 371 ) ---> milk ( 972 )  - conf( 0.18598382749326145 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# herb & pepper ( 371 ) ---> french fries ( 1282 )  - conf( 0.14016172506738545 )
# <class 'tuple'>
# <class 'tuple'>
# herb & pepper ( 371 ) ---> olive oil ( 494 )  - conf( 0.10242587601078167 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# herb & pepper ( 371 ) ---> spaghetti ( 1306 )  - conf( 0.3288409703504043 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# herb & pepper ( 371 ) ---> chocolate ( 1230 )  - conf( 0.18328840970350405 )
# <class 'tuple'>
# <class 'tuple'>
# herb & pepper ( 371 ) ---> mineral water ( 1788 )  - conf( 0.3450134770889488 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# herb & pepper ( 371 ) ---> green tea ( 991 )  - conf( 0.1293800539083558 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# herb & pepper ( 371 ) ---> frozen vegetables ( 715 )  - conf( 0.12129380053908356 )
# <class 'tuple'>
# <class 'tuple'>
# grated cheese ( 393 ) ---> herb & pepper ( 371 )  - conf( 0.12468193384223919 )
# <class 'tuple'>
# <class 'tuple'>
# herb & pepper ( 371 ) ---> grated cheese ( 393 )  - conf( 0.1320754716981132 )
# <class 'tuple'>
# <class 'tuple'>
# herb & pepper ( 371 ) ---> pancakes ( 713 )  - conf( 0.14824797843665768 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# tomato sauce ( 106 ) ---> chocolate ( 1230 )  - conf( 0.3584905660377358 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# tomato sauce ( 106 ) ---> spaghetti ( 1306 )  - conf( 0.44339622641509435 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# tomato sauce ( 106 ) ---> mineral water ( 1788 )  - conf( 0.4056603773584906 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# tomato sauce ( 106 ) ---> ground beef ( 737 )  - conf( 0.37735849056603776 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# strawberries ( 160 ) ---> french fries ( 1282 )  - conf( 0.26875 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# strawberries ( 160 ) ---> mineral water ( 1788 )  - conf( 0.2375 )
# <class 'tuple'>
# <class 'tuple'>
# burgers ( 654 ) ---> cake ( 608 )  - conf( 0.13149847094801223 )
# <class 'tuple'>
# <class 'tuple'>
# cake ( 608 ) ---> burgers ( 654 )  - conf( 0.14144736842105263 )
# <class 'tuple'>
# <class 'tuple'>
# cake ( 608 ) ---> eggs ( 1348 )  - conf( 0.23519736842105263 )
# <class 'tuple'>
# <class 'tuple'>
# eggs ( 1348 ) ---> cake ( 608 )  - conf( 0.10608308605341246 )
# <class 'tuple'>
# <class 'tuple'>
# cake ( 608 ) ---> ground beef ( 737 )  - conf( 0.10032894736842106 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# cake ( 608 ) ---> spaghetti ( 1306 )  - conf( 0.2236842105263158 )
# <class 'tuple'>
# <class 'tuple'>
# spaghetti ( 1306 ) ---> cake ( 608 )  - conf( 0.10413476263399694 )
# <class 'tuple'>
# <class 'tuple'>
# cake ( 608 ) ---> mineral water ( 1788 )  - conf( 0.33881578947368424 )
# <class 'tuple'>
# <class 'tuple'>
# mineral water ( 1788 ) ---> cake ( 608 )  - conf( 0.11521252796420582 )
# <class 'tuple'>
# <class 'tuple'>
# cake ( 608 ) ---> chocolate ( 1230 )  - conf( 0.16776315789473684 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# cake ( 608 ) ---> pancakes ( 713 )  - conf( 0.14638157894736842 )
# <class 'tuple'>
# <class 'tuple'>
# pancakes ( 713 ) ---> cake ( 608 )  - conf( 0.12482468443197756 )
# <class 'tuple'>
# <class 'tuple'>
# cake ( 608 ) ---> frozen vegetables ( 715 )  - conf( 0.12664473684210525 )
# <class 'tuple'>
# <class 'tuple'>
# frozen vegetables ( 715 ) ---> cake ( 608 )  - conf( 0.1076923076923077 )
# <class 'tuple'>
# <class 'tuple'>
# cake ( 608 ) ---> french fries ( 1282 )  - conf( 0.22039473684210525 )
# <class 'tuple'>
# <class 'tuple'>
# french fries ( 1282 ) ---> cake ( 608 )  - conf( 0.10452418096723869 )
# <class 'tuple'>
# <class 'tuple'>
# cake ( 608 ) ---> green tea ( 991 )  - conf( 0.17434210526315788 )
# <class 'tuple'>
# <class 'tuple'>
# green tea ( 991 ) ---> cake ( 608 )  - conf( 0.10696266397578204 )
# <class 'tuple'>
# <class 'tuple'>
# cake ( 608 ) ---> milk ( 972 )  - conf( 0.16447368421052633 )
# <class 'tuple'>
# <class 'tuple'>
# milk ( 972 ) ---> cake ( 608 )  - conf( 0.102880658436214 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# hot dogs ( 243 ) ---> french fries ( 1282 )  - conf( 0.22633744855967078 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# hot dogs ( 243 ) ---> chocolate ( 1230 )  - conf( 0.16872427983539096 )
# <class 'tuple'>
# <class 'tuple'>
# hot dogs ( 243 ) ---> mineral water ( 1788 )  - conf( 0.2839506172839506 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# hot dogs ( 243 ) ---> frozen smoothie ( 475 )  - conf( 0.14814814814814814 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# hot dogs ( 243 ) ---> green tea ( 991 )  - conf( 0.205761316872428 )
# <class 'tuple'>
# <class 'tuple'>
# hot dogs ( 243 ) ---> spaghetti ( 1306 )  - conf( 0.2674897119341564 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# brownies ( 253 ) ---> french fries ( 1282 )  - conf( 0.233201581027668 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# brownies ( 253 ) ---> eggs ( 1348 )  - conf( 0.21739130434782608 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# brownies ( 253 ) ---> cake ( 608 )  - conf( 0.16205533596837945 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# brownies ( 253 ) ---> chocolate ( 1230 )  - conf( 0.14624505928853754 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# brownies ( 253 ) ---> green tea ( 991 )  - conf( 0.1976284584980237 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# brownies ( 253 ) ---> milk ( 972 )  - conf( 0.16205533596837945 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# brownies ( 253 ) ---> spaghetti ( 1306 )  - conf( 0.21739130434782608 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# brownies ( 253 ) ---> ground beef ( 737 )  - conf( 0.14624505928853754 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# brownies ( 253 ) ---> pancakes ( 713 )  - conf( 0.16205533596837945 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# brownies ( 253 ) ---> mineral water ( 1788 )  - conf( 0.2845849802371542 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# cereals ( 193 ) ---> pancakes ( 713 )  - conf( 0.18134715025906736 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# cereals ( 193 ) ---> ground beef ( 737 )  - conf( 0.17616580310880828 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# cereals ( 193 ) ---> spaghetti ( 1306 )  - conf( 0.25906735751295334 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# cereals ( 193 ) ---> mineral water ( 1788 )  - conf( 0.39896373056994816 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# cereals ( 193 ) ---> chocolate ( 1230 )  - conf( 0.21761658031088082 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# cereals ( 193 ) ---> french fries ( 1282 )  - conf( 0.18652849740932642 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# cereals ( 193 ) ---> milk ( 972 )  - conf( 0.27461139896373055 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# cereals ( 193 ) ---> green tea ( 991 )  - conf( 0.2538860103626943 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# muffins ( 181 ) ---> french fries ( 1282 )  - conf( 0.22099447513812154 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# light mayo ( 204 ) ---> chocolate ( 1230 )  - conf( 0.18627450980392157 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# light mayo ( 204 ) ---> french fries ( 1282 )  - conf( 0.2696078431372549 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# light mayo ( 204 ) ---> eggs ( 1348 )  - conf( 0.20098039215686275 )
# <class 'tuple'>
# <class 'tuple'>
# light mayo ( 204 ) ---> mineral water ( 1788 )  - conf( 0.23039215686274508 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# light mayo ( 204 ) ---> pancakes ( 713 )  - conf( 0.20098039215686275 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# gums ( 101 ) ---> mineral water ( 1788 )  - conf( 0.36633663366336633 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# yogurt cake ( 205 ) ---> eggs ( 1348 )  - conf( 0.16585365853658537 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# yogurt cake ( 205 ) ---> mineral water ( 1788 )  - conf( 0.2048780487804878 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# yogurt cake ( 205 ) ---> french fries ( 1282 )  - conf( 0.18536585365853658 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# mint ( 131 ) ---> mineral water ( 1788 )  - conf( 0.33587786259541985 )
# <class 'tuple'>
# <class 'tuple'>
# butter ( 226 ) ---> chocolate ( 1230 )  - conf( 0.2743362831858407 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# butter ( 226 ) ---> french fries ( 1282 )  - conf( 0.20353982300884957 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# butter ( 226 ) ---> spaghetti ( 1306 )  - conf( 0.2079646017699115 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# butter ( 226 ) ---> green tea ( 991 )  - conf( 0.24336283185840707 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# butter ( 226 ) ---> milk ( 972 )  - conf( 0.20353982300884957 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# butter ( 226 ) ---> eggs ( 1348 )  - conf( 0.20353982300884957 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# french wine ( 169 ) ---> milk ( 972 )  - conf( 0.21893491124260356 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# french wine ( 169 ) ---> chocolate ( 1230 )  - conf( 0.23076923076923078 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# french wine ( 169 ) ---> eggs ( 1348 )  - conf( 0.26627218934911245 )
# <class 'tuple'>
# <class 'tuple'>
# french wine ( 169 ) ---> spaghetti ( 1306 )  - conf( 0.3431952662721893 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# french wine ( 169 ) ---> mineral water ( 1788 )  - conf( 0.3668639053254438 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# carrots ( 115 ) ---> mineral water ( 1788 )  - conf( 0.34782608695652173 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# carrots ( 115 ) ---> spaghetti ( 1306 )  - conf( 0.30434782608695654 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# mushroom cream sauce ( 143 ) ---> escalope ( 595 )  - conf( 0.3006993006993007 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# mushroom cream sauce ( 143 ) ---> french fries ( 1282 )  - conf( 0.24475524475524477 )
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# nonfat milk ( 78 ) ---> mineral water ( 1788 )  - conf( 0.48717948717948717 )
# <class 'tuple'>
# <class 'tuple'>
# fromage blanc ( 102 ) ---> mineral water ( 1788 )  - conf( 0.3333333333333333 )
# <class 'tuple'>
# <class 'tuple'>
# 1305 rules generated
# FP_Growth_spent_time 6.784826755523682
# 21

# %%
print(count[2][('ham', 'whole wheat rice')])
# Out:
# 34

# %%
print(minsup)
# Out:
# 33.7545

# %%
a
# Out:
# {'cake'}

# %% [markdown]
# # FP-growth     big_minsup and big_minconf with Market_Basket_Optimisation.csv

# %%
import csv
import pandas as pd
from itertools import combinations
import time


#Read data from CSV
# data = pd.read_csv('groceries.csv')
data = pd.read_csv('Market_Basket_Optimisation.csv', header=None)
#
#Parameters
minsup = float(input("Support-Threshold: "))
minsup = minsup * len(data)
minconf = float(input("Confidence-Threshold: "))
print(len(data))#9835
time_start = time.time()
#Add all data in a list of lists
items = []  
# print(len(data.values[0]))#1列(ROW)有32的物品
for i in range(0, len(data)):  #將所有data中的物品一列一列放到items
     items.append([str(data.values[i, j]) for j in range(0, len(data.values[0]))])

#Creating a list of dictionaries
count = [dict() for x in range(len(data.values[0]) + 1)]
# print(items)
# #Count support for each individual items
s=[]
for i in items:
    for j in i:      #讀取所有items
        s.append(j)
for i in s:                      #創字典 放在count[1]
    #If item is present in dictionary, increment its count by 1
    if i in count[1]:
        count[1][i] = count[1][i] + 1
    #If item is not present in dictionary, set its count to 1
    else:
        count[1][i] = 1     #{'i':1}

# #Remove infrequent and empty items #去除小於minsup,nan
for i in count[1].copy():
    if(count[1][i] < minsup):
        count[1].pop(i)
count[1].pop('nan') #去除以key = 'NAN'產生的值

# #Storing transactions as lists without infrequent items
a = list(count[1]) #列出所有符合的KEY
item = [list() for i in range(len(data))] #創造len(data) = 9835個list 
c = 0 
for i in range(0,len(items)): ##將所有data中的物品一列一列放到items
    for j in range(len(items[i])):
#         print(items[i][j])
        if(a.__contains__(items[i][j]) != 0): #確認物品是否存在
            item[i].append(items[i][j]) #將物品分成[['a', 'b', 'c'],[]]與itmes不同的地方是裡練已經沒有NAN了

#Function to sort list to support
def sort(a): #a = 所有符合的KEY的list
    for i in range(len(a) - 1):
        for j in range(len(a) - i - 1):
            if(count[1][a[j]] < count[1][a[j + 1]]): #如果下一個比上一個大則互換位子
                a[j],a[j + 1] = a[j + 1],a[j]
                
#Call function to sort all transactions in descending order of their support
for i in range(0,len(data)): #9835
    if(len(item[i]) > 1): #如果不只一個物件就排序他
        sort(item[i])

#Tree class for FP-Tree
class tree: #設計樹根，分支
    def __init__(self, name, sup, parent):
        self.name = name
        self.sup = sup
        self.nodeLink = None
        self.parent = parent
        self.children = []

#Function to check if the node is present is a child of the current node
def ispresent(node,name):    #確認是否有children
    f = -1               
    for i in node.children:
        f += 1
        if(i.name == name):
            return f
    return -1

#HeaderTable which stores the reference of last/first occurence of an item. Used as a linked list to generate candidate trees 
lastocc = count[1].copy() #符合sup的字典
for i in lastocc: #lastocc字典中所有值皆為NONE
    lastocc[i] = None
#Function to create FP-tree
root = tree("root", -1, None)
z = 0
for i in item: #item為沒有NAN的items
    current = root
    for j in range(len(i)): #len(i)9835
        if(ispresent(current,i[j])>=0): #第一次通常不符合此情形，直接執行else，看有沒有children
            current = current.children[ispresent(current, i[j])]
            current.sup=current.sup + 1
        else:
            child=tree(i[j], 1, current)    #創建i[j]子根
            current.children.append(child) #將子根放入children =[] 
            t = current #t 記錄柱上一層的tree1
            current = current.children[ispresent(current, i[j])] #現在current.children裡有子根，所以self.name = i[j]如下示意，
            #ispresent(current,i[j])回傳 0 ，現在的current為tree2
            current.parent = t #紀錄上一層tree1
            if(lastocc[current.name] == None):
                lastocc[current.name] = current #創建{'i[j]': tree2-1()} 
            else:#創出第一層並列樹枝
                current.nodeLink = lastocc[current.name] #將tree2-2連結到tree4
                lastocc[current.name] = current #CURRENT = TREE2-2 {'i[j]': tree2-2}
            
# class tree1:
#     def __init__(self, name, sup, parent):
#         self.name = 'root'
#         self.sup = -1
#         self.nodeLink = None
#         self.parent = none
#         self.children = [
#   class tree2-1:
#     def __init__(self, name, sup, parent):      [['A','B','C'],['C','A']]
#         self.name = 'A'
#         self.sup = 1
#         self.nodeLink = NONE
#         self.parent = parent
#         self.children = [
#                                     class tree3:
#                                         def __init__(self, name, sup, parent):
#                                             self.name = 'B'
#                                             self.sup = 1
#                                             self.nodeLink = None
#                                             self.parent = parent
#                                             self.children = [
#                                                                 class tree4:
#                                                                     def __init__(self, name, sup, parent):
#                                                                         self.name = 'B'
#                                                                         self.sup = 1
#                                                                         self.nodeLink = None
#                                                                         self.parent = parent
#                                                                         self.children = []
#                                                                 ]
#         ],
#   class tree2-2:
#     def __init__(self, name, sup, parent):
#         self.name = 'C'
#         self.sup = sup
#         self.nodeLink = TREE 4
#         self.parent = TREE1
#         self.children = []
# ]

#Function to extract single item set from a tuple
def value(a):
    a = str(a)
    a = a[:-2]
    a = a[2:]
    a = a[:-1]
    return a

#Function to get frequent itemsets with suffix 'node' and length n
def singlepath(node, n):
    c = 0
    sup = node.sup
    path = []
    pathname = []
    current = node
    
    #Get the path from current node to root
    while(current.parent!=None): #查看目current是否為'root'，如果是則無parent，重複做直道回到最上層('root')
        path.append(current)     #將current內容紀錄(tree)
        pathname.append(current.name)      #('c')
        current = current.parent  #往上一層移動
    path.remove(node) #除了自己以外的路線
    pathname.remove(node.name) 
    candidatepath = []
    temp_candidatepath = []
   
    #Generate combinations of length n in the path
    a = (list(combinations(pathname, n))) #列出除了自己以外的長度為n的組合
    for j in a:
        temp_candidatepath.append(tuple(sorted(j)))   #以tuple形式存在temp_candidatapath裡
    #Append the suffix 'node.name' to the above paths
    for j in temp_candidatepath:
        j = list(j) #再次變回list
        j.append(node.name) #將原本剔除的當前TREE名加回去 變成包含當前的組合，就是在做freqent pattern
        candidatepath.append(sorted(j)) #在加回去變成 [['a','c'],['b','c']]
    #Update counts of the generated itemsets
    for j in candidatepath:
        j = tuple(j) #j = ('a','c')
        if j in count[n+1]: #count[1]為符合minsup的字典，n至少會從1開始 
            count[n + 1][j] = count[n+1][j] + sup  # 將之前已創好的value值，加上當前tree所有的sup
        else:
            count[n + 1][j] = sup #創建新字典,此sup為當前tree存有的sup
            
    #Iterating in the candidate tree recursively 
    if(node.nodeLink != None): #查看是否存在分支
        node=node.nodeLink
        singlepath(node, i) #i為組合長度
    
#Check if itemset is frequent
def frequent(n): #算出現次數
    f=0
    for i in count[n]:
        if(count[n][i] >= minsup):
            f=1
    if(f == 1):
        return 1
    else:
        return 0

#Call singlepath function for all frequent nodes
for i in range(1, len(data.values[0]) + 1): #1列(ROW)有32的物品, +1是確保有32為一組的組合  #!
    if(frequent(i) == 1):
        for j in lastocc: #開始製造組合，將結果放到count[]裡，count唯有32空字典的list
            singlepath(lastocc[j], i)

#Remove infrequent itemsets
for z in range(len(data.values[0]) + 1):            
    for i in count[z].copy():
            if(count[z][i] < minsup): #查看所有的dict裡面的東西，是否符合minsup
                count[z].pop(i) #去掉不符合的
frequent_pattern = []
for items in count:
    for want in items:
        frequent_pattern.append(want)
                
#Get 'q', the length of the longest itemset
i=2
while(len(count[i-1]) != 0): #從這邊就能知道最大符合長度是多長，因為不符合的都被刪掉了
    i = i + 1
q = i - 2

#Find maximal and closed itemsets
maximal = []
closed = []
for i in range(1, q):
    for j in count[i]:
        fm = 0
        fc = 0
        for k in count[i+1]:
            a = set(list([j]))
            b = set(list(k))
            #Set is maximal if no immediate superset is frequent
            if(a.intersection(b) == a): #如果兩者重疊則maximal
                fm = 1 
                #Set is closed if none of its immediate supersets have equal support
                if(count[i][j] == count[i+1][k]): #出現次數相同
                    fc = 1
        if(fm == 0):
            maximal.append(j)
        if(fc == 0):
            closed.append(j)
#All sets at the top of the tree are automatically maximal and closed
for i in count[q]:
    maximal.append(i)
    closed.append(i)
print("frequent_pattern")
print(len(frequent_pattern))
print(frequent_pattern)
    
#Find Association Rules 
print("Association_Rules")
ant=count.copy()
for i in range(q, 0, -1): #從後面樹回來
    for j in ant[i]:  #ant = count
        for k in range(i-1, 0, -1): # i = q(最大長度)
            s = list(combinations(list(j), k))  #將所有可能組出來   
            #Traverse through list of all combinations of antecedants
            for n in s:
                #Sorting to prevent duplicate itemsets 
                r=tuple(sorted(set(j).difference(set(n))))
                l=len(n) #輸入進來的字元長度
                #Check if len(n)==1 to be able to extract key to search in the support dictionary. 
                if(l == 1):
                    n=value(n)
                    l=1
                if(len(r) == 1):
                    r2=value(r)
                if(n != None):
                    #If rule's confidence is greater than minconfidence, then print the rule
                    if((ant[len(j)][j] / ant[l][n]) >= minconf):
                        #Rule is only significant if it is present in CLOSED, otherwise it is redundant
                        if(closed.__contains__((n))):
                            c += 1
                            if(len(r) == 1):
                                print(n,"(",ant[l][n],")","--->",r2,"(",ant[len(r)][r2],")", " - conf(",(ant[len(j)][j]/ant[l][n]),")")
                            else:
                                print(n,"(",ant[l][n],")","--->",r,"(",ant[len(r)][r],")", " conf(",(ant[len(j)][j]/ant[l][n]),")")
print(c, "rules generated")
time_end = time.time()
print('FP_Growth_spent_time', time_end - time_start)
# print( time_end - time_start)
# Out:
# Support-Threshold: 0.045
# Confidence-Threshold: 0.1
# 7501
# frequent_pattern
# 32
# ['shrimp', 'low fat yogurt', 'green tea', 'honey', 'mineral water', 'frozen smoothie', 'olive oil', 'burgers', 'eggs', 'turkey', 'milk', 'whole wheat rice', 'french fries', 'soup', 'frozen vegetables', 'spaghetti', 'cookies', 'cooking oil', 'champagne', 'chocolate', 'chicken', 'tomatoes', 'pancakes', 'grated cheese', 'ground beef', 'escalope', 'herb & pepper', 'cake', ('eggs', 'mineral water'), ('milk', 'mineral water'), ('mineral water', 'spaghetti'), ('chocolate', 'mineral water')]
# Association_Rules
# eggs ( 1348 ) ---> mineral water ( 1788 )  - conf( 0.28338278931750743 )
# mineral water ( 1788 ) ---> eggs ( 1348 )  - conf( 0.21364653243847875 )
# milk ( 972 ) ---> mineral water ( 1788 )  - conf( 0.37037037037037035 )
# mineral water ( 1788 ) ---> milk ( 972 )  - conf( 0.20134228187919462 )
# mineral water ( 1788 ) ---> spaghetti ( 1306 )  - conf( 0.2505592841163311 )
# spaghetti ( 1306 ) ---> mineral water ( 1788 )  - conf( 0.3430321592649311 )
# chocolate ( 1230 ) ---> mineral water ( 1788 )  - conf( 0.32195121951219513 )
# mineral water ( 1788 ) ---> chocolate ( 1230 )  - conf( 0.2214765100671141 )
# 8 rules generated
# FP_Growth_spent_time 1.766601800918579

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-124-6d355b1b8b7b> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.plot(count[1].items())
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1644         """
#    1645         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1646         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1647         for line in lines:
#    1648             self.add_line(line)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     337             self.axes.xaxis.update_units(x)
#     338         if self.axes.yaxis is not None:
# --> 339             self.axes.yaxis.update_units(y)
#     340
#     341         if x.shape[0] != y.shape[0]:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axis.py in update_units(self, data)
#    1514         neednew = self.converter != converter
#    1515         self.converter = converter
# -> 1516         default = self.converter.default_units(data, self)
#    1517         if default is not None and self.units is None:
#    1518             self.set_units(default)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/category.py in default_units(data, axis)
#     105         # the conversion call stack is default_units -> axis_info -> convert
#     106         if axis.units is None:
# --> 107             axis.set_units(UnitData(data))
#     108         else:
#     109             axis.units.update(data)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/category.py in __init__(self, data)
#     173         self._counter = itertools.count()
#     174         if data is not None:
# --> 175             self.update(data)
#     176
#     177     @staticmethod
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/category.py in update(self, data)
#     208         # check if convertible to number:
#     209         convertible = True
# --> 210         for val in OrderedDict.fromkeys(data):
#     211             # OrderedDict just iterates over unique values in data.
#     212             cbook._check_isinstance((str, bytes), value=val)
#
# TypeError: unhashable type: 'dict_items'
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 108 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 112 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 56 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 46 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 52 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 56 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49 missing from current font.
#   font.set_text(s, 0, flags=flags)
